# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install optuna

# %%
# !python /content/drive/MyDrive/s1/run_stage1.py \
  --packet_csv /content/drive/MyDrive/s1/data/ar002_et12_20260511_002-stage1_packets.csv \
  --flow_csv /content/drive/MyDrive/s1/data/ar002_et12_20260511_002-stage1_flows.csv \
  --config /content/drive/MyDrive/s1/stage1_config_0617.yaml \
  --out_dir /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2 \
  --export_embeddings
# Out:
# [INFO] 已启用 CUDNN 确定性模式（可能影响性能）
# [INFO] 随机种子已设置: 42
# [INFO] 确定性模式: True
# [INFO] device=cuda
#
# ============================================================
# [STEP 1] Building dataloaders...
# ============================================================
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] pipeline.py ------ build_dataloaders --- split_method chronological
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ chronological_train_val_test_split-----------nominal_b1= 124025 nominal_b2= 141742
# [INFO] splits.py ------ chronological_train_val_test_split-----------b1= 124025 b2= 141818
# ********** splits.py *****************_sanitize_three_way_boundaries: 边界安全修正，保证每个 split 至少有一个样本
# [INFO] splits.py ------ chronological_train_val_test_split-----------train_df
#              flow_id  label  flow_start_timestamp_us
# 0  1051312184880716      0         1778495267572457
# 1  1051316147181637      0         1778495267572458
# 2  1051370242672817      0         1778495267572471
# [INFO] splits.py ------ chronological_train_val_test_split-----------val_df
#                  flow_id  label  flow_start_timestamp_us
# 124025  459827689366897      0         1778495289434741
# 124026  459877026526947      0         1778495289434753
# 124027  461372474545671      0         1778495289435101
# [INFO] splits.py ------ chronological_train_val_test_split-----------test_df
#                   flow_id  label  flow_start_timestamp_us
# 141818  1403934704123844      0         1778495292785631
# 141819  1403994154207061      0         1778495292785644
# 141820  1405386316874419      0         1778495292785969
#
# ================================================================================
# [INFO] Split report: chronological_train_val_test_split
# ================================================================================
# [INFO] train:
#        num_flows     = 124025
#        label_counts  = {0: 119522, 1: 4503}
#        label1_ratio  = 0.036307
#        time_range    = [1778495267572457, 1778495289434530]
# [INFO] val:
#        num_flows     = 17793
#        label_counts  = {0: 17086, 1: 707}
#        label1_ratio  = 0.039735
#        time_range    = [1778495289434741, 1778495292785562]
# [INFO] test:
#        num_flows     = 35360
#        label_counts  = {0: 33933, 1: 1427}
#        label1_ratio  = 0.040356
#        time_range    = [1778495292785631, 1778495299611559]
# ================================================================================
#
# [INFO] splits.py ------ chronological_train_val_test_split
# [INFO] 方案C模式：flow特征维度=68
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/precomputed/seqLen64headtrain.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/precomputed/seqLen64headval.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/precomputed/seqLen64headtest.npz
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/precomputed/seqLen64headtrain.npz
# [INFO] Dataset ------ Has separate flow features (方案C)
# [INFO]   Flow features shape: (124025, 68)
# [INFO] Dataset ------ Loaded 124025 flows
# [INFO]   X shape: (124025, 64, 51)
# [INFO]   Time shape: (124025, 64)
# [INFO]   Mask shape: (124025, 64)
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/precomputed/seqLen64headval.npz
# [INFO] Dataset ------ Has separate flow features (方案C)
# [INFO]   Flow features shape: (17793, 68)
# [INFO] Dataset ------ Loaded 17793 flows
# [INFO]   X shape: (17793, 64, 51)
# [INFO]   Time shape: (17793, 64)
# [INFO]   Mask shape: (17793, 64)
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/precomputed/seqLen64headtest.npz
# [INFO] Dataset ------ Has separate flow features (方案C)
# [INFO]   Flow features shape: (35360, 68)
# [INFO] Dataset ------ Loaded 35360 flows
# [INFO]   X shape: (35360, 64, 51)
# [INFO]   Time shape: (35360, 64)
# [INFO]   Mask shape: (35360, 64)
# 计算样本权重: class_counts [119522   4503]
# 计算样本权重: sample_weights [8.36666053e-06 8.36666053e-06 8.36666053e-06 ... 2.22074173e-04
#  8.36666053e-06 2.22074173e-04]
# [INFO] pipeline.py ------ build_dataloaders ----- end
#
# [INFO] Preprocessor Summary:
# external_test False
# num_train_flows 124025
# num_val_flows 17793
# num_test_flows 35360
# 真实训练集类别分布 label_counts_train {'0': 119522, '1': 4503}
# label_counts_val {'0': 17086, '1': 707}
# label_counts_test {'0': 33933, '1': 1427}
# preprocessor {'packet_numerical_used': ['pkt_len', 'ip_len', 'payload_len', 'ttl_or_hop_limit', 'tcp_window', 'tcp_header_len', 'udp_len'], 'packet_categorical_used': ['ip_version', 'protocol', 'l7_proto', 'icmp_type', 'icmp_code'], 'packet_binary_used': ['direction', 'has_tcp', 'has_udp', 'has_icmp', 'tcp_fin', 'tcp_syn', 'tcp_rst', 'tcp_psh', 'tcp_ack_flag', 'tcp_urg', 'tcp_ece', 'tcp_cwr'], 'flow_numerical_used': ['flow_duration', 'total_fwd_packets', 'total_backward_packets', 'total_length_of_fwd_packets', 'total_length_of_bwd_packets', 'fwd_packet_length_max', 'fwd_packet_length_min', 'fwd_packet_length_mean', 'fwd_packet_length_std', 'bwd_packet_length_max', 'bwd_packet_length_min', 'bwd_packet_length_mean', 'bwd_packet_length_std', 'flow_bytes_per_s', 'flow_packets_per_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_total', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_total', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'bwd_psh_flags', 'fwd_urg_flags', 'bwd_urg_flags', 'fwd_header_length', 'bwd_header_length', 'fwd_packets_per_s', 'bwd_packets_per_s', 'min_packet_length', 'max_packet_length', 'packet_length_mean', 'packet_length_std', 'packet_length_variance', 'fin_flag_count', 'syn_flag_count', 'rst_flag_count', 'psh_flag_count', 'ack_flag_count', 'urg_flag_count', 'cwe_flag_count', 'ece_flag_count', 'down_up_ratio', 'average_packet_size', 'avg_fwd_segment_size', 'avg_bwd_segment_size', 'init_win_bytes_forward', 'init_win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min'], 'flow_categorical_used': [], 'flow_binary_used': ['has_init_win_bytes_forward', 'has_init_win_bytes_backward'], 'packet_log1p_used': ['pkt_len', 'ip_len', 'payload_len', 'ttl_or_hop_limit', 'tcp_window', 'tcp_header_len', 'udp_len'], 'flow_log1p_used': ['flow_duration', 'total_fwd_packets', 'total_backward_packets', 'total_length_of_fwd_packets', 'total_length_of_bwd_packets', 'fwd_packet_length_max', 'fwd_packet_length_min', 'fwd_packet_length_mean', 'fwd_packet_length_std', 'bwd_packet_length_max', 'bwd_packet_length_min', 'bwd_packet_length_mean', 'bwd_packet_length_std', 'flow_bytes_per_s', 'flow_packets_per_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_total', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_total', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_header_length', 'bwd_header_length', 'fwd_packets_per_s', 'bwd_packets_per_s', 'min_packet_length', 'max_packet_length', 'packet_length_mean', 'packet_length_std', 'packet_length_variance', 'average_packet_size', 'avg_fwd_segment_size', 'avg_bwd_segment_size', 'init_win_bytes_forward', 'init_win_bytes_backward', 'act_data_pkt_fwd', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min'], 'scaler': 'standard', 'clip_enabled': True, 'clip_lower_quantile': 0.001, 'clip_upper_quantile': 0.999, 'packet_clip_bounds_count': 7, 'flow_clip_bounds_count': 66, 'packet_feature_dim': 51, 'flow_feature_dim': 68, 'input_dim': 51, 'has_flow_features': True}
#
# ============================================================
# [STEP 2] Building model...
# ============================================================
# [INFO] 方案C - 分层特征注入
# [INFO]   Packet input dim: 51
# [INFO]   Flow feature dim: 68
# [INFO]------model --- __init__---d_model=128, nhead=8, num_layers=2, dim_feedforward=128, dropout=0.3, max_seq_len=64, use_positional_encoding=True, use_time_encoding=True
# [INFO] 方案C - 分层特征注入已启用
# [INFO]   Flow特征维度: 68
# [INFO]   融合方法: gated
# [INFO]   模型维度: 128
# [INFO] Encoding: Time-Aware (TE(pos+p) from paper)
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
#
# ============================================================
# 📊 Model Statistics:
# ============================================================
#   Total parameters:      298,051
#   Trainable parameters:  298,051
#   Non-trainable params:  0
#
#   Parameter breakdown:
#   ────────────────────────────────────────
#     projection.proj.weight                        6,528
#     projection.proj.bias                            128
#     encoder.layers.0.self_attn.in_proj_weight     49,152
#     encoder.layers.0.self_attn.in_proj_bias         384
#     encoder.layers.0.self_attn.out_proj.weight     16,384
#     encoder.layers.0.self_attn.out_proj.bias        128
#     encoder.layers.0.linear1.weight              16,384
#     encoder.layers.0.linear1.bias                   128
#     encoder.layers.0.linear2.weight              16,384
#     encoder.layers.0.linear2.bias                   128
#     encoder.layers.0.norm1.weight                   128
#     encoder.layers.0.norm1.bias                     128
#     encoder.layers.0.norm2.weight                   128
#     encoder.layers.0.norm2.bias                     128
#     encoder.layers.1.self_attn.in_proj_weight     49,152
#     encoder.layers.1.self_attn.in_proj_bias         384
#     encoder.layers.1.self_attn.out_proj.weight     16,384
#     encoder.layers.1.self_attn.out_proj.bias        128
#     encoder.layers.1.linear1.weight              16,384
#     encoder.layers.1.linear1.bias                   128
#     encoder.layers.1.linear2.weight              16,384
#     encoder.layers.1.linear2.bias                   128
#     encoder.layers.1.norm1.weight                   128
#     encoder.layers.1.norm1.bias                     128
#     encoder.layers.1.norm2.weight                   128
#     encoder.layers.1.norm2.bias                     128
#     attention_pool.attention.0.weight             8,192
#     attention_pool.attention.0.bias                  64
#     attention_pool.attention.2.weight                64
#     attention_pool.attention.2.bias                   1
#     flow_encoder.encoder.0.weight                 8,704
#     flow_encoder.encoder.0.bias                     128
#     flow_encoder.encoder.1.weight                   128
#     flow_encoder.encoder.1.bias                     128
#     flow_encoder.encoder.4.weight                16,384
#     flow_encoder.encoder.4.bias                     128
#     flow_fusion.gate.0.weight                    32,768
#     flow_fusion.gate.0.bias                         128
#     flow_fusion.post_gate.0.weight                  128
#     flow_fusion.post_gate.0.bias                    128
#     classifier.0.weight                             128
#     classifier.0.bias                               128
#     classifier.1.weight                          16,384
#     classifier.1.bias                               128
#     classifier.4.weight                           8,192
#     classifier.4.bias                                64
#     classifier.7.weight                             128
#     classifier.7.bias                                 2
#
#   Model size: 1.14 MB
# ============================================================
#
#
# ============================================================
# [STEP 3] Training model...
# ============================================================
# [INFO] trainer.py ------ train_model
# [INFO] train_model收到的标签分布: {np.int64(0): np.int64(119522), np.int64(1): np.int64(4503)}
# [INFO] 不平衡比率 (多数:少数): 26.5:1
# [INFO] 自动推荐focal_gamma: 2.0 (配置值为: 2.0)
# [INFO] Class distribution: [119522   4503]
# [INFO] Imbalance ratio: 26.5:1
# [INFO] 极度不平衡，使用反比权重
# [INFO] Computed alpha weights: [0.0363072 0.9636928]
# [INFO] Few class weight / Many class weight: 26.54
# [Epoch 001] train_loss=0.013267 val_loss=0.014523 val_accuracy=0.6373 val_macro_f1=0.4735 val_weighted_f1=0.7439val_auc=0.9584*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/seqLen64headstage1_best_model.pt
# [Epoch 002] train_loss=0.009548 val_loss=0.011052 val_accuracy=0.6610 val_macro_f1=0.4878 val_weighted_f1=0.7620val_auc=0.9695*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/seqLen64headstage1_best_model.pt
# [Epoch 003] train_loss=0.008622 val_loss=0.009393 val_accuracy=0.6803 val_macro_f1=0.4997 val_weighted_f1=0.7764val_auc=0.9769*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0
/content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/seqLen64headstage1_training_curves.png
# Figure(1000x800)
# [INFO] 混淆矩阵已保存: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/seqLen64headstage1_confusion_matrix.png
# Figure(1000x600)
# [INFO] 各类别 F1 图已保存: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/seqLen64headstage1_per_class_f1.png
#
# [TEST] Full metrics: {'accuracy': 0.9724830316742081, 'macro_precision': 0.8045263600967858, 'macro_recall': 0.9124911138733318, 'macro_f1': 0.849306283915364, 'weighted_precision': 0.9782219431425889, 'weighted_recall': 0.9724830316742081, 'weighted_f1': 0.9745520958784841, 'precision_label1': 0.6155804480651731, 'recall_label1': 0.8472319551506657, 'f1_label1': 0.7130639929224417, 'auc': 0.984592912811761, 'pr_auc': 0.8116476731505124, 'per_class_f1': {'0': 0.9855485749082862, '1': 0.7130639929224417}, 'confusion_matrix': [[33178, 755], [218, 1209]], 'num_classes': 2, 'num_samples': 35360, 'loss': 0.26769611168026275, 'threshold': 0.9000000000000002}
#
# ============================================================
# [STEP 4] Exporting embeddings...args Namespace(packet_csv='/content/drive/MyDrive/s1/data/ar002_et12_20260511_002-stage1_packets.csv', flow_csv='/content/drive/MyDrive/s1/data/ar002_et12_20260511_002-stage1_flows.csv', config='/content/drive/MyDrive/s1/stage1_config_0617.yaml', out_dir='/content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2', external_packet_csv=None, external_flow_csv=None, export_embeddings=True)
# ============================================================
# [INFO] Exported Stage1 embeddings: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/stage1_train_embeddings.npz
# [INFO] Keys: ['flow_id', 'label', 'z', 'split', 'flow_start_timestamp_us', 'source_id', 'destination_id']
# [INFO] z shape: (124025, 128)
# [INFO] saved embeddings: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/stage1_train_embeddings.npz
# [INFO] Stage1 build_stage2_metadata_from_npz  npz_path:  /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/stage1_train_embeddings.npz
# [INFO] Exported Stage1 embeddings: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/stage1_val_embeddings.npz
# [INFO] Keys: ['flow_id', 'label', 'z', 'split', 'flow_start_timestamp_us', 'source_id', 'destination_id']
# [INFO] z shape: (17793, 128)
# [INFO] saved embeddings: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/stage1_val_embeddings.npz
# [INFO] Stage1 build_stage2_metadata_from_npz  npz_path:  /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/stage1_val_embeddings.npz
# [INFO] Exported Stage1 embeddings: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/stage1_test_embeddings.npz
# [INFO] Keys: ['flow_id', 'label', 'z', 'split', 'flow_start_timestamp_us', 'source_id', 'destination_id']
# [INFO] z shape: (35360, 128)
# [INFO] saved embeddings: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/stage1_test_embeddings.npz
# [INFO] Stage1 build_stage2_metadata_from_npz  npz_path:  /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/stage1_test_embeddings.npz
# [INFO] saved Stage2 flow metadata: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617_v2/stage1_flow_metadata.csv
