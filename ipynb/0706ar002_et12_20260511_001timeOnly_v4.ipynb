# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0706ar002_et12_20260511_001/timeOnly/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0706ar002_et12_20260511_001/timeOnly/transformer \
  --context_method time_only \
  --context_policy online \
  --window_size 128 \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: time_only, window_size: 128, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [array([0]), array([0, 1]), array([0, 1, 2])]
#
# [Context Diagnostics] by split:
#           count        mean       std    min    50%    90%    95%    max
# split
# test    84380.0  127.000000  0.000000  127.0  127.0  127.0  127.0  127.0
# train  295329.0  126.972478  1.529251    0.0  127.0  127.0  127.0  127.0
# val     42189.0  127.000000  0.000000  127.0  127.0  127.0  127.0  127.0
#
# [Context Diagnostics] by split and label:
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0706ar002_et12_20260511_001/timeOnly_v2/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0706ar002_et12_20260511_001/timeOnly_v2/transformer \
  --context_method time_only \
  --context_policy online \
  --window_size 128 \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: time_only, window_size: 128, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [array([0]), array([0, 1]), array([0, 1, 2])]
#
# [Context Diagnostics] by split:
#           count        mean       std    min    50%    90%    95%    max
# split
# test    84380.0  127.000000  0.000000  127.0  127.0  127.0  127.0  127.0
# train  295329.0  126.972478  1.529251    0.0  127.0  127.0  127.0  127.0
# val     42189.0  127.000000  0.000000  127.0  127.0  127.0  127.0  127.0
#
# [Context Diagnostics] by split and label:
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0706ar002_et12_20260511_001/timeOnly_v3/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0706ar002_et12_20260511_001/timeOnly_v3/transformer \
  --context_method time_only \
  --context_policy online \
  --window_size 128 \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: time_only, window_size: 128, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [array([0]), array([0, 1]), array([0, 1, 2])]
#
# [Context Diagnostics] by split:
#           count        mean       std    min    50%    90%    95%    max
# split
# test    84380.0  127.000000  0.000000  127.0  127.0  127.0  127.0  127.0
# train  295329.0  126.972478  1.529251    0.0  127.0  127.0  127.0  127.0
# val     42189.0  127.000000  0.000000  127.0  127.0  127.0  127.0  127.0
#
# [Context Diagnostics] by split and label:
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0706ar002_et12_20260511_001/timeOnly_v4/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0706ar002_et12_20260511_001/timeOnly_v4/transformer \
  --context_method time_only \
  --context_policy online \
  --window_size 128 \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: time_only, window_size: 128, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [array([0]), array([0, 1]), array([0, 1, 2])]
#
# [Context Diagnostics] by split:
#           count        mean       std    min    50%    90%    95%    max
# split
# test    84380.0  127.000000  0.000000  127.0  127.0  127.0  127.0  127.0
# train  295329.0  126.972478  1.529251    0.0  127.0  127.0  127.0  127.0
# val     42189.0  127.000000  0.000000  127.0  127.0  127.0  127.0  127.0
#
# [Context Diagnostics] by split and label:
# ...
