# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_timeonly_noP_cls_head3_0610 \
  --config /content/drive/MyDrive/s2/stage2_config_noposition.yaml \
  --context_method time_only \
  --context_policy split_isolated \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=128.36, p50=129.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:383: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): Identity()
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.3, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.3, inplace=False)
#         (dropout2): Dropout(p=0.3, inplace=False)
#       )
#     )
#   )
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.15, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): GELU(approximate='none')
#     (6): Dropout(p=0.09, inplace=False)
#     (7): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] weighted sampler class_counts: [26257, 899]
# [INFO]---trainer.py---make_loss_fn---label 分布: [26257.   899.]
# [INFO] Class distribution: [26257   899]
# [INFO] Imbalance ratio: 29.2:1
# [INFO] 极度不平衡，使用反比权重
# [INFO] Computed alpha weights: [0.03310502 0.96689498]
# [INFO] Few class weight / Many class weight: 29.21
# [INFO] Using FocalLoss: gamma=2.0, label_smoothing=0.02
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit----metric_for_best =  f1_label1
# [Stage2Trainer]---fit lr=  0.0003
# [EPOCH 001] train_loss=0.029004 val_loss=0.005914 val_macro_f1=0.6081 val_weighted_f1=0.8937964261360375 val_f1_label1=0.3014 val_auc=0.9738*
# [EPOCH 002] train_loss=0.002866 val_loss=0.005352 val_macro_f1=0.6587 val_weighted_f1=0.9224632376998776 val_f1_label1=0.3756 val_auc=0.9759*
# [EPOCH 003] train_loss=0.002109 val_loss=0.007220 val_macro_f1=0.6633 val_weighted_f1=0.9248871497781788 val_f1_label1=0.3824 val_auc=0.9753*
# [EPOCH 058] train_loss=0.000578 val_loss=0.030890 val_macro_f1=0.8485 val_weighted_f1=0.9790392238471242 val_f1_label1=0.7083 val_auc=0.9602
# [EPOCH 059] train_loss=0.000533 val_loss=0.035293 val_macro_f1=0.8417 val_weighted_f1=0.9783312335832397 val_f1_label1=0.6950 val_auc=0.9591
# [EPOCH 060] train_loss=0.000432 val_loss=0.033610 val_macro_f1=0.8534 val_weighted_f1=0.9797556239101989 val_f1_label1=0.7178 val_auc=0.9634
# [EPOCH 061] train_loss=0.000606 val_loss=0.038405 val_macro_f1=0.8584 val_weighted_f1=0.9804741822889678 val_f1_label1=0.7273 val_auc=0.9553
# [EPOCH 062] train_loss=0.000644 val_loss=0.029330 val_macro_f1=0.8505 val_weighted_f1=0.9791703980454404 val_f1_label1=0.7123 val_auc=0.9251
# [EPOCH 063] train_loss=0.000682 val_loss=0.026709 val_macro_f1=0.8284 val_weighted_f1=0.9750950005303419 val_f1_label1=0.6709 val_auc=0.9336
# [EPOCH 064] train_loss=0.000488 val_loss=0.031552 val_macro_f1=0.8323 val_weighted_f1=0.9762721768679086 val_f1_label1=0.6777 val_auc=0.9342
# [EPOCH 065] train_loss=0.000418 val_loss=0.033477 val_macro_f1=0.8196 val_weighted_f1=0.9738620048004413 val_f1_label1=0.6540 val_auc=0.9618
# [EPOCH 066] train_loss=0.000480 val_loss=0.039180 val_macro_f1=0.8375 val_weighted_f1=0.9773994549640043 val_f1_label1=0.6873 val_auc=0.9432
# [EPOCH 067] train_loss=0.000384 val_loss=0.039092 val_macro_f1=0.8504 val_weighted_f1=0.9795573955181603 val_f1_label1=0.7117 val_auc=0.9187
# [EPOCH 068] train_loss=0.000543 val_loss=0.029277 val_macro_f1=0.7683 val_weighted_f1=0.9628343379275569 val_f1_label1=0.5594 val_auc=0.9622
# [EPOCH 069] train_loss=0.000546 val_loss=0.034549 val_macro_f1=0.8467 val_weighted_f1=0.978525846655051 val_f1_label1=0.7051 val_auc=0.9633
# [EPOCH 070] train_loss=0.000418 val_loss=0.035198 val_macro_f1=0.8521 val_weighted_f1=0.9795382899460021 val_f1_label1=0.7153 val_auc=0.9640
# [EPOCH 071] train_loss=0.000470 val_loss=0.033892 val_macro_f1=0.8612 val_weighted_f1=0.9806582267564803 val_f1_label1=0.7329 val_auc=0.9694
# [INFO] Early stopping at epoch=71, best_epoch=51
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.5800
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9815440603067325, 'macro_precision': 0.8525936806174388, 'macro_recall': 0.8808454667808638, 'macro_f1': 0.8661240794520213, 'weighted_precision': 0.982340720894535, 'weighted_recall': 0.9815440603067325, 'weighted_f1': 0.9818994969778977, 'precision_label1': 0.7132867132867133, 'recall_label1': 0.7727272727272727, 'f1_label1': 0.7418181818181818, 'auc': 0.9534605815897876, 'per_class_f1': {'0': 0.9904299770858607, '1': 0.7418181818181818}, 'confusion_matrix': [[3674, 41], [30, 102]], 'num_classes': 2, 'num_samples': 3847, 'threshold': 0.5800000000000001}
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_timeonly_noP_cls_head3_0610/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_timeonly_noP_cls_head3_0610/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_timeonly_noP_cls_head3_0610/stage2_predictions_test.csv
#
# ==================================================
#             Stage1 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0481
#   F1 (Macro):        0.8124
#   F1 (Weighted):     0.9752
#   AUC (OvR Macro):   0.8976
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9870
#   Class_1                       : 0.6377
#
# [TEST] Full metrics: {'accuracy': 0.974960876369327, 'macro_precision': 0.8068126520681265, 'macro_recall': 0.8181830453563714, 'macro_f1': 0.8123840666328541, 'weighted_precision': 0.9754326727338086, 'weighted_recall': 0.974960876369327, 'weighted_f1': 0.9751886387813983, 'precision_label1': 0.6259259259259259, 'recall_label1': 0.65, 'f1_label1': 0.6377358490566037, 'auc': 0.897557474248214, 'per_class_f1': {'0': 0.9870322842091044, '1': 0.6377358490566037}, 'confusion_matrix': [[7307, 101], [91, 169]], 'num_classes': 2, 'num_samples': 7668, 'loss': 0.048055056176526514, 'threshold': 0.5800000000000001, 'positive_count': 260, 'positive_rate': 0.03390714658320292}
# [INFO] saved summary: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_timeonly_noP_cls_head3_0610/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_timeonly_noP_cls_head3_0610

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_cls_head3_0610 \
  --config /content/drive/MyDrive/s2/stage2_config_noposition.yaml \
  --context_method source_host \
  --context_policy split_isolated \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=35.78, p50=11.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:383: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): Identity()
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.3, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.3, inplace=False)
#         (dropout2): Dropout(p=0.3, inplace=False)
#       )
#     )
#   )
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.15, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): GELU(approximate='none')
#     (6): Dropout(p=0.09, inplace=False)
#     (7): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] weighted sampler class_counts: [26257, 899]
# [INFO]---trainer.py---make_loss_fn---label 分布: [26257.   899.]
# [INFO] Class distribution: [26257   899]
# [INFO] Imbalance ratio: 29.2:1
# [INFO] 极度不平衡，使用反比权重
# [INFO] Computed alpha weights: [0.03310502 0.96689498]
# [INFO] Few class weight / Many class weight: 29.21
# [INFO] Using FocalLoss: gamma=2.0, label_smoothing=0.02
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit----metric_for_best =  f1_label1
# [Stage2Trainer]---fit lr=  0.0003
# [EPOCH 001] train_loss=0.032255 val_loss=0.005144 val_macro_f1=0.6352 val_weighted_f1=0.9096047821589255 val_f1_label1=0.3405 val_auc=0.9735*
# [EPOCH 002] train_loss=0.002818 val_loss=0.005627 val_macro_f1=0.6562 val_weighted_f1=0.9213098234474053 val_f1_label1=0.3716 val_auc=0.9757*
# [EPOCH 003] train_loss=0.002157 val_loss=0.007045 val_macro_f1=0.6562 val_weighted_f1=0.9224775387463138 val_f1_label1=0.3704 val_auc=0.9760
# [EPOCH 004] train_loss=0.001655 val_loss=0.008342 val_macro_f1=0.6935 val_weighted_f1=0.9383017632582741 val_f1_label1=0.4307 val_auc=0.9755*
# [EPOCH 005] train_loss=0.001543 val_loss=0.010502 val_macro_f1=0.7512 val_weighted_f1=0.9570269308450123 val_f1_label1=0.5302 val_auc=0.9731*
# [EPOCH 006] train_loss=0.001263 val_loss=0.012720 val_macro_f1=0.7519 val_weighted_f1=0.9572059597679976 val_f1_label1=0.5315 val_auc=0.9710*
# [EPOCH 007] train_loss=0.001110 val_loss=0.014518 val_macro_f1=0.7561 val_weighted_f1=0.958283554989975 val_f1_label1=0.5390 val_auc=0.9687*
# [EPOCH 008] train_loss=0.001174 val_loss=0.015977 val_macro_f1=0.7497 val_weighted_f1=0.9570693540815208 val_f1_label1=0.5271 val_auc=0.9671
# [EPOCH 009] train_loss=0.001164 val_loss=0.015959 val_macro_f1=0.7641 val_weighted_f1=0.9602752086573175 val_f1_label1=0.5534 val_auc=0.9711*
# [EPOCH 010] train_loss=0.001023 val_loss=0.017559 val_macro_f1=0.7748 val_weighted_f1=0.9628429844206645 val_f1_label1=0.5729 val_auc=0.9637*
# [EPOCH 029] train_loss=0.000728 val_loss=0.031183 val_macro_f1=0.7647 val_weighted_f1=0.9626092019259895 val_f1_label1=0.5523 val_auc=0.9526
# [EPOCH 030] train_loss=0.000702 val_loss=0.027070 val_macro_f1=0.7809 val_weighted_f1=0.9661830523456733 val_f1_label1=0.5819 val_auc=0.9683
# [EPOCH 031] train_loss=0.000688 val_loss=0.026992 val_macro_f1=0.7893 val_weighted_f1=0.967122845997842 val_f1_label1=0.5983 val_auc=0.9750
# [EPOCH 032] train_loss=0.000784 val_loss=0.023326 val_macro_f1=0.7692 val_weighted_f1=0.9634298294117376 val_f1_label1=0.5606 val_auc=0.9630
# [EPOCH 033] train_loss=0.000675 val_loss=0.026413 val_macro_f1=0.7927 val_weighted_f1=0.9680109954621233 val_f1_label1=0.6045 val_auc=0.9571
# [EPOCH 034] train_loss=0.000682 val_loss=0.029533 val_macro_f1=0.7886 val_weighted_f1=0.9674808956902814 val_f1_label1=0.5966 val_auc=0.9530
# [EPOCH 035] train_loss=0.000611 val_loss=0.033962 val_macro_f1=0.7903 val_weighted_f1=0.9679851231886751 val_f1_label1=0.5994 val_auc=0.9555
# [EPOCH 036] train_loss=0.000618 val_loss=0.040304 val_macro_f1=0.7984 val_weighted_f1=0.9701027220679643 val_f1_label1=0.6140 val_auc=0.9461
# [EPOCH 037] train_loss=0.000756 val_loss=0.029633 val_macro_f1=0.7780 val_weighted_f1=0.9646602900046014 val_f1_label1=0.5775 val_auc=0.9700
# [EPOCH 038] train_loss=0.000609 val_loss=0.029154 val_macro_f1=0.7877 val_weighted_f1=0.9666215048052017 val_f1_label1=0.5956 val_auc=0.9703
# [EPOCH 039] train_loss=0.000620 val_loss=0.033251 val_macro_f1=0.7938 val_weighted_f1=0.9688807014025489 val_f1_label1=0.6059 val_auc=0.9702
# [EPOCH 040] train_loss=0.000575 val_loss=0.036788 val_macro_f1=0.7954 val_weighted_f1=0.9695120542450265 val_f1_label1=0.6084 val_auc=0.9721
# [INFO] Early stopping at epoch=40, best_epoch=20
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.9400
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9823238887444762, 'macro_precision': 0.8823025166591189, 'macro_recall': 0.8374097638566009, 'macro_f1': 0.8583370157607895, 'weighted_precision': 0.981438499005408, 'weighted_recall': 0.9823238887444762, 'weighted_f1': 0.981772682862915, 'precision_label1': 0.7758620689655172, 'recall_label1': 0.6818181818181818, 'f1_label1': 0.7258064516129032, 'auc': 0.9719268730372363, 'per_class_f1': {'0': 0.9908675799086758, '1': 0.7258064516129032}, 'confusion_matrix': [[3689, 26], [42, 90]], 'num_classes': 2, 'num_samples': 3847, 'threshold': 0.9400000000000001}
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_cls_head3_0610/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_cls_head3_0610/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_cls_head3_0610/stage2_predictions_test.csv
#
# ==================================================
#             Stage1 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0381
#   F1 (Macro):        0.8358
#   F1 (Weighted):     0.9793
#   AUC (OvR Macro):   0.9539
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9897
#   Class_1                       : 0.6819
#
# [TEST] Full metrics: {'accuracy': 0.9800469483568075, 'macro_precision': 0.864595175438863, 'macro_recall': 0.8115374231599933, 'macro_f1': 0.8358065597378961, 'weighted_precision': 0.9788007210820221, 'weighted_recall': 0.9800469483568075, 'weighted_f1': 0.9792642330157559, 'precision_label1': 0.7420814479638009, 'recall_label1': 0.6307692307692307, 'f1_label1': 0.681912681912682, 'auc': 0.9539094949327132, 'per_class_f1': {'0': 0.9897004375631101, '1': 0.681912681912682}, 'confusion_matrix': [[7351, 57], [96, 164]], 'num_classes': 2, 'num_samples': 7668, 'loss': 0.03809682765965287, 'threshold': 0.9400000000000001, 'positive_count': 260, 'positive_rate': 0.03390714658320292}
# [INFO] saved summary: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_cls_head3_0610/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_cls_head3_0610

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_cls_head3_0610 \
  --config /content/drive/MyDrive/s2/stage2_config_noposition.yaml \
  --context_method source_host \
  --context_policy online \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=47.01, p50=22.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:383: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): Identity()
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.3, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.3, inplace=False)
#         (dropout2): Dropout(p=0.3, inplace=False)
#       )
#     )
#   )
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.15, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): GELU(approximate='none')
#     (6): Dropout(p=0.09, inplace=False)
#     (7): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] weighted sampler class_counts: [26257, 899]
# [INFO]---trainer.py---make_loss_fn---label 分布: [26257.   899.]
# [INFO] Class distribution: [26257   899]
# [INFO] Imbalance ratio: 29.2:1
# [INFO] 极度不平衡，使用反比权重
# [INFO] Computed alpha weights: [0.03310502 0.96689498]
# [INFO] Few class weight / Many class weight: 29.21
# [INFO] Using FocalLoss: gamma=2.0, label_smoothing=0.02
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit----metric_for_best =  f1_label1
# [Stage2Trainer]---fit lr=  0.0003
# [EPOCH 001] train_loss=0.032255 val_loss=0.005278 val_macro_f1=0.6349 val_weighted_f1=0.9098915802915925 val_f1_label1=0.3397 val_auc=0.9733*
# [EPOCH 002] train_loss=0.002818 val_loss=0.005574 val_macro_f1=0.6589 val_weighted_f1=0.9229079001824596 val_f1_label1=0.3754 val_auc=0.9754*
# [EPOCH 003] train_loss=0.002157 val_loss=0.006996 val_macro_f1=0.6623 val_weighted_f1=0.9248357950952293 val_f1_label1=0.3805 val_auc=0.9756*
# [EPOCH 004] train_loss=0.001655 val_loss=0.008299 val_macro_f1=0.7187 val_weighted_f1=0.9465072748719697 val_f1_label1=0.4741 val_auc=0.9745*
# [EPOCH 005] train_loss=0.001543 val_loss=0.010382 val_macro_f1=0.7727 val_weighted_f1=0.9621725326120304 val_f1_label1=0.5693 val_auc=0.9734*
# [EPOCH 006] train_loss=0.001263 val_loss=0.012550 val_macro_f1=0.7941 val_weighted_f1=0.9670299899136269 val_f1_label1=0.6085 val_auc=0.9720*
# [EPOCH 007] train_loss=0.001110 val_loss=0.014429 val_macro_f1=0.8010 val_weighted_f1=0.968810685465218 val_f1_label1=0.6209 val_auc=0.9696*
# [EPOCH 008] train_loss=0.001174 val_loss=0.015741 val_macro_f1=0.7912 val_weighted_f1=0.9667070789009011 val_f1_label1=0.6027 val_auc=0.9669
# [EPOCH 009] train_loss=0.001164 val_loss=0.015858 val_macro_f1=0.8001 val_weighted_f1=0.9686180754740225 val_f1_label1=0.6192 val_auc=0.9714
# [EPOCH 010] train_loss=0.001023 val_loss=0.017312 val_macro_f1=0.8144 val_weighted_f1=0.9714063061642453 val_f1_label1=0.6459 val_auc=0.9635*
# [EPOCH 011] train_loss=0.001135 val_loss=0.015666 val_macro_f1=0.8020 val_weighted_f1=0.969003580413187 val_f1_label1=0.6226 val_auc=0.9686
# [EPOCH 012] train_loss=0.000937 val_loss=0.020077 val_macro_f1=0.8313 val_weighted_f1=0.9751544723941435 val_f1_label1=0.6769 val_auc=0.9637*
# [EPOCH 013] train_loss=0.000982 val_loss=0.016863 val_macro_f1=0.7659 val_weighted_f1=0.9605246736614447 val_f1_label1=0.5569 val_auc=0.9616
# [EPOCH 050] train_loss=0.000565 val_loss=0.036628 val_macro_f1=0.8487 val_weighted_f1=0.9782680227433108 val_f1_label1=0.7097 val_auc=0.9687
# [EPOCH 051] train_loss=0.000646 val_loss=0.043694 val_macro_f1=0.8434 val_weighted_f1=0.9781785122380803 val_f1_label1=0.6986 val_auc=0.9682
# [EPOCH 052] train_loss=0.000584 val_loss=0.040092 val_macro_f1=0.8509 val_weighted_f1=0.9789318016793135 val_f1_label1=0.7133 val_auc=0.9617
# [EPOCH 053] train_loss=0.000678 val_loss=0.042237 val_macro_f1=0.8452 val_weighted_f1=0.9781643916869611 val_f1_label1=0.7023 val_auc=0.9603
# [EPOCH 054] train_loss=0.000604 val_loss=0.041299 val_macro_f1=0.8475 val_weighted_f1=0.9780573313971304 val_f1_label1=0.7074 val_auc=0.9650
# [EPOCH 055] train_loss=0.000614 val_loss=0.046870 val_macro_f1=0.8515 val_weighted_f1=0.9788422585582053 val_f1_label1=0.7148 val_auc=0.9663
# [EPOCH 056] train_loss=0.000773 val_loss=0.038278 val_macro_f1=0.8420 val_weighted_f1=0.977302157087458 val_f1_label1=0.6968 val_auc=0.9655
# [EPOCH 057] train_loss=0.000703 val_loss=0.044748 val_macro_f1=0.8359 val_weighted_f1=0.9769031331870986 val_f1_label1=0.6846 val_auc=0.9615
# [EPOCH 058] train_loss=0.000621 val_loss=0.047596 val_macro_f1=0.8363 val_weighted_f1=0.9771866264307204 val_f1_label1=0.6849 val_auc=0.9588
# [EPOCH 059] train_loss=0.000599 val_loss=0.048787 val_macro_f1=0.8352 val_weighted_f1=0.9771153115740198 val_f1_label1=0.6828 val_auc=0.9596
# [EPOCH 060] train_loss=0.000657 val_loss=0.036117 val_macro_f1=0.8340 val_weighted_f1=0.9750606097747481 val_f1_label1=0.6825 val_auc=0.9543
# [EPOCH 061] train_loss=0.000853 val_loss=0.020747 val_macro_f1=0.8408 val_weighted_f1=0.9770928184915099 val_f1_label1=0.6945 val_auc=0.9573
# [INFO] Early stopping at epoch=61, best_epoch=41
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.8800
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9812841174941512, 'macro_precision': 0.8542470137268923, 'macro_recall': 0.8697510094212652, 'macro_f1': 0.8618175287356322, 'weighted_precision': 0.9817110133903169, 'weighted_recall': 0.9812841174941512, 'weighted_f1': 0.981484508752902, 'precision_label1': 0.717391304347826, 'recall_label1': 0.75, 'f1_label1': 0.7333333333333333, 'auc': 0.9721532281088134, 'per_class_f1': {'0': 0.990301724137931, '1': 0.7333333333333333}, 'confusion_matrix': [[3676, 39], [33, 99]], 'num_classes': 2, 'num_samples': 3847, 'threshold': 0.88}
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_cls_head3_0610/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_cls_head3_0610/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_cls_head3_0610/stage2_predictions_test.csv
#
# ==================================================
#             Stage1 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0454
#   F1 (Macro):        0.8255
#   F1 (Weighted):     0.9773
#   AUC (OvR Macro):   0.9569
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9883
#   Class_1                       : 0.6628
#
# [TEST] Full metrics: {'accuracy': 0.9774387063119457, 'macro_precision': 0.8298995999456289, 'macro_recall': 0.8213210250872238, 'macro_f1': 0.8255484897225862, 'weighted_precision': 0.9771503025854548, 'weighted_recall': 0.9774387063119457, 'weighted_f1': 0.9772901065193356, 'precision_label1': 0.6719367588932806, 'recall_label1': 0.6538461538461539, 'f1_label1': 0.6627680311890838, 'auc': 0.956932733842831, 'per_class_f1': {'0': 0.9883289482560885, '1': 0.6627680311890838}, 'confusion_matrix': [[7325, 83], [90, 170]], 'num_classes': 2, 'num_samples': 7668, 'loss': 0.04538291681524389, 'threshold': 0.88, 'positive_count': 260, 'positive_rate': 0.03390714658320292}
# [INFO] saved summary: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_cls_head3_0610/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_cls_head3_0610

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_destination_host_noP_cls_head3_0610 \
  --config /content/drive/MyDrive/s2/stage2_config_noposition.yaml \
  --context_method destination_host \
  --context_policy split_isolated \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=28.57, p50=5.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:383: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): Identity()
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.3, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.3, inplace=False)
#         (dropout2): Dropout(p=0.3, inplace=False)
#       )
#     )
#   )
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.15, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): GELU(approximate='none')
#     (6): Dropout(p=0.09, inplace=False)
#     (7): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] weighted sampler class_counts: [26257, 899]
# [INFO]---trainer.py---make_loss_fn---label 分布: [26257.   899.]
# [INFO] Class distribution: [26257   899]
# [INFO] Imbalance ratio: 29.2:1
# [INFO] 极度不平衡，使用反比权重
# [INFO] Computed alpha weights: [0.03310502 0.96689498]
# [INFO] Few class weight / Many class weight: 29.21
# [INFO] Using FocalLoss: gamma=2.0, label_smoothing=0.02
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit----metric_for_best =  f1_label1
# [Stage2Trainer]---fit lr=  0.0003
# [EPOCH 001] train_loss=0.031445 val_loss=0.005166 val_macro_f1=0.6422 val_weighted_f1=0.9136713865897833 val_f1_label1=0.3506 val_auc=0.9722*
# [EPOCH 002] train_loss=0.002907 val_loss=0.005686 val_macro_f1=0.6546 val_weighted_f1=0.9197588122782573 val_f1_label1=0.3698 val_auc=0.9778*
# [EPOCH 003] train_loss=0.002230 val_loss=0.006424 val_macro_f1=0.6820 val_weighted_f1=0.931673446921213 val_f1_label1=0.4139 val_auc=0.9781*
# [EPOCH 004] train_loss=0.001740 val_loss=0.007313 val_macro_f1=0.7128 val_weighted_f1=0.9443447526108126 val_f1_label1=0.4642 val_auc=0.9770*
# [EPOCH 005] train_loss=0.001722 val_loss=0.009136 val_macro_f1=0.7243 val_weighted_f1=0.9485103533975777 val_f1_label1=0.4836 val_auc=0.9765*
# [EPOCH 006] train_loss=0.001503 val_loss=0.010736 val_macro_f1=0.7346 val_weighted_f1=0.9520311782152784 val_f1_label1=0.5011 val_auc=0.9755*
# [EPOCH 007] train_loss=0.001303 val_loss=0.010898 val_macro_f1=0.7232 val_weighted_f1=0.9481651507008065 val_f1_label1=0.4816 val_auc=0.9738
# [EPOCH 008] train_loss=0.001347 val_loss=0.014417 val_macro_f1=0.7644 val_weighted_f1=0.9601605797470141 val_f1_label1=0.5542 val_auc=0.9738*
# [EPOCH 009] train_loss=0.001285 val_loss=0.015860 val_macro_f1=0.7656 val_weighted_f1=0.9606396881324085 val_f1_label1=0.5561 val_auc=0.9721*
# [EPOCH 010] train_loss=0.001100 val_loss=0.018955 val_macro_f1=0.7701 val_weighted_f1=0.9617377341363067 val_f1_label1=0.5644 val_auc=0.9659*
# [EPOCH 011] train_loss=0.001112 val_loss=0.020862 val_macro_f1=0.7745 val_weighted_f1=0.9629600917648921 val_f1_label1=0.5722 val_auc=0.9585*
# [EPOCH 012] train_loss=0.001402 val_loss=0.017747 val_macro_f1=0.7712 val_weighted_f1=0.961804971609506 val_f1_label1=0.5665 val_auc=0.9608
# [INFO] Early stopping at epoch=122, best_epoch=102
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.9300
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9792045749935014, 'macro_precision': 0.8404683215242443, 'macro_recall': 0.8504078469758147, 'macro_f1': 0.8453597887213542, 'weighted_precision': 0.9795150337425235, 'weighted_recall': 0.9792045749935014, 'weighted_f1': 0.9793541640253786, 'precision_label1': 0.6911764705882353, 'recall_label1': 0.7121212121212122, 'f1_label1': 0.7014925373134329, 'auc': 0.973067824952078, 'per_class_f1': {'0': 0.9892270401292755, '1': 0.7014925373134329}, 'confusion_matrix': [[3673, 42], [38, 94]], 'num_classes': 2, 'num_samples': 3847, 'threshold': 0.93}
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_destination_host_noP_cls_head3_0610/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_destination_host_noP_cls_head3_0610/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_destination_host_noP_cls_head3_0610/stage2_predictions_test.csv
#
# ==================================================
#             Stage1 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0593
#   F1 (Macro):        0.8080
#   F1 (Weighted):     0.9750
#   AUC (OvR Macro):   0.9603
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9872
#   Class_1                       : 0.6289
#
# [TEST] Full metrics: {'accuracy': 0.9752217005738133, 'macro_precision': 0.812769687162891, 'macro_recall': 0.8034733759760757, 'macro_f1': 0.8080445982865623, 'weighted_precision': 0.9748588820067313, 'weighted_recall': 0.9752217005738133, 'weighted_f1': 0.9750348061050741, 'precision_label1': 0.6388888888888888, 'recall_label1': 0.6192307692307693, 'f1_label1': 0.62890625, 'auc': 0.9603209627845157, 'per_class_f1': {'0': 0.9871829465731247, '1': 0.62890625}, 'confusion_matrix': [[7317, 91], [99, 161]], 'num_classes': 2, 'num_samples': 7668, 'loss': 0.059347677197040365, 'threshold': 0.93, 'positive_count': 260, 'positive_rate': 0.03390714658320292}
# [INFO] saved summary: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_destination_host_noP_cls_head3_0610/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_destination_host_noP_cls_head3_0610

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_endpoint_noP_cls_head3_0610 \
  --config /content/drive/MyDrive/s2/stage2_config_noposition.yaml \
  --context_method endpoint \
  --context_policy split_isolated \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=61.57, p50=46.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:383: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): Identity()
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.3, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.3, inplace=False)
#         (dropout2): Dropout(p=0.3, inplace=False)
#       )
#     )
#   )
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.15, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): GELU(approximate='none')
#     (6): Dropout(p=0.09, inplace=False)
#     (7): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] weighted sampler class_counts: [26257, 899]
# [INFO]---trainer.py---make_loss_fn---label 分布: [26257.   899.]
# [INFO] Class distribution: [26257   899]
# [INFO] Imbalance ratio: 29.2:1
# [INFO] 极度不平衡，使用反比权重
# [INFO] Computed alpha weights: [0.03310502 0.96689498]
# [INFO] Few class weight / Many class weight: 29.21
# [INFO] Using FocalLoss: gamma=2.0, label_smoothing=0.02
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit----metric_for_best =  f1_label1
# [Stage2Trainer]---fit lr=  0.0003
# [EPOCH 001] train_loss=0.031037 val_loss=0.005260 val_macro_f1=0.6216 val_weighted_f1=0.9024948452903817 val_f1_label1=0.3201 val_auc=0.9684*
# [EPOCH 002] train_loss=0.002897 val_loss=0.005240 val_macro_f1=0.6575 val_weighted_f1=0.9215233204050802 val_f1_label1=0.3741 val_auc=0.9749*
# [EPOCH 003] train_loss=0.002126 val_loss=0.006698 val_macro_f1=0.6566 val_weighted_f1=0.9226421509796708 val_f1_label1=0.3709 val_auc=0.9756
# [EPOCH 004] train_loss=0.001677 val_loss=0.007932 val_macro_f1=0.7077 val_weighted_f1=0.9426430934852064 val_f1_label1=0.4554 val_auc=0.9744*
# [EPOCH 005] train_loss=0.001644 val_loss=0.010164 val_macro_f1=0.7423 val_weighted_f1=0.9544267324439976 val_f1_label1=0.5145 val_auc=0.9733*
# [EPOCH 006] train_loss=0.001364 val_loss=0.012413 val_macro_f1=0.7579 val_weighted_f1=0.9589372671529812 val_f1_label1=0.5420 val_auc=0.9707*
# [EPOCH 061] train_loss=0.000530 val_loss=0.029257 val_macro_f1=0.8174 val_weighted_f1=0.9737170233218375 val_f1_label1=0.6495 val_auc=0.9713
# [EPOCH 062] train_loss=0.000392 val_loss=0.030186 val_macro_f1=0.8049 val_weighted_f1=0.9707936744297613 val_f1_label1=0.6269 val_auc=0.9693
# [EPOCH 063] train_loss=0.000529 val_loss=0.027469 val_macro_f1=0.8133 val_weighted_f1=0.9717351468323076 val_f1_label1=0.6433 val_auc=0.9745
# [EPOCH 064] train_loss=0.000421 val_loss=0.031207 val_macro_f1=0.8252 val_weighted_f1=0.9747518377516954 val_f1_label1=0.6645 val_auc=0.9706
# [EPOCH 065] train_loss=0.000330 val_loss=0.035130 val_macro_f1=0.8139 val_weighted_f1=0.9734920250901652 val_f1_label1=0.6426 val_auc=0.9692
# [EPOCH 066] train_loss=0.000412 val_loss=0.039952 val_macro_f1=0.8139 val_weighted_f1=0.9734920250901652 val_f1_label1=0.6426 val_auc=0.9686
# [EPOCH 067] train_loss=0.000411 val_loss=0.034235 val_macro_f1=0.8103 val_weighted_f1=0.9711424600492772 val_f1_label1=0.6377 val_auc=0.9619
# [EPOCH 068] train_loss=0.000631 val_loss=0.026963 val_macro_f1=0.8272 val_weighted_f1=0.9747524057048106 val_f1_label1=0.6687 val_auc=0.9633
# [EPOCH 069] train_loss=0.000472 val_loss=0.031549 val_macro_f1=0.8228 val_weighted_f1=0.9739374639956213 val_f1_label1=0.6605 val_auc=0.9555
# [EPOCH 070] train_loss=0.000401 val_loss=0.028988 val_macro_f1=0.8226 val_weighted_f1=0.9732609573985141 val_f1_label1=0.6608 val_auc=0.9566
# [EPOCH 071] train_loss=0.000446 val_loss=0.036326 val_macro_f1=0.8196 val_weighted_f1=0.9743905379853741 val_f1_label1=0.6535 val_auc=0.9493
# [EPOCH 072] train_loss=0.000406 val_loss=0.036757 val_macro_f1=0.8230 val_weighted_f1=0.974610274461838 val_f1_label1=0.6602 val_auc=0.9554
# [EPOCH 073] train_loss=0.000421 val_loss=0.039661 val_macro_f1=0.8208 val_weighted_f1=0.974464794811627 val_f1_label1=0.6557 val_auc=0.9425
# [EPOCH 074] train_loss=0.000553 val_loss=0.035482 val_macro_f1=0.8218 val_weighted_f1=0.9741371159353551 val_f1_label1=0.6582 val_auc=0.9613
# [INFO] Early stopping at epoch=74, best_epoch=54
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.8800
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9773849753054328, 'macro_precision': 0.8166874718618262, 'macro_recall': 0.8786920347485623, 'macro_f1': 0.8446394676997762, 'weighted_precision': 0.9798439339866328, 'weighted_recall': 0.9773849753054328, 'weighted_f1': 0.9783928855150372, 'precision_label1': 0.6415094339622641, 'recall_label1': 0.7727272727272727, 'f1_label1': 0.7010309278350515, 'auc': 0.9449049716546352, 'per_class_f1': {'0': 0.9882480075645009, '1': 0.7010309278350515}, 'confusion_matrix': [[3658, 57], [30, 102]], 'num_classes': 2, 'num_samples': 3847, 'threshold': 0.88}
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_endpoint_noP_cls_head3_0610/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_endpoint_noP_cls_head3_0610/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_endpoint_noP_cls_head3_0610/stage2_predictions_test.csv
#
# ==================================================
#             Stage1 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0406
#   F1 (Macro):        0.7807
#   F1 (Weighted):     0.9692
#   AUC (OvR Macro):   0.8765
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9829
#   Class_1                       : 0.5786
#
# [TEST] Full metrics: {'accuracy': 0.9671361502347418, 'macro_precision': 0.749982644074364, 'macro_recall': 0.8215556986210334, 'macro_f1': 0.7807483305958115, 'weighted_precision': 0.9719811083241323, 'weighted_recall': 0.9671361502347418, 'weighted_f1': 0.9691924797866283, 'precision_label1': 0.5118343195266272, 'recall_label1': 0.6653846153846154, 'f1_label1': 0.5785953177257525, 'auc': 0.8765326466190397, 'per_class_f1': {'0': 0.9829013434658705, '1': 0.5785953177257525}, 'confusion_matrix': [[7243, 165], [87, 173]], 'num_classes': 2, 'num_samples': 7668, 'loss': 0.040562088320136996, 'threshold': 0.88, 'positive_count': 260, 'positive_rate': 0.03390714658320292}
# [INFO] saved summary: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_endpoint_noP_cls_head3_0610/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_endpoint_noP_cls_head3_0610

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_source_or_dest_noP_cls_head3_0610 \
  --config /content/drive/MyDrive/s2/stage2_config_noposition_same_source_or_dest.yaml \
  --context_method endpoint \
  --context_policy split_isolated \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=47.64, p50=25.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:383: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): Identity()
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.3, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.3, inplace=False)
#         (dropout2): Dropout(p=0.3, inplace=False)
#       )
#     )
#   )
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.15, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): GELU(approximate='none')
#     (6): Dropout(p=0.09, inplace=False)
#     (7): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] weighted sampler class_counts: [26257, 899]
# [INFO]---trainer.py---make_loss_fn---label 分布: [26257.   899.]
# [INFO] Class distribution: [26257   899]
# [INFO] Imbalance ratio: 29.2:1
# [INFO] 极度不平衡，使用反比权重
# [INFO] Computed alpha weights: [0.03310502 0.96689498]
# [INFO] Few class weight / Many class weight: 29.21
# [INFO] Using FocalLoss: gamma=2.0, label_smoothing=0.02
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit----metric_for_best =  f1_label1
# [Stage2Trainer]---fit lr=  0.0003
# [EPOCH 001] train_loss=0.031508 val_loss=0.005168 val_macro_f1=0.6309 val_weighted_f1=0.9073030436334911 val_f1_label1=0.3342 val_auc=0.9697*
# [EPOCH 002] train_loss=0.002865 val_loss=0.005323 val_macro_f1=0.6568 val_weighted_f1=0.9211937287935393 val_f1_label1=0.3729 val_auc=0.9765*
# [EPOCH 003] train_loss=0.002138 val_loss=0.006514 val_macro_f1=0.6583 val_weighted_f1=0.9230222878298935 val_f1_label1=0.3740 val_auc=0.9759*
# [EPOCH 004] train_loss=0.001664 val_loss=0.007701 val_macro_f1=0.7182 val_weighted_f1=0.9463357129871574 val_f1_label1=0.4732 val_auc=0.9752*
# [EPOCH 005] train_loss=0.001610 val_loss=0.010080 val_macro_f1=0.7471 val_weighted_f1=0.9559560520248032 val_f1_label1=0.5229 val_auc=0.9738*
# [EPOCH 006] train_loss=0.001309 val_loss=0.012801 val_macro_f1=0.7630 val_weighted_f1=0.9602071572327647 val_f1_label1=0.5512 val_auc=0.9720*
# [EPOCH 007] train_loss=0.001314 val_loss=0.013253 val_macro_f1=0.7637 val_weighted_f1=0.9603893078617257 val_f1_label1=0.5526 val_auc=0.9718*
# [EPOCH 008] train_loss=0.001185 val_loss=0.015949 val_macro_f1=0.7726 val_weighted_f1=0.9627065210941125 val_f1_label1=0.5685 val_auc=0.9712*
# [EPOCH 009] train_loss=0.001027 val_loss=0.018221 val_macro_f1=0.7935 val_weighted_f1=0.9675236262969531 val_f1_label1=0.6066 val_auc=0.9683*
# [EPOCH 047] train_loss=0.000552 val_loss=0.032183 val_macro_f1=0.8008 val_weighted_f1=0.9701294589496218 val_f1_label1=0.6190 val_auc=0.9266
# [EPOCH 048] train_loss=0.000535 val_loss=0.031734 val_macro_f1=0.8053 val_weighted_f1=0.9702883517362523 val_f1_label1=0.6282 val_auc=0.9099
# [EPOCH 049] train_loss=0.000548 val_loss=0.032299 val_macro_f1=0.8052 val_weighted_f1=0.9704151604603006 val_f1_label1=0.6279 val_auc=0.9171
# [INFO] Early stopping at epoch=49, best_epoch=29
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.9700
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9825838315570574, 'macro_precision': 0.9074711900218837, 'macro_recall': 0.8083180390717403, 'macro_f1': 0.8504895435084368, 'weighted_precision': 0.9812252581557636, 'weighted_recall': 0.9825838315570574, 'weighted_f1': 0.9813783250566138, 'precision_label1': 0.8282828282828283, 'recall_label1': 0.6212121212121212, 'f1_label1': 0.70995670995671, 'auc': 0.9504669847873077, 'per_class_f1': {'0': 0.9910223770601635, '1': 0.70995670995671}, 'confusion_matrix': [[3698, 17], [50, 82]], 'num_classes': 2, 'num_samples': 3847, 'threshold': 0.97}
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_source_or_dest_noP_cls_head3_0610/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_source_or_dest_noP_cls_head3_0610/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_source_or_dest_noP_cls_head3_0610/stage2_predictions_test.csv
#
# ==================================================
#             Stage1 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0366
#   F1 (Macro):        0.8237
#   F1 (Weighted):     0.9788
#   AUC (OvR Macro):   0.9381
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9901
#   Class_1                       : 0.6574
#
# [TEST] Full metrics: {'accuracy': 0.980699008868023, 'macro_precision': 0.9049198332133728, 'macro_recall': 0.7710520850639642, 'macro_f1': 0.8237385936661299, 'weighted_precision': 0.9788779909931979, 'weighted_recall': 0.980699008868023, 'weighted_f1': 0.9787901480971873, 'precision_label1': 0.8255813953488372, 'recall_label1': 0.5461538461538461, 'f1_label1': 0.6574074074074074, 'auc': 0.9381022595115469, 'per_class_f1': {'0': 0.9900697799248523, '1': 0.6574074074074074}, 'confusion_matrix': [[7378, 30], [118, 142]], 'num_classes': 2, 'num_samples': 7668, 'loss': 0.03658081743560615, 'threshold': 0.97, 'positive_count': 260, 'positive_rate': 0.03390714658320292}
# [INFO] saved summary: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_source_or_dest_noP_cls_head3_0610/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_source_or_dest_noP_cls_head3_0610
