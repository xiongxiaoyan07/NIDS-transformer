# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 完整对比实验
# !python /content/drive/MyDrive/s1/run_comparison_0616.py \
    --config /content/drive/MyDrive/s1/stage1_config_0616.yaml \
    --data_dir /content/drive/MyDrive/s1/data/ \
    --tensor_dir /content/drive/MyDrive/s1/tensors_ar_002 \
    --experiment_name comparison_0616_seed130_all_models \
    --output_dir /content/drive/MyDrive/s1/0616_compare_seed130_all_models \
    --num_epochs 500 \
    --seed 130 \
    --device cuda
# Out:
# [INFO] 已启用 CUDNN 确定性模式（可能影响性能）
# [INFO] 随机种子已设置: 130
# [INFO] 确定性模式: True
#
# ...
# 加载数据...
# ...
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] pipeline.py ------ build_dataloaders --- split_method chronological
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ chronological_train_val_test_split-----------nominal_b1= 27070 nominal_b2= 30937
# [INFO] splits.py ------ chronological_train_val_test_split-----------b1= 27156 b2= 31003
# ********** splits.py *****************_sanitize_three_way_boundaries: 边界安全修正，保证每个 split 至少有一个样本
# [INFO] splits.py ------ chronological_train_val_test_split-----------train_df
#             flow_id  label  flow_start_timestamp_us
# 0  522872073268161      1         1753970809973708
# 1  522920726303049      0         1753970809973719
# 2  522928050697957      0         1753970809973721
# [INFO] splits.py ------ chronological_train_val_test_split-----------val_df
# ...
