# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.9.0-py3-none-any.whl.metadata (15 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.18.5-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.51)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.5.2)
# Downloading optuna-4.9.0-py3-none-any.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 8.7 MB/s eta 0:00:00
# Downloading alembic-1.18.5-py3-none-any.whl (264 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.7/264.7 kB 24.9 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.18.5 colorlog-6.10.1 optuna-4.9.0

# %%
# !python /content/drive/MyDrive/s1/run_stage1.py \
  --packet_csv /content/drive/MyDrive/s1/data/ar002_et12_20260511_002-stage1_packets.csv \
  --flow_csv /content/drive/MyDrive/s1/data/ar002_et12_20260511_002-stage1_flows.csv \
  --config /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/stage1_config_C_residual.yaml \
  --out_dir /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/
# Out:
# [INFO] 随机种子已设置: 130
# [INFO] device=cuda
#
# ============================================================
# [STEP 1] Building dataloaders...
# ============================================================
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] pipeline.py ------ build_dataloaders --- split_method chronological
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [data_io.py] --- read_stage1_csvs--- seed = 130, strategy = head, max_seq_len = 128
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ chronological_train_val_test_split-----------nominal_b1= 124025 nominal_b2= 141742
# [INFO] splits.py ------ chronological_train_val_test_split-----------b1= 124025 b2= 141742
# ********** splits.py *****************_sanitize_three_way_boundaries: 边界安全修正，保证每个 split 至少有一个样本
# [INFO] splits.py ------ chronological_train_val_test_split-----------train_df
#              flow_id  label  flow_start_timestamp_us
# 0  1051312184880716      0         1778495267572457
# 1  1051316147181637      0         1778495267572458
# 2  1051370242672817      0         1778495267572471
# [INFO] splits.py ------ chronological_train_val_test_split-----------val_df
#                  flow_id  label  flow_start_timestamp_us
# 124025  459827689366897      0         1778495289434741
# 124026  459877026526947      0         1778495289434753
# 124027  461372474545671      0         1778495289435101
# [INFO] splits.py ------ chronological_train_val_test_split-----------test_df
#                   flow_id  label  flow_start_timestamp_us
# 141742  1350660494982982      0         1778495292773227
# 141743  1351802573801186      0         1778495292773493
# 141744  1352169519950492      0         1778495292773578
#
# ================================================================================
# [INFO] Split report: chronological_train_val_test_split
# ================================================================================
# [INFO] train:
#        num_flows     = 124025
#        label_counts  = {0: 119522, 1: 4503}
#        label1_ratio  = 0.036307
#        time_range    = [1778495267572457, 1778495289434530]
# [INFO] val:
#        num_flows     = 17717
#        label_counts  = {0: 17010, 1: 707}
#        label1_ratio  = 0.039905
#        time_range    = [1778495289434741, 1778495292773185]
# [INFO] test:
#        num_flows     = 35436
#        label_counts  = {0: 34009, 1: 1427}
#        label1_ratio  = 0.040270
#        time_range    = [1778495292773227, 1778495299611559]
# ================================================================================
#
# [INFO] splits.py ------ chronological_train_val_test_split
# [INFO] 方案C模式：flow特征维度=68
# 每个packet都包含flow信息的方案是 =  C
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/precomputed/seqLen128headtrainC.npz
# 每个packet都包含flow信息的方案是 =  C
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/precomputed/seqLen128headvalC.npz
# 每个packet都包含flow信息的方案是 =  C
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/precomputed/seqLen128headtestC.npz
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/precomputed/seqLen128headtrainC.npz
# [INFO] Dataset ------ Has separate flow features (方案C)
# [INFO]   Flow features shape: (124025, 68)
# [INFO] Dataset ------ Loaded 124025 flows
# [INFO]   X shape: (124025, 128, 35)
# [INFO]   Time shape: (124025, 128)
# [INFO]   Mask shape: (124025, 128)
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/precomputed/seqLen128headvalC.npz
# [INFO] Dataset ------ Has separate flow features (方案C)
# [INFO]   Flow features shape: (17717, 68)
# [INFO] Dataset ------ Loaded 17717 flows
# [INFO]   X shape: (17717, 128, 35)
# [INFO]   Time shape: (17717, 128)
# [INFO]   Mask shape: (17717, 128)
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/precomputed/seqLen128headtestC.npz
# [INFO] Dataset ------ Has separate flow features (方案C)
# [INFO]   Flow features shape: (35436, 68)
# [INFO] Dataset ------ Loaded 35436 flows
# [INFO]   X shape: (35436, 128, 35)
# [INFO]   Time shape: (35436, 128)
# [INFO]   Mask shape: (35436, 128)
# [INFO] sampler mode: controlled positive fraction=0.1
# [INFO] class_counts: class0=119522, class1=4503
# [INFO] sample weight class0=7.52999448e-06, class1=2.22074173e-05
# [INFO] pipeline.py ------ build_dataloaders ----- end
#
# [DEBUG] --TRAIN--- Checking train_loader consistency...
# [DEBUG --TRAIN--- batch 0 flow_ids]: tensor([1324993807622842,  894603835854097, 1859049894040564,  548799535983674,
#         1234217053243725])
# [DEBUG --TRAIN--- batch 0 flow_ids]: tensor([ 831924003798793, 2221767065688243,  122228186739812,  279572808781463,
#         1690793356506220])
#
# [DEBUG] --TRAIN-trainNoSampler-- Checking train_loader  consistency...
# [DEBUG --TRAIN-trainNoSampler-- batch 0 flow_ids]: tensor([1051312184880716, 1051316147181637, 1051370242672817, 1051375929166793,
#         1051443757981247])
# [DEBUG --TRAIN-trainNoSampler-- batch 0 flow_ids]: tensor([1059311595825947, 1059316242632454, 1059322299802324, 1059326272255494,
#         1059329687152658])
#
# [DEBUG] --VAL--- Checking VAL_loader consistency...
# [DEBUG --VAL--- batch 0 flow_ids]: tensor([459827689366897, 459877026526947, 461372474545671, 463942836130573,
#         464314188728827])
# [DEBUG --VAL--- batch 0 flow_ids]: tensor([541950448389964, 542144216433744, 542469370534637, 542783051393323,
#         542944490124386])
#
# [DEBUG] --TEST--- Checking TEST_loader consistency...
# [DEBUG --TEST--- batch 0 flow_ids]: tensor([1350660494982982, 1351802573801186, 1352169519950492, 1352449181798375,
#         1352723597245167])
# [DEBUG --TEST--- batch 0 flow_ids]: tensor([1165927589303842, 1165926536090674, 1166320036293051, 1166876402104022,
#         1166934493882566])
#
# [INFO] Preprocessor Summary:
# external_test False
# num_train_flows 124025
# num_val_flows 17717
# num_test_flows 35436
# 真实训练集类别分布 label_counts_train {'0': 119522, '1': 4503}
# label_counts_val {'0': 17010, '1': 707}
# label_counts_test {'0': 34009, '1': 1427}
# preprocessor {'packet_numerical_used': ['pkt_len', 'ip_len', 'payload_len', 'ttl_or_hop_limit', 'tcp_window', 'tcp_header_len', 'udp_len'], 'packet_categorical_used': ['ip_version', 'protocol', 'icmp_type', 'icmp_code'], 'packet_binary_used': ['direction', 'has_tcp', 'has_udp', 'has_icmp', 'tcp_fin', 'tcp_syn', 'tcp_rst', 'tcp_psh', 'tcp_ack_flag', 'tcp_urg', 'tcp_ece', 'tcp_cwr'], 'flow_numerical_used': ['flow_duration', 'total_fwd_packets', 'total_backward_packets', 'total_length_of_fwd_packets', 'total_length_of_bwd_packets', 'fwd_packet_length_max', 'fwd_packet_length_min', 'fwd_packet_length_mean', 'fwd_packet_length_std', 'bwd_packet_length_max', 'bwd_packet_length_min', 'bwd_packet_length_mean', 'bwd_packet_length_std', 'flow_bytes_per_s', 'flow_packets_per_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_total', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_total', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'bwd_psh_flags', 'fwd_urg_flags', 'bwd_urg_flags', 'fwd_header_length', 'bwd_header_length', 'fwd_packets_per_s', 'bwd_packets_per_s', 'min_packet_length', 'max_packet_length', 'packet_length_mean', 'packet_length_std', 'packet_length_variance', 'fin_flag_count', 'syn_flag_count', 'rst_flag_count', 'psh_flag_count', 'ack_flag_count', 'urg_flag_count', 'cwe_flag_count', 'ece_flag_count', 'down_up_ratio', 'average_packet_size', 'avg_fwd_segment_size', 'avg_bwd_segment_size', 'init_win_bytes_forward', 'init_win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min'], 'flow_categorical_used': [], 'flow_binary_used': ['has_init_win_bytes_forward', 'has_init_win_bytes_backward'], 'packet_log1p_used': ['pkt_len', 'ip_len', 'payload_len', 'tcp_window', 'tcp_header_len', 'udp_len'], 'flow_log1p_used': ['flow_duration', 'total_fwd_packets', 'total_backward_packets', 'total_length_of_fwd_packets', 'total_length_of_bwd_packets', 'fwd_packet_length_max', 'fwd_packet_length_min', 'fwd_packet_length_mean', 'fwd_packet_length_std', 'bwd_packet_length_max', 'bwd_packet_length_min', 'bwd_packet_length_mean', 'bwd_packet_length_std', 'flow_bytes_per_s', 'flow_packets_per_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_total', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_total', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_header_length', 'bwd_header_length', 'fwd_packets_per_s', 'bwd_packets_per_s', 'min_packet_length', 'max_packet_length', 'packet_length_mean', 'packet_length_std', 'packet_length_variance', 'average_packet_size', 'avg_fwd_segment_size', 'avg_bwd_segment_size', 'init_win_bytes_forward', 'init_win_bytes_backward', 'act_data_pkt_fwd', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min'], 'scaler': 'robust', 'clip_enabled': True, 'clip_lower_quantile': 0.001, 'clip_upper_quantile': 0.999, 'packet_clip_bounds_count': 7, 'flow_clip_bounds_count': 66, 'packet_feature_dim': 35, 'flow_feature_dim': 68, 'input_dim': 35, 'has_flow_features': True}
#
# ============================================================
# [STEP 2] Building model...
# ============================================================
# [INFO] 方案C - 分层特征注入
# [INFO]   Packet input dim: 35
# [INFO]   Flow feature dim: 68
# [INFO]------model --- __init__--fusion_method=residual_gated===-d_model=128, nhead=4, num_layers=2, dim_feedforward=256, dropout=0.2, max_seq_len=128, use_positional_encoding=True, use_time_encoding=True, use_flow_fusion=True, inject_to_packets=False
# [INFO---model.__init__] 方案C - 分层特征注入已启用
# [INFO]   Flow特征维度: 68
# [INFO]   融合方法: residual_gated
# [INFO]   模型维度: 128
# [INFO] Encoding: Time-Aware (TE(pos+p) from paper)
# [INFO] Stage1Transformer.__init__*********** cls_head_config= 3
#
# ============================================================
# 📊 Model Statistics:
# ============================================================
#   Total parameters:      461,252
#   Trainable parameters:  461,252
#   Non-trainable params:  0
#
#   Parameter breakdown:
#   ────────────────────────────────────────
#     projection.proj.weight                        4,480
#     projection.proj.bias                            128
#     projection.norm.weight                          128
#     projection.norm.bias                            128
#     encoder.layers.0.self_attn.in_proj_weight     49,152
#     encoder.layers.0.self_attn.in_proj_bias         384
#     encoder.layers.0.self_attn.out_proj.weight     16,384
#     encoder.layers.0.self_attn.out_proj.bias        128
#     encoder.layers.0.linear1.weight              32,768
#     encoder.layers.0.linear1.bias                   256
#     encoder.layers.0.linear2.weight              32,768
#     encoder.layers.0.linear2.bias                   128
#     encoder.layers.0.norm1.weight                   128
#     encoder.layers.0.norm1.bias                     128
#     encoder.layers.0.norm2.weight                   128
#     encoder.layers.0.norm2.bias                     128
#     encoder.layers.1.self_attn.in_proj_weight     49,152
#     encoder.layers.1.self_attn.in_proj_bias         384
#     encoder.layers.1.self_attn.out_proj.weight     16,384
#     encoder.layers.1.self_attn.out_proj.bias        128
#     encoder.layers.1.linear1.weight              32,768
#     encoder.layers.1.linear1.bias                   256
#     encoder.layers.1.linear2.weight              32,768
#     encoder.layers.1.linear2.bias                   128
#     encoder.layers.1.norm1.weight                   128
#     encoder.layers.1.norm1.bias                     128
#     encoder.layers.1.norm2.weight                   128
#     encoder.layers.1.norm2.bias                     128
#     encoder.norm.weight                             128
#     encoder.norm.bias                               128
#     attention_pool.attention.0.weight             8,192
#     attention_pool.attention.0.bias                  64
#     attention_pool.attention.2.weight                64
#     attention_pool.attention.2.bias                   1
#     attention_pool.fusion.0.weight               49,152
#     attention_pool.fusion.0.bias                    128
#     attention_pool.fusion.1.weight                  128
#     attention_pool.fusion.1.bias                    128
#     flow_encoder.encoder.0.weight                 8,704
#     flow_encoder.encoder.0.bias                     128
#     flow_encoder.encoder.1.weight                   128
#     flow_encoder.encoder.1.bias                     128
#     flow_encoder.encoder.4.weight                16,384
#     flow_encoder.encoder.4.bias                     128
#     flow_fusion.scale_logit                           1
#     flow_fusion.flow_delta.0.weight              32,768
#     flow_fusion.flow_delta.0.bias                   128
#     flow_fusion.flow_delta.1.weight                 128
#     flow_fusion.flow_delta.1.bias                   128
#     flow_fusion.flow_delta.4.weight              16,384
#     flow_fusion.flow_delta.4.bias                   128
#     flow_fusion.gate_linear.weight               32,768
#     flow_fusion.gate_linear.bias                    128
#     classifier.0.weight                             128
#     classifier.0.bias                               128
#     classifier.1.weight                          16,384
#     classifier.1.bias                               128
#     classifier.4.weight                           8,192
#     classifier.4.bias                                64
#     classifier.7.weight                             128
#     classifier.7.bias                                 2
#
#   Model size: 1.76 MB
# ============================================================
#
#
# ============================================================
# [STEP 3] Training model...
# ============================================================
# [INFO] trainer.py ------ train_model
# [train_model----]loss_name =  cb_focal
# [INFO] ClassBalancedFocalLoss counts: [119522   4503]
# [INFO] ClassBalancedFocalLoss weights: [0.9944439 1.0055561]
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 5/500] train_loss=0.045689 val_loss=0.024072 val_accuracy=0.9702 val_f1_label1=0.6835 val_macro_f1=0.8339 val_weighted_f1=0.9724val_auc=0.9798
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 10/500] train_loss=0.039867 val_loss=0.022351 val_accuracy=0.9726 val_f1_label1=0.7041 val_macro_f1=0.8449 val_weighted_f1=0.9744val_auc=0.9837
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 15/500] train_loss=0.037037 val_loss=0.020083 val_accuracy=0.9783 val_f1_label1=0.7452 val_macro_f1=0.8669 val_weighted_f1=0.9789val_auc=0.9856
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 20/500] train_loss=0.035249 val_loss=0.020380 val_accuracy=0.9800 val_f1_label1=0.7595 val_macro_f1=0.8745 val_weighted_f1=0.9804val_auc=0.9868
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 25/500] train_loss=0.033070 val_loss=0.021275 val_accuracy=0.9789 val_f1_label1=0.7581 val_macro_f1=0.8735 val_weighted_f1=0.9798val_auc=0.9870
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 30/500] train_loss=0.032767 val_loss=0.019658 val_accuracy=0.9801 val_f1_label1=0.7634 val_macro_f1=0.8765 val_weighted_f1=0.9806val_auc=0.9876
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 35/500] train_loss=0.030458 val_loss=0.020210 val_accuracy=0.9798 val_f1_label1=0.7632 val_macro_f1=0.8763 val_weighted_f1=0.9804val_auc=0.9880
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 40/500] train_loss=0.029547 val_loss=0.019203 val_accuracy=0.9809 val_f1_label1=0.7702 val_macro_f1=0.8801 val_weighted_f1=0.9812val_auc=0.9875
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 45/500] train_loss=0.029069 val_loss=0.020142 val_accuracy=0.9804 val_f1_label1=0.7714 val_macro_f1=0.8805 val_weighted_f1=0.9810val_auc=0.9879
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 50/500] train_loss=0.028428 val_loss=0.019744 val_accuracy=0.9799 val_f1_label1=0.7630 val_macro_f1=0.8762 val_weighted_f1=0.9805val_auc=0.9873
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 55/500] train_loss=0.028159 val_loss=0.019692 val_accuracy=0.9814 val_f1_label1=0.7773 val_macro_f1=0.8838 val_weighted_f1=0.9818val_auc=0.9878
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 60/500] train_loss=0.028816 val_loss=0.019669 val_accuracy=0.9801 val_f1_label1=0.7705 val_macro_f1=0.8801 val_weighted_f1=0.9809val_auc=0.9880
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 65/500] train_loss=0.027824 val_loss=0.019438 val_accuracy=0.9806 val_f1_label1=0.7722 val_macro_f1=0.8810 val_weighted_f1=0.9812val_auc=0.9875
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 70/500] train_loss=0.027285 val_loss=0.020134 val_accuracy=0.9793 val_f1_label1=0.7676 val_macro_f1=0.8784 val_weighted_f1=0.9803val_auc=0.9878
# [Epoch 75/500] train_loss=0.027402 val_loss=0.019366 val_accuracy=0.9799 val_f1_label1=0.7700 val_macro_f1=0.8798 val_weighted_f1=0.9807val_auc=0.9875
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 80/500] train_loss=0.027186 val_loss=0.019387 val_accuracy=0.9801 val_f1_label1=0.7672 val_macro_f1=0.8784 val_weighted_f1=0.9807val_auc=0.9875
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 85/500] train_loss=0.026850 val_loss=0.019519 val_accuracy=0.9800 val_f1_label1=0.7698 val_macro_f1=0.8797 val_weighted_f1=0.9808val_auc=0.9877
# [Epoch 90/500] train_loss=0.026227 val_loss=0.019767 val_accuracy=0.9809 val_f1_label1=0.7774 val_macro_f1=0.8837 val_weighted_f1=0.9815val_auc=0.9874
# [Epoch 95/500] train_loss=0.026152 val_loss=0.019774 val_accuracy=0.9796 val_f1_label1=0.7661 val_macro_f1=0.8777 val_weighted_f1=0.9804val_auc=0.9873
# [INFO] saved best model: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_best_model.pt
# [Epoch 100/500] train_loss=0.025708 val_loss=0.020136 val_accuracy=0.9800 val_f1_label1=0.7701 val_macro_f1=0.8798 val_weighted_f1=0.9808val_auc=0.9871
# [Epoch 105/500] train_loss=0.025546 val_loss=0.019902 val_accuracy=0.9799 val_f1_label1=0.7682 val_macro_f1=0.8789 val_weighted_f1=0.9807val_auc=0.9871
# [Epoch 110/500] train_loss=0.025127 val_loss=0.019850 val_accuracy=0.9800 val_f1_label1=0.7692 val_macro_f1=0.8794 val_weighted_f1=0.9808val_auc=0.9871
# [Epoch 115/500] train_loss=0.026218 val_loss=0.019873 val_accuracy=0.9800 val_f1_label1=0.7687 val_macro_f1=0.8791 val_weighted_f1=0.9807val_auc=0.9871
# [Epoch 120/500] train_loss=0.025777 val_loss=0.020043 val_accuracy=0.9796 val_f1_label1=0.7652 val_macro_f1=0.8773 val_weighted_f1=0.9804val_auc=0.9871
# [INFO] early stopping at epoch 122
#
# 在验证集上寻找最优决策阈值...
# 验证集上不存在同时满足 P>=0.85、R>=0.85 的阈值
# 当前最平衡的结果为：
# {'threshold': np.float64(0.5670000000000004), 'f1': 0.7779349363507779, 'precision_label1': 0.7779349363507779, 'recall_label1': 0.7779349363507779, 'f1_macro': 0.8843525357826788, 'precision': 0.8843525357826788, 'recall': 0.8843525357826788}
#
# [THRESHOLD] 最优阈值: 0.55
#   F1_class1: 0.7820
#   F1_macro: 0.8864
#   Precision_macro: 0.8786
#   Recall_macro: 0.8945
#
# 使用阈值 0.552 评估测试集...
# [INFO] --- train_model --- 计算F1上限
#
# ========== F1 CEILING DIAGNOSIS ==========
#
# [VAL ORACLE]
# threshold: 0.5491616725921631
# precision_label1: 0.7624161073825504
# recall_label1: 0.8033946251768034
# f1_label1: 0.7823691460055097
# tp: 568
# fp: 177
# tn: 16833
# fn: 139
# roc_auc: 0.9878205432032243
# pr_auc: 0.8676417271200262
# num_samples: 17717
# num_positive: 707
# num_negative: 17010
#
# [TEST AT VAL THRESHOLD]
# threshold: 0.5491616725921631
# precision_label1: 0.759780370624571
# recall_label1: 0.7757533286615277
# f1_label1: 0.7676837725381414
# tp: 1107
# fp: 350
# tn: 33659
# fn: 320
#
# [TEST ORACLE - DIAGNOSTIC ONLY]
# threshold: 0.5594101548194885
# precision_label1: 0.7719298245614035
# recall_label1: 0.7708479327259986
# f1_label1: 0.7713884992987375
# tp: 1100
# fp: 325
# tn: 33684
# fn: 327
# roc_auc: 0.9843134189941849
# pr_auc: 0.8493534093721142
# num_samples: 35436
# num_positive: 1427
# num_negative: 34009
#
# Threshold transfer gap: 0.0037047267605961887
#
# ==================================================
#             Stage1 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0765
#   F1_label1:         0.7689
#   Precision_label1:  0.7628
#   Recall_label1:     0.7751
#   F1 (Macro):        0.8795
#   Recall (Macro):    0.8825
#   Precision (Macro): 0.8767
#   F1 (Weighted):     0.9813
#   AUC (OvR Macro):   0.9843
#   PR_AUC:            0.8494
# ==================================================
#
# [RESULT] 测试集 --- 各类别 F1 (降序):
#   Class_0                       : 0.9902
#   Class_1                       : 0.7689
# Figure(1400x500)
# [INFO] 训练曲线已保存: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_training_curves.png
# Figure(1000x800)
# [INFO] 混淆矩阵已保存: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_confusion_matrix.png
# Figure(1000x600)
# [INFO] 各类别 F1 图已保存: /content/drive/MyDrive/s1/0702_C/cb_focal_cls3/seqLen128headstage1_per_class_f1.png
#
# [TEST] Full metrics: {'accuracy': 0.9812337735636076, 'macro_precision': 0.876656777537201, 'macro_recall': 0.8824687941233578, 'macro_f1': 0.8795381583982935, 'weighted_precision': 0.9813816264593911, 'weighted_recall': 0.9812337735636076, 'weighted_f1': 0.9813056123531528, 'precision_label1': 0.7627586206896552, 'recall_label1': 0.775052557813595, 'f1_label1': 0.7688564476885644, 'auc': 0.9843134189941849, 'pr_auc': 0.8493534093721142, 'per_class_f1': {'0': 0.9902198691080226, '1': 0.7688564476885644}, 'confusion_matrix': [[33665, 344], [321, 1106]], 'num_classes': 2, 'num_samples': 35436, 'loss': 0.07650152642266414, 'threshold': 0.5520000000000004}
#
# ============================================================
# [STEP 4] Exporting embeddings...args Namespace(packet_csv='/content/drive/MyDrive/s1/data/ar002_et12_20260511_002-stage1_packets.csv', flow_csv='/content/drive/MyDrive/s1/data/ar002_et12_20260511_002-stage1_flows.csv', config='/content/drive/MyDrive/s1/0702_C/cb_focal_cls3/stage1_config_C_residual.yaml', out_dir='/content/drive/MyDrive/s1/0702_C/cb_focal_cls3/', external_packet_csv=None, external_flow_csv=None, export_embeddings=False)
# ============================================================
