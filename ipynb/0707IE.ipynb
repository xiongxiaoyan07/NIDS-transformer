# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws128 \
  --context_method source_host \
  --context_policy online \
  --window_size 128 \
  --model_type target_query_gated \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: source_host, window_size: 128, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [array([0]), array([1]), array([2])]
#
# [Context Diagnostics] by split:
#           count       mean        std  min    50%    90%    95%    max
# split
# test    84380.0  98.841088  47.513911  0.0  127.0  127.0  127.0  127.0
# train  295329.0  77.019328  53.856065  0.0  106.0  127.0  127.0  127.0
# val     42189.0  96.761431  48.540006  0.0  127.0  127.0  127.0  127.0
#
# [Context Diagnostics] by split and label:
#                 count        mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0   98.012293  47.967612  0.0  127.0  127.0  127.0  127.0
#       1        3520.0  117.879830  29.739745  0.0  127.0  127.0  127.0  127.0
# train 0      283999.0   76.147736  54.024357  0.0  102.0  127.0  127.0  127.0
#       1       11330.0   98.866726  44.149883  0.0  127.0  127.0  127.0  127.0
# val   0       40395.0   95.924347  48.970889  0.0  127.0  127.0  127.0  127.0
#       1        1794.0  115.609810  32.243435  0.0  127.0  127.0  127.0  127.0
#
# [Context no-history rate] by split and label:
# split  label
# test   0        0.022298
#        1        0.015909
# train  0        0.065166
#        1        0.035305
# val    0        0.024756
#        1        0.018952
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] context lengths: min=1, mean=84.36, p50=128.0, p95=128.0, max=128
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = target_query_gated
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Stage2TargetQueryGatedAttention.__init__ use_positional_encoding=True, position_mode=age, nhead=4, dim_feedforward=256, dropout=0.25, cls_head_config=1
# Stage2TargetQueryGatedAttention(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
#   (query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (attn_dropout): Dropout(p=0.25, inplace=False)
#   (context_update): Sequential(
#     (0): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=384, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (gate): Sequential(
#     (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=512, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): Sigmoid()
#   )
#   (fused_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (final_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] make_train_loader: n0=283999, n1=11330, target_pos_frac=0.080, w0=3.23945e-06, w1=7.0609e-06, sample_weights=[3.23944803e-06 3.23944803e-06 3.23944803e-06 ... 7.06090026e-06
#  3.23944803e-06 3.23944803e-06]
# [INFO]---trainer.py---make_loss_fn---label 分布: [283999.  11330.]
# [INFO]manual_alpha = [1.0, 1.05]
# [INFO] Using manual alpha: [1.0, 1.05]
# [INFO] Using FocalLoss: gamma=1.0, label_smoothing=0.0
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit lr=3e-05, weight_decay=0.0003, patience=15, threshold=0.5, metric_for_best=pr_auc
# fit------best threshold =  0.6237373737373737
# [EPOCH 001] train_loss=0.177037 val_loss=0.027566 val_f1_label1=0.8099 val_macro_f1=0.9007 val_weighted_f1=0.9838820751692907 val_pr_auc=0.8742 val_auc=0.9878lr=0.00000720 *
# fit------best threshold =  0.6979797979797979
# [EPOCH 002] train_loss=0.034282 val_loss=0.024387 val_f1_label1=0.8228 val_macro_f1=0.9077 val_weighted_f1=0.9853118602234245 val_pr_auc=0.9020 val_auc=0.9901lr=0.00001290 *
# fit------best threshold =  0.6880808080808081
# [EPOCH 003] train_loss=0.029400 val_loss=0.025172 val_f1_label1=0.8265 val_macro_f1=0.9095 val_weighted_f1=0.9854471478426098 val_pr_auc=0.9062 val_auc=0.9909lr=0.00001860 *
# fit------best threshold =  0.6781818181818181
# [EPOCH 004] train_loss=0.026653 val_loss=0.024815 val_f1_label1=0.8266 val_macro_f1=0.9095 val_weighted_f1=0.9854274370856243 val_pr_auc=0.9090 val_auc=0.9915lr=0.00002430 *
# fit------best threshold =  0.6781818181818181
# [EPOCH 005] train_loss=0.024785 val_loss=0.023852 val_f1_label1=0.8289 val_macro_f1=0.9108 val_weighted_f1=0.9856472464230138 val_pr_auc=0.9121 val_auc=0.9917lr=0.00003000 *
# fit------best threshold =  0.6682828282828283
# [EPOCH 006] train_loss=0.023770 val_loss=0.023638 val_f1_label1=0.8297 val_macro_f1=0.9112 val_weighted_f1=0.9857031849539338 val_pr_auc=0.9124 val_auc=0.9917lr=0.00003000 *
# fit------best threshold =  0.6781818181818181
# [EPOCH 007] train_loss=0.023067 val_loss=0.023501 val_f1_label1=0.8301 val_macro_f1=0.9115 val_weighted_f1=0.9858441686055636 val_pr_auc=0.9119 val_auc=0.9912lr=0.00003000
# fit------best threshold =  0.6484848484848484
# [EPOCH 008] train_loss=0.022487 val_loss=0.023836 val_f1_label1=0.8306 val_macro_f1=0.9116 val_weighted_f1=0.9857002054521212 val_pr_auc=0.9122 val_auc=0.9915lr=0.00003000
# fit------best threshold =  0.6138383838383838
# [EPOCH 009] train_loss=0.022096 val_loss=0.023374 val_f1_label1=0.8317 val_macro_f1=0.9122 val_weighted_f1=0.9857711969444866 val_pr_auc=0.9115 val_auc=0.9911lr=0.00003000
# fit------best threshold =  0.6484848484848484
# [EPOCH 010] train_loss=0.021933 val_loss=0.023103 val_f1_label1=0.8318 val_macro_f1=0.9123 val_weighted_f1=0.9859748908273586 val_pr_auc=0.9120 val_auc=0.9909lr=0.00002999
# fit------best threshold =  0.6682828282828283
# [EPOCH 011] train_loss=0.021531 val_loss=0.024903 val_f1_label1=0.8314 val_macro_f1=0.9120 val_weighted_f1=0.985808497491045 val_pr_auc=0.9117 val_auc=0.9909lr=0.00002999
# fit------best threshold =  0.6385858585858586
# [EPOCH 012] train_loss=0.021100 val_loss=0.022961 val_f1_label1=0.8320 val_macro_f1=0.9124 val_weighted_f1=0.9859195996809919 val_pr_auc=0.9128 val_auc=0.9912lr=0.00002999 *
# fit------best threshold =  0.6385858585858586
# [EPOCH 013] train_loss=0.021300 val_loss=0.024180 val_f1_label1=0.8329 val_macro_f1=0.9128 val_weighted_f1=0.9859054399537364 val_pr_auc=0.9112 val_auc=0.9904lr=0.00002998
# fit------best threshold =  0.6336363636363637
# [EPOCH 014] train_loss=0.020820 val_loss=0.023664 val_f1_label1=0.8327 val_macro_f1=0.9127 val_weighted_f1=0.9859715647724356 val_pr_auc=0.9117 val_auc=0.9904lr=0.00002998
# fit------best threshold =  0.693030303030303
# [EPOCH 015] train_loss=0.021141 val_loss=0.025867 val_f1_label1=0.8315 val_macro_f1=0.9121 val_weighted_f1=0.9858754795996442 val_pr_auc=0.9108 val_auc=0.9906lr=0.00002997
# fit------best threshold =  0.6484848484848484
# [EPOCH 016] train_loss=0.020735 val_loss=0.024841 val_f1_label1=0.8340 val_macro_f1=0.9134 val_weighted_f1=0.9859904995024055 val_pr_auc=0.9108 val_auc=0.9902lr=0.00002996
# fit------best threshold =  0.6138383838383838
# [EPOCH 017] train_loss=0.020473 val_loss=0.024526 val_f1_label1=0.8331 val_macro_f1=0.9129 val_weighted_f1=0.9857933987210552 val_pr_auc=0.9107 val_auc=0.9902lr=0.00002996
# fit------best threshold =  0.6237373737373737
# [EPOCH 018] train_loss=0.019611 val_loss=0.024580 val_f1_label1=0.8326 val_macro_f1=0.9126 val_weighted_f1=0.9858342190087638 val_pr_auc=0.9106 val_auc=0.9902lr=0.00002995
# fit------best threshold =  0.6534343434343434
# [EPOCH 019] train_loss=0.019983 val_loss=0.024833 val_f1_label1=0.8313 val_macro_f1=0.9120 val_weighted_f1=0.9857943265603399 val_pr_auc=0.9110 val_auc=0.9905lr=0.00002994
# fit------best threshold =  0.6336363636363637
# [EPOCH 020] train_loss=0.019789 val_loss=0.025588 val_f1_label1=0.8310 val_macro_f1=0.9118 val_weighted_f1=0.9856708103518109 val_pr_auc=0.9087 val_auc=0.9897lr=0.00002993
# fit------best threshold =  0.6039393939393939
# [EPOCH 021] train_loss=0.019563 val_loss=0.026014 val_f1_label1=0.8328 val_macro_f1=0.9126 val_weighted_f1=0.9856053318559467 val_pr_auc=0.9104 val_auc=0.9902lr=0.00002992
# fit------best threshold =  0.6138383838383838
# [EPOCH 022] train_loss=0.019147 val_loss=0.024674 val_f1_label1=0.8348 val_macro_f1=0.9138 val_weighted_f1=0.9860103225709619 val_pr_auc=0.9105 val_auc=0.9902lr=0.00002991
# fit------best threshold =  0.6039393939393939
# [EPOCH 023] train_loss=0.019003 val_loss=0.026236 val_f1_label1=0.8314 val_macro_f1=0.9119 val_weighted_f1=0.9854862497623064 val_pr_auc=0.9099 val_auc=0.9904lr=0.00002990
# fit------best threshold =  0.594040404040404
# [EPOCH 024] train_loss=0.019251 val_loss=0.025883 val_f1_label1=0.8312 val_macro_f1=0.9118 val_weighted_f1=0.985566447250682 val_pr_auc=0.9087 val_auc=0.9898lr=0.00002989
# fit------best threshold =  0.6385858585858586
# [EPOCH 025] train_loss=0.018448 val_loss=0.025824 val_f1_label1=0.8309 val_macro_f1=0.9117 val_weighted_f1=0.9857016348475339 val_pr_auc=0.9091 val_auc=0.9903lr=0.00002988
# fit------best threshold =  0.6286868686868686
# [EPOCH 026] train_loss=0.018760 val_loss=0.026642 val_f1_label1=0.8299 val_macro_f1=0.9112 val_weighted_f1=0.9855271806392268 val_pr_auc=0.9080 val_auc=0.9902lr=0.00002987
# fit------best threshold =  0.5791919191919191
# [EPOCH 027] train_loss=0.018574 val_loss=0.025968 val_f1_label1=0.8327 val_macro_f1=0.9126 val_weighted_f1=0.9857251459601362 val_pr_auc=0.9089 val_auc=0.9903lr=0.00002986
# [INFO] Early stopping at epoch=27, best_epoch=12
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.6386
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9861101234919055, 'macro_precision': 0.9240411784334155, 'macro_recall': 0.9013957694522443, 'macro_f1': 0.9123755034303012, 'weighted_precision': 0.9857901887218816, 'weighted_recall': 0.9861101234919055, 'weighted_f1': 0.9859195996809919, 'precision_label1': 0.8565525383707202, 'recall_label1': 0.8088071348940914, 'f1_label1': 0.8319954128440367, 'auc': 0.9911598991177286, 'pr_auc': 0.9127873554175314, 'per_class_f1': {'0': 0.9927555940165657, '1': 0.8319954128440367}, 'confusion_matrix': [[40152, 243], [343, 1451]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6385858585858586}
#
# ========== STAGE2 THRESHOLD ORACLE DIAGNOSIS ==========
# [VAL ORACLE THRESHOLD] 0.638586
# [VAL ORACLE METRICS] {'accuracy': 0.9861101234919055, 'macro_precision': 0.9240411784334155, 'macro_recall': 0.9013957694522443, 'macro_f1': 0.9123755034303012, 'weighted_precision': 0.9857901887218816, 'weighted_recall': 0.9861101234919055, 'weighted_f1': 0.9859195996809919, 'precision_label1': 0.8565525383707202, 'recall_label1': 0.8088071348940914, 'f1_label1': 0.8319954128440367, 'auc': 0.9911601957978229, 'pr_auc': 0.9127801911628701, 'per_class_f1': {'0': 0.9927555940165657, '1': 0.8319954128440367}, 'confusion_matrix': [[40152, 243], [343, 1451]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6385858585858586}
#
# [TEST AT VAL THRESHOLD] 0.638586
# [TEST AT VAL THRESHOLD METRICS] {'accuracy': 0.9832661768191514, 'macro_precision': 0.8930997355203298, 'macro_recall': 0.8992903348660986, 'macro_f1': 0.8961682257028769, 'weighted_precision': 0.9834016179668603, 'weighted_recall': 0.9832661768191514, 'weighted_f1': 0.9833315436725552, 'precision_label1': 0.7945779765231973, 'recall_label1': 0.8076704545454545, 'f1_label1': 0.8010707241476472, 'auc': 0.990287170375846, 'pr_auc': 0.8831835303955565, 'per_class_f1': {'0': 0.9912657272581065, '1': 0.8010707241476472}, 'confusion_matrix': [[80125, 735], [677, 2843]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6385858585858586}
#
# [TEST ORACLE THRESHOLD - DIAGNOSTIC ONLY] 0.623737
# [TEST ORACLE METRICS] {'accuracy': 0.9831832187722209, 'macro_precision': 0.8898033708734834, 'macro_recall': 0.9038663557102062, 'macro_f1': 0.8966965876058335, 'weighted_precision': 0.9835054939822926, 'weighted_recall': 0.9831832187722209, 'weighted_f1': 0.9833322042521013, 'precision_label1': 0.7875718587462359, 'recall_label1': 0.8173295454545455, 'f1_label1': 0.8021748222501046, 'auc': 0.990287170375846, 'pr_auc': 0.8831835303955565, 'per_class_f1': {'0': 0.9912183529615625, '1': 0.8021748222501046}, 'confusion_matrix': [[80084, 776], [643, 2877]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6237373737373737}
#
# [THRESHOLD TRANSFER GAP] 0.001104
# =======================================================
#
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws128/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws128/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws128/stage2_predictions_test.csv
#
# ==================================================
#             Stage2 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0302
#   F1 (Macro):        0.8961
#   Recall (Macro):    0.8991
#   Precision (Macro): 0.8931
#   F1_class1:         0.8009
#   R1_class1:         0.8074
#   P1_class1:         0.7945
#   AUC (OvR Macro):   0.9903
#   PR_AUC:            0.8832
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9913
#   Class_1                       : 0.8009
#
# [TEST] Full metrics: {'accuracy': 0.9832543256695899, 'macro_precision': 0.8930648851875329, 'macro_recall': 0.899148289411553, 'macro_f1': 0.8960806925334863, 'weighted_precision': 0.9833874621290072, 'weighted_recall': 0.9832543256695899, 'weighted_f1': 0.9833186204962499, 'precision_label1': 0.7945205479452054, 'recall_label1': 0.8073863636363636, 'f1_label1': 0.8009017894885163, 'auc': 0.990286994707463, 'pr_auc': 0.883188786200487, 'per_class_f1': {'0': 0.9912595955784564, '1': 0.8009017894885163}, 'confusion_matrix': [[80125, 735], [678, 2842]], 'num_classes': 2, 'num_samples': 84380, 'loss': 0.030159747358721144, 'threshold': 0.6385858585858586, 'positive_count': 3520, 'positive_rate': 0.041716046456506284}
# [INFO] saved summary: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws128/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws128

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/dst_newM/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/dst_newM/ws128 \
  --context_method destination_host \
  --context_policy online \
  --window_size 128 \
  --model_type target_query_gated \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: destination_host, window_size: 128, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [array([0]), array([1]), array([2])]
#
# [Context Diagnostics] by split:
#           count       mean        std  min    50%    90%    95%    max
# split
# test    84380.0  89.765975  50.671856  0.0  127.0  127.0  127.0  127.0
# train  295329.0  66.671583  54.095576  0.0   61.0  127.0  127.0  127.0
# val     42189.0  87.496693  51.429910  0.0  127.0  127.0  127.0  127.0
#
# [Context Diagnostics] by split and label:
#                 count       mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0  90.827467  50.273394  0.0  127.0  127.0  127.0  127.0
#       1        3520.0  65.381818  53.590606  0.0   54.0  127.0  127.0  127.0
# train 0      283999.0  67.537115  54.077592  0.0   64.0  127.0  127.0  127.0
#       1       11330.0  44.976081  49.858196  0.0   19.0  127.0  127.0  127.0
# val   0       40395.0  88.509419  51.087733  0.0  127.0  127.0  127.0  127.0
#       1        1794.0  64.693423  53.790454  0.0   55.0  127.0  127.0  127.0
#
# [Context no-history rate] by split and label:
# split  label
# test   0        0.020814
#        1        0.058807
# train  0        0.070208
#        1        0.117652
# val    0        0.023419
#        1        0.049610
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] context lengths: min=1, mean=74.37, p50=89.0, p95=128.0, max=128
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = target_query_gated
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Stage2TargetQueryGatedAttention.__init__ use_positional_encoding=True, position_mode=age, nhead=4, dim_feedforward=256, dropout=0.25, cls_head_config=1
# Stage2TargetQueryGatedAttention(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
#   (query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (attn_dropout): Dropout(p=0.25, inplace=False)
#   (context_update): Sequential(
#     (0): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=384, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (gate): Sequential(
#     (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=512, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): Sigmoid()
#   )
#   (fused_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (final_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] make_train_loader: n0=283999, n1=11330, target_pos_frac=0.080, w0=3.23945e-06, w1=7.0609e-06, sample_weights=[3.23944803e-06 3.23944803e-06 3.23944803e-06 ... 7.06090026e-06
#  3.23944803e-06 3.23944803e-06]
# [INFO]---trainer.py---make_loss_fn---label 分布: [283999.  11330.]
# [INFO]manual_alpha = [1.0, 1.05]
# [INFO] Using manual alpha: [1.0, 1.05]
# [INFO] Using FocalLoss: gamma=1.0, label_smoothing=0.0
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit lr=3e-05, weight_decay=0.0003, patience=15, threshold=0.5, metric_for_best=pr_auc
# fit------best threshold =  0.598989898989899
# [EPOCH 001] train_loss=0.178018 val_loss=0.027821 val_f1_label1=0.7990 val_macro_f1=0.8950 val_weighted_f1=0.982858664808883 val_pr_auc=0.8686 val_auc=0.9872lr=0.00000720 *
# fit------best threshold =  0.6583838383838384
# [EPOCH 002] train_loss=0.035241 val_loss=0.024625 val_f1_label1=0.8250 val_macro_f1=0.9087 val_weighted_f1=0.9852876948266396 val_pr_auc=0.9008 val_auc=0.9897lr=0.00001290 *
# fit------best threshold =  0.6534343434343434
# [EPOCH 003] train_loss=0.030050 val_loss=0.025393 val_f1_label1=0.8235 val_macro_f1=0.9078 val_weighted_f1=0.9850409012367336 val_pr_auc=0.9037 val_auc=0.9902lr=0.00001860 *
# fit------best threshold =  0.6237373737373737
# [EPOCH 004] train_loss=0.027773 val_loss=0.025287 val_f1_label1=0.8262 val_macro_f1=0.9093 val_weighted_f1=0.9852034199727258 val_pr_auc=0.9045 val_auc=0.9901lr=0.00002430 *
# fit------best threshold =  0.6633333333333333
# [EPOCH 005] train_loss=0.026089 val_loss=0.024820 val_f1_label1=0.8260 val_macro_f1=0.9092 val_weighted_f1=0.9853558087545673 val_pr_auc=0.9057 val_auc=0.9901lr=0.00003000 *
# fit------best threshold =  0.6534343434343434
# [EPOCH 006] train_loss=0.025185 val_loss=0.024337 val_f1_label1=0.8273 val_macro_f1=0.9099 val_weighted_f1=0.9855311174519148 val_pr_auc=0.9051 val_auc=0.9901lr=0.00003000
# fit------best threshold =  0.6633333333333333
# [EPOCH 007] train_loss=0.024542 val_loss=0.024393 val_f1_label1=0.8280 val_macro_f1=0.9103 val_weighted_f1=0.9856351182249983 val_pr_auc=0.9052 val_auc=0.9898lr=0.00003000
# fit------best threshold =  0.6484848484848484
# [EPOCH 008] train_loss=0.024045 val_loss=0.024706 val_f1_label1=0.8264 val_macro_f1=0.9095 val_weighted_f1=0.9854095164773301 val_pr_auc=0.9049 val_auc=0.9898lr=0.00003000
# fit------best threshold =  0.598989898989899
# [EPOCH 009] train_loss=0.023896 val_loss=0.024169 val_f1_label1=0.8270 val_macro_f1=0.9097 val_weighted_f1=0.9853202750724418 val_pr_auc=0.9046 val_auc=0.9895lr=0.00003000
# fit------best threshold =  0.6237373737373737
# [EPOCH 010] train_loss=0.023648 val_loss=0.023791 val_f1_label1=0.8274 val_macro_f1=0.9100 val_weighted_f1=0.9855828529151787 val_pr_auc=0.9051 val_auc=0.9893lr=0.00002999
# fit------best threshold =  0.598989898989899
# [EPOCH 011] train_loss=0.023321 val_loss=0.025177 val_f1_label1=0.8253 val_macro_f1=0.9087 val_weighted_f1=0.9850278045585543 val_pr_auc=0.9053 val_auc=0.9894lr=0.00002999
# fit------best threshold =  0.5890909090909091
# [EPOCH 012] train_loss=0.022730 val_loss=0.024285 val_f1_label1=0.8273 val_macro_f1=0.9098 val_weighted_f1=0.9852602375862453 val_pr_auc=0.9060 val_auc=0.9896lr=0.00002999 *
# fit------best threshold =  0.6435353535353535
# [EPOCH 013] train_loss=0.023139 val_loss=0.024971 val_f1_label1=0.8277 val_macro_f1=0.9102 val_weighted_f1=0.985561191935646 val_pr_auc=0.9045 val_auc=0.9890lr=0.00002998
# fit------best threshold =  0.5643434343434344
# [EPOCH 014] train_loss=0.022634 val_loss=0.024335 val_f1_label1=0.8288 val_macro_f1=0.9106 val_weighted_f1=0.9854184243020416 val_pr_auc=0.9051 val_auc=0.9890lr=0.00002998
# fit------best threshold =  0.6237373737373737
# [EPOCH 015] train_loss=0.022850 val_loss=0.025949 val_f1_label1=0.8317 val_macro_f1=0.9121 val_weighted_f1=0.9856098469465403 val_pr_auc=0.9046 val_auc=0.9889lr=0.00002997
# fit------best threshold =  0.6435353535353535
# [EPOCH 016] train_loss=0.022562 val_loss=0.025564 val_f1_label1=0.8300 val_macro_f1=0.9113 val_weighted_f1=0.9856767152636189 val_pr_auc=0.9051 val_auc=0.9889lr=0.00002996
# fit------best threshold =  0.6088888888888889
# [EPOCH 017] train_loss=0.022380 val_loss=0.025491 val_f1_label1=0.8309 val_macro_f1=0.9117 val_weighted_f1=0.9855898521579602 val_pr_auc=0.9049 val_auc=0.9890lr=0.00002996
# fit------best threshold =  0.598989898989899
# [EPOCH 018] train_loss=0.021540 val_loss=0.025682 val_f1_label1=0.8279 val_macro_f1=0.9101 val_weighted_f1=0.9852935292781898 val_pr_auc=0.9047 val_auc=0.9888lr=0.00002995
# fit------best threshold =  0.598989898989899
# [EPOCH 019] train_loss=0.021969 val_loss=0.025041 val_f1_label1=0.8305 val_macro_f1=0.9115 val_weighted_f1=0.9855604526367621 val_pr_auc=0.9047 val_auc=0.9887lr=0.00002994
# fit------best threshold =  0.598989898989899
# [EPOCH 020] train_loss=0.021483 val_loss=0.025764 val_f1_label1=0.8288 val_macro_f1=0.9106 val_weighted_f1=0.9853802685260795 val_pr_auc=0.9042 val_auc=0.9888lr=0.00002993
# fit------best threshold =  0.6385858585858586
# [EPOCH 021] train_loss=0.021118 val_loss=0.027096 val_f1_label1=0.8285 val_macro_f1=0.9104 val_weighted_f1=0.9854309029195395 val_pr_auc=0.9034 val_auc=0.9880lr=0.00002992
# fit------best threshold =  0.5791919191919191
# [EPOCH 022] train_loss=0.021089 val_loss=0.025541 val_f1_label1=0.8278 val_macro_f1=0.9100 val_weighted_f1=0.9852795811387559 val_pr_auc=0.9039 val_auc=0.9882lr=0.00002991
# fit------best threshold =  0.598989898989899
# [EPOCH 023] train_loss=0.020810 val_loss=0.025886 val_f1_label1=0.8296 val_macro_f1=0.9110 val_weighted_f1=0.985438987716714 val_pr_auc=0.9041 val_auc=0.9883lr=0.00002990
# fit------best threshold =  0.6336363636363637
# [EPOCH 024] train_loss=0.020989 val_loss=0.026390 val_f1_label1=0.8298 val_macro_f1=0.9112 val_weighted_f1=0.9856829290035792 val_pr_auc=0.9031 val_auc=0.9879lr=0.00002989
# fit------best threshold =  0.6088888888888889
# [EPOCH 025] train_loss=0.020316 val_loss=0.026376 val_f1_label1=0.8275 val_macro_f1=0.9099 val_weighted_f1=0.9852780433442324 val_pr_auc=0.9036 val_auc=0.9883lr=0.00002988
# fit------best threshold =  0.6484848484848484
# [EPOCH 026] train_loss=0.020553 val_loss=0.027352 val_f1_label1=0.8279 val_macro_f1=0.9102 val_weighted_f1=0.9854554347705267 val_pr_auc=0.9032 val_auc=0.9885lr=0.00002987
# fit------best threshold =  0.6633333333333333
# [EPOCH 027] train_loss=0.020183 val_loss=0.026509 val_f1_label1=0.8276 val_macro_f1=0.9101 val_weighted_f1=0.9856287963231206 val_pr_auc=0.9043 val_auc=0.9885lr=0.00002986
# [INFO] Early stopping at epoch=27, best_epoch=12
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.5891
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9852094147763635, 'macro_precision': 0.9070109489955163, 'macro_recall': 0.912643891570739, 'macro_f1': 0.9098059574231556, 'weighted_precision': 0.9853148992304506, 'weighted_recall': 0.9852094147763635, 'weighted_f1': 0.9852602375862453, 'precision_label1': 0.8214285714285714, 'recall_label1': 0.8333333333333334, 'f1_label1': 0.8273381294964028, 'auc': 0.9896324451007285, 'pr_auc': 0.9059618119122035, 'per_class_f1': {'0': 0.9922737853499084, '1': 0.8273381294964028}, 'confusion_matrix': [[40070, 325], [299, 1495]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.5890909090909091}
#
# ========== STAGE2 THRESHOLD ORACLE DIAGNOSIS ==========
# [VAL ORACLE THRESHOLD] 0.589091
# [VAL ORACLE METRICS] {'accuracy': 0.9852094147763635, 'macro_precision': 0.9070109489955163, 'macro_recall': 0.912643891570739, 'macro_f1': 0.9098059574231556, 'weighted_precision': 0.9853148992304506, 'weighted_recall': 0.9852094147763635, 'weighted_f1': 0.9852602375862453, 'precision_label1': 0.8214285714285714, 'recall_label1': 0.8333333333333334, 'f1_label1': 0.8273381294964028, 'auc': 0.9896315481609077, 'pr_auc': 0.9059531996865707, 'per_class_f1': {'0': 0.9922737853499084, '1': 0.8273381294964028}, 'confusion_matrix': [[40070, 325], [299, 1495]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.5890909090909091}
#
# [TEST AT VAL THRESHOLD] 0.589091
# [TEST AT VAL THRESHOLD METRICS] {'accuracy': 0.982602512443707, 'macro_precision': 0.8808614813175285, 'macro_recall': 0.9111716308209475, 'macro_f1': 0.8953712141709633, 'weighted_precision': 0.9833819543644673, 'weighted_recall': 0.982602512443707, 'weighted_f1': 0.9829353785456747, 'precision_label1': 0.7690089145254326, 'recall_label1': 0.8332386363636364, 'f1_label1': 0.7998363785110445, 'auc': 0.9894534043127292, 'pr_auc': 0.8796793510304997, 'per_class_f1': {'0': 0.9909060498308823, '1': 0.7998363785110445}, 'confusion_matrix': [[79979, 881], [587, 2933]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.5890909090909091}
#
# [TEST ORACLE THRESHOLD - DIAGNOSTIC ONLY] 0.623737
# [TEST ORACLE METRICS] {'accuracy': 0.9830647072766058, 'macro_precision': 0.8890158231722687, 'macro_recall': 0.9032610727295213, 'macro_f1': 0.8959962971344733, 'weighted_precision': 0.9833941895486723, 'weighted_recall': 0.9830647072766058, 'weighted_f1': 0.9832169543508781, 'precision_label1': 0.786046511627907, 'recall_label1': 0.8161931818181818, 'f1_label1': 0.8008362369337979, 'auc': 0.9894534043127292, 'pr_auc': 0.8796793510304997, 'per_class_f1': {'0': 0.9911563573351487, '1': 0.8008362369337979}, 'confusion_matrix': [[80078, 782], [647, 2873]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6237373737373737}
#
# [THRESHOLD TRANSFER GAP] 0.001000
# =======================================================
#
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/dst_newM/ws128/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/dst_newM/ws128/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/dst_newM/ws128/stage2_predictions_test.csv
#
# ==================================================
#             Stage2 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0309
#   F1 (Macro):        0.8954
#   Recall (Macro):    0.9112
#   Precision (Macro): 0.8809
#   F1_class1:         0.7998
#   R1_class1:         0.8332
#   P1_class1:         0.7690
#   AUC (OvR Macro):   0.9895
#   PR_AUC:            0.8797
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9909
#   Class_1                       : 0.7998
#
# [TEST] Full metrics: {'accuracy': 0.982602512443707, 'macro_precision': 0.8808614813175285, 'macro_recall': 0.9111716308209475, 'macro_f1': 0.8953712141709633, 'weighted_precision': 0.9833819543644673, 'weighted_recall': 0.982602512443707, 'weighted_f1': 0.9829353785456747, 'precision_label1': 0.7690089145254326, 'recall_label1': 0.8332386363636364, 'f1_label1': 0.7998363785110445, 'auc': 0.9894529633850875, 'pr_auc': 0.8796865876633022, 'per_class_f1': {'0': 0.9909060498308823, '1': 0.7998363785110445}, 'confusion_matrix': [[79979, 881], [587, 2933]], 'num_classes': 2, 'num_samples': 84380, 'loss': 0.03090711395524371, 'threshold': 0.5890909090909091, 'positive_count': 3520, 'positive_rate': 0.041716046456506284}
# [INFO] saved summary: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/dst_newM/ws128/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/dst_newM/ws128

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/endpoint_newM/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/endpoint_newM/ws128\
  --context_method endpoint \
  --context_policy online \
  --window_size 128 \
  --model_type target_query_gated \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: endpoint, window_size: 128, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [array([0]), array([1]), array([2])]
#
# [Context Diagnostics] by split:
#           count        mean        std  min    50%    90%    95%    max
# split
# test    84380.0  125.905404   9.287464  0.0  127.0  127.0  127.0  127.0
# train  295329.0  115.416298  29.844794  0.0  127.0  127.0  127.0  127.0
# val     42189.0  125.640096  10.434685  1.0  127.0  127.0  127.0  127.0
#
# [Context Diagnostics] by split and label:
#                 count        mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0  125.906431   9.286644  0.0  127.0  127.0  127.0  127.0
#       1        3520.0  125.881818   9.307583  7.0  127.0  127.0  127.0  127.0
# train 0      283999.0  115.390924  29.891515  0.0  127.0  127.0  127.0  127.0
#       1       11330.0  116.052339  28.642728  0.0  127.0  127.0  127.0  127.0
# val   0       40395.0  125.659091  10.361372  1.0  127.0  127.0  127.0  127.0
#       1        1794.0  125.212375  11.962436  5.0  127.0  127.0  127.0  127.0
#
# [Context no-history rate] by split and label:
# split  label
# test   0        0.000074
#        1        0.000000
# train  0        0.001915
#        1        0.002118
# val    0        0.000000
#        1        0.000000
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] context lengths: min=1, mean=119.54, p50=128.0, p95=128.0, max=128
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = target_query_gated
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Stage2TargetQueryGatedAttention.__init__ use_positional_encoding=True, position_mode=age, nhead=4, dim_feedforward=256, dropout=0.25, cls_head_config=1
# Stage2TargetQueryGatedAttention(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
#   (query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (attn_dropout): Dropout(p=0.25, inplace=False)
#   (context_update): Sequential(
#     (0): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=384, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (gate): Sequential(
#     (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=512, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): Sigmoid()
#   )
#   (fused_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (final_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] make_train_loader: n0=283999, n1=11330, target_pos_frac=0.080, w0=3.23945e-06, w1=7.0609e-06, sample_weights=[3.23944803e-06 3.23944803e-06 3.23944803e-06 ... 7.06090026e-06
#  3.23944803e-06 3.23944803e-06]
# [INFO]---trainer.py---make_loss_fn---label 分布: [283999.  11330.]
# [INFO]manual_alpha = [1.0, 1.05]
# [INFO] Using manual alpha: [1.0, 1.05]
# [INFO] Using FocalLoss: gamma=1.0, label_smoothing=0.0
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit lr=3e-05, weight_decay=0.0003, patience=15, threshold=0.5, metric_for_best=pr_auc
# fit------best threshold =  0.598989898989899
# [EPOCH 001] train_loss=0.164100 val_loss=0.026818 val_f1_label1=0.8091 val_macro_f1=0.9003 val_weighted_f1=0.9837270153658662 val_pr_auc=0.8760 val_auc=0.9880lr=0.00000720 *
# fit------best threshold =  0.6484848484848484
# [EPOCH 002] train_loss=0.034014 val_loss=0.024571 val_f1_label1=0.8244 val_macro_f1=0.9084 val_weighted_f1=0.9852025331370985 val_pr_auc=0.9004 val_auc=0.9896lr=0.00001290 *
# fit------best threshold =  0.6781818181818181
# [EPOCH 003] train_loss=0.029791 val_loss=0.025419 val_f1_label1=0.8231 val_macro_f1=0.9077 val_weighted_f1=0.9851863604101109 val_pr_auc=0.9031 val_auc=0.9899lr=0.00001860 *
# fit------best threshold =  0.6682828282828283
# [EPOCH 004] train_loss=0.027534 val_loss=0.025433 val_f1_label1=0.8263 val_macro_f1=0.9094 val_weighted_f1=0.9853916049030623 val_pr_auc=0.9039 val_auc=0.9898lr=0.00002430 *
# fit------best threshold =  0.6633333333333333
# [EPOCH 005] train_loss=0.025861 val_loss=0.025116 val_f1_label1=0.8266 val_macro_f1=0.9095 val_weighted_f1=0.9853798800876046 val_pr_auc=0.9050 val_auc=0.9898lr=0.00003000 *
# fit------best threshold =  0.6435353535353535
# [EPOCH 006] train_loss=0.025075 val_loss=0.025088 val_f1_label1=0.8269 val_macro_f1=0.9097 val_weighted_f1=0.9853779421938066 val_pr_auc=0.9043 val_auc=0.9895lr=0.00003000
# fit------best threshold =  0.6286868686868686
# [EPOCH 007] train_loss=0.024439 val_loss=0.024750 val_f1_label1=0.8268 val_macro_f1=0.9096 val_weighted_f1=0.9853739616947328 val_pr_auc=0.9045 val_auc=0.9894lr=0.00003000
# fit------best threshold =  0.6633333333333333
# [EPOCH 008] train_loss=0.023805 val_loss=0.025432 val_f1_label1=0.8252 val_macro_f1=0.9088 val_weighted_f1=0.9853470111492908 val_pr_auc=0.9047 val_auc=0.9896lr=0.00003000
# fit------best threshold =  0.6781818181818181
# [EPOCH 009] train_loss=0.023518 val_loss=0.024685 val_f1_label1=0.8259 val_macro_f1=0.9093 val_weighted_f1=0.9856198080357464 val_pr_auc=0.9040 val_auc=0.9893lr=0.00003000
# fit------best threshold =  0.5197979797979798
# [EPOCH 010] train_loss=0.023331 val_loss=0.024059 val_f1_label1=0.8263 val_macro_f1=0.9091 val_weighted_f1=0.9849810572129482 val_pr_auc=0.9047 val_auc=0.9893lr=0.00002999
# fit------best threshold =  0.702929292929293
# [EPOCH 011] train_loss=0.023051 val_loss=0.026061 val_f1_label1=0.8245 val_macro_f1=0.9086 val_weighted_f1=0.9854904944615742 val_pr_auc=0.9042 val_auc=0.9892lr=0.00002999
# fit------best threshold =  0.598989898989899
# [EPOCH 012] train_loss=0.022397 val_loss=0.024564 val_f1_label1=0.8245 val_macro_f1=0.9084 val_weighted_f1=0.9851084897662759 val_pr_auc=0.9050 val_auc=0.9894lr=0.00002999
# fit------best threshold =  0.594040404040404
# [EPOCH 013] train_loss=0.022647 val_loss=0.025179 val_f1_label1=0.8254 val_macro_f1=0.9088 val_weighted_f1=0.985106736838436 val_pr_auc=0.9042 val_auc=0.9889lr=0.00002998
# fit------best threshold =  0.5890909090909091
# [EPOCH 014] train_loss=0.022231 val_loss=0.024627 val_f1_label1=0.8255 val_macro_f1=0.9089 val_weighted_f1=0.9852370223121701 val_pr_auc=0.9045 val_auc=0.9888lr=0.00002998
# fit------best threshold =  0.6583838383838384
# [EPOCH 015] train_loss=0.022482 val_loss=0.027040 val_f1_label1=0.8247 val_macro_f1=0.9085 val_weighted_f1=0.9851538117079596 val_pr_auc=0.9039 val_auc=0.9891lr=0.00002997
# fit------best threshold =  0.6385858585858586
# [EPOCH 016] train_loss=0.022105 val_loss=0.025859 val_f1_label1=0.8272 val_macro_f1=0.9098 val_weighted_f1=0.985427658257253 val_pr_auc=0.9035 val_auc=0.9887lr=0.00002996
# fit------best threshold =  0.6286868686868686
# [EPOCH 017] train_loss=0.021823 val_loss=0.025745 val_f1_label1=0.8268 val_macro_f1=0.9096 val_weighted_f1=0.98536403579652 val_pr_auc=0.9039 val_auc=0.9887lr=0.00002996
# fit------best threshold =  0.5890909090909091
# [EPOCH 018] train_loss=0.021171 val_loss=0.025841 val_f1_label1=0.8243 val_macro_f1=0.9082 val_weighted_f1=0.9849650550712453 val_pr_auc=0.9031 val_auc=0.9886lr=0.00002995
# fit------best threshold =  0.598989898989899
# [EPOCH 019] train_loss=0.021313 val_loss=0.026060 val_f1_label1=0.8246 val_macro_f1=0.9083 val_weighted_f1=0.9849866604073763 val_pr_auc=0.9033 val_auc=0.9887lr=0.00002994
# fit------best threshold =  0.6336363636363637
# [EPOCH 020] train_loss=0.021090 val_loss=0.026311 val_f1_label1=0.8236 val_macro_f1=0.9079 val_weighted_f1=0.9850957565122923 val_pr_auc=0.9023 val_auc=0.9882lr=0.00002993
# [INFO] Early stopping at epoch=20, best_epoch=5
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.6633
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9854938491075873, 'macro_precision': 0.9160782863904986, 'macro_recall': 0.9032045796919301, 'macro_f1': 0.9095295673229209, 'weighted_precision': 0.9852858731467642, 'weighted_recall': 0.9854938491075873, 'weighted_f1': 0.9853798800876046, 'precision_label1': 0.8404377880184332, 'recall_label1': 0.8132664437012264, 'f1_label1': 0.826628895184136, 'auc': 0.9897702909520988, 'pr_auc': 0.9050084969426753, 'per_class_f1': {'0': 0.9924302394617059, '1': 0.826628895184136}, 'confusion_matrix': [[40118, 277], [335, 1459]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6633333333333333}
#
# ========== STAGE2 THRESHOLD ORACLE DIAGNOSIS ==========
# [VAL ORACLE THRESHOLD] 0.663333
# [VAL ORACLE METRICS] {'accuracy': 0.9854938491075873, 'macro_precision': 0.9160782863904986, 'macro_recall': 0.9032045796919301, 'macro_f1': 0.9095295673229209, 'weighted_precision': 0.9852858731467642, 'weighted_recall': 0.9854938491075873, 'weighted_f1': 0.9853798800876046, 'precision_label1': 0.8404377880184332, 'recall_label1': 0.8132664437012264, 'f1_label1': 0.826628895184136, 'auc': 0.9897707463215464, 'pr_auc': 0.9049999664401562, 'per_class_f1': {'0': 0.9924302394617059, '1': 0.826628895184136}, 'confusion_matrix': [[40118, 277], [335, 1459]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6633333333333333}
#
# [TEST AT VAL THRESHOLD] 0.663333
# [TEST AT VAL THRESHOLD METRICS] {'accuracy': 0.9828987911827447, 'macro_precision': 0.8880865606698118, 'macro_recall': 0.9020876079306546, 'macro_f1': 0.8949493840135432, 'weighted_precision': 0.9832260098727885, 'weighted_recall': 0.9828987911827447, 'weighted_f1': 0.9830502965016084, 'precision_label1': 0.7842868874897345, 'recall_label1': 0.8139204545454546, 'f1_label1': 0.7988289418653283, 'auc': 0.9893607111337215, 'pr_auc': 0.8775524848529231, 'per_class_f1': {'0': 0.9910698261617581, '1': 0.7988289418653283}, 'confusion_matrix': [[80072, 788], [655, 2865]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6633333333333333}
#
# [TEST ORACLE THRESHOLD - DIAGNOSTIC ONLY] 0.663333
# [TEST ORACLE METRICS] {'accuracy': 0.9828987911827447, 'macro_precision': 0.8880865606698118, 'macro_recall': 0.9020876079306546, 'macro_f1': 0.8949493840135432, 'weighted_precision': 0.9832260098727885, 'weighted_recall': 0.9828987911827447, 'weighted_f1': 0.9830502965016084, 'precision_label1': 0.7842868874897345, 'recall_label1': 0.8139204545454546, 'f1_label1': 0.7988289418653283, 'auc': 0.9893607111337215, 'pr_auc': 0.8775524848529231, 'per_class_f1': {'0': 0.9910698261617581, '1': 0.7988289418653283}, 'confusion_matrix': [[80072, 788], [655, 2865]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6633333333333333}
#
# [THRESHOLD TRANSFER GAP] 0.000000
# =======================================================
#
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/endpoint_newM/ws128/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/endpoint_newM/ws128/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/endpoint_newM/ws128/stage2_predictions_test.csv
#
# ==================================================
#             Stage2 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0317
#   F1 (Macro):        0.8949
#   Recall (Macro):    0.9021
#   Precision (Macro): 0.8881
#   F1_class1:         0.7988
#   R1_class1:         0.8139
#   P1_class1:         0.7843
#   AUC (OvR Macro):   0.9894
#   PR_AUC:            0.8776
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9911
#   Class_1                       : 0.7988
#
# [TEST] Full metrics: {'accuracy': 0.9828987911827447, 'macro_precision': 0.8880865606698118, 'macro_recall': 0.9020876079306546, 'macro_f1': 0.8949493840135432, 'weighted_precision': 0.9832260098727885, 'weighted_recall': 0.9828987911827447, 'weighted_f1': 0.9830502965016084, 'precision_label1': 0.7842868874897345, 'recall_label1': 0.8139204545454546, 'f1_label1': 0.7988289418653283, 'auc': 0.9893604968182943, 'pr_auc': 0.8775690908094399, 'per_class_f1': {'0': 0.9910698261617581, '1': 0.7988289418653283}, 'confusion_matrix': [[80072, 788], [655, 2865]], 'num_classes': 2, 'num_samples': 84380, 'loss': 0.03174725686052119, 'threshold': 0.6633333333333333, 'positive_count': 3520, 'positive_rate': 0.041716046456506284}
# [INFO] saved summary: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/endpoint_newM/ws128/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/endpoint_newM/ws128

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws64 \
  --context_method source_host \
  --context_policy online \
  --window_size 64 \
  --model_type target_query_gated \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: source_host, window_size: 64, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [array([0]), array([1]), array([2])]
#
# [Context Diagnostics] by split:
#           count       mean        std  min   50%   90%   95%   max
# split
# test    84380.0  51.957893  21.295111  0.0  63.0  63.0  63.0  63.0
# train  295329.0  43.601705  25.760844  0.0  63.0  63.0  63.0  63.0
# val     42189.0  51.143260  21.969256  0.0  63.0  63.0  63.0  63.0
#
# [Context Diagnostics] by split and label:
#                 count       mean        std  min   50%   90%   95%   max
# split label
# test  0       80860.0  51.625649  21.514954  0.0  63.0  63.0  63.0  63.0
#       1        3520.0  59.590057  13.287276  0.0  63.0  63.0  63.0  63.0
# train 0      283999.0  43.189427  25.900253  0.0  63.0  63.0  63.0  63.0
#       1       11330.0  53.935922  19.289177  0.0  63.0  63.0  63.0  63.0
# val   0       40395.0  50.795990  22.185318  0.0  63.0  63.0  63.0  63.0
#       1        1794.0  58.962653  14.286224  0.0  63.0  63.0  63.0  63.0
#
# [Context no-history rate] by split and label:
# split  label
# test   0        0.022298
#        1        0.015909
# train  0        0.065166
#        1        0.035305
# val    0        0.024756
#        1        0.018952
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] context lengths: min=1, mean=47.03, p50=64.0, p95=64.0, max=64
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = target_query_gated
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Stage2TargetQueryGatedAttention.__init__ use_positional_encoding=True, position_mode=age, nhead=4, dim_feedforward=256, dropout=0.25, cls_head_config=1
# Stage2TargetQueryGatedAttention(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
#   (query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (attn_dropout): Dropout(p=0.25, inplace=False)
#   (context_update): Sequential(
#     (0): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=384, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (gate): Sequential(
#     (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=512, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): Sigmoid()
#   )
#   (fused_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (final_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] make_train_loader: n0=283999, n1=11330, target_pos_frac=0.080, w0=3.23945e-06, w1=7.0609e-06, sample_weights=[3.23944803e-06 3.23944803e-06 3.23944803e-06 ... 7.06090026e-06
#  3.23944803e-06 3.23944803e-06]
# [INFO]---trainer.py---make_loss_fn---label 分布: [283999.  11330.]
# [INFO]manual_alpha = [1.0, 1.05]
# [INFO] Using manual alpha: [1.0, 1.05]
# [INFO] Using FocalLoss: gamma=1.0, label_smoothing=0.0
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit lr=3e-05, weight_decay=0.0003, patience=15, threshold=0.5, metric_for_best=pr_auc
# fit------best threshold =  0.6187878787878788
# [EPOCH 001] train_loss=0.176079 val_loss=0.027351 val_f1_label1=0.8099 val_macro_f1=0.9007 val_weighted_f1=0.9838820751692907 val_pr_auc=0.8742 val_auc=0.9877lr=0.00000720 *
# fit------best threshold =  0.6583838383838384
# [EPOCH 002] train_loss=0.033982 val_loss=0.024236 val_f1_label1=0.8239 val_macro_f1=0.9081 val_weighted_f1=0.9852193273523534 val_pr_auc=0.9019 val_auc=0.9900lr=0.00001290 *
# fit------best threshold =  0.6880808080808081
# [EPOCH 003] train_loss=0.029593 val_loss=0.025084 val_f1_label1=0.8265 val_macro_f1=0.9095 val_weighted_f1=0.985437298753922 val_pr_auc=0.9068 val_auc=0.9911lr=0.00001860 *
# fit------best threshold =  0.702929292929293
# [EPOCH 004] train_loss=0.026588 val_loss=0.024790 val_f1_label1=0.8274 val_macro_f1=0.9100 val_weighted_f1=0.985596804880268 val_pr_auc=0.9096 val_auc=0.9916lr=0.00002430 *
# fit------best threshold =  0.6534343434343434
# [EPOCH 005] train_loss=0.024601 val_loss=0.024131 val_f1_label1=0.8316 val_macro_f1=0.9121 val_weighted_f1=0.9857041664845053 val_pr_auc=0.9122 val_auc=0.9918lr=0.00003000 *
# fit------best threshold =  0.6682828282828283
# [EPOCH 006] train_loss=0.023646 val_loss=0.024060 val_f1_label1=0.8308 val_macro_f1=0.9117 val_weighted_f1=0.9857464960100382 val_pr_auc=0.9126 val_auc=0.9918lr=0.00003000 *
# fit------best threshold =  0.6435353535353535
# [EPOCH 007] train_loss=0.023099 val_loss=0.023218 val_f1_label1=0.8313 val_macro_f1=0.9120 val_weighted_f1=0.9857943265603399 val_pr_auc=0.9124 val_auc=0.9913lr=0.00003000
# fit------best threshold =  0.6583838383838384
# [EPOCH 008] train_loss=0.022586 val_loss=0.023943 val_f1_label1=0.8294 val_macro_f1=0.9110 val_weighted_f1=0.9856390001434759 val_pr_auc=0.9118 val_auc=0.9913lr=0.00003000
# fit------best threshold =  0.6187878787878788
# [EPOCH 009] train_loss=0.022213 val_loss=0.023703 val_f1_label1=0.8309 val_macro_f1=0.9117 val_weighted_f1=0.9856772350131275 val_pr_auc=0.9110 val_auc=0.9909lr=0.00003000
# fit------best threshold =  0.6138383838383838
# [EPOCH 010] train_loss=0.021904 val_loss=0.023064 val_f1_label1=0.8300 val_macro_f1=0.9113 val_weighted_f1=0.9856422810249572 val_pr_auc=0.9117 val_auc=0.9909lr=0.00002999
# fit------best threshold =  0.6534343434343434
# [EPOCH 011] train_loss=0.021702 val_loss=0.024982 val_f1_label1=0.8292 val_macro_f1=0.9108 val_weighted_f1=0.9855446134994648 val_pr_auc=0.9110 val_auc=0.9907lr=0.00002999
# fit------best threshold =  0.6187878787878788
# [EPOCH 012] train_loss=0.021179 val_loss=0.023476 val_f1_label1=0.8302 val_macro_f1=0.9114 val_weighted_f1=0.9856257727511314 val_pr_auc=0.9118 val_auc=0.9909lr=0.00002999
# fit------best threshold =  0.6286868686868686
# [EPOCH 013] train_loss=0.021351 val_loss=0.024006 val_f1_label1=0.8306 val_macro_f1=0.9116 val_weighted_f1=0.9856656248902039 val_pr_auc=0.9113 val_auc=0.9905lr=0.00002998
# fit------best threshold =  0.6088888888888889
# [EPOCH 014] train_loss=0.020856 val_loss=0.024024 val_f1_label1=0.8311 val_macro_f1=0.9118 val_weighted_f1=0.9856746572962952 val_pr_auc=0.9114 val_auc=0.9903lr=0.00002998
# fit------best threshold =  0.6781818181818181
# [EPOCH 015] train_loss=0.021099 val_loss=0.025636 val_f1_label1=0.8320 val_macro_f1=0.9124 val_weighted_f1=0.9858950885115991 val_pr_auc=0.9102 val_auc=0.9903lr=0.00002997
# fit------best threshold =  0.6237373737373737
# [EPOCH 016] train_loss=0.020812 val_loss=0.024920 val_f1_label1=0.8297 val_macro_f1=0.9111 val_weighted_f1=0.9855296821888152 val_pr_auc=0.9098 val_auc=0.9900lr=0.00002996
# fit------best threshold =  0.6385858585858586
# [EPOCH 017] train_loss=0.020643 val_loss=0.025040 val_f1_label1=0.8314 val_macro_f1=0.9120 val_weighted_f1=0.9857209663090709 val_pr_auc=0.9106 val_auc=0.9902lr=0.00002996
# fit------best threshold =  0.6484848484848484
# [EPOCH 018] train_loss=0.019826 val_loss=0.025010 val_f1_label1=0.8308 val_macro_f1=0.9117 val_weighted_f1=0.985760634076175 val_pr_auc=0.9106 val_auc=0.9904lr=0.00002995
# fit------best threshold =  0.6286868686868686
# [EPOCH 019] train_loss=0.020088 val_loss=0.024579 val_f1_label1=0.8312 val_macro_f1=0.9119 val_weighted_f1=0.9857029548094796 val_pr_auc=0.9104 val_auc=0.9903lr=0.00002994
# fit------best threshold =  0.5890909090909091
# [EPOCH 020] train_loss=0.019909 val_loss=0.025185 val_f1_label1=0.8316 val_macro_f1=0.9120 val_weighted_f1=0.9855182603773803 val_pr_auc=0.9099 val_auc=0.9898lr=0.00002993
# fit------best threshold =  0.6286868686868686
# [EPOCH 021] train_loss=0.019707 val_loss=0.026602 val_f1_label1=0.8313 val_macro_f1=0.9119 val_weighted_f1=0.9855702240086236 val_pr_auc=0.9098 val_auc=0.9899lr=0.00002992
# [INFO] Early stopping at epoch=21, best_epoch=6
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.6683
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9858730948825524, 'macro_precision': 0.9192314006423195, 'macro_recall': 0.9044679401280251, 'macro_f1': 0.911703419071809, 'weighted_precision': 0.9856459835397771, 'weighted_recall': 0.9858730948825524, 'weighted_f1': 0.9857464960100382, 'precision_label1': 0.8466435185185185, 'recall_label1': 0.8154960981047937, 'f1_label1': 0.8307779670641681, 'auc': 0.9917891231005747, 'pr_auc': 0.9126435602044154, 'per_class_f1': {'0': 0.9926288710794499, '1': 0.8307779670641681}, 'confusion_matrix': [[40130, 265], [331, 1463]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6682828282828283}
#
# ========== STAGE2 THRESHOLD ORACLE DIAGNOSIS ==========
# [VAL ORACLE THRESHOLD] 0.668283
# [VAL ORACLE METRICS] {'accuracy': 0.9858730948825524, 'macro_precision': 0.9192314006423195, 'macro_recall': 0.9044679401280251, 'macro_f1': 0.911703419071809, 'weighted_precision': 0.9856459835397771, 'weighted_recall': 0.9858730948825524, 'weighted_f1': 0.9857464960100382, 'precision_label1': 0.8466435185185185, 'recall_label1': 0.8154960981047937, 'f1_label1': 0.8307779670641681, 'auc': 0.9917888333200173, 'pr_auc': 0.9126424347294314, 'per_class_f1': {'0': 0.9926288710794499, '1': 0.8307779670641681}, 'confusion_matrix': [[40130, 265], [331, 1463]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6682828282828283}
#
# [TEST AT VAL THRESHOLD] 0.668283
# [TEST AT VAL THRESHOLD METRICS] {'accuracy': 0.9827565773880066, 'macro_precision': 0.8868019953656014, 'macro_recall': 0.9020134056056484, 'macro_f1': 0.8942448374026941, 'weighted_precision': 0.9831177302599923, 'weighted_recall': 0.9827565773880066, 'weighted_f1': 0.9829228342996963, 'precision_label1': 0.781718963165075, 'recall_label1': 0.8139204545454546, 'f1_label1': 0.7974947807933194, 'auc': 0.9898279820059361, 'pr_auc': 0.8811089802892486, 'per_class_f1': {'0': 0.9909948940120687, '1': 0.7974947807933194}, 'confusion_matrix': [[80060, 800], [655, 2865]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6682828282828283}
#
# [TEST ORACLE THRESHOLD - DIAGNOSTIC ONLY] 0.697980
# [TEST ORACLE METRICS] {'accuracy': 0.9832661768191514, 'macro_precision': 0.8959853784845891, 'macro_recall': 0.8942634435500191, 'macro_f1': 0.8951223332762083, 'weighted_precision': 0.9832300786758087, 'weighted_recall': 0.9832661768191514, 'weighted_f1': 0.9832479455055276, 'precision_label1': 0.8007990867579908, 'recall_label1': 0.7971590909090909, 'f1_label1': 0.7989749430523918, 'auc': 0.9898279820059361, 'pr_auc': 0.8811089802892486, 'per_class_f1': {'0': 0.9912697235000247, '1': 0.7989749430523918}, 'confusion_matrix': [[80162, 698], [714, 2806]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6979797979797979}
#
# [THRESHOLD TRANSFER GAP] 0.001480
# =======================================================
#
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws64/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws64/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws64/stage2_predictions_test.csv
#
# ==================================================
#             Stage2 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0316
#   F1 (Macro):        0.8942
#   Recall (Macro):    0.9020
#   Precision (Macro): 0.8868
#   F1_class1:         0.7975
#   R1_class1:         0.8139
#   P1_class1:         0.7817
#   AUC (OvR Macro):   0.9898
#   PR_AUC:            0.8811
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9910
#   Class_1                       : 0.7975
#
# [TEST] Full metrics: {'accuracy': 0.9827565773880066, 'macro_precision': 0.8868019953656014, 'macro_recall': 0.9020134056056484, 'macro_f1': 0.8942448374026941, 'weighted_precision': 0.9831177302599923, 'weighted_recall': 0.9827565773880066, 'weighted_f1': 0.9829228342996963, 'precision_label1': 0.781718963165075, 'recall_label1': 0.8139204545454546, 'f1_label1': 0.7974947807933194, 'auc': 0.9898280856502821, 'pr_auc': 0.8811219577953415, 'per_class_f1': {'0': 0.9909948940120687, '1': 0.7974947807933194}, 'confusion_matrix': [[80060, 800], [655, 2865]], 'num_classes': 2, 'num_samples': 84380, 'loss': 0.03161273336759939, 'threshold': 0.6682828282828283, 'positive_count': 3520, 'positive_rate': 0.041716046456506284}
# [INFO] saved summary: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws64/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws64

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws32 \
  --context_method source_host \
  --context_policy online \
  --window_size 32 \
  --model_type target_query_gated \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: source_host, window_size: 32, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [array([0]), array([1]), array([2])]
#
# [Context Diagnostics] by split:
#           count       mean        std  min   50%   90%   95%   max
# split
# test    84380.0  26.947867   9.177503  0.0  31.0  31.0  31.0  31.0
# train  295329.0  23.536693  11.809374  0.0  31.0  31.0  31.0  31.0
# val     42189.0  26.576975   9.543724  0.0  31.0  31.0  31.0  31.0
#
# [Context Diagnostics] by split and label:
#                 count       mean        std  min   50%   90%   95%   max
# split label
# test  0       80860.0  26.831820   9.274035  0.0  31.0  31.0  31.0  31.0
#       1        3520.0  29.613636   5.992146  0.0  31.0  31.0  31.0  31.0
# train 0      283999.0  23.361899  11.891854  0.0  31.0  31.0  31.0  31.0
#       1       11330.0  27.918094   8.396667  0.0  31.0  31.0  31.0  31.0
# val   0       40395.0  26.452308   9.639156  0.0  31.0  31.0  31.0  31.0
#       1        1794.0  29.384058   6.454197  0.0  31.0  31.0  31.0  31.0
#
# [Context no-history rate] by split and label:
# split  label
# test   0        0.022298
#        1        0.015909
# train  0        0.065166
#        1        0.035305
# val    0        0.024756
#        1        0.018952
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] context lengths: min=1, mean=25.52, p50=32.0, p95=32.0, max=32
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = target_query_gated
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Stage2TargetQueryGatedAttention.__init__ use_positional_encoding=True, position_mode=age, nhead=4, dim_feedforward=256, dropout=0.25, cls_head_config=1
# Stage2TargetQueryGatedAttention(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
#   (query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (attn_dropout): Dropout(p=0.25, inplace=False)
#   (context_update): Sequential(
#     (0): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=384, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (gate): Sequential(
#     (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=512, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): Sigmoid()
#   )
#   (fused_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (final_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] make_train_loader: n0=283999, n1=11330, target_pos_frac=0.080, w0=3.23945e-06, w1=7.0609e-06, sample_weights=[3.23944803e-06 3.23944803e-06 3.23944803e-06 ... 7.06090026e-06
#  3.23944803e-06 3.23944803e-06]
# [INFO]---trainer.py---make_loss_fn---label 分布: [283999.  11330.]
# [INFO]manual_alpha = [1.0, 1.05]
# [INFO] Using manual alpha: [1.0, 1.05]
# [INFO] Using FocalLoss: gamma=1.0, label_smoothing=0.0
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit lr=3e-05, weight_decay=0.0003, patience=15, threshold=0.5, metric_for_best=pr_auc
# fit------best threshold =  0.6237373737373737
# [EPOCH 001] train_loss=0.175605 val_loss=0.027349 val_f1_label1=0.8096 val_macro_f1=0.9006 val_weighted_f1=0.9839336198151548 val_pr_auc=0.8738 val_auc=0.9876lr=0.00000720 *
# fit------best threshold =  0.6682828282828283
# [EPOCH 002] train_loss=0.034061 val_loss=0.024552 val_f1_label1=0.8231 val_macro_f1=0.9077 val_weighted_f1=0.985135710149413 val_pr_auc=0.9017 val_auc=0.9900lr=0.00001290 *
# fit------best threshold =  0.6831313131313131
# [EPOCH 003] train_loss=0.029445 val_loss=0.025252 val_f1_label1=0.8264 val_macro_f1=0.9094 val_weighted_f1=0.9853956299200392 val_pr_auc=0.9064 val_auc=0.9911lr=0.00001860 *
# fit------best threshold =  0.6682828282828283
# [EPOCH 004] train_loss=0.026741 val_loss=0.025082 val_f1_label1=0.8282 val_macro_f1=0.9104 val_weighted_f1=0.985495235138737 val_pr_auc=0.9090 val_auc=0.9916lr=0.00002430 *
# fit------best threshold =  0.6682828282828283
# [EPOCH 005] train_loss=0.024822 val_loss=0.023854 val_f1_label1=0.8278 val_macro_f1=0.9102 val_weighted_f1=0.9855133424534878 val_pr_auc=0.9116 val_auc=0.9918lr=0.00003000 *
# fit------best threshold =  0.6781818181818181
# [EPOCH 006] train_loss=0.023583 val_loss=0.024205 val_f1_label1=0.8299 val_macro_f1=0.9113 val_weighted_f1=0.9856868701429977 val_pr_auc=0.9123 val_auc=0.9918lr=0.00003000 *
# fit------best threshold =  0.6682828282828283
# [EPOCH 007] train_loss=0.023052 val_loss=0.023620 val_f1_label1=0.8312 val_macro_f1=0.9120 val_weighted_f1=0.9858738766175018 val_pr_auc=0.9116 val_auc=0.9912lr=0.00003000
# fit------best threshold =  0.6633333333333333
# [EPOCH 008] train_loss=0.022600 val_loss=0.023849 val_f1_label1=0.8297 val_macro_f1=0.9112 val_weighted_f1=0.9857273757858519 val_pr_auc=0.9116 val_auc=0.9914lr=0.00003000
# fit------best threshold =  0.6088888888888889
# [EPOCH 009] train_loss=0.022160 val_loss=0.023567 val_f1_label1=0.8299 val_macro_f1=0.9112 val_weighted_f1=0.9855757576841613 val_pr_auc=0.9105 val_auc=0.9908lr=0.00003000
# fit------best threshold =  0.6138383838383838
# [EPOCH 010] train_loss=0.021993 val_loss=0.023001 val_f1_label1=0.8317 val_macro_f1=0.9122 val_weighted_f1=0.9858588616455894 val_pr_auc=0.9111 val_auc=0.9908lr=0.00002999
# fit------best threshold =  0.6484848484848484
# [EPOCH 011] train_loss=0.021834 val_loss=0.024423 val_f1_label1=0.8304 val_macro_f1=0.9115 val_weighted_f1=0.9856923939593422 val_pr_auc=0.9104 val_auc=0.9907lr=0.00002999
# fit------best threshold =  0.598989898989899
# [EPOCH 012] train_loss=0.021224 val_loss=0.023117 val_f1_label1=0.8311 val_macro_f1=0.9118 val_weighted_f1=0.9856463744668316 val_pr_auc=0.9114 val_auc=0.9909lr=0.00002999
# fit------best threshold =  0.6138383838383838
# [EPOCH 013] train_loss=0.021751 val_loss=0.024406 val_f1_label1=0.8311 val_macro_f1=0.9118 val_weighted_f1=0.9856219290474807 val_pr_auc=0.9098 val_auc=0.9901lr=0.00002998
# fit------best threshold =  0.6039393939393939
# [EPOCH 014] train_loss=0.020981 val_loss=0.024164 val_f1_label1=0.8304 val_macro_f1=0.9114 val_weighted_f1=0.9855950746426728 val_pr_auc=0.9102 val_auc=0.9901lr=0.00002998
# fit------best threshold =  0.6633333333333333
# [EPOCH 015] train_loss=0.021312 val_loss=0.025975 val_f1_label1=0.8315 val_macro_f1=0.9120 val_weighted_f1=0.985749296064709 val_pr_auc=0.9093 val_auc=0.9901lr=0.00002997
# fit------best threshold =  0.6732323232323232
# [EPOCH 016] train_loss=0.021018 val_loss=0.025228 val_f1_label1=0.8319 val_macro_f1=0.9124 val_weighted_f1=0.9859298852774967 val_pr_auc=0.9094 val_auc=0.9900lr=0.00002996
# fit------best threshold =  0.6484848484848484
# [EPOCH 017] train_loss=0.020886 val_loss=0.025240 val_f1_label1=0.8307 val_macro_f1=0.9117 val_weighted_f1=0.9857079984586378 val_pr_auc=0.9093 val_auc=0.9900lr=0.00002996
# fit------best threshold =  0.5890909090909091
# [EPOCH 018] train_loss=0.019965 val_loss=0.025288 val_f1_label1=0.8293 val_macro_f1=0.9108 val_weighted_f1=0.9853649918835476 val_pr_auc=0.9088 val_auc=0.9901lr=0.00002995
# fit------best threshold =  0.6088888888888889
# [EPOCH 019] train_loss=0.020266 val_loss=0.025077 val_f1_label1=0.8308 val_macro_f1=0.9116 val_weighted_f1=0.9855474976778074 val_pr_auc=0.9085 val_auc=0.9897lr=0.00002994
# fit------best threshold =  0.6336363636363637
# [EPOCH 020] train_loss=0.020076 val_loss=0.025177 val_f1_label1=0.8308 val_macro_f1=0.9117 val_weighted_f1=0.9857464960100382 val_pr_auc=0.9082 val_auc=0.9893lr=0.00002993
# fit------best threshold =  0.5890909090909091
# [EPOCH 021] train_loss=0.019734 val_loss=0.026590 val_f1_label1=0.8308 val_macro_f1=0.9115 val_weighted_f1=0.9853621875643339 val_pr_auc=0.9084 val_auc=0.9895lr=0.00002992
# [INFO] Early stopping at epoch=21, best_epoch=6
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.6782
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9858256891606817, 'macro_precision': 0.9194961326512961, 'macro_recall': 0.9033778684652932, 'macro_f1': 0.911262524287154, 'weighted_precision': 0.9855791681608791, 'weighted_recall': 0.9858256891606817, 'weighted_f1': 0.9856868701429977, 'precision_label1': 0.8472706155632985, 'recall_label1': 0.8132664437012264, 'f1_label1': 0.8299203640500569, 'auc': 0.9918064409386517, 'pr_auc': 0.9122875118148617, 'per_class_f1': {'0': 0.9926046845242512, '1': 0.8299203640500569}, 'confusion_matrix': [[40132, 263], [335, 1459]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6781818181818181}
#
# ========== STAGE2 THRESHOLD ORACLE DIAGNOSIS ==========
# [VAL ORACLE THRESHOLD] 0.678182
# [VAL ORACLE METRICS] {'accuracy': 0.9858256891606817, 'macro_precision': 0.9194961326512961, 'macro_recall': 0.9033778684652932, 'macro_f1': 0.911262524287154, 'weighted_precision': 0.9855791681608791, 'weighted_recall': 0.9858256891606817, 'weighted_f1': 0.9856868701429977, 'precision_label1': 0.8472706155632985, 'recall_label1': 0.8132664437012264, 'f1_label1': 0.8299203640500569, 'auc': 0.9918062132539279, 'pr_auc': 0.9122822477643192, 'per_class_f1': {'0': 0.9926046845242512, '1': 0.8299203640500569}, 'confusion_matrix': [[40132, 263], [335, 1459]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6781818181818181}
#
# [TEST AT VAL THRESHOLD] 0.678182
# [TEST AT VAL THRESHOLD METRICS] {'accuracy': 0.9830528561270443, 'macro_precision': 0.8900727460487357, 'macro_recall': 0.9010810983630517, 'macro_f1': 0.8954919465137829, 'weighted_precision': 0.9833035933424191, 'weighted_recall': 0.9830528561270443, 'weighted_f1': 0.9831707588485702, 'precision_label1': 0.7883554083885209, 'recall_label1': 0.8116477272727273, 'f1_label1': 0.7998320268756999, 'auc': 0.9903927154537585, 'pr_auc': 0.8834044305122036, 'per_class_f1': {'0': 0.9911518661518661, '1': 0.7998320268756999}, 'confusion_matrix': [[80093, 767], [663, 2857]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6781818181818181}
#
# [TEST ORACLE THRESHOLD - DIAGNOSTIC ONLY] 0.678182
# [TEST ORACLE METRICS] {'accuracy': 0.9830528561270443, 'macro_precision': 0.8900727460487357, 'macro_recall': 0.9010810983630517, 'macro_f1': 0.8954919465137829, 'weighted_precision': 0.9833035933424191, 'weighted_recall': 0.9830528561270443, 'weighted_f1': 0.9831707588485702, 'precision_label1': 0.7883554083885209, 'recall_label1': 0.8116477272727273, 'f1_label1': 0.7998320268756999, 'auc': 0.9903927154537585, 'pr_auc': 0.8834044305122036, 'per_class_f1': {'0': 0.9911518661518661, '1': 0.7998320268756999}, 'confusion_matrix': [[80093, 767], [663, 2857]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6781818181818181}
#
# [THRESHOLD TRANSFER GAP] 0.000000
# =======================================================
#
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws32/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws32/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws32/stage2_predictions_test.csv
#
# ==================================================
#             Stage2 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0312
#   F1 (Macro):        0.8955
#   Recall (Macro):    0.9011
#   Precision (Macro): 0.8901
#   F1_class1:         0.7998
#   R1_class1:         0.8116
#   P1_class1:         0.7884
#   AUC (OvR Macro):   0.9904
#   PR_AUC:            0.8834
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9912
#   Class_1                       : 0.7998
#
# [TEST] Full metrics: {'accuracy': 0.9830528561270443, 'macro_precision': 0.8900727460487357, 'macro_recall': 0.9010810983630517, 'macro_f1': 0.8954919465137829, 'weighted_precision': 0.9833035933424191, 'weighted_recall': 0.9830528561270443, 'weighted_f1': 0.9831707588485702, 'precision_label1': 0.7883554083885209, 'recall_label1': 0.8116477272727273, 'f1_label1': 0.7998320268756999, 'auc': 0.9903926961302363, 'pr_auc': 0.8834167214073265, 'per_class_f1': {'0': 0.9911518661518661, '1': 0.7998320268756999}, 'confusion_matrix': [[80093, 767], [663, 2857]], 'num_classes': 2, 'num_samples': 84380, 'loss': 0.03121184423703499, 'threshold': 0.6781818181818181, 'positive_count': 3520, 'positive_rate': 0.041716046456506284}
# [INFO] saved summary: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws32/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws32

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws16 \
  --context_method source_host \
  --context_policy online \
  --window_size 16 \
  --model_type target_query_gated \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: source_host, window_size: 16, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [array([0]), array([1]), array([2])]
#
# [Context Diagnostics] by split:
#           count       mean       std  min   50%   90%   95%   max
# split
# test    84380.0  13.635269  3.784058  0.0  15.0  15.0  15.0  15.0
# train  295329.0  12.239851  5.189272  0.0  15.0  15.0  15.0  15.0
# val     42189.0  13.492095  3.957225  0.0  15.0  15.0  15.0  15.0
#
# [Context Diagnostics] by split and label:
#                 count       mean       std  min   50%   90%   95%   max
# split label
# test  0       80860.0  13.600012  3.823507  0.0  15.0  15.0  15.0  15.0
#       1        3520.0  14.445170  2.596663  0.0  15.0  15.0  15.0  15.0
# train 0      283999.0  12.174536  5.231010  0.0  15.0  15.0  15.0  15.0
#       1       11330.0  13.877052  3.638775  0.0  15.0  15.0  15.0  15.0
# val   0       40395.0  13.454091  3.996618  0.0  15.0  15.0  15.0  15.0
#       1        1794.0  14.347826  2.800780  0.0  15.0  15.0  15.0  15.0
#
# [Context no-history rate] by split and label:
# split  label
# test   0        0.022298
#        1        0.015909
# train  0        0.065166
#        1        0.035305
# val    0        0.024756
#        1        0.018952
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] context lengths: min=1, mean=13.64, p50=16.0, p95=16.0, max=16
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = target_query_gated
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Stage2TargetQueryGatedAttention.__init__ use_positional_encoding=True, position_mode=age, nhead=4, dim_feedforward=256, dropout=0.25, cls_head_config=1
# Stage2TargetQueryGatedAttention(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
#   (query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (attn_dropout): Dropout(p=0.25, inplace=False)
#   (context_update): Sequential(
#     (0): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=384, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (gate): Sequential(
#     (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=512, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): Sigmoid()
#   )
#   (fused_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (final_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] make_train_loader: n0=283999, n1=11330, target_pos_frac=0.080, w0=3.23945e-06, w1=7.0609e-06, sample_weights=[3.23944803e-06 3.23944803e-06 3.23944803e-06 ... 7.06090026e-06
#  3.23944803e-06 3.23944803e-06]
# [INFO]---trainer.py---make_loss_fn---label 分布: [283999.  11330.]
# [INFO]manual_alpha = [1.0, 1.05]
# [INFO] Using manual alpha: [1.0, 1.05]
# [INFO] Using FocalLoss: gamma=1.0, label_smoothing=0.0
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit lr=3e-05, weight_decay=0.0003, patience=15, threshold=0.5, metric_for_best=pr_auc
# fit------best threshold =  0.6187878787878788
# [EPOCH 001] train_loss=0.178096 val_loss=0.027302 val_f1_label1=0.8109 val_macro_f1=0.9013 val_weighted_f1=0.9839858452021533 val_pr_auc=0.8736 val_auc=0.9876lr=0.00000720 *
# fit------best threshold =  0.6534343434343434
# [EPOCH 002] train_loss=0.034140 val_loss=0.024545 val_f1_label1=0.8240 val_macro_f1=0.9082 val_weighted_f1=0.9851628495210021 val_pr_auc=0.9014 val_auc=0.9899lr=0.00001290 *
# fit------best threshold =  0.693030303030303
# [EPOCH 003] train_loss=0.029553 val_loss=0.025500 val_f1_label1=0.8251 val_macro_f1=0.9088 val_weighted_f1=0.9853291154451522 val_pr_auc=0.9055 val_auc=0.9906lr=0.00001860 *
# fit------best threshold =  0.6880808080808081
# [EPOCH 004] train_loss=0.026935 val_loss=0.025132 val_f1_label1=0.8272 val_macro_f1=0.9099 val_weighted_f1=0.9855410169313189 val_pr_auc=0.9071 val_auc=0.9910lr=0.00002430 *
# fit------best threshold =  0.6732323232323232
# [EPOCH 005] train_loss=0.025007 val_loss=0.024102 val_f1_label1=0.8281 val_macro_f1=0.9103 val_weighted_f1=0.9856111774883046 val_pr_auc=0.9091 val_auc=0.9912lr=0.00003000 *
# fit------best threshold =  0.6336363636363637
# [EPOCH 006] train_loss=0.023946 val_loss=0.024600 val_f1_label1=0.8264 val_macro_f1=0.9093 val_weighted_f1=0.985197388990316 val_pr_auc=0.9094 val_auc=0.9913lr=0.00003000 *
# fit------best threshold =  0.6633333333333333
# [EPOCH 007] train_loss=0.023228 val_loss=0.024121 val_f1_label1=0.8285 val_macro_f1=0.9105 val_weighted_f1=0.985627256206387 val_pr_auc=0.9088 val_auc=0.9906lr=0.00003000
# fit------best threshold =  0.6583838383838384
# [EPOCH 008] train_loss=0.022797 val_loss=0.024337 val_f1_label1=0.8273 val_macro_f1=0.9100 val_weighted_f1=0.9855450616269665 val_pr_auc=0.9087 val_auc=0.9908lr=0.00003000
# fit------best threshold =  0.6286868686868686
# [EPOCH 009] train_loss=0.022361 val_loss=0.024101 val_f1_label1=0.8279 val_macro_f1=0.9102 val_weighted_f1=0.9854694007701341 val_pr_auc=0.9083 val_auc=0.9904lr=0.00003000
# fit------best threshold =  0.6187878787878788
# [EPOCH 010] train_loss=0.022111 val_loss=0.023363 val_f1_label1=0.8284 val_macro_f1=0.9105 val_weighted_f1=0.9855752317355652 val_pr_auc=0.9089 val_auc=0.9904lr=0.00002999
# fit------best threshold =  0.6534343434343434
# [EPOCH 011] train_loss=0.021975 val_loss=0.025559 val_f1_label1=0.8268 val_macro_f1=0.9096 val_weighted_f1=0.98536403579652 val_pr_auc=0.9076 val_auc=0.9900lr=0.00002999
# fit------best threshold =  0.6138383838383838
# [EPOCH 012] train_loss=0.021538 val_loss=0.023630 val_f1_label1=0.8288 val_macro_f1=0.9107 val_weighted_f1=0.9855188395291079 val_pr_auc=0.9094 val_auc=0.9904lr=0.00002999
# fit------best threshold =  0.6435353535353535
# [EPOCH 013] train_loss=0.021935 val_loss=0.024525 val_f1_label1=0.8273 val_macro_f1=0.9099 val_weighted_f1=0.985507262533801 val_pr_auc=0.9077 val_auc=0.9897lr=0.00002998
# fit------best threshold =  0.6435353535353535
# [EPOCH 014] train_loss=0.021156 val_loss=0.024858 val_f1_label1=0.8287 val_macro_f1=0.9107 val_weighted_f1=0.9856492886294156 val_pr_auc=0.9075 val_auc=0.9894lr=0.00002998
# fit------best threshold =  0.7078787878787879
# [EPOCH 015] train_loss=0.021541 val_loss=0.026057 val_f1_label1=0.8288 val_macro_f1=0.9108 val_weighted_f1=0.9857775043560317 val_pr_auc=0.9079 val_auc=0.9898lr=0.00002997
# fit------best threshold =  0.6583838383838384
# [EPOCH 016] train_loss=0.021312 val_loss=0.025529 val_f1_label1=0.8277 val_macro_f1=0.9101 val_weighted_f1=0.9855332638362686 val_pr_auc=0.9067 val_auc=0.9893lr=0.00002996
# fit------best threshold =  0.6237373737373737
# [EPOCH 017] train_loss=0.020983 val_loss=0.025405 val_f1_label1=0.8285 val_macro_f1=0.9104 val_weighted_f1=0.9854169118939217 val_pr_auc=0.9070 val_auc=0.9893lr=0.00002996
# fit------best threshold =  0.594040404040404
# [EPOCH 018] train_loss=0.020105 val_loss=0.025555 val_f1_label1=0.8262 val_macro_f1=0.9092 val_weighted_f1=0.9851042387640966 val_pr_auc=0.9071 val_auc=0.9897lr=0.00002995
# fit------best threshold =  0.6088888888888889
# [EPOCH 019] train_loss=0.020567 val_loss=0.025521 val_f1_label1=0.8260 val_macro_f1=0.9091 val_weighted_f1=0.98510644953766 val_pr_auc=0.9071 val_auc=0.9895lr=0.00002994
# fit------best threshold =  0.5890909090909091
# [EPOCH 020] train_loss=0.020417 val_loss=0.025410 val_f1_label1=0.8289 val_macro_f1=0.9106 val_weighted_f1=0.9853217449657041 val_pr_auc=0.9067 val_auc=0.9889lr=0.00002993
# fit------best threshold =  0.598989898989899
# [EPOCH 021] train_loss=0.019960 val_loss=0.026796 val_f1_label1=0.8278 val_macro_f1=0.9100 val_weighted_f1=0.9851655990321323 val_pr_auc=0.9066 val_auc=0.9890lr=0.00002992
# [INFO] Early stopping at epoch=21, best_epoch=6
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.6336
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9851620090544929, 'macro_precision': 0.9073833834651457, 'macro_recall': 0.911287490877087, 'macro_f1': 0.909325116617981, 'weighted_precision': 0.9852346145392903, 'weighted_recall': 0.9851620090544929, 'weighted_f1': 0.985197388990316, 'precision_label1': 0.8222958057395143, 'recall_label1': 0.830546265328874, 'f1_label1': 0.8264004437049363, 'auc': 0.9912560234683614, 'pr_auc': 0.9094516742225537, 'per_class_f1': {'0': 0.9922497895310256, '1': 0.8264004437049363}, 'confusion_matrix': [[40073, 322], [304, 1490]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6336363636363637}
#
# ========== STAGE2 THRESHOLD ORACLE DIAGNOSIS ==========
# [VAL ORACLE THRESHOLD] 0.633636
# [VAL ORACLE METRICS] {'accuracy': 0.9851620090544929, 'macro_precision': 0.9073833834651457, 'macro_recall': 0.911287490877087, 'macro_f1': 0.909325116617981, 'weighted_precision': 0.9852346145392903, 'weighted_recall': 0.9851620090544929, 'weighted_f1': 0.985197388990316, 'precision_label1': 0.8222958057395143, 'recall_label1': 0.830546265328874, 'f1_label1': 0.8264004437049363, 'auc': 0.9912556094961364, 'pr_auc': 0.9094444500670823, 'per_class_f1': {'0': 0.9922497895310256, '1': 0.8264004437049363}, 'confusion_matrix': [[40073, 322], [304, 1490]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6336363636363637}
#
# [TEST AT VAL THRESHOLD] 0.633636
# [TEST AT VAL THRESHOLD METRICS] {'accuracy': 0.9823180848542309, 'macro_precision': 0.8783933061211819, 'macro_recall': 0.9111590880983967, 'macro_f1': 0.8940192473465869, 'weighted_precision': 0.983185253803242, 'weighted_recall': 0.9823180848542309, 'weighted_f1': 0.9826849457735043, 'precision_label1': 0.7640625, 'recall_label1': 0.8335227272727272, 'f1_label1': 0.7972826086956522, 'auc': 0.9903322995834551, 'pr_auc': 0.8824822561404417, 'per_class_f1': {'0': 0.9907558859975217, '1': 0.7972826086956522}, 'confusion_matrix': [[79954, 906], [586, 2934]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6336363636363637}
#
# [TEST ORACLE THRESHOLD - DIAGNOSTIC ONLY] 0.673232
# [TEST ORACLE METRICS] {'accuracy': 0.9830291538279213, 'macro_precision': 0.889708773635596, 'macro_recall': 0.9013404551638073, 'macro_f1': 0.895429720950419, 'weighted_precision': 0.9832953686054409, 'weighted_recall': 0.9830291538279213, 'weighted_f1': 0.9831539231871926, 'precision_label1': 0.7876033057851239, 'recall_label1': 0.8122159090909091, 'f1_label1': 0.7997202797202797, 'auc': 0.9903322995834551, 'pr_auc': 0.8824822561404417, 'per_class_f1': {'0': 0.9911391621805581, '1': 0.7997202797202797}, 'confusion_matrix': [[80089, 771], [661, 2859]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6732323232323232}
#
# [THRESHOLD TRANSFER GAP] 0.002438
# =======================================================
#
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws16/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws16/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws16/stage2_predictions_test.csv
#
# ==================================================
#             Stage2 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0312
#   F1 (Macro):        0.8940
#   Recall (Macro):    0.9112
#   Precision (Macro): 0.8784
#   F1_class1:         0.7973
#   R1_class1:         0.8335
#   P1_class1:         0.7641
#   AUC (OvR Macro):   0.9903
#   PR_AUC:            0.8825
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9908
#   Class_1                       : 0.7973
#
# [TEST] Full metrics: {'accuracy': 0.9823180848542309, 'macro_precision': 0.8783933061211819, 'macro_recall': 0.9111590880983967, 'macro_f1': 0.8940192473465869, 'weighted_precision': 0.983185253803242, 'weighted_recall': 0.9823180848542309, 'weighted_f1': 0.9826849457735043, 'precision_label1': 0.7640625, 'recall_label1': 0.8335227272727272, 'f1_label1': 0.7972826086956522, 'auc': 0.9903322872866683, 'pr_auc': 0.8824929919628437, 'per_class_f1': {'0': 0.9907558859975217, '1': 0.7972826086956522}, 'confusion_matrix': [[79954, 906], [586, 2934]], 'num_classes': 2, 'num_samples': 84380, 'loss': 0.031193484015220655, 'threshold': 0.6336363636363637, 'positive_count': 3520, 'positive_rate': 0.041716046456506284}
# [INFO] saved summary: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws16/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws16

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws256 \
  --context_method source_host \
  --context_policy online \
  --window_size 256 \
  --model_type target_query_gated \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: source_host, window_size: 256, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [array([0]), array([1]), array([2])]
#
# [Context Diagnostics] by split:
#           count        mean         std  min    50%    90%    95%    max
# split
# test    84380.0  181.984854  101.838499  0.0  255.0  255.0  255.0  255.0
# train  295329.0  126.913161  106.819337  0.0  106.0  255.0  255.0  255.0
# val     42189.0  174.628126  103.023715  0.0  255.0  255.0  255.0  255.0
#
# [Context Diagnostics] by split and label:
#                 count        mean         std  min    50%    90%    95%    max
# split label
# test  0       80860.0  180.046686  102.603530  0.0  255.0  255.0  255.0  255.0
#       1        3520.0  226.507670   68.636921  0.0  255.0  255.0  255.0  255.0
# train 0      283999.0  125.298973  106.879271  0.0  102.0  255.0  255.0  255.0
#       1       11330.0  167.374581   96.890245  0.0  215.0  255.0  255.0  255.0
# val   0       40395.0  172.818641  103.713432  0.0  255.0  255.0  255.0  255.0
#       1        1794.0  215.371795   75.317306  0.0  255.0  255.0  255.0  255.0
#
# [Context no-history rate] by split and label:
# split  label
# test   0        0.022298
#        1        0.015909
# train  0        0.065166
#        1        0.035305
# val    0        0.024756
#        1        0.018952
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] context lengths: min=1, mean=143.70, p50=156.0, p95=256.0, max=256
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = target_query_gated
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Stage2TargetQueryGatedAttention.__init__ use_positional_encoding=True, position_mode=age, nhead=4, dim_feedforward=256, dropout=0.25, cls_head_config=1
# Stage2TargetQueryGatedAttention(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
#   (query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (attn_dropout): Dropout(p=0.25, inplace=False)
#   (context_update): Sequential(
#     (0): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=384, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (gate): Sequential(
#     (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=512, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): Sigmoid()
#   )
#   (fused_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (final_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] make_train_loader: n0=283999, n1=11330, target_pos_frac=0.080, w0=3.23945e-06, w1=7.0609e-06, sample_weights=[3.23944803e-06 3.23944803e-06 3.23944803e-06 ... 7.06090026e-06
#  3.23944803e-06 3.23944803e-06]
# [INFO]---trainer.py---make_loss_fn---label 分布: [283999.  11330.]
# [INFO]manual_alpha = [1.0, 1.05]
# [INFO] Using manual alpha: [1.0, 1.05]
# [INFO] Using FocalLoss: gamma=1.0, label_smoothing=0.0
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit lr=3e-05, weight_decay=0.0003, patience=15, threshold=0.5, metric_for_best=pr_auc
# fit------best threshold =  0.6336363636363637
# [EPOCH 001] train_loss=0.178235 val_loss=0.027674 val_f1_label1=0.8101 val_macro_f1=0.9009 val_weighted_f1=0.9839640515883885 val_pr_auc=0.8748 val_auc=0.9878lr=0.00000720 *
# fit------best threshold =  0.6732323232323232
# [EPOCH 002] train_loss=0.034060 val_loss=0.024421 val_f1_label1=0.8225 val_macro_f1=0.9075 val_weighted_f1=0.9851519282333877 val_pr_auc=0.9021 val_auc=0.9901lr=0.00001290 *
# fit------best threshold =  0.6682828282828283
# [EPOCH 003] train_loss=0.029512 val_loss=0.025256 val_f1_label1=0.8272 val_macro_f1=0.9098 val_weighted_f1=0.985403780709757 val_pr_auc=0.9063 val_auc=0.9910lr=0.00001860 *
# fit------best threshold =  0.6682828282828283
# [EPOCH 004] train_loss=0.026770 val_loss=0.024853 val_f1_label1=0.8270 val_macro_f1=0.9097 val_weighted_f1=0.9854057641221338 val_pr_auc=0.9091 val_auc=0.9915lr=0.00002430 *
# fit------best threshold =  0.6385858585858586
# [EPOCH 005] train_loss=0.024648 val_loss=0.023511 val_f1_label1=0.8286 val_macro_f1=0.9105 val_weighted_f1=0.9854588946034584 val_pr_auc=0.9123 val_auc=0.9918lr=0.00003000 *
# fit------best threshold =  0.6583838383838384
# [EPOCH 006] train_loss=0.023712 val_loss=0.023858 val_f1_label1=0.8313 val_macro_f1=0.9120 val_weighted_f1=0.9857557179963385 val_pr_auc=0.9128 val_auc=0.9917lr=0.00003000 *
# fit------best threshold =  0.6732323232323232
# [EPOCH 007] train_loss=0.022924 val_loss=0.023206 val_f1_label1=0.8310 val_macro_f1=0.9119 val_weighted_f1=0.9859288086425654 val_pr_auc=0.9120 val_auc=0.9912lr=0.00003000
# fit------best threshold =  0.6534343434343434
# [EPOCH 008] train_loss=0.022572 val_loss=0.023688 val_f1_label1=0.8307 val_macro_f1=0.9117 val_weighted_f1=0.9857567150420412 val_pr_auc=0.9122 val_auc=0.9914lr=0.00003000
# fit------best threshold =  0.6187878787878788
# [EPOCH 009] train_loss=0.021985 val_loss=0.023753 val_f1_label1=0.8334 val_macro_f1=0.9130 val_weighted_f1=0.9858647115941882 val_pr_auc=0.9113 val_auc=0.9909lr=0.00003000
# fit------best threshold =  0.6286868686868686
# [EPOCH 010] train_loss=0.021953 val_loss=0.023064 val_f1_label1=0.8346 val_macro_f1=0.9137 val_weighted_f1=0.9861377832726583 val_pr_auc=0.9119 val_auc=0.9909lr=0.00002999
# fit------best threshold =  0.6435353535353535
# [EPOCH 011] train_loss=0.021525 val_loss=0.024666 val_f1_label1=0.8299 val_macro_f1=0.9112 val_weighted_f1=0.9856000302722286 val_pr_auc=0.9113 val_auc=0.9908lr=0.00002999
# fit------best threshold =  0.6336363636363637
# [EPOCH 012] train_loss=0.021092 val_loss=0.023029 val_f1_label1=0.8328 val_macro_f1=0.9128 val_weighted_f1=0.9859651067068279 val_pr_auc=0.9122 val_auc=0.9909lr=0.00002999
# fit------best threshold =  0.6385858585858586
# [EPOCH 013] train_loss=0.021231 val_loss=0.024097 val_f1_label1=0.8321 val_macro_f1=0.9124 val_weighted_f1=0.9858641323989502 val_pr_auc=0.9106 val_auc=0.9903lr=0.00002998
# fit------best threshold =  0.5791919191919191
# [EPOCH 014] train_loss=0.020794 val_loss=0.023782 val_f1_label1=0.8307 val_macro_f1=0.9115 val_weighted_f1=0.9855436945557403 val_pr_auc=0.9114 val_auc=0.9903lr=0.00002998
# fit------best threshold =  0.6831313131313131
# [EPOCH 015] train_loss=0.020896 val_loss=0.025611 val_f1_label1=0.8294 val_macro_f1=0.9110 val_weighted_f1=0.9856912738115161 val_pr_auc=0.9100 val_auc=0.9904lr=0.00002997
# fit------best threshold =  0.6237373737373737
# [EPOCH 016] train_loss=0.020675 val_loss=0.024575 val_f1_label1=0.8332 val_macro_f1=0.9129 val_weighted_f1=0.9858323880752482 val_pr_auc=0.9105 val_auc=0.9902lr=0.00002996
# fit------best threshold =  0.6385858585858586
# [EPOCH 017] train_loss=0.020542 val_loss=0.024502 val_f1_label1=0.8333 val_macro_f1=0.9130 val_weighted_f1=0.9859246525194981 val_pr_auc=0.9109 val_auc=0.9902lr=0.00002996
# fit------best threshold =  0.6336363636363637
# [EPOCH 018] train_loss=0.019561 val_loss=0.024981 val_f1_label1=0.8312 val_macro_f1=0.9119 val_weighted_f1=0.9857376811510373 val_pr_auc=0.9100 val_auc=0.9900lr=0.00002995
# fit------best threshold =  0.6484848484848484
# [EPOCH 019] train_loss=0.019815 val_loss=0.024963 val_f1_label1=0.8309 val_macro_f1=0.9118 val_weighted_f1=0.9857401655988768 val_pr_auc=0.9106 val_auc=0.9903lr=0.00002994
# fit------best threshold =  0.6534343434343434
# [EPOCH 020] train_loss=0.019603 val_loss=0.025466 val_f1_label1=0.8313 val_macro_f1=0.9120 val_weighted_f1=0.9857943265603399 val_pr_auc=0.9092 val_auc=0.9898lr=0.00002993
# fit------best threshold =  0.693030303030303
# [EPOCH 021] train_loss=0.019516 val_loss=0.026044 val_f1_label1=0.8315 val_macro_f1=0.9122 val_weighted_f1=0.9859487624765868 val_pr_auc=0.9097 val_auc=0.9897lr=0.00002992
# [INFO] Early stopping at epoch=21, best_epoch=6
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.6584
# [INFO] Val metrics at selected threshold: {'accuracy': 0.985849392021617, 'macro_precision': 0.9174967955975208, 'macro_recall': 0.9065861946058591, 'macro_f1': 0.9119616149396974, 'weighted_precision': 0.9856762982866482, 'weighted_recall': 0.985849392021617, 'weighted_f1': 0.9857557179963385, 'precision_label1': 0.8429799426934097, 'recall_label1': 0.8199554069119287, 'f1_label1': 0.8313082791749081, 'auc': 0.9917280070010982, 'pr_auc': 0.9127743499056563, 'per_class_f1': {'0': 0.9926149507044867, '1': 0.8313082791749081}, 'confusion_matrix': [[40121, 274], [323, 1471]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6583838383838384}
#
# ========== STAGE2 THRESHOLD ORACLE DIAGNOSIS ==========
# [VAL ORACLE THRESHOLD] 0.658384
# [VAL ORACLE METRICS] {'accuracy': 0.985849392021617, 'macro_precision': 0.9174967955975208, 'macro_recall': 0.9065861946058591, 'macro_f1': 0.9119616149396974, 'weighted_precision': 0.9856762982866482, 'weighted_recall': 0.985849392021617, 'weighted_f1': 0.9857557179963385, 'precision_label1': 0.8429799426934097, 'recall_label1': 0.8199554069119287, 'f1_label1': 0.8313082791749081, 'auc': 0.9917282070876737, 'pr_auc': 0.9127687732956894, 'per_class_f1': {'0': 0.9926149507044867, '1': 0.8313082791749081}, 'confusion_matrix': [[40121, 274], [323, 1471]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6583838383838384}
#
# [TEST AT VAL THRESHOLD] 0.658384
# [TEST AT VAL THRESHOLD METRICS] {'accuracy': 0.9828869400331832, 'macro_precision': 0.8860753328994375, 'macro_recall': 0.905749696445034, 'macro_f1': 0.8956409780885926, 'weighted_precision': 0.9833599035522607, 'weighted_recall': 0.9828869400331832, 'weighted_f1': 0.9830995364771585, 'precision_label1': 0.7799352750809061, 'recall_label1': 0.821590909090909, 'f1_label1': 0.8002213613724405, 'auc': 0.9898080014840466, 'pr_auc': 0.8817303433478595, 'per_class_f1': {'0': 0.9910605948047446, '1': 0.8002213613724405}, 'confusion_matrix': [[80044, 816], [628, 2892]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6583838383838384}
#
# [TEST ORACLE THRESHOLD - DIAGNOSTIC ONLY] 0.663333
# [TEST ORACLE METRICS] {'accuracy': 0.9830291538279213, 'macro_precision': 0.8877654874901064, 'macro_recall': 0.9050087272052707, 'macro_f1': 0.8961788720187569, 'weighted_precision': 0.9834348890712444, 'weighted_recall': 0.9830291538279213, 'weighted_f1': 0.9832137118021193, 'precision_label1': 0.7833876221498371, 'recall_label1': 0.8198863636363637, 'f1_label1': 0.8012215435868961, 'auc': 0.9898080014840466, 'pr_auc': 0.8817303433478595, 'per_class_f1': {'0': 0.9911362004506178, '1': 0.8012215435868961}, 'confusion_matrix': [[80062, 798], [634, 2886]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6633333333333333}
#
# [THRESHOLD TRANSFER GAP] 0.001000
# =======================================================
#
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws256/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws256/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws256/stage2_predictions_test.csv
#
# ==================================================
#             Stage2 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0310
#   F1 (Macro):        0.8956
#   Recall (Macro):    0.9057
#   Precision (Macro): 0.8861
#   F1_class1:         0.8002
#   R1_class1:         0.8216
#   P1_class1:         0.7799
#   AUC (OvR Macro):   0.9898
#   PR_AUC:            0.8817
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9911
#   Class_1                       : 0.8002
#
# [TEST] Full metrics: {'accuracy': 0.9828869400331832, 'macro_precision': 0.8860753328994375, 'macro_recall': 0.905749696445034, 'macro_f1': 0.8956409780885926, 'weighted_precision': 0.9833599035522607, 'weighted_recall': 0.9828869400331832, 'weighted_f1': 0.9830995364771585, 'precision_label1': 0.7799352750809061, 'recall_label1': 0.821590909090909, 'f1_label1': 0.8002213613724405, 'auc': 0.9898081543155397, 'pr_auc': 0.8817387902501872, 'per_class_f1': {'0': 0.9910605948047446, '1': 0.8002213613724405}, 'confusion_matrix': [[80044, 816], [628, 2892]], 'num_classes': 2, 'num_samples': 84380, 'loss': 0.03101240275964661, 'threshold': 0.6583838383838384, 'positive_count': 3520, 'positive_rate': 0.041716046456506284}
# [INFO] saved summary: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws256/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/src_newM/ws256

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/dual_host_attention/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0707ar002_et12_20260511_001/dual_host_attention/ws128 \
  --context_method source_destination \
  --context_policy online \
  --window_size 128 \
  --model_type source_destination_attention \
  --context_scale 0.2 \
  --gate_bias_init -2.0 \
  --use_context_length_feature \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: source_destination, window_size: 128, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [{'source': array([0]), 'destination': array([0])}, {'source': array([1]), 'destination': array([1])}, {'source': array([2]), 'destination': array([2])}]
#
# [Dual Context Diagnostics] by split:
#
# source_history_len:
#           count       mean        std  min    50%    90%    95%    max
# split
# test    84380.0  98.841088  47.513911  0.0  127.0  127.0  127.0  127.0
# train  295329.0  77.019328  53.856065  0.0  106.0  127.0  127.0  127.0
# val     42189.0  96.761431  48.540006  0.0  127.0  127.0  127.0  127.0
#
# destination_history_len:
#           count       mean        std  min    50%    90%    95%    max
# split
# test    84380.0  89.765975  50.671856  0.0  127.0  127.0  127.0  127.0
# train  295329.0  66.671583  54.095576  0.0   61.0  127.0  127.0  127.0
# val     42189.0  87.496693  51.429910  0.0  127.0  127.0  127.0  127.0
#
# total_history_len:
#           count        mean        std  min    50%    90%    95%    max
# split
# test    84380.0  188.607063  58.724723  0.0  175.0  254.0  254.0  254.0
# train  295329.0  143.690911  72.604584  0.0  135.0  254.0  254.0  254.0
# val     42189.0  184.258124  59.231725  0.0  166.0  254.0  254.0  254.0
#
# [Dual Context Diagnostics] by split and label:
#
# source_history_len:
#                 count        mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0   98.012293  47.967612  0.0  127.0  127.0  127.0  127.0
#       1        3520.0  117.879830  29.739745  0.0  127.0  127.0  127.0  127.0
# train 0      283999.0   76.147736  54.024357  0.0  102.0  127.0  127.0  127.0
#       1       11330.0   98.866726  44.149883  0.0  127.0  127.0  127.0  127.0
# val   0       40395.0   95.924347  48.970889  0.0  127.0  127.0  127.0  127.0
#       1        1794.0  115.609810  32.243435  0.0  127.0  127.0  127.0  127.0
#
# destination_history_len:
#                 count       mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0  90.827467  50.273394  0.0  127.0  127.0  127.0  127.0
#       1        3520.0  65.381818  53.590606  0.0   54.0  127.0  127.0  127.0
# train 0      283999.0  67.537115  54.077592  0.0   64.0  127.0  127.0  127.0
#       1       11330.0  44.976081  49.858196  0.0   19.0  127.0  127.0  127.0
# val   0       40395.0  88.509419  51.087733  0.0  127.0  127.0  127.0  127.0
#       1        1794.0  64.693423  53.790454  0.0   55.0  127.0  127.0  127.0
#
# total_history_len:
#                 count        mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0  188.839760  58.771755  0.0  175.0  254.0  254.0  254.0
#       1        3520.0  183.261648  57.382659  5.0  166.0  254.0  254.0  254.0
# train 0      283999.0  143.684851  72.742683  0.0  135.0  254.0  254.0  254.0
#       1       11330.0  143.842807  69.055692  0.0  134.0  254.0  254.0  254.0
# val   0       40395.0  184.433767  59.259928  0.0  167.0  254.0  254.0  254.0
#       1        1794.0  180.303233  58.469822  4.0  162.5  254.0  254.0  254.0
#
# [Dual Context no-history rate] by split and label:
#              source_no_history  destination_no_history  both_no_history
# split label
# test  0               0.022298                0.020814         0.000099
#       1               0.015909                0.058807         0.000000
# train 0               0.065166                0.070208         0.003676
#       1               0.035305                0.117652         0.004237
# val   0               0.024756                0.023419         0.000025
#       1               0.018952                0.049610         0.000000
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] source context lengths: min=1, mean=84.36, p50=128.0, p95=128.0, max=128
# [INFO] destination context lengths: min=1, mean=74.37, p50=89.0, p95=128.0, max=128
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = source_destination_attention
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Stage2SourceDestinationAttention.__init__ use_positional_encoding=True, position_mode=age, nhead=4, dim_feedforward=256, dropout=0.25, context_scale=0.2, gate_bias_init=-2.0, use_context_length_feature=True, use_multiplicative_fusion=False, cls_head_config=1
# Stage2SourceDestinationAttention(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
#   (src_query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (src_history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (src_cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (src_context_ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (src_context_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (dst_context_ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (dst_context_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (attn_dropout): Dropout(p=0.25, inplace=False)
#   (base_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (delta_head): Sequential(
#     (0): LayerNorm((644,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=644, out_features=128, bias=True)
#     (3): GELU(approximate='none')
#     (4): Dropout(p=0.25, inplace=False)
#     (5): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (gate): Sequential(
#     (0): LayerNorm((644,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=644, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] make_train_loader: n0=283999, n1=11330, target_pos_frac=0.080, w0=3.23945e-06, w1=7.0609e-06, sample_weights=[3.23944803e-06 3.23944803e-06 3.23944803e-06 ... 7.06090026e-06
#  3.23944803e-06 3.23944803e-06]
# [INFO]---trainer.py---make_loss_fn---label 分布: [283999.  11330.]
# [INFO]manual_alpha = [1.0, 1.05]
# [INFO] Using manual alpha: [1.0, 1.05]
# [INFO] Using FocalLoss: gamma=1.0, label_smoothing=0.0
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit lr=3e-05, weight_decay=0.0003, patience=15, threshold=0.5, metric_for_best=pr_auc
# fit------best threshold =  0.5692929292929293
# [EPOCH 001] train_loss=0.215347 val_loss=0.086162 val_f1_label1=0.5318 val_macro_f1=0.7560 val_weighted_f1=0.9610337267732616 val_pr_auc=0.4708 val_auc=0.9455lr=0.00000720 *
# fit------best threshold =  0.5742424242424242
# [EPOCH 002] train_loss=0.044720 val_loss=0.025656 val_f1_label1=0.8090 val_macro_f1=0.9002 val_weighted_f1=0.9835635881799303 val_pr_auc=0.8605 val_auc=0.9879lr=0.00001290 *
# fit------best threshold =  0.598989898989899
# [EPOCH 003] train_loss=0.032772 val_loss=0.024547 val_f1_label1=0.8186 val_macro_f1=0.9052 val_weighted_f1=0.9844090878052704 val_pr_auc=0.8940 val_auc=0.9897lr=0.00001860 *
# fit------best threshold =  0.6286868686868686
# [EPOCH 004] train_loss=0.029023 val_loss=0.023812 val_f1_label1=0.8211 val_macro_f1=0.9065 val_weighted_f1=0.9847094029881442 val_pr_auc=0.9042 val_auc=0.9916lr=0.00002430 *
# fit------best threshold =  0.6286868686868686
# [EPOCH 005] train_loss=0.025915 val_loss=0.023055 val_f1_label1=0.8203 val_macro_f1=0.9062 val_weighted_f1=0.9848366473839297 val_pr_auc=0.9078 val_auc=0.9921lr=0.00003000 *
# fit------best threshold =  0.5890909090909091
# [EPOCH 006] train_loss=0.024965 val_loss=0.022955 val_f1_label1=0.8223 val_macro_f1=0.9072 val_weighted_f1=0.9848310579462144 val_pr_auc=0.9091 val_auc=0.9920lr=0.00003000 *
# fit------best threshold =  0.6088888888888889
# [EPOCH 007] train_loss=0.024450 val_loss=0.022326 val_f1_label1=0.8233 val_macro_f1=0.9078 val_weighted_f1=0.9850835812419139 val_pr_auc=0.9100 val_auc=0.9922lr=0.00003000 *
# fit------best threshold =  0.6534343434343434
# [EPOCH 008] train_loss=0.023566 val_loss=0.023357 val_f1_label1=0.8231 val_macro_f1=0.9077 val_weighted_f1=0.9850891326516321 val_pr_auc=0.9100 val_auc=0.9924lr=0.00003000
# fit------best threshold =  0.5692929292929293
# [EPOCH 009] train_loss=0.023058 val_loss=0.022123 val_f1_label1=0.8260 val_macro_f1=0.9091 val_weighted_f1=0.98510644953766 val_pr_auc=0.9107 val_auc=0.9922lr=0.00003000 *
# fit------best threshold =  0.594040404040404
# [EPOCH 010] train_loss=0.022977 val_loss=0.022526 val_f1_label1=0.8292 val_macro_f1=0.9109 val_weighted_f1=0.985572692303899 val_pr_auc=0.9109 val_auc=0.9920lr=0.00002999 *
# fit------best threshold =  0.598989898989899
# [EPOCH 011] train_loss=0.022261 val_loss=0.022505 val_f1_label1=0.8305 val_macro_f1=0.9115 val_weighted_f1=0.9855501751766368 val_pr_auc=0.9117 val_auc=0.9921lr=0.00002999 *
# fit------best threshold =  0.5445454545454546
# [EPOCH 012] train_loss=0.021686 val_loss=0.022812 val_f1_label1=0.8290 val_macro_f1=0.9106 val_weighted_f1=0.9852668825263572 val_pr_auc=0.9115 val_auc=0.9918lr=0.00002999
# fit------best threshold =  0.5890909090909091
# [EPOCH 013] train_loss=0.021938 val_loss=0.022978 val_f1_label1=0.8294 val_macro_f1=0.9108 val_weighted_f1=0.9853687906549164 val_pr_auc=0.9103 val_auc=0.9916lr=0.00002998
# fit------best threshold =  0.5197979797979798
# [EPOCH 014] train_loss=0.021384 val_loss=0.023234 val_f1_label1=0.8303 val_macro_f1=0.9113 val_weighted_f1=0.9854065389360382 val_pr_auc=0.9097 val_auc=0.9910lr=0.00002998
# fit------best threshold =  0.6336363636363637
# [EPOCH 015] train_loss=0.021527 val_loss=0.023279 val_f1_label1=0.8310 val_macro_f1=0.9118 val_weighted_f1=0.9857299149551432 val_pr_auc=0.9108 val_auc=0.9915lr=0.00002997
# fit------best threshold =  0.6336363636363637
# [EPOCH 016] train_loss=0.021280 val_loss=0.023552 val_f1_label1=0.8313 val_macro_f1=0.9120 val_weighted_f1=0.9857801594840213 val_pr_auc=0.9108 val_auc=0.9912lr=0.00002996
# fit------best threshold =  0.6336363636363637
# [EPOCH 017] train_loss=0.021215 val_loss=0.023141 val_f1_label1=0.8311 val_macro_f1=0.9119 val_weighted_f1=0.9858597076641967 val_pr_auc=0.9096 val_auc=0.9910lr=0.00002996
# fit------best threshold =  0.5841414141414141
# [EPOCH 018] train_loss=0.019918 val_loss=0.023922 val_f1_label1=0.8297 val_macro_f1=0.9111 val_weighted_f1=0.9854811451119073 val_pr_auc=0.9078 val_auc=0.9905lr=0.00002995
# fit------best threshold =  0.6484848484848484
# [EPOCH 019] train_loss=0.020701 val_loss=0.023865 val_f1_label1=0.8304 val_macro_f1=0.9115 val_weighted_f1=0.9857793944268526 val_pr_auc=0.9093 val_auc=0.9909lr=0.00002994
# fit------best threshold =  0.6088888888888889
# [EPOCH 020] train_loss=0.020118 val_loss=0.024062 val_f1_label1=0.8313 val_macro_f1=0.9119 val_weighted_f1=0.9856437084045986 val_pr_auc=0.9090 val_auc=0.9905lr=0.00002993
