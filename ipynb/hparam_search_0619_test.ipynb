# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/s2/tune_transformer_hyperparams.py \
  --stage1_dir /content/drive/MyDrive/s1/tensors_ar_002 \
  --output_dir /content/drive/MyDrive/s2/hparam_search_0619_test \
  --config /content/drive/MyDrive/s2/stage2_config_0619.yaml \
  --search_mode test \
  --device cuda \
  --patience_per_trial 20 \
  --epochs_per_trial 200 \
  --skip_completed
# Out:
# [INFO] Search mode: test
# [INFO] Search parameters: ['model.cls_head']
# [INFO] Max combinations: 100
# [INFO] Device: cuda
# [INFO] Pre-loading Stage1 data...
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Loaded 177178 flows
# [INFO] z shape: (177178, 128)
#
# ...
# Hyperparameter Search Configuration
# ...
# Search parameters: ['model.cls_head']
# Total combinations: 3
# Output directory: /content/drive/MyDrive/s2/hparam_search_0619_test
# ...
#
#
# ...
# Trial 1/3: cls_head=1
# hparams: {'model.cls_head': 1}
# ...
# [INFO] 随机种子已设置: 42
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:535: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** dropout= 0.3
# ...
