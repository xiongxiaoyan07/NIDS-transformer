# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_exp3_transformer_context \
  --config /content/drive/MyDrive/s2/stage2_config_noposition.yaml \
  --context_method time_only \
  --context_policy split_isolated \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=128.36, p50=129.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:383: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): Identity()
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.3, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.3, inplace=False)
#         (dropout2): Dropout(p=0.3, inplace=False)
#       )
#     )
#   )
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.15, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): GELU(approximate='none')
#     (6): Dropout(p=0.09, inplace=False)
#     (7): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] weighted sampler class_counts: [26257, 899]
# [INFO]---trainer.py---make_loss_fn---label 分布: [26257.   899.]
# [INFO] Stage2 class distribution: [26257, 899]
# [INFO] Stage2 alpha weights: [0.033105022831050226, 0.9668949771689497]
# [INFO] Using FocalLoss: gamma=2.0, label_smoothing=0.02
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit----metric_for_best =  f1_label1
# [EPOCH 001] train_loss=0.002976 val_loss=0.000600 val_macro_f1=0.5750 val_weighted_f1=0.869167653883879 val_f1_label1=0.2591 val_auc=0.9719*
# [EPOCH 002] train_loss=0.000068 val_loss=0.000853 val_macro_f1=0.6242 val_weighted_f1=0.9039749244575944 val_f1_label1=0.3238 val_auc=0.9718*
# [EPOCH 054] train_loss=0.000032 val_loss=0.003665 val_macro_f1=0.7172 val_weighted_f1=0.9473912909478232 val_f1_label1=0.4701 val_auc=0.9080
# [EPOCH 055] train_loss=0.000031 val_loss=0.004012 val_macro_f1=0.7408 val_weighted_f1=0.9544690298240484 val_f1_label1=0.5113 val_auc=0.8947
# [EPOCH 056] train_loss=0.000036 val_loss=0.003707 val_macro_f1=0.7318 val_weighted_f1=0.9517242398808432 val_f1_label1=0.4957 val_auc=0.8947
# [EPOCH 057] train_loss=0.000031 val_loss=0.003572 val_macro_f1=0.7471 val_weighted_f1=0.9559560520248032 val_f1_label1=0.5229 val_auc=0.8998
# [EPOCH 058] train_loss=0.000028 val_loss=0.004136 val_macro_f1=0.7783 val_weighted_f1=0.9640060299249189 val_f1_label1=0.5788 val_auc=0.8931
# [EPOCH 059] train_loss=0.000031 val_loss=0.004010 val_macro_f1=0.7539 val_weighted_f1=0.9581467895777098 val_f1_label1=0.5346 val_auc=0.8922
# [EPOCH 060] train_loss=0.000029 val_loss=0.003731 val_macro_f1=0.7829 val_weighted_f1=0.9647021632934557 val_f1_label1=0.5876 val_auc=0.8926
# [EPOCH 061] train_loss=0.000032 val_loss=0.003003 val_macro_f1=0.7718 val_weighted_f1=0.9615705822880573 val_f1_label1=0.5680 val_auc=0.9229
# [EPOCH 062] train_loss=0.000031 val_loss=0.003793 val_macro_f1=0.7608 val_weighted_f1=0.9596618249983069 val_f1_label1=0.5472 val_auc=0.9055
# [EPOCH 063] train_loss=0.000026 val_loss=0.004173 val_macro_f1=0.7710 val_weighted_f1=0.9623371905408361 val_f1_label1=0.5657 val_auc=0.8869
# [EPOCH 064] train_loss=0.000024 val_loss=0.004117 val_macro_f1=0.7525 val_weighted_f1=0.9577869742872953 val_f1_label1=0.5321 val_auc=0.8840
# [EPOCH 065] train_loss=0.000034 val_loss=0.003098 val_macro_f1=0.7451 val_weighted_f1=0.9547353642938475 val_f1_label1=0.5200 val_auc=0.9110
# [INFO] Early stopping at epoch=65, best_epoch=45
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.9600
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9815440603067325, 'macro_precision': 0.8553972356095706, 'macro_recall': 0.8735388882091439, 'macro_f1': 0.8642212570583203, 'weighted_precision': 0.9820388923453317, 'weighted_recall': 0.9815440603067325, 'weighted_f1': 0.9817737190379234, 'precision_label1': 0.7194244604316546, 'recall_label1': 0.7575757575757576, 'f1_label1': 0.7380073800738007, 'auc': 0.944473673477711, 'per_class_f1': {'0': 0.9904351340428398, '1': 0.7380073800738007}, 'confusion_matrix': [[3676, 39], [32, 100]], 'num_classes': 2, 'num_samples': 3847, 'threshold': 0.9600000000000001}
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_exp3_transformer_context/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_exp3_transformer_context/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_exp3_transformer_context/stage2_predictions_test.csv
#
# ==================================================
#             Stage1 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0069
#   F1 (Macro):        0.8168
#   F1 (Weighted):     0.9761
#   AUC (OvR Macro):   0.9273
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9877
#   Class_1                       : 0.6459
#
# [TEST] Full metrics: {'accuracy': 0.976264997391758, 'macro_precision': 0.8204322955719017, 'macro_recall': 0.8132912443927562, 'macro_f1': 0.8168176761119106, 'weighted_precision': 0.9760038252658028, 'weighted_recall': 0.976264997391758, 'weighted_f1': 0.9761312702562144, 'precision_label1': 0.6535433070866141, 'recall_label1': 0.6384615384615384, 'f1_label1': 0.6459143968871596, 'auc': 0.9272805387107492, 'per_class_f1': {'0': 0.9877209553366617, '1': 0.6459143968871596}, 'confusion_matrix': [[7320, 88], [94, 166]], 'num_classes': 2, 'num_samples': 7668, 'threshold': 0.9600000000000001, 'loss': 0.006920106919975381, 'positive_count': 260, 'positive_rate': 0.03390714658320292}
# [INFO] saved summary: /content/drive/MyDrive/s2/stage2_exp3_transformer_context/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/stage2_exp3_transformer_context

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_exp3_transformer_context_source_host \
  --config /content/drive/MyDrive/s2/stage2_config_noposition.yaml \
  --context_method source_host \
  --context_policy split_isolated \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_exp3_transformer_context_destination_host \
  --config /content/drive/MyDrive/s2/stage2_config_noposition.yaml \
  --context_method destination_host \
  --context_policy split_isolated \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_exp3_transformer_context_same_endpoint \
  --config /content/drive/MyDrive/s2/stage2_config_noposition.yaml \
  --context_method endpoint \
  --context_policy split_isolated \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128
