# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip -q install optuna

# %%
# !python /content/drive/MyDrive/s2/tune_stage2_optuna.py \
  --stage1_dir /content/drive/MyDrive/s1/tensors_ar_002 \
  --config /content/drive/MyDrive/s2/stage2_config_0622_timeonly.yaml \
  --out_dir /content/drive/MyDrive/s2/stage2_optuna_0622_timeonly \
  --study_name stage2_transformer_timeonly \
  --n_trials 50 \
  --max_epochs 35 \
  --patience 6 \
  --final_epochs 150 \
  --final_patience 15 \
  --objective_metric macro_f1 \
  --profile fast \
  --num_workers 2 \
  --batch_sizes 64,128,256 \
  --eval_batch_sizes 128,256,512
# Out:
# [TUNE] device=cuda
# [TUNE] Loading and sorting Stage1 outputs once...
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [TUNE] flows=177178, input_dim=128
# [TUNE] split counts={'train': 124025, 'test': 35360, 'val': 17793}
# [I 2026-06-22 15:13:48,782] A new study created in RDB with name: stage2_transformer_timeonly
#   0% 0/50 [00:00<?, ?it/s][TUNE] Building exact context indices for window_size=128
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:535: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= mean
# [INFO] Stage2Transformer.__init__*********** dropout= 0.30000000000000004
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 2
# ...

# %%
# !python /content/drive/MyDrive/s2/tune_stage2_optuna.py \
  --stage1_dir /content/drive/MyDrive/s1/tensors_ar_002 \
  --config /content/drive/MyDrive/s2/stage2_config_0622_source.yaml \
  --out_dir /content/drive/MyDrive/s2/stage2_optuna_0622_src \
  --study_name stage2_transformer_src \
  --n_trials 50 \
  --max_epochs 35 \
  --patience 6 \
  --final_epochs 150 \
  --final_patience 15 \
  --objective_metric macro_f1 \
  --profile fast \
  --num_workers 2 \
  --batch_sizes 64,128,256 \
  --eval_batch_sizes 128,256,512
# Out:
# [TUNE] device=cuda
# [TUNE] Loading and sorting Stage1 outputs once...
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [TUNE] flows=177178, input_dim=128
# [TUNE] split counts={'train': 124025, 'test': 35360, 'val': 17793}
# [I 2026-06-22 20:29:56,620] A new study created in RDB with name: stage2_transformer_src
#   0% 0/50 [00:00<?, ?it/s][TUNE] Building exact context indices for window_size=128
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:535: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= mean
# [INFO] Stage2Transformer.__init__*********** dropout= 0.30000000000000004
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 2
# ...

# %%
# !python /content/drive/MyDrive/s2/tune_stage2_optuna.py \
  --stage1_dir /content/drive/MyDrive/s1/tensors_ar_002 \
  --config /content/drive/MyDrive/s2/stage2_config_0622_dest.yaml \
  --out_dir /content/drive/MyDrive/s2/stage2_optuna_0622_dst \
  --study_name stage2_transformer_dst \
  --n_trials 50 \
  --max_epochs 35 \
  --patience 6 \
  --final_epochs 150 \
  --final_patience 15 \
  --objective_metric macro_f1 \
  --profile fast \
  --num_workers 2 \
  --batch_sizes 64,128,256 \
  --eval_batch_sizes 128,256,512
# Out:
# [TUNE] device=cuda
# [TUNE] Loading and sorting Stage1 outputs once...
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [TUNE] flows=177178, input_dim=128
# [TUNE] split counts={'train': 124025, 'test': 35360, 'val': 17793}
# [I 2026-06-23 01:21:15,664] A new study created in RDB with name: stage2_transformer_dst
#   0% 0/50 [00:00<?, ?it/s][TUNE] Building exact context indices for window_size=128
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:535: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= mean
# [INFO] Stage2Transformer.__init__*********** dropout= 0.30000000000000004
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 2
# ...

# %%
# !python /content/drive/MyDrive/s2/tune_stage2_optuna.py \
  --stage1_dir /content/drive/MyDrive/s1/tensors_ar_002 \
  --config /content/drive/MyDrive/s2/stage2_config_0622_same_endpoint.yaml \
  --out_dir /content/drive/MyDrive/s2/stage2_optuna_0622_same_endpoint \
  --study_name stage2_transformer_same_endpoint \
  --n_trials 50 \
  --max_epochs 35 \
  --patience 6 \
  --final_epochs 150 \
  --final_patience 15 \
  --objective_metric macro_f1 \
  --profile fast \
  --num_workers 2 \
  --batch_sizes 64,128,256 \
  --eval_batch_sizes 128,256,512
# Out:
# [TUNE] device=cuda
# [TUNE] Loading and sorting Stage1 outputs once...
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [TUNE] flows=177178, input_dim=128
# [TUNE] split counts={'train': 124025, 'test': 35360, 'val': 17793}
# [I 2026-06-23 05:02:54,243] A new study created in RDB with name: stage2_transformer_same_endpoint
#   0% 0/50 [00:00<?, ?it/s][TUNE] Building exact context indices for window_size=128
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:535: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= mean
# [INFO] Stage2Transformer.__init__*********** dropout= 0.30000000000000004
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 2
# ...
