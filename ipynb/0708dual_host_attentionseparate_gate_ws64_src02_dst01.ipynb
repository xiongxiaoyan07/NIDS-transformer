# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/separate_gate_ws64_src02_dst01 \
  --context_method source_destination \
  --context_policy online \
  --window_size 64 \
  --model_type source_destination_attention \
  --context_scale 0.2 \
  --source_context_scale 0.2 \
  --destination_context_scale 0.1 \
  --gate_bias_init -2.0 \
  --use_context_length_feature \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: source_destination, window_size: 64, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [{'source': array([0]), 'destination': array([0])}, {'source': array([1]), 'destination': array([1])}, {'source': array([2]), 'destination': array([2])}]
#
# [Dual Context Diagnostics] by split:
#
# source_history_len:
#           count       mean        std  min   50%   90%   95%   max
# split
# test    84380.0  51.957893  21.295111  0.0  63.0  63.0  63.0  63.0
# train  295329.0  43.601705  25.760844  0.0  63.0  63.0  63.0  63.0
# val     42189.0  51.143260  21.969256  0.0  63.0  63.0  63.0  63.0
#
# destination_history_len:
#           count       mean        std  min   50%   90%   95%   max
# split
# test    84380.0  48.873181  22.788240  0.0  63.0  63.0  63.0  63.0
# train  295329.0  39.256964  26.558420  0.0  61.0  63.0  63.0  63.0
# val     42189.0  47.933016  23.359634  0.0  63.0  63.0  63.0  63.0
#
# total_history_len:
#           count        mean        std  min    50%    90%    95%    max
# split
# test    84380.0  100.831074  27.077641  0.0  112.0  126.0  126.0  126.0
# train  295329.0   82.858669  34.644915  0.0   75.0  126.0  126.0  126.0
# val     42189.0   99.076276  27.562866  0.0  104.0  126.0  126.0  126.0
#
# [Dual Context Diagnostics] by split and label:
#
# source_history_len:
#                 count       mean        std  min   50%   90%   95%   max
# split label
# test  0       80860.0  51.625649  21.514954  0.0  63.0  63.0  63.0  63.0
#       1        3520.0  59.590057  13.287276  0.0  63.0  63.0  63.0  63.0
# train 0      283999.0  43.189427  25.900253  0.0  63.0  63.0  63.0  63.0
#       1       11330.0  53.935922  19.289177  0.0  63.0  63.0  63.0  63.0
# val   0       40395.0  50.795990  22.185318  0.0  63.0  63.0  63.0  63.0
#       1        1794.0  58.962653  14.286224  0.0  63.0  63.0  63.0  63.0
#
# destination_history_len:
#                 count       mean        std  min   50%   90%   95%   max
# split label
# test  0       80860.0  49.304316  22.533661  0.0  63.0  63.0  63.0  63.0
#       1        3520.0  38.969318  26.118659  0.0  54.0  63.0  63.0  63.0
# train 0      283999.0  39.665580  26.476605  0.0  63.0  63.0  63.0  63.0
#       1       11330.0  29.014563  26.553414  0.0  19.0  63.0  63.0  63.0
# val   0       40395.0  48.351306  23.131866  0.0  63.0  63.0  63.0  63.0
#       1        1794.0  38.514493  26.302841  0.0  55.0  63.0  63.0  63.0
#
# total_history_len:
#                 count        mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0  100.929965  27.052385  0.0  112.0  126.0  126.0  126.0
#       1        3520.0   98.559375  27.557816  5.0  104.0  126.0  126.0  126.0
# train 0      283999.0   82.855007  34.701367  0.0   75.0  126.0  126.0  126.0
#       1       11330.0   82.950485  33.199865  0.0   74.0  126.0  126.0  126.0
# val   0       40395.0   99.147295  27.526268  0.0  104.0  126.0  126.0  126.0
#       1        1794.0   97.477146  28.335213  4.0  101.0  126.0  126.0  126.0
#
# [Dual Context no-history rate] by split and label:
#              source_no_history  destination_no_history  both_no_history
# split label
# test  0               0.022298                0.020814         0.000099
#       1               0.015909                0.058807         0.000000
# train 0               0.065166                0.070208         0.003676
#       1               0.035305                0.117652         0.004237
# val   0               0.024756                0.023419         0.000025
#       1               0.018952                0.049610         0.000000
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] source context lengths: min=1, mean=47.03, p50=64.0, p95=64.0, max=64
# [INFO] destination context lengths: min=1, mean=43.05, p50=64.0, p95=64.0, max=64
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = source_destination_attention
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Stage2SourceDestinationAttention.__init__ use_positional_encoding=True, position_mode=age, nhead=4, dim_feedforward=256, dropout=0.25, context_scale=0.2, gate_bias_init=-2.0, source_context_scale=0.2, destination_context_scale=0.1, use_context_length_feature=True, use_multiplicative_fusion=False, cls_head_config=1
# Stage2SourceDestinationAttention(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
#   (src_query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (src_history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (src_cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (src_context_ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (src_context_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (dst_context_ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (dst_context_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (attn_dropout): Dropout(p=0.25, inplace=False)
#   (base_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (source_delta_head): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=386, out_features=128, bias=True)
#     (3): GELU(approximate='none')
#     (4): Dropout(p=0.25, inplace=False)
#     (5): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (source_gate): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=386, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
#   (destination_delta_head): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=386, out_features=128, bias=True)
#     (3): GELU(approximate='none')
#     (4): Dropout(p=0.25, inplace=False)
#     (5): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (destination_gate): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=386, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] make_train_loader: n0=283999, n1=11330, target_pos_frac=0.080, w0=3.23945e-06, w1=7.0609e-06, sample_weights=[3.23944803e-06 3.23944803e-06 3.23944803e-06 ... 7.06090026e-06
#  3.23944803e-06 3.23944803e-06]
# [INFO]---trainer.py---make_loss_fn---label 分布: [283999.  11330.]
# [INFO]manual_alpha = [1.0, 1.05]
# [INFO] Using manual alpha: [1.0, 1.05]
# [INFO] Using FocalLoss: gamma=1.0, label_smoothing=0.0
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit lr=3e-05, weight_decay=0.0003, patience=15, threshold=0.5, metric_for_best=pr_auc
# fit------best threshold =  0.5841414141414141
# [EPOCH 001] train_loss=0.221825 val_loss=0.092819 val_f1_label1=0.5205 val_macro_f1=0.7500 val_weighted_f1=0.9598580829540885 val_pr_auc=0.4552 val_auc=0.9435lr=0.00000720 *
# fit------best threshold =  0.594040404040404
# [EPOCH 002] train_loss=0.046924 val_loss=0.025295 val_f1_label1=0.8133 val_macro_f1=0.9025 val_weighted_f1=0.9841453424883563 val_pr_auc=0.8630 val_auc=0.9880lr=0.00001290 *
# fit------best threshold =  0.6088888888888889
# [EPOCH 003] train_loss=0.032960 val_loss=0.024447 val_f1_label1=0.8203 val_macro_f1=0.9061 val_weighted_f1=0.984627101394808 val_pr_auc=0.8944 val_auc=0.9900lr=0.00001860 *
# fit------best threshold =  0.5791919191919191
# [EPOCH 004] train_loss=0.029205 val_loss=0.023026 val_f1_label1=0.8216 val_macro_f1=0.9068 val_weighted_f1=0.9847565961887981 val_pr_auc=0.9034 val_auc=0.9917lr=0.00002430 *
# fit------best threshold =  0.598989898989899
# [EPOCH 005] train_loss=0.026633 val_loss=0.023189 val_f1_label1=0.8230 val_macro_f1=0.9076 val_weighted_f1=0.9849466784188903 val_pr_auc=0.9063 val_auc=0.9920lr=0.00003000 *
# fit------best threshold =  0.6039393939393939
# [EPOCH 006] train_loss=0.025388 val_loss=0.023317 val_f1_label1=0.8258 val_macro_f1=0.9090 val_weighted_f1=0.9851362588499551 val_pr_auc=0.9080 val_auc=0.9921lr=0.00003000 *
# fit------best threshold =  0.6187878787878788
# [EPOCH 007] train_loss=0.024813 val_loss=0.022292 val_f1_label1=0.8248 val_macro_f1=0.9086 val_weighted_f1=0.9852795581157091 val_pr_auc=0.9097 val_auc=0.9921lr=0.00003000 *
# fit------best threshold =  0.6187878787878788
# [EPOCH 008] train_loss=0.023652 val_loss=0.022877 val_f1_label1=0.8257 val_macro_f1=0.9090 val_weighted_f1=0.9852311600445336 val_pr_auc=0.9103 val_auc=0.9922lr=0.00003000 *
# fit------best threshold =  0.6138383838383838
# [EPOCH 009] train_loss=0.023133 val_loss=0.022290 val_f1_label1=0.8275 val_macro_f1=0.9100 val_weighted_f1=0.985515295457667 val_pr_auc=0.9105 val_auc=0.9919lr=0.00003000 *
# fit------best threshold =  0.6336363636363637
# [EPOCH 010] train_loss=0.023047 val_loss=0.022210 val_f1_label1=0.8277 val_macro_f1=0.9102 val_weighted_f1=0.9856089895768817 val_pr_auc=0.9119 val_auc=0.9919lr=0.00002999 *
# fit------best threshold =  0.6534343434343434
# [EPOCH 011] train_loss=0.022641 val_loss=0.022753 val_f1_label1=0.8274 val_macro_f1=0.9100 val_weighted_f1=0.9855590090832554 val_pr_auc=0.9114 val_auc=0.9919lr=0.00002999
# fit------best threshold =  0.6435353535353535
# [EPOCH 012] train_loss=0.022043 val_loss=0.022461 val_f1_label1=0.8293 val_macro_f1=0.9110 val_weighted_f1=0.9857114237814621 val_pr_auc=0.9129 val_auc=0.9920lr=0.00002999 *
# fit------best threshold =  0.6435353535353535
# [EPOCH 013] train_loss=0.022299 val_loss=0.022912 val_f1_label1=0.8281 val_macro_f1=0.9104 val_weighted_f1=0.9855772450845331 val_pr_auc=0.9113 val_auc=0.9919lr=0.00002998
# fit------best threshold =  0.5890909090909091
# [EPOCH 014] train_loss=0.021692 val_loss=0.022421 val_f1_label1=0.8285 val_macro_f1=0.9105 val_weighted_f1=0.9855691804166948 val_pr_auc=0.9122 val_auc=0.9918lr=0.00002998
# fit------best threshold =  0.6138383838383838
# [EPOCH 015] train_loss=0.021941 val_loss=0.023204 val_f1_label1=0.8282 val_macro_f1=0.9103 val_weighted_f1=0.9854331786826867 val_pr_auc=0.9106 val_auc=0.9914lr=0.00002997
# fit------best threshold =  0.598989898989899
# [EPOCH 016] train_loss=0.021874 val_loss=0.022983 val_f1_label1=0.8296 val_macro_f1=0.9110 val_weighted_f1=0.985438987716714 val_pr_auc=0.9127 val_auc=0.9917lr=0.00002996
# fit------best threshold =  0.6237373737373737
# [EPOCH 017] train_loss=0.021426 val_loss=0.023097 val_f1_label1=0.8288 val_macro_f1=0.9107 val_weighted_f1=0.9856152033703999 val_pr_auc=0.9095 val_auc=0.9910lr=0.00002996
# fit------best threshold =  0.6088888888888889
# [EPOCH 018] train_loss=0.020526 val_loss=0.023118 val_f1_label1=0.8299 val_macro_f1=0.9112 val_weighted_f1=0.9855757576841613 val_pr_auc=0.9115 val_auc=0.9914lr=0.00002995
# fit------best threshold =  0.6039393939393939
# [EPOCH 019] train_loss=0.020991 val_loss=0.023412 val_f1_label1=0.8280 val_macro_f1=0.9102 val_weighted_f1=0.9854113746511822 val_pr_auc=0.9102 val_auc=0.9912lr=0.00002994
# fit------best threshold =  0.6039393939393939
# [EPOCH 020] train_loss=0.020628 val_loss=0.023048 val_f1_label1=0.8305 val_macro_f1=0.9115 val_weighted_f1=0.985598924465069 val_pr_auc=0.9110 val_auc=0.9911lr=0.00002993
# fit------best threshold =  0.6138383838383838
# [EPOCH 021] train_loss=0.020249 val_loss=0.024002 val_f1_label1=0.8304 val_macro_f1=0.9114 val_weighted_f1=0.9855707193451507 val_pr_auc=0.9107 val_auc=0.9909lr=0.00002992
# fit------best threshold =  0.5791919191919191
# [EPOCH 022] train_loss=0.019951 val_loss=0.023641 val_f1_label1=0.8319 val_macro_f1=0.9122 val_weighted_f1=0.9856948906927994 val_pr_auc=0.9100 val_auc=0.9909lr=0.00002991
# fit------best threshold =  0.6237373737373737
# [EPOCH 023] train_loss=0.019773 val_loss=0.024159 val_f1_label1=0.8308 val_macro_f1=0.9117 val_weighted_f1=0.9856977548500194 val_pr_auc=0.9090 val_auc=0.9906lr=0.00002990
# fit------best threshold =  0.5890909090909091
# [EPOCH 024] train_loss=0.020298 val_loss=0.024485 val_f1_label1=0.8317 val_macro_f1=0.9121 val_weighted_f1=0.9856098469465403 val_pr_auc=0.9089 val_auc=0.9902lr=0.00002989
# fit------best threshold =  0.6088888888888889
# [EPOCH 025] train_loss=0.019317 val_loss=0.024481 val_f1_label1=0.8306 val_macro_f1=0.9115 val_weighted_f1=0.9855642787764645 val_pr_auc=0.9085 val_auc=0.9900lr=0.00002988
# fit------best threshold =  0.6286868686868686
# [EPOCH 026] train_loss=0.019610 val_loss=0.025294 val_f1_label1=0.8298 val_macro_f1=0.9112 val_weighted_f1=0.9855718806700035 val_pr_auc=0.9093 val_auc=0.9907lr=0.00002987
# fit------best threshold =  0.6138383838383838
# [EPOCH 027] train_loss=0.019615 val_loss=0.025573 val_f1_label1=0.8303 val_macro_f1=0.9114 val_weighted_f1=0.9856014544602872 val_pr_auc=0.9094 val_auc=0.9907lr=0.00002986
# [INFO] Early stopping at epoch=27, best_epoch=12
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.6435
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9859205006044229, 'macro_precision': 0.923602930691044, 'macro_recall': 0.8991661150486769, 'macro_f1': 0.9109838826414873, 'weighted_precision': 0.9855737299858462, 'weighted_recall': 0.9859205006044229, 'weighted_f1': 0.9857114237814621, 'precision_label1': 0.8558718861209964, 'recall_label1': 0.8043478260869565, 'f1_label1': 0.8293103448275863, 'auc': 0.9919869190296545, 'pr_auc': 0.912873578094678, 'per_class_f1': {'0': 0.9926574204553883, '1': 0.8293103448275863}, 'confusion_matrix': [[40152, 243], [351, 1443]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6435353535353535}
#
# ========== STAGE2 THRESHOLD ORACLE DIAGNOSIS ==========
# [VAL ORACLE THRESHOLD] 0.643535
# [VAL ORACLE METRICS] {'accuracy': 0.9859205006044229, 'macro_precision': 0.923602930691044, 'macro_recall': 0.8991661150486769, 'macro_f1': 0.9109838826414873, 'weighted_precision': 0.9855737299858462, 'weighted_recall': 0.9859205006044229, 'weighted_f1': 0.9857114237814621, 'precision_label1': 0.8558718861209964, 'recall_label1': 0.8043478260869565, 'f1_label1': 0.8293103448275863, 'auc': 0.99198645676067, 'pr_auc': 0.9128735467348699, 'per_class_f1': {'0': 0.9926574204553883, '1': 0.8293103448275863}, 'confusion_matrix': [[40152, 243], [351, 1443]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6435353535353535}
#
# [TEST AT VAL THRESHOLD] 0.643535
# [TEST AT VAL THRESHOLD METRICS] {'accuracy': 0.9832898791182745, 'macro_precision': 0.8924870219067206, 'macro_recall': 0.9007971831223439, 'macro_f1': 0.896593834322609, 'weighted_precision': 0.9834734047936088, 'weighted_recall': 0.9832898791182745, 'weighted_f1': 0.9833774032762573, 'precision_label1': 0.7932184546970539, 'recall_label1': 0.8107954545454545, 'f1_label1': 0.8019106490587243, 'auc': 0.9910848436129787, 'pr_auc': 0.8864464639034532, 'per_class_f1': {'0': 0.9912770195864936, '1': 0.8019106490587243}, 'confusion_matrix': [[80116, 744], [666, 2854]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6435353535353535}
#
# [TEST ORACLE THRESHOLD - DIAGNOSTIC ONLY] 0.643535
# [TEST ORACLE METRICS] {'accuracy': 0.9832898791182745, 'macro_precision': 0.8924870219067206, 'macro_recall': 0.9007971831223439, 'macro_f1': 0.896593834322609, 'weighted_precision': 0.9834734047936088, 'weighted_recall': 0.9832898791182745, 'weighted_f1': 0.9833774032762573, 'precision_label1': 0.7932184546970539, 'recall_label1': 0.8107954545454545, 'f1_label1': 0.8019106490587243, 'auc': 0.9910848436129787, 'pr_auc': 0.8864464639034532, 'per_class_f1': {'0': 0.9912770195864936, '1': 0.8019106490587243}, 'confusion_matrix': [[80116, 744], [666, 2854]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6435353535353535}
#
# [THRESHOLD TRANSFER GAP] 0.000000
# =======================================================
#
# [INFO] saved predictions: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/separate_gate_ws64_src02_dst01/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/separate_gate_ws64_src02_dst01/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/separate_gate_ws64_src02_dst01/stage2_predictions_test.csv
#
# ==================================================
#             Stage2 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0278
#   F1 (Macro):        0.8966
#   Recall (Macro):    0.9008
#   Precision (Macro): 0.8925
#   F1_class1:         0.8019
#   R1_class1:         0.8108
#   P1_class1:         0.7932
#   AUC (OvR Macro):   0.9911
#   PR_AUC:            0.8865
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9913
#   Class_1                       : 0.8019
#
# [TEST] Full metrics: {'accuracy': 0.9832898791182745, 'macro_precision': 0.8924870219067206, 'macro_recall': 0.9007971831223439, 'macro_f1': 0.896593834322609, 'weighted_precision': 0.9834734047936088, 'weighted_recall': 0.9832898791182745, 'weighted_f1': 0.9833774032762573, 'precision_label1': 0.7932184546970539, 'recall_label1': 0.8107954545454545, 'f1_label1': 0.8019106490587243, 'auc': 0.9910837474422682, 'pr_auc': 0.8864550447509748, 'per_class_f1': {'0': 0.9912770195864936, '1': 0.8019106490587243}, 'confusion_matrix': [[80116, 744], [666, 2854]], 'num_classes': 2, 'num_samples': 84380, 'loss': 0.027787391035568675, 'threshold': 0.6435353535353535, 'positive_count': 3520, 'positive_rate': 0.041716046456506284}
# [INFO] saved summary: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/separate_gate_ws64_src02_dst01/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/separate_gate_ws64_src02_dst01

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/separate_gate_ws64_src02_dst02 \
  --context_method source_destination \
  --context_policy online \
  --window_size 64 \
  --model_type source_destination_attention \
  --context_scale 0.2 \
  --source_context_scale 0.2 \
  --destination_context_scale 0.2 \
  --gate_bias_init -2.0 \
  --use_context_length_feature \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: source_destination, window_size: 64, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [{'source': array([0]), 'destination': array([0])}, {'source': array([1]), 'destination': array([1])}, {'source': array([2]), 'destination': array([2])}]
#
# [Dual Context Diagnostics] by split:
#
# source_history_len:
#           count       mean        std  min   50%   90%   95%   max
# split
# test    84380.0  51.957893  21.295111  0.0  63.0  63.0  63.0  63.0
# train  295329.0  43.601705  25.760844  0.0  63.0  63.0  63.0  63.0
# val     42189.0  51.143260  21.969256  0.0  63.0  63.0  63.0  63.0
#
# destination_history_len:
#           count       mean        std  min   50%   90%   95%   max
# split
# test    84380.0  48.873181  22.788240  0.0  63.0  63.0  63.0  63.0
# train  295329.0  39.256964  26.558420  0.0  61.0  63.0  63.0  63.0
# val     42189.0  47.933016  23.359634  0.0  63.0  63.0  63.0  63.0
#
# total_history_len:
#           count        mean        std  min    50%    90%    95%    max
# split
# test    84380.0  100.831074  27.077641  0.0  112.0  126.0  126.0  126.0
# train  295329.0   82.858669  34.644915  0.0   75.0  126.0  126.0  126.0
# val     42189.0   99.076276  27.562866  0.0  104.0  126.0  126.0  126.0
#
# [Dual Context Diagnostics] by split and label:
#
# source_history_len:
#                 count       mean        std  min   50%   90%   95%   max
# split label
# test  0       80860.0  51.625649  21.514954  0.0  63.0  63.0  63.0  63.0
#       1        3520.0  59.590057  13.287276  0.0  63.0  63.0  63.0  63.0
# train 0      283999.0  43.189427  25.900253  0.0  63.0  63.0  63.0  63.0
#       1       11330.0  53.935922  19.289177  0.0  63.0  63.0  63.0  63.0
# val   0       40395.0  50.795990  22.185318  0.0  63.0  63.0  63.0  63.0
#       1        1794.0  58.962653  14.286224  0.0  63.0  63.0  63.0  63.0
#
# destination_history_len:
#                 count       mean        std  min   50%   90%   95%   max
# split label
# test  0       80860.0  49.304316  22.533661  0.0  63.0  63.0  63.0  63.0
#       1        3520.0  38.969318  26.118659  0.0  54.0  63.0  63.0  63.0
# train 0      283999.0  39.665580  26.476605  0.0  63.0  63.0  63.0  63.0
#       1       11330.0  29.014563  26.553414  0.0  19.0  63.0  63.0  63.0
# val   0       40395.0  48.351306  23.131866  0.0  63.0  63.0  63.0  63.0
#       1        1794.0  38.514493  26.302841  0.0  55.0  63.0  63.0  63.0
#
# total_history_len:
#                 count        mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0  100.929965  27.052385  0.0  112.0  126.0  126.0  126.0
#       1        3520.0   98.559375  27.557816  5.0  104.0  126.0  126.0  126.0
# train 0      283999.0   82.855007  34.701367  0.0   75.0  126.0  126.0  126.0
#       1       11330.0   82.950485  33.199865  0.0   74.0  126.0  126.0  126.0
# val   0       40395.0   99.147295  27.526268  0.0  104.0  126.0  126.0  126.0
#       1        1794.0   97.477146  28.335213  4.0  101.0  126.0  126.0  126.0
#
# [Dual Context no-history rate] by split and label:
#              source_no_history  destination_no_history  both_no_history
# split label
# test  0               0.022298                0.020814         0.000099
#       1               0.015909                0.058807         0.000000
# train 0               0.065166                0.070208         0.003676
#       1               0.035305                0.117652         0.004237
# val   0               0.024756                0.023419         0.000025
#       1               0.018952                0.049610         0.000000
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] source context lengths: min=1, mean=47.03, p50=64.0, p95=64.0, max=64
# [INFO] destination context lengths: min=1, mean=43.05, p50=64.0, p95=64.0, max=64
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = source_destination_attention
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Stage2SourceDestinationAttention.__init__ use_positional_encoding=True, position_mode=age, nhead=4, dim_feedforward=256, dropout=0.25, context_scale=0.2, gate_bias_init=-2.0, source_context_scale=0.2, destination_context_scale=0.2, use_context_length_feature=True, use_multiplicative_fusion=False, cls_head_config=1
# Stage2SourceDestinationAttention(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
#   (src_query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (src_history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (src_cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (src_context_ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (src_context_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (dst_context_ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (dst_context_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (attn_dropout): Dropout(p=0.25, inplace=False)
#   (base_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (source_delta_head): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=386, out_features=128, bias=True)
#     (3): GELU(approximate='none')
#     (4): Dropout(p=0.25, inplace=False)
#     (5): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (source_gate): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=386, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
#   (destination_delta_head): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=386, out_features=128, bias=True)
#     (3): GELU(approximate='none')
#     (4): Dropout(p=0.25, inplace=False)
#     (5): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (destination_gate): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=386, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] make_train_loader: n0=283999, n1=11330, target_pos_frac=0.080, w0=3.23945e-06, w1=7.0609e-06, sample_weights=[3.23944803e-06 3.23944803e-06 3.23944803e-06 ... 7.06090026e-06
#  3.23944803e-06 3.23944803e-06]
# [INFO]---trainer.py---make_loss_fn---label 分布: [283999.  11330.]
# [INFO]manual_alpha = [1.0, 1.05]
# [INFO] Using manual alpha: [1.0, 1.05]
# [INFO] Using FocalLoss: gamma=1.0, label_smoothing=0.0
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit lr=3e-05, weight_decay=0.0003, patience=15, threshold=0.5, metric_for_best=pr_auc
# fit------best threshold =  0.5346464646464646
# [EPOCH 001] train_loss=0.214255 val_loss=0.078361 val_f1_label1=0.5507 val_macro_f1=0.7651 val_weighted_f1=0.9611833399549792 val_pr_auc=0.4893 val_auc=0.9505lr=0.00000720 *
# fit------best threshold =  0.5890909090909091
# [EPOCH 002] train_loss=0.044434 val_loss=0.025177 val_f1_label1=0.8136 val_macro_f1=0.9027 val_weighted_f1=0.9841580451782272 val_pr_auc=0.8654 val_auc=0.9881lr=0.00001290 *
# fit------best threshold =  0.6088888888888889
# [EPOCH 003] train_loss=0.032752 val_loss=0.024364 val_f1_label1=0.8203 val_macro_f1=0.9061 val_weighted_f1=0.984640627145882 val_pr_auc=0.8952 val_auc=0.9904lr=0.00001860 *
# fit------best threshold =  0.5742424242424242
# [EPOCH 004] train_loss=0.029050 val_loss=0.022974 val_f1_label1=0.8216 val_macro_f1=0.9068 val_weighted_f1=0.984729397627221 val_pr_auc=0.9036 val_auc=0.9918lr=0.00002430 *
# fit------best threshold =  0.5841414141414141
# [EPOCH 005] train_loss=0.026571 val_loss=0.023137 val_f1_label1=0.8225 val_macro_f1=0.9073 val_weighted_f1=0.9848390416816215 val_pr_auc=0.9064 val_auc=0.9921lr=0.00003000 *
# fit------best threshold =  0.6088888888888889
# [EPOCH 006] train_loss=0.025354 val_loss=0.023372 val_f1_label1=0.8249 val_macro_f1=0.9085 val_weighted_f1=0.9850732394720693 val_pr_auc=0.9081 val_auc=0.9921lr=0.00003000 *
# fit------best threshold =  0.6138383838383838
# [EPOCH 007] train_loss=0.024787 val_loss=0.022346 val_f1_label1=0.8249 val_macro_f1=0.9087 val_weighted_f1=0.9852738935684214 val_pr_auc=0.9097 val_auc=0.9920lr=0.00003000 *
# fit------best threshold =  0.6088888888888889
# [EPOCH 008] train_loss=0.023627 val_loss=0.023052 val_f1_label1=0.8256 val_macro_f1=0.9089 val_weighted_f1=0.9851758337953055 val_pr_auc=0.9100 val_auc=0.9921lr=0.00003000 *
# fit------best threshold =  0.6138383838383838
# [EPOCH 009] train_loss=0.023111 val_loss=0.022377 val_f1_label1=0.8285 val_macro_f1=0.9106 val_weighted_f1=0.9856172506573588 val_pr_auc=0.9102 val_auc=0.9918lr=0.00003000 *
# fit------best threshold =  0.6385858585858586
# [EPOCH 010] train_loss=0.023032 val_loss=0.022295 val_f1_label1=0.8280 val_macro_f1=0.9103 val_weighted_f1=0.9856590462389906 val_pr_auc=0.9117 val_auc=0.9918lr=0.00002999 *
# fit------best threshold =  0.6534343434343434
# [EPOCH 011] train_loss=0.022587 val_loss=0.022758 val_f1_label1=0.8275 val_macro_f1=0.9100 val_weighted_f1=0.9855630543360916 val_pr_auc=0.9114 val_auc=0.9919lr=0.00002999
# fit------best threshold =  0.6435353535353535
# [EPOCH 012] train_loss=0.022004 val_loss=0.022528 val_f1_label1=0.8290 val_macro_f1=0.9108 val_weighted_f1=0.9856853661799245 val_pr_auc=0.9126 val_auc=0.9920lr=0.00002999 *
# fit------best threshold =  0.6484848484848484
# [EPOCH 013] train_loss=0.022260 val_loss=0.023043 val_f1_label1=0.8283 val_macro_f1=0.9104 val_weighted_f1=0.9856192265020233 val_pr_auc=0.9111 val_auc=0.9918lr=0.00002998
# fit------best threshold =  0.5841414141414141
# [EPOCH 014] train_loss=0.021637 val_loss=0.022498 val_f1_label1=0.8285 val_macro_f1=0.9105 val_weighted_f1=0.9855551738088304 val_pr_auc=0.9120 val_auc=0.9917lr=0.00002998
# fit------best threshold =  0.6088888888888889
# [EPOCH 015] train_loss=0.021914 val_loss=0.023233 val_f1_label1=0.8285 val_macro_f1=0.9104 val_weighted_f1=0.9854309029195395 val_pr_auc=0.9107 val_auc=0.9913lr=0.00002997
# fit------best threshold =  0.5890909090909091
# [EPOCH 016] train_loss=0.021812 val_loss=0.023098 val_f1_label1=0.8302 val_macro_f1=0.9113 val_weighted_f1=0.9854515459389727 val_pr_auc=0.9126 val_auc=0.9916lr=0.00002996
# fit------best threshold =  0.6138383838383838
# [EPOCH 017] train_loss=0.021339 val_loss=0.023058 val_f1_label1=0.8287 val_macro_f1=0.9106 val_weighted_f1=0.9855630926792114 val_pr_auc=0.9100 val_auc=0.9911lr=0.00002996
# fit------best threshold =  0.594040404040404
# [EPOCH 018] train_loss=0.020410 val_loss=0.023300 val_f1_label1=0.8281 val_macro_f1=0.9102 val_weighted_f1=0.9853532323247575 val_pr_auc=0.9114 val_auc=0.9914lr=0.00002995
# fit------best threshold =  0.5692929292929293
# [EPOCH 019] train_loss=0.020888 val_loss=0.023709 val_f1_label1=0.8281 val_macro_f1=0.9101 val_weighted_f1=0.9852150380424973 val_pr_auc=0.9098 val_auc=0.9910lr=0.00002994
# fit------best threshold =  0.5791919191919191
# [EPOCH 020] train_loss=0.020535 val_loss=0.023317 val_f1_label1=0.8305 val_macro_f1=0.9114 val_weighted_f1=0.9854384643595381 val_pr_auc=0.9117 val_auc=0.9912lr=0.00002993
# fit------best threshold =  0.6039393939393939
# [EPOCH 021] train_loss=0.020183 val_loss=0.024269 val_f1_label1=0.8308 val_macro_f1=0.9116 val_weighted_f1=0.9855371804000395 val_pr_auc=0.9107 val_auc=0.9908lr=0.00002992
# fit------best threshold =  0.594040404040404
# [EPOCH 022] train_loss=0.019874 val_loss=0.023872 val_f1_label1=0.8317 val_macro_f1=0.9121 val_weighted_f1=0.9857221708707684 val_pr_auc=0.9102 val_auc=0.9908lr=0.00002991
# fit------best threshold =  0.5890909090909091
# [EPOCH 023] train_loss=0.019685 val_loss=0.024377 val_f1_label1=0.8295 val_macro_f1=0.9109 val_weighted_f1=0.9854453764717572 val_pr_auc=0.9094 val_auc=0.9904lr=0.00002990
# fit------best threshold =  0.5742424242424242
# [EPOCH 024] train_loss=0.020199 val_loss=0.024796 val_f1_label1=0.8302 val_macro_f1=0.9113 val_weighted_f1=0.9854027835911642 val_pr_auc=0.9088 val_auc=0.9900lr=0.00002989
# fit------best threshold =  0.6039393939393939
# [EPOCH 025] train_loss=0.019238 val_loss=0.024588 val_f1_label1=0.8294 val_macro_f1=0.9109 val_weighted_f1=0.9854313371065484 val_pr_auc=0.9087 val_auc=0.9901lr=0.00002988
# fit------best threshold =  0.5692929292929293
# [EPOCH 026] train_loss=0.019594 val_loss=0.025422 val_f1_label1=0.8298 val_macro_f1=0.9109 val_weighted_f1=0.9851853543472378 val_pr_auc=0.9096 val_auc=0.9906lr=0.00002987
# fit------best threshold =  0.5742424242424242
# [EPOCH 027] train_loss=0.019553 val_loss=0.025815 val_f1_label1=0.8287 val_macro_f1=0.9104 val_weighted_f1=0.9852517788376265 val_pr_auc=0.9094 val_auc=0.9905lr=0.00002986
# [INFO] Early stopping at epoch=27, best_epoch=12
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.6435
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9858967977434876, 'macro_precision': 0.9235479252223175, 'macro_recall': 0.898887408248231, 'macro_f1': 0.9108094965919076, 'weighted_precision': 0.9855466585279073, 'weighted_recall': 0.9858967977434876, 'weighted_f1': 0.9856853661799245, 'precision_label1': 0.8557863501483679, 'recall_label1': 0.8037904124860646, 'f1_label1': 0.8289738430583501, 'auc': 0.9919592656850281, 'pr_auc': 0.9126216527963581, 'per_class_f1': {'0': 0.9926451501254651, '1': 0.8289738430583501}, 'confusion_matrix': [[40152, 243], [352, 1442]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6435353535353535}
#
# ========== STAGE2 THRESHOLD ORACLE DIAGNOSIS ==========
# [VAL ORACLE THRESHOLD] 0.643535
# [VAL ORACLE METRICS] {'accuracy': 0.9858967977434876, 'macro_precision': 0.9235479252223175, 'macro_recall': 0.898887408248231, 'macro_f1': 0.9108094965919076, 'weighted_precision': 0.9855466585279073, 'weighted_recall': 0.9858967977434876, 'weighted_f1': 0.9856853661799245, 'precision_label1': 0.8557863501483679, 'recall_label1': 0.8037904124860646, 'f1_label1': 0.8289738430583501, 'auc': 0.9919593070822506, 'pr_auc': 0.9126128620888346, 'per_class_f1': {'0': 0.9926451501254651, '1': 0.8289738430583501}, 'confusion_matrix': [[40152, 243], [352, 1442]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6435353535353535}
#
# [TEST AT VAL THRESHOLD] 0.643535
# [TEST AT VAL THRESHOLD METRICS] {'accuracy': 0.983278027968713, 'macro_precision': 0.8926787927084997, 'macro_recall': 0.9002475518854136, 'macro_f1': 0.8964231178452791, 'weighted_precision': 0.9834446785478336, 'weighted_recall': 0.983278027968713, 'weighted_f1': 0.9833578361533506, 'precision_label1': 0.7936507936507936, 'recall_label1': 0.8096590909090909, 'f1_label1': 0.8015750246097595, 'auc': 0.9910097014621232, 'pr_auc': 0.8862225496578874, 'per_class_f1': {'0': 0.9912712110807985, '1': 0.8015750246097595}, 'confusion_matrix': [[80119, 741], [670, 2850]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6435353535353535}
#
# [TEST ORACLE THRESHOLD - DIAGNOSTIC ONLY] 0.643535
# [TEST ORACLE METRICS] {'accuracy': 0.983278027968713, 'macro_precision': 0.8926787927084997, 'macro_recall': 0.9002475518854136, 'macro_f1': 0.8964231178452791, 'weighted_precision': 0.9834446785478336, 'weighted_recall': 0.983278027968713, 'weighted_f1': 0.9833578361533506, 'precision_label1': 0.7936507936507936, 'recall_label1': 0.8096590909090909, 'f1_label1': 0.8015750246097595, 'auc': 0.9910097014621232, 'pr_auc': 0.8862225496578874, 'per_class_f1': {'0': 0.9912712110807985, '1': 0.8015750246097595}, 'confusion_matrix': [[80119, 741], [670, 2850]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6435353535353535}
#
# [THRESHOLD TRANSFER GAP] 0.000000
# =======================================================
#
# [INFO] saved predictions: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/separate_gate_ws64_src02_dst02/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/separate_gate_ws64_src02_dst02/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/separate_gate_ws64_src02_dst02/stage2_predictions_test.csv
#
# ==================================================
#             Stage2 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0278
#   F1 (Macro):        0.8965
#   Recall (Macro):    0.9003
#   Precision (Macro): 0.8928
#   F1_class1:         0.8017
#   R1_class1:         0.8097
#   P1_class1:         0.7939
#   AUC (OvR Macro):   0.9910
#   PR_AUC:            0.8862
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9913
#   Class_1                       : 0.8017
#
# [TEST] Full metrics: {'accuracy': 0.9832898791182745, 'macro_precision': 0.8927893803564453, 'macro_recall': 0.9002537354124975, 'macro_f1': 0.8964826074983588, 'weighted_precision': 0.9834539991937492, 'weighted_recall': 0.9832898791182745, 'weighted_f1': 0.9833685190692697, 'precision_label1': 0.7938718662952646, 'recall_label1': 0.8096590909090909, 'f1_label1': 0.8016877637130801, 'auc': 0.9910098999673959, 'pr_auc': 0.8862373509887234, 'per_class_f1': {'0': 0.9912774512836375, '1': 0.8016877637130801}, 'confusion_matrix': [[80120, 740], [670, 2850]], 'num_classes': 2, 'num_samples': 84380, 'loss': 0.027837589670530977, 'threshold': 0.6435353535353535, 'positive_count': 3520, 'positive_rate': 0.041716046456506284}
# [INFO] saved summary: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/separate_gate_ws64_src02_dst02/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/dual_host_attention/separate_gate_ws64_src02_dst02

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/source_destination_attention/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/source_destination_attention/ws128_src02_dst01_precision_at_recall80 \
  --context_method source_destination \
  --context_policy online \
  --window_size 128 \
  --model_type source_destination_attention \
  --source_context_scale 0.2 \
  --destination_context_scale 0.1 \
  --gate_bias_init -2.0 \
  --source_gate_bias_init -2.0 \
  --destination_gate_bias_init -3.0 \
  --use_context_length_feature \
  --threshold_metric precision_at_recall \
  --threshold_recall_floor 0.80 \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: source_destination, window_size: 128, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [{'source': array([0]), 'destination': array([0])}, {'source': array([1]), 'destination': array([1])}, {'source': array([2]), 'destination': array([2])}]
#
# [Dual Context Diagnostics] by split:
#
# source_history_len:
#           count       mean        std  min    50%    90%    95%    max
# split
# test    84380.0  98.841088  47.513911  0.0  127.0  127.0  127.0  127.0
# train  295329.0  77.019328  53.856065  0.0  106.0  127.0  127.0  127.0
# val     42189.0  96.761431  48.540006  0.0  127.0  127.0  127.0  127.0
#
# destination_history_len:
#           count       mean        std  min    50%    90%    95%    max
# split
# test    84380.0  89.765975  50.671856  0.0  127.0  127.0  127.0  127.0
# train  295329.0  66.671583  54.095576  0.0   61.0  127.0  127.0  127.0
# val     42189.0  87.496693  51.429910  0.0  127.0  127.0  127.0  127.0
#
# total_history_len:
#           count        mean        std  min    50%    90%    95%    max
# split
# test    84380.0  188.607063  58.724723  0.0  175.0  254.0  254.0  254.0
# train  295329.0  143.690911  72.604584  0.0  135.0  254.0  254.0  254.0
# val     42189.0  184.258124  59.231725  0.0  166.0  254.0  254.0  254.0
#
# [Dual Context Diagnostics] by split and label:
#
# source_history_len:
#                 count        mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0   98.012293  47.967612  0.0  127.0  127.0  127.0  127.0
#       1        3520.0  117.879830  29.739745  0.0  127.0  127.0  127.0  127.0
# train 0      283999.0   76.147736  54.024357  0.0  102.0  127.0  127.0  127.0
#       1       11330.0   98.866726  44.149883  0.0  127.0  127.0  127.0  127.0
# val   0       40395.0   95.924347  48.970889  0.0  127.0  127.0  127.0  127.0
#       1        1794.0  115.609810  32.243435  0.0  127.0  127.0  127.0  127.0
#
# destination_history_len:
#                 count       mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0  90.827467  50.273394  0.0  127.0  127.0  127.0  127.0
#       1        3520.0  65.381818  53.590606  0.0   54.0  127.0  127.0  127.0
# train 0      283999.0  67.537115  54.077592  0.0   64.0  127.0  127.0  127.0
#       1       11330.0  44.976081  49.858196  0.0   19.0  127.0  127.0  127.0
# val   0       40395.0  88.509419  51.087733  0.0  127.0  127.0  127.0  127.0
#       1        1794.0  64.693423  53.790454  0.0   55.0  127.0  127.0  127.0
#
# total_history_len:
#                 count        mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0  188.839760  58.771755  0.0  175.0  254.0  254.0  254.0
#       1        3520.0  183.261648  57.382659  5.0  166.0  254.0  254.0  254.0
# train 0      283999.0  143.684851  72.742683  0.0  135.0  254.0  254.0  254.0
#       1       11330.0  143.842807  69.055692  0.0  134.0  254.0  254.0  254.0
# val   0       40395.0  184.433767  59.259928  0.0  167.0  254.0  254.0  254.0
#       1        1794.0  180.303233  58.469822  4.0  162.5  254.0  254.0  254.0
#
# [Dual Context no-history rate] by split and label:
#              source_no_history  destination_no_history  both_no_history
# split label
# test  0               0.022298                0.020814         0.000099
#       1               0.015909                0.058807         0.000000
# train 0               0.065166                0.070208         0.003676
#       1               0.035305                0.117652         0.004237
# val   0               0.024756                0.023419         0.000025
#       1               0.018952                0.049610         0.000000
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] source context lengths: min=1, mean=84.36, p50=128.0, p95=128.0, max=128
# [INFO] destination context lengths: min=1, mean=74.37, p50=89.0, p95=128.0, max=128
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = source_destination_attention
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Stage2SourceDestinationAttention.__init__ use_positional_encoding=True, position_mode=age, nhead=4, dim_feedforward=256, dropout=0.25, context_scale=0.2, gate_bias_init=-2.0, source_gate_bias_init=-2.0, destination_gate_bias_init=-3.0, source_context_scale=0.2, destination_context_scale=0.1, use_context_length_feature=True, use_multiplicative_fusion=False, cls_head_config=1
# Stage2SourceDestinationAttention(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
#   (src_query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (src_history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (src_cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (src_context_ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (src_context_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (dst_context_ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (dst_context_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (attn_dropout): Dropout(p=0.25, inplace=False)
#   (base_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (source_delta_head): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=386, out_features=128, bias=True)
#     (3): GELU(approximate='none')
#     (4): Dropout(p=0.25, inplace=False)
#     (5): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (source_gate): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=386, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
#   (destination_delta_head): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=386, out_features=128, bias=True)
#     (3): GELU(approximate='none')
#     (4): Dropout(p=0.25, inplace=False)
#     (5): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (destination_gate): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=386, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] make_train_loader: n0=283999, n1=11330, target_pos_frac=0.080, w0=3.23945e-06, w1=7.0609e-06, sample_weights=[3.23944803e-06 3.23944803e-06 3.23944803e-06 ... 7.06090026e-06
#  3.23944803e-06 3.23944803e-06]
# [INFO]---trainer.py---make_loss_fn---label 分布: [283999.  11330.]
# [INFO]manual_alpha = [1.0, 1.05]
# [INFO] Using manual alpha: [1.0, 1.05]
# [INFO] Using FocalLoss: gamma=1.0, label_smoothing=0.0
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit lr=3e-05, weight_decay=0.0003, patience=15, threshold=0.5, metric_for_best=pr_auc
# fit------best threshold =  0.4505050505050505
# [EPOCH 001] train_loss=0.221179 val_loss=0.090877 val_f1_label1=0.3873 val_macro_f1=0.6640 val_weighted_f1=0.9171289199102547 val_pr_auc=0.4646 val_auc=0.9455lr=0.00000720 *
# fit------best threshold =  0.6039393939393939
# [EPOCH 002] train_loss=0.046509 val_loss=0.025222 val_f1_label1=0.8106 val_macro_f1=0.9011 val_weighted_f1=0.9839598854871897 val_pr_auc=0.8640 val_auc=0.9880lr=0.00001290 *
# fit------best threshold =  0.6484848484848484
# [EPOCH 003] train_loss=0.032754 val_loss=0.024329 val_f1_label1=0.8179 val_macro_f1=0.9050 val_weighted_f1=0.9846773822111885 val_pr_auc=0.8945 val_auc=0.9900lr=0.00001860 *
# fit------best threshold =  0.6484848484848484
# [EPOCH 004] train_loss=0.029323 val_loss=0.023414 val_f1_label1=0.8200 val_macro_f1=0.9061 val_weighted_f1=0.9848740812482782 val_pr_auc=0.9033 val_auc=0.9916lr=0.00002430 *
# fit------best threshold =  0.6336363636363637
# [EPOCH 005] train_loss=0.026718 val_loss=0.023181 val_f1_label1=0.8204 val_macro_f1=0.9063 val_weighted_f1=0.9849043122814054 val_pr_auc=0.9060 val_auc=0.9919lr=0.00003000 *
# fit------best threshold =  0.6583838383838384
# [EPOCH 006] train_loss=0.025460 val_loss=0.023773 val_f1_label1=0.8206 val_macro_f1=0.9064 val_weighted_f1=0.9849126411293923 val_pr_auc=0.9071 val_auc=0.9919lr=0.00003000 *
# fit------best threshold =  0.6385858585858586
# [EPOCH 007] train_loss=0.024761 val_loss=0.022598 val_f1_label1=0.8232 val_macro_f1=0.9078 val_weighted_f1=0.9851767977109708 val_pr_auc=0.9089 val_auc=0.9920lr=0.00003000 *
# fit------best threshold =  0.6534343434343434
# [EPOCH 008] train_loss=0.023733 val_loss=0.022978 val_f1_label1=0.8242 val_macro_f1=0.9083 val_weighted_f1=0.9852687905719056 val_pr_auc=0.9103 val_auc=0.9923lr=0.00003000 *
# fit------best threshold =  0.6187878787878788
# [EPOCH 009] train_loss=0.023302 val_loss=0.022112 val_f1_label1=0.8242 val_macro_f1=0.9083 val_weighted_f1=0.9852687905719056 val_pr_auc=0.9110 val_auc=0.9920lr=0.00003000 *
# fit------best threshold =  0.6187878787878788
# [EPOCH 010] train_loss=0.023203 val_loss=0.022235 val_f1_label1=0.8272 val_macro_f1=0.9099 val_weighted_f1=0.9855509039635161 val_pr_auc=0.9112 val_auc=0.9920lr=0.00002999 *
# fit------best threshold =  0.6682828282828283
# [EPOCH 011] train_loss=0.022632 val_loss=0.022926 val_f1_label1=0.8274 val_macro_f1=0.9100 val_weighted_f1=0.9855729598418005 val_pr_auc=0.9117 val_auc=0.9920lr=0.00002999 *
# fit------best threshold =  0.6583838383838384
# [EPOCH 012] train_loss=0.021739 val_loss=0.022564 val_f1_label1=0.8287 val_macro_f1=0.9107 val_weighted_f1=0.985687351509249 val_pr_auc=0.9133 val_auc=0.9922lr=0.00002999 *
# fit------best threshold =  0.6583838383838384
# [EPOCH 013] train_loss=0.022248 val_loss=0.023257 val_f1_label1=0.8315 val_macro_f1=0.9121 val_weighted_f1=0.9859101527670339 val_pr_auc=0.9095 val_auc=0.9914lr=0.00002998
# fit------best threshold =  0.6138383838383838
# [EPOCH 014] train_loss=0.021627 val_loss=0.022488 val_f1_label1=0.8263 val_macro_f1=0.9094 val_weighted_f1=0.9854668080316655 val_pr_auc=0.9124 val_auc=0.9919lr=0.00002998
# fit------best threshold =  0.6633333333333333
# [EPOCH 015] train_loss=0.021741 val_loss=0.023929 val_f1_label1=0.8284 val_macro_f1=0.9105 val_weighted_f1=0.9856512592354504 val_pr_auc=0.9072 val_auc=0.9908lr=0.00002997
# fit------best threshold =  0.6484848484848484
# [EPOCH 016] train_loss=0.021605 val_loss=0.023264 val_f1_label1=0.8282 val_macro_f1=0.9104 val_weighted_f1=0.9856291997084949 val_pr_auc=0.9100 val_auc=0.9914lr=0.00002996
# fit------best threshold =  0.6336363636363637
# [EPOCH 017] train_loss=0.021379 val_loss=0.022530 val_f1_label1=0.8285 val_macro_f1=0.9106 val_weighted_f1=0.9856652722007613 val_pr_auc=0.9099 val_auc=0.9914lr=0.00002996
# fit------best threshold =  0.6435353535353535
# [EPOCH 018] train_loss=0.020234 val_loss=0.023080 val_f1_label1=0.8287 val_macro_f1=0.9107 val_weighted_f1=0.9856733243055608 val_pr_auc=0.9109 val_auc=0.9915lr=0.00002995
# fit------best threshold =  0.6435353535353535
# [EPOCH 019] train_loss=0.020833 val_loss=0.023531 val_f1_label1=0.8292 val_macro_f1=0.9109 val_weighted_f1=0.9857315268275152 val_pr_auc=0.9091 val_auc=0.9909lr=0.00002994
# fit------best threshold =  0.6435353535353535
# [EPOCH 020] train_loss=0.020578 val_loss=0.022974 val_f1_label1=0.8304 val_macro_f1=0.9115 val_weighted_f1=0.9857793944268526 val_pr_auc=0.9105 val_auc=0.9915lr=0.00002993
# fit------best threshold =  0.6633333333333333
# [EPOCH 021] train_loss=0.020128 val_loss=0.024308 val_f1_label1=0.8283 val_macro_f1=0.9105 val_weighted_f1=0.9856332271561303 val_pr_auc=0.9099 val_auc=0.9911lr=0.00002992
# fit------best threshold =  0.6336363636363637
# [EPOCH 022] train_loss=0.019833 val_loss=0.023572 val_f1_label1=0.8303 val_macro_f1=0.9115 val_weighted_f1=0.985813811931253 val_pr_auc=0.9112 val_auc=0.9914lr=0.00002991
# fit------best threshold =  0.6583838383838384
# [EPOCH 023] train_loss=0.019655 val_loss=0.024068 val_f1_label1=0.8281 val_macro_f1=0.9104 val_weighted_f1=0.9856391607735898 val_pr_auc=0.9113 val_auc=0.9915lr=0.00002990
# fit------best threshold =  0.6534343434343434
# [EPOCH 024] train_loss=0.020123 val_loss=0.024688 val_f1_label1=0.8294 val_macro_f1=0.9110 val_weighted_f1=0.9857254864776172 val_pr_auc=0.9086 val_auc=0.9901lr=0.00002989
# fit------best threshold =  0.6385858585858586
# [EPOCH 025] train_loss=0.019147 val_loss=0.023741 val_f1_label1=0.8259 val_macro_f1=0.9092 val_weighted_f1=0.9854227656760368 val_pr_auc=0.9099 val_auc=0.9906lr=0.00002988
# fit------best threshold =  0.6633333333333333
# [EPOCH 026] train_loss=0.019558 val_loss=0.025456 val_f1_label1=0.8272 val_macro_f1=0.9099 val_weighted_f1=0.9855131426575615 val_pr_auc=0.9090 val_auc=0.9914lr=0.00002987
# fit------best threshold =  0.6385858585858586
# [EPOCH 027] train_loss=0.019313 val_loss=0.024372 val_f1_label1=0.8260 val_macro_f1=0.9092 val_weighted_f1=0.9854268415722843 val_pr_auc=0.9104 val_auc=0.9916lr=0.00002986
# [INFO] Early stopping at epoch=27, best_epoch=12
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.6584
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9859205006044229, 'macro_precision': 0.9248056938953979, 'macro_recall': 0.897568140863157, 'macro_f1': 0.9106891163191705, 'weighted_precision': 0.985542869914941, 'weighted_recall': 0.9859205006044229, 'weighted_f1': 0.985687351509249, 'precision_label1': 0.8584229390681004, 'recall_label1': 0.8010033444816054, 'f1_label1': 0.828719723183391, 'auc': 0.9922250220543702, 'pr_auc': 0.9133370886017915, 'per_class_f1': {'0': 0.9926585094549499, '1': 0.828719723183391}, 'confusion_matrix': [[40158, 237], [357, 1437]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6583838383838384, 'threshold_objective': 'precision_at_recall', 'threshold_objective_value': 0.8584229390681004, 'threshold_recall_floor': 0.8, 'threshold_precision_floor': 0.0}
#
# ========== STAGE2 THRESHOLD ORACLE DIAGNOSIS ==========
# [VAL ORACLE THRESHOLD] 0.658384
# [VAL ORACLE METRICS] {'accuracy': 0.9859205006044229, 'macro_precision': 0.9248056938953979, 'macro_recall': 0.897568140863157, 'macro_f1': 0.9106891163191705, 'weighted_precision': 0.985542869914941, 'weighted_recall': 0.9859205006044229, 'weighted_f1': 0.985687351509249, 'precision_label1': 0.8584229390681004, 'recall_label1': 0.8010033444816054, 'f1_label1': 0.828719723183391, 'auc': 0.9922246494793677, 'pr_auc': 0.913327537303977, 'per_class_f1': {'0': 0.9926585094549499, '1': 0.828719723183391}, 'confusion_matrix': [[40158, 237], [357, 1437]], 'num_classes': 2, 'num_samples': 42189, 'threshold': 0.6583838383838384, 'threshold_objective': 'precision_at_recall', 'threshold_objective_value': 0.8584229390681004, 'threshold_recall_floor': 0.8, 'threshold_precision_floor': 0.0}
#
# [TEST AT VAL THRESHOLD] 0.658384
# [TEST AT VAL THRESHOLD METRICS] {'accuracy': 0.983396539464328, 'macro_precision': 0.8951802427466562, 'macro_recall': 0.8978638724619432, 'macro_f1': 0.8965170264663709, 'weighted_precision': 0.9834536078410376, 'weighted_recall': 0.983396539464328, 'weighted_f1': 0.9834246321736981, 'precision_label1': 0.7988716502115656, 'recall_label1': 0.8045454545454546, 'f1_label1': 0.8016985138004247, 'auc': 0.991240965375059, 'pr_auc': 0.8876490291838819, 'per_class_f1': {'0': 0.991335539132317, '1': 0.8016985138004247}, 'confusion_matrix': [[80147, 713], [688, 2832]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6583838383838384}
#
# [TEST ORACLE THRESHOLD - DIAGNOSTIC ONLY] 0.663333
# [TEST ORACLE METRICS] {'accuracy': 0.9834794975112586, 'macro_precision': 0.8965251645643599, 'macro_recall': 0.8969561236592989, 'macro_f1': 0.896740514484145, 'weighted_precision': 0.9834884929421743, 'weighted_recall': 0.9834794975112586, 'weighted_f1': 0.9834839838556791, 'precision_label1': 0.8016458569807038, 'recall_label1': 0.8025568181818182, 'f1_label1': 0.8021010789324248, 'auc': 0.991240965375059, 'pr_auc': 0.8876490291838819, 'per_class_f1': {'0': 0.9913799500358653, '1': 0.8021010789324248}, 'confusion_matrix': [[80161, 699], [695, 2825]], 'num_classes': 2, 'num_samples': 84380, 'threshold': 0.6633333333333333, 'threshold_objective': 'precision_at_recall', 'threshold_objective_value': 0.8016458569807038, 'threshold_recall_floor': 0.8, 'threshold_precision_floor': 0.0}
#
# [THRESHOLD TRANSFER GAP] 0.000403
# =======================================================
#
# [INFO] saved predictions: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/source_destination_attention/ws128_src02_dst01_precision_at_recall80/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/source_destination_attention/ws128_src02_dst01_precision_at_recall80/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/source_destination_attention/ws128_src02_dst01_precision_at_recall80/stage2_predictions_test.csv
#
# ==================================================
#             Stage2 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0278
#   F1 (Macro):        0.8965
#   Recall (Macro):    0.8979
#   Precision (Macro): 0.8952
#   F1_class1:         0.8017
#   R1_class1:         0.8045
#   P1_class1:         0.7989
#   AUC (OvR Macro):   0.9912
#   PR_AUC:            0.8877
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9913
#   Class_1                       : 0.8017
#
# [TEST] Full metrics: {'accuracy': 0.983396539464328, 'macro_precision': 0.8951802427466562, 'macro_recall': 0.8978638724619432, 'macro_f1': 0.8965170264663709, 'weighted_precision': 0.9834536078410376, 'weighted_recall': 0.983396539464328, 'weighted_f1': 0.9834246321736981, 'precision_label1': 0.7988716502115656, 'recall_label1': 0.8045454545454546, 'f1_label1': 0.8016985138004247, 'auc': 0.991240870514132, 'pr_auc': 0.8876581028960786, 'per_class_f1': {'0': 0.991335539132317, '1': 0.8016985138004247}, 'confusion_matrix': [[80147, 713], [688, 2832]], 'num_classes': 2, 'num_samples': 84380, 'loss': 0.02779806487808979, 'threshold': 0.6583838383838384, 'positive_count': 3520, 'positive_rate': 0.041716046456506284}
# [INFO] saved summary: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/source_destination_attention/ws128_src02_dst01_precision_at_recall80/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/source_destination_attention/ws128_src02_dst01_precision_at_recall80

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/source_destination_attention/stage2_config_used.yaml \
  --out_dir /content/drive/MyDrive/s2/0708ar002_et12_20260511_001/source_destination_attention/ws128_precision_regularized_v1 \
  --context_method source_destination \
  --context_policy online \
  --window_size 128 \
  --model_type source_destination_attention \
  --source_context_scale 0.2 \
  --destination_context_scale 0.1 \
  --gate_bias_init -2.0 \
  --source_gate_bias_init -2.0 \
  --destination_gate_bias_init -3.0 \
  --use_context_length_feature \
  --metric_for_best precision_label1 \
  --threshold_metric precision_lcb_at_recall \
  --threshold_recall_floor 0.80 \
  --threshold_precision_lcb_z 1.0 \
  --false_positive_penalty_weight 0.08 \
  --false_positive_penalty_margin 0.55 \
  --false_positive_topk_ratio 0.5 \
  --positive_margin_penalty_weight 0.02 \
  --positive_margin 0.45 \
  --sampler_pos_fraction 0.06 \
  --negative_alpha 1.0 \
  --positive_alpha 1.03 \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [S2-ContextIndexBuilder]--context method: source_destination, window_size: 128, include_target: True, context_policy: online, endpoint_mode: same_endpoint, deduplicate: True
# [INFO] Stage2 --------- context_indices =  [{'source': array([0]), 'destination': array([0])}, {'source': array([1]), 'destination': array([1])}, {'source': array([2]), 'destination': array([2])}]
#
# [Dual Context Diagnostics] by split:
#
# source_history_len:
#           count       mean        std  min    50%    90%    95%    max
# split
# test    84380.0  98.841088  47.513911  0.0  127.0  127.0  127.0  127.0
# train  295329.0  77.019328  53.856065  0.0  106.0  127.0  127.0  127.0
# val     42189.0  96.761431  48.540006  0.0  127.0  127.0  127.0  127.0
#
# destination_history_len:
#           count       mean        std  min    50%    90%    95%    max
# split
# test    84380.0  89.765975  50.671856  0.0  127.0  127.0  127.0  127.0
# train  295329.0  66.671583  54.095576  0.0   61.0  127.0  127.0  127.0
# val     42189.0  87.496693  51.429910  0.0  127.0  127.0  127.0  127.0
#
# total_history_len:
#           count        mean        std  min    50%    90%    95%    max
# split
# test    84380.0  188.607063  58.724723  0.0  175.0  254.0  254.0  254.0
# train  295329.0  143.690911  72.604584  0.0  135.0  254.0  254.0  254.0
# val     42189.0  184.258124  59.231725  0.0  166.0  254.0  254.0  254.0
#
# [Dual Context Diagnostics] by split and label:
#
# source_history_len:
#                 count        mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0   98.012293  47.967612  0.0  127.0  127.0  127.0  127.0
#       1        3520.0  117.879830  29.739745  0.0  127.0  127.0  127.0  127.0
# train 0      283999.0   76.147736  54.024357  0.0  102.0  127.0  127.0  127.0
#       1       11330.0   98.866726  44.149883  0.0  127.0  127.0  127.0  127.0
# val   0       40395.0   95.924347  48.970889  0.0  127.0  127.0  127.0  127.0
#       1        1794.0  115.609810  32.243435  0.0  127.0  127.0  127.0  127.0
#
# destination_history_len:
#                 count       mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0  90.827467  50.273394  0.0  127.0  127.0  127.0  127.0
#       1        3520.0  65.381818  53.590606  0.0   54.0  127.0  127.0  127.0
# train 0      283999.0  67.537115  54.077592  0.0   64.0  127.0  127.0  127.0
#       1       11330.0  44.976081  49.858196  0.0   19.0  127.0  127.0  127.0
# val   0       40395.0  88.509419  51.087733  0.0  127.0  127.0  127.0  127.0
#       1        1794.0  64.693423  53.790454  0.0   55.0  127.0  127.0  127.0
#
# total_history_len:
#                 count        mean        std  min    50%    90%    95%    max
# split label
# test  0       80860.0  188.839760  58.771755  0.0  175.0  254.0  254.0  254.0
#       1        3520.0  183.261648  57.382659  5.0  166.0  254.0  254.0  254.0
# train 0      283999.0  143.684851  72.742683  0.0  135.0  254.0  254.0  254.0
#       1       11330.0  143.842807  69.055692  0.0  134.0  254.0  254.0  254.0
# val   0       40395.0  184.433767  59.259928  0.0  167.0  254.0  254.0  254.0
#       1        1794.0  180.303233  58.469822  4.0  162.5  254.0  254.0  254.0
#
# [Dual Context no-history rate] by split and label:
#              source_no_history  destination_no_history  both_no_history
# split label
# test  0               0.022298                0.020814         0.000099
#       1               0.015909                0.058807         0.000000
# train 0               0.065166                0.070208         0.003676
#       1               0.035305                0.117652         0.004237
# val   0               0.024756                0.023419         0.000025
#       1               0.018952                0.049610         0.000000
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] source context lengths: min=1, mean=84.36, p50=128.0, p95=128.0, max=128
# [INFO] destination context lengths: min=1, mean=74.37, p50=89.0, p95=128.0, max=128
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = source_destination_attention
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Stage2SourceDestinationAttention.__init__ use_positional_encoding=True, position_mode=age, nhead=4, dim_feedforward=256, dropout=0.25, context_scale=0.2, gate_bias_init=-2.0, source_gate_bias_init=-2.0, destination_gate_bias_init=-3.0, source_context_scale=0.2, destination_context_scale=0.1, use_context_length_feature=True, use_multiplicative_fusion=False, cls_head_config=1
# Stage2SourceDestinationAttention(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
#   (src_query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (src_history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (src_cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (src_context_ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (src_context_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_query_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_history_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (dst_cross_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (dst_context_ffn): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): Dropout(p=0.25, inplace=False)
#   )
#   (dst_context_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (attn_dropout): Dropout(p=0.25, inplace=False)
#   (base_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (source_delta_head): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=386, out_features=128, bias=True)
#     (3): GELU(approximate='none')
#     (4): Dropout(p=0.25, inplace=False)
#     (5): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (source_gate): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=386, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
#   (destination_delta_head): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Dropout(p=0.25, inplace=False)
#     (2): Linear(in_features=386, out_features=128, bias=True)
#     (3): GELU(approximate='none')
#     (4): Dropout(p=0.25, inplace=False)
#     (5): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (destination_gate): Sequential(
#     (0): LayerNorm((386,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=386, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=128, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] make_train_loader: n0=283999, n1=11330, target_pos_frac=0.060, w0=3.30987e-06, w1=5.29568e-06, sample_weights=[3.30987081e-06 3.30987081e-06 3.30987081e-06 ... 5.29567520e-06
#  3.30987081e-06 3.30987081e-06]
# [INFO]---trainer.py---make_loss_fn---label 分布: [283999.  11330.]
# [INFO]manual_alpha = [1.0, 1.03]
# [INFO] Using manual alpha: [1.0, 1.03]
# [INFO] Using FocalLoss: gamma=1.0, label_smoothing=0.0
# [INFO] PrecisionRegularizedLoss enabled: fp_weight=0.08, fp_margin=0.55, fp_power=2.0, fp_topk_ratio=0.5, pos_weight=0.02, pos_margin=0.45, pos_power=2.0
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit lr=3e-05, weight_decay=0.0003, patience=15, threshold=0.5, metric_for_best=precision_label1
# fit------best threshold =  0.4406060606060606
# [EPOCH 001] train_loss=0.220769 val_loss=0.090088 val_f1_label1=0.3706 val_macro_f1=0.6533 val_weighted_f1=0.9118718472814907 val_pr_auc=0.4535 val_auc=0.9433lr=0.00000720 *
# fit------best threshold =  0.5593939393939393
# [EPOCH 002] train_loss=0.041858 val_loss=0.024712 val_f1_label1=0.8150 val_macro_f1=0.9034 val_weighted_f1=0.9843982942628249 val_pr_auc=0.8677 val_auc=0.9880lr=0.00001290 *
# fit------best threshold =  0.5791919191919191
# [EPOCH 003] train_loss=0.027781 val_loss=0.023315 val_f1_label1=0.8207 val_macro_f1=0.9065 val_weighted_f1=0.9849397442837996 val_pr_auc=0.8953 val_auc=0.9896lr=0.00001860 *
# fit------best threshold =  0.594040404040404
# [EPOCH 004] train_loss=0.025178 val_loss=0.022948 val_f1_label1=0.8200 val_macro_f1=0.9061 val_weighted_f1=0.9848740812482782 val_pr_auc=0.9022 val_auc=0.9909lr=0.00002430
# fit------best threshold =  0.5742424242424242
# [EPOCH 005] train_loss=0.024186 val_loss=0.022180 val_f1_label1=0.8191 val_macro_f1=0.9056 val_weighted_f1=0.9847773401520844 val_pr_auc=0.9061 val_auc=0.9918lr=0.00003000
# fit------best threshold =  0.5742424242424242
# [EPOCH 006] train_loss=0.022271 val_loss=0.021768 val_f1_label1=0.8217 val_macro_f1=0.9070 val_weighted_f1=0.9850179093188177 val_pr_auc=0.9083 val_auc=0.9922lr=0.00003000 *
# fit------best threshold =  0.6138383838383838
# [EPOCH 007] train_loss=0.021948 val_loss=0.022665 val_f1_label1=0.8224 val_macro_f1=0.9073 val_weighted_f1=0.9850699799972856 val_pr_auc=0.9079 val_auc=0.9919lr=0.00003000 *
# fit------best threshold =  0.5692929292929293
# [EPOCH 008] train_loss=0.020707 val_loss=0.021737 val_f1_label1=0.8220 val_macro_f1=0.9071 val_weighted_f1=0.9850670676355086 val_pr_auc=0.9104 val_auc=0.9923lr=0.00003000 *
# fit------best threshold =  0.6138383838383838
# [EPOCH 009] train_loss=0.019698 val_loss=0.022057 val_f1_label1=0.8238 val_macro_f1=0.9081 val_weighted_f1=0.9852152237400946 val_pr_auc=0.9115 val_auc=0.9923lr=0.00003000 *
# fit------best threshold =  0.5445454545454546
# [EPOCH 010] train_loss=0.019840 val_loss=0.021379 val_f1_label1=0.8212 val_macro_f1=0.9068 val_weighted_f1=0.9849877068816221 val_pr_auc=0.9116 val_auc=0.9922lr=0.00002999
# fit------best threshold =  0.5890909090909091
# [EPOCH 011] train_loss=0.019296 val_loss=0.021914 val_f1_label1=0.8247 val_macro_f1=0.9086 val_weighted_f1=0.985303060197487 val_pr_auc=0.9118 val_auc=0.9921lr=0.00002999 *
# fit------best threshold =  0.594040404040404
# [EPOCH 012] train_loss=0.019390 val_loss=0.021930 val_f1_label1=0.8232 val_macro_f1=0.9078 val_weighted_f1=0.9851767977109708 val_pr_auc=0.9116 val_auc=0.9921lr=0.00002999
# fit------best threshold =  0.6187878787878788
# [EPOCH 013] train_loss=0.018885 val_loss=0.022128 val_f1_label1=0.8260 val_macro_f1=0.9093 val_weighted_f1=0.9854407075870333 val_pr_auc=0.9112 val_auc=0.9919lr=0.00002998 *
# fit------best threshold =  0.5395959595959596
# [EPOCH 014] train_loss=0.019003 val_loss=0.021465 val_f1_label1=0.8223 val_macro_f1=0.9073 val_weighted_f1=0.9850794983915216 val_pr_auc=0.9106 val_auc=0.9920lr=0.00002998
# fit------best threshold =  0.6435353535353535
# [EPOCH 015] train_loss=0.018893 val_loss=0.022649 val_f1_label1=0.8259 val_macro_f1=0.9092 val_weighted_f1=0.9854227656760368 val_pr_auc=0.9105 val_auc=0.9919lr=0.00002997
# fit------best threshold =  0.6138383838383838
# [EPOCH 016] train_loss=0.018243 val_loss=0.022386 val_f1_label1=0.8296 val_macro_f1=0.9112 val_weighted_f1=0.9857374734522316 val_pr_auc=0.9099 val_auc=0.9914lr=0.00002996 *
# fit------best threshold =  0.6138383838383838
# [EPOCH 017] train_loss=0.018689 val_loss=0.022241 val_f1_label1=0.8245 val_macro_f1=0.9085 val_weighted_f1=0.9852810929097846 val_pr_auc=0.9099 val_auc=0.9917lr=0.00002996
# fit------best threshold =  0.598989898989899
# [EPOCH 018] train_loss=0.018636 val_loss=0.022521 val_f1_label1=0.8258 val_macro_f1=0.9092 val_weighted_f1=0.9854089082044478 val_pr_auc=0.9094 val_auc=0.9912lr=0.00002995
# fit------best threshold =  0.6138383838383838
# [EPOCH 019] train_loss=0.017992 val_loss=0.022759 val_f1_label1=0.8259 val_macro_f1=0.9092 val_weighted_f1=0.9853991186275689 val_pr_auc=0.9095 val_auc=0.9914lr=0.00002994
# fit------best threshold =  0.5890909090909091
# [EPOCH 020] train_loss=0.017827 val_loss=0.023089 val_f1_label1=0.8262 val_macro_f1=0.9094 val_weighted_f1=0.9854251605158878 val_pr_auc=0.9084 val_auc=0.9907lr=0.00002993
# fit------best threshold =  0.6286868686868686
# [EPOCH 021] train_loss=0.017173 val_loss=0.022987 val_f1_label1=0.8281 val_macro_f1=0.9104 val_weighted_f1=0.9856251674124703 val_pr_auc=0.9100 val_auc=0.9912lr=0.00002992 *
# fit------best threshold =  0.5791919191919191
# [EPOCH 022] train_loss=0.017554 val_loss=0.022361 val_f1_label1=0.8247 val_macro_f1=0.9086 val_weighted_f1=0.9853127560344606 val_pr_auc=0.9103 val_auc=0.9910lr=0.00002991
# fit------best threshold =  0.5890909090909091
# [EPOCH 023] train_loss=0.018006 val_loss=0.022788 val_f1_label1=0.8256 val_macro_f1=0.9091 val_weighted_f1=0.9854007527580178 val_pr_auc=0.9089 val_auc=0.9909lr=0.00002990
# fit------best threshold =  0.6088888888888889
# [EPOCH 024] train_loss=0.017463 val_loss=0.023168 val_f1_label1=0.8262 val_macro_f1=0.9094 val_weighted_f1=0.9854488557143339 val_pr_auc=0.9107 val_auc=0.9912lr=0.00002989
# fit------best threshold =  0.6187878787878788
# [EPOCH 025] train_loss=0.017161 val_loss=0.023163 val_f1_label1=0.8274 val_macro_f1=0.9100 val_weighted_f1=0.9855729598418005 val_pr_auc=0.9109 val_auc=0.9912lr=0.00002988
# fit------best threshold =  0.6187878787878788
# [EPOCH 026] train_loss=0.017296 val_loss=0.023085 val_f1_label1=0.8265 val_macro_f1=0.9095 val_weighted_f1=0.9854749378047192 val_pr_auc=0.9108 val_auc=0.9912lr=0.00002987
# fit------best threshold =  0.594040404040404
# [EPOCH 027] train_loss=0.017318 val_loss=0.023266 val_f1_label1=0.8234 val_macro_f1=0.9079 val_weighted_f1=0.9851987600742169 val_pr_auc=0.9094 val_auc=0.9909lr=0.00002986
# fit------best threshold =  0.6088888888888889
# [EPOCH 028] train_loss=0.017185 val_loss=0.023895 val_f1_label1=0.8241 val_macro_f1=0.9082 val_weighted_f1=0.9852509259764991 val_pr_auc=0.9069 val_auc=0.9906lr=0.00002984
# fit------best threshold =  0.6138383838383838
# [EPOCH 029] train_loss=0.016653 val_loss=0.023694 val_f1_label1=0.8251 val_macro_f1=0.9088 val_weighted_f1=0.9853291154451522 val_pr_auc=0.9096 val_auc=0.9906lr=0.00002983
# fit------best threshold =  0.6088888888888889
# [EPOCH 030] train_loss=0.016974 val_loss=0.024523 val_f1_label1=0.8235 val_macro_f1=0.9079 val_weighted_f1=0.9851891654980167 val_pr_auc=0.9077 val_auc=0.9902lr=0.00002981
# fit------best threshold =  0.6039393939393939
# [EPOCH 031] train_loss=0.016333 val_loss=0.024252 val_f1_label1=0.8247 val_macro_f1=0.9086 val_weighted_f1=0.985303060197487 val_pr_auc=0.9089 val_auc=0.9904lr=0.00002980
# fit------best threshold =  0.6039393939393939
# [EPOCH 032] train_loss=0.016402 val_loss=0.024800 val_f1_label1=0.8246 val_macro_f1=0.9085 val_weighted_f1=0.985298968562895 val_pr_auc=0.9058 val_auc=0.9901lr=0.00002978
# fit------best threshold =  0.6088888888888889
# [EPOCH 033] train_loss=0.016416 val_loss=0.024730 val_f1_label1=0.8252 val_macro_f1=0.9088 val_weighted_f1=0.9853470111492908 val_pr_auc=0.9088 val_auc=0.9905lr=0.00002977
# fit------best threshold =  0.5692929292929293
# [EPOCH 034] train_loss=0.016024 val_loss=0.024450 val_f1_label1=0.8245 val_macro_f1=0.9085 val_weighted_f1=0.9852948720217869 val_pr_auc=0.9075 val_auc=0.9900lr=0.00002975
# fit------best threshold =  0.6138383838383838
# [EPOCH 035] train_loss=0.016304 val_loss=0.024483 val_f1_label1=0.8256 val_macro_f1=0.9091 val_weighted_f1=0.9854007527580178 val_pr_auc=0.9083 val_auc=0.9897lr=0.00002973
