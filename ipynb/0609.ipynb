# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_source_host_noP_0609_cls_head3 \
  --config /content/drive/MyDrive/s2/stage2_config_noposition.yaml \
  --context_method source_host \
  --context_policy split_isolated \
  --window_size 128 \
  --epochs 500 \
  --cls_head 3 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- args------model.pooling=: last
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=128.36, p50=129.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2Transformer.__init__*********** use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:84: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_destination_host_noP_0609_cls_head3 \
  --config /content/drive/MyDrive/s2/stage2_config_noposition.yaml \
  --context_method destination_host \
  --context_policy split_isolated \
  --window_size 128 \
  --epochs 500 \
  --cls_head 3 \
  --batch_size 128

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_T_C_same_endpoint_noP_0609_cls_head3 \
  --config /content/drive/MyDrive/s2/stage2_config_noposition.yaml \
  --context_method endpoint \
  --context_policy split_isolated \
  --window_size 128 \
  --epochs 500 \
  --cls_head 3 \
  --batch_size 128
