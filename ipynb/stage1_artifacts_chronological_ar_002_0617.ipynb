# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install optuna

# %%
# !python /content/drive/MyDrive/s1/run_stage1.py \
  --packet_csv /content/drive/MyDrive/s1/data/ar002_et12_20260511_002-stage1_packets.csv \
  --flow_csv /content/drive/MyDrive/s1/data/ar002_et12_20260511_002-stage1_flows.csv \
  --config /content/drive/MyDrive/s1/stage1_config_0617.yaml \
  --out_dir /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617 \
  --export_embeddings
# Out:
# [INFO] 已启用 CUDNN 确定性模式（可能影响性能）
# [INFO] 随机种子已设置: 42
# [INFO] 确定性模式: True
# [INFO] device=cuda
#
# ============================================================
# [STEP 1] Building dataloaders...
# ============================================================
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] pipeline.py ------ build_dataloaders --- split_method chronological
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ chronological_train_val_test_split-----------nominal_b1= 124025 nominal_b2= 141742
# [INFO] splits.py ------ chronological_train_val_test_split-----------b1= 124025 b2= 141818
# ********** splits.py *****************_sanitize_three_way_boundaries: 边界安全修正，保证每个 split 至少有一个样本
# [INFO] splits.py ------ chronological_train_val_test_split-----------train_df
#              flow_id  label  flow_start_timestamp_us
# 0  1051312184880716      0         1778495267572457
# 1  1051316147181637      0         1778495267572458
# 2  1051370242672817      0         1778495267572471
# [INFO] splits.py ------ chronological_train_val_test_split-----------val_df
#                  flow_id  label  flow_start_timestamp_us
# 124025  459827689366897      0         1778495289434741
# 124026  459877026526947      0         1778495289434753
# 124027  461372474545671      0         1778495289435101
# [INFO] splits.py ------ chronological_train_val_test_split-----------test_df
#                   flow_id  label  flow_start_timestamp_us
# 141818  1403934704123844      0         1778495292785631
# 141819  1403994154207061      0         1778495292785644
# 141820  1405386316874419      0         1778495292785969
#
# ================================================================================
# [INFO] Split report: chronological_train_val_test_split
# ================================================================================
# [INFO] train:
#        num_flows     = 124025
#        label_counts  = {0: 119522, 1: 4503}
#        label1_ratio  = 0.036307
#        time_range    = [1778495267572457, 1778495289434530]
# [INFO] val:
#        num_flows     = 17793
#        label_counts  = {0: 17086, 1: 707}
#        label1_ratio  = 0.039735
#        time_range    = [1778495289434741, 1778495292785562]
# [INFO] test:
#        num_flows     = 35360
#        label_counts  = {0: 33933, 1: 1427}
#        label1_ratio  = 0.040356
#        time_range    = [1778495292785631, 1778495299611559]
# ================================================================================
#
# [INFO] splits.py ------ chronological_train_val_test_split
# [INFO] 方案C模式：flow特征维度=68
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/precomputed/seqLen64headtrain.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/precomputed/seqLen64headval.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/precomputed/seqLen64headtest.npz
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/precomputed/seqLen64headtrain.npz
# [INFO] Dataset ------ Has separate flow features (方案C)
# [INFO]   Flow features shape: (124025, 68)
# [INFO] Dataset ------ Loaded 124025 flows
# [INFO]   X shape: (124025, 64, 51)
# [INFO]   Time shape: (124025, 64)
# [INFO]   Mask shape: (124025, 64)
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/precomputed/seqLen64headval.npz
# [INFO] Dataset ------ Has separate flow features (方案C)
# [INFO]   Flow features shape: (17793, 68)
# [INFO] Dataset ------ Loaded 17793 flows
# [INFO]   X shape: (17793, 64, 51)
# [INFO]   Time shape: (17793, 64)
# [INFO]   Mask shape: (17793, 64)
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/precomputed/seqLen64headtest.npz
# [INFO] Dataset ------ Has separate flow features (方案C)
# [INFO]   Flow features shape: (35360, 68)
# [INFO] Dataset ------ Loaded 35360 flows
# [INFO]   X shape: (35360, 64, 51)
# [INFO]   Time shape: (35360, 64)
# [INFO]   Mask shape: (35360, 64)
# 计算样本权重: class_counts [119522   4503]
# 计算样本权重: sample_weights [8.36666053e-06 8.36666053e-06 8.36666053e-06 ... 2.22074173e-04
#  8.36666053e-06 2.22074173e-04]
# [INFO] pipeline.py ------ build_dataloaders ----- end
#
# [INFO] Preprocessor Summary:
# external_test False
# num_train_flows 124025
# num_val_flows 17793
# num_test_flows 35360
# 真实训练集类别分布 label_counts_train {'0': 119522, '1': 4503}
# label_counts_val {'0': 17086, '1': 707}
# label_counts_test {'0': 33933, '1': 1427}
# preprocessor {'packet_numerical_used': ['pkt_len', 'ip_len', 'payload_len', 'ttl_or_hop_limit', 'tcp_window', 'tcp_header_len', 'udp_len'], 'packet_categorical_used': ['ip_version', 'protocol', 'l7_proto', 'icmp_type', 'icmp_code'], 'packet_binary_used': ['direction', 'has_tcp', 'has_udp', 'has_icmp', 'tcp_fin', 'tcp_syn', 'tcp_rst', 'tcp_psh', 'tcp_ack_flag', 'tcp_urg', 'tcp_ece', 'tcp_cwr'], 'flow_numerical_used': ['flow_duration', 'total_fwd_packets', 'total_backward_packets', 'total_length_of_fwd_packets', 'total_length_of_bwd_packets', 'fwd_packet_length_max', 'fwd_packet_length_min', 'fwd_packet_length_mean', 'fwd_packet_length_std', 'bwd_packet_length_max', 'bwd_packet_length_min', 'bwd_packet_length_mean', 'bwd_packet_length_std', 'flow_bytes_per_s', 'flow_packets_per_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_total', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_total', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'bwd_psh_flags', 'fwd_urg_flags', 'bwd_urg_flags', 'fwd_header_length', 'bwd_header_length', 'fwd_packets_per_s', 'bwd_packets_per_s', 'min_packet_length', 'max_packet_length', 'packet_length_mean', 'packet_length_std', 'packet_length_variance', 'fin_flag_count', 'syn_flag_count', 'rst_flag_count', 'psh_flag_count', 'ack_flag_count', 'urg_flag_count', 'cwe_flag_count', 'ece_flag_count', 'down_up_ratio', 'average_packet_size', 'avg_fwd_segment_size', 'avg_bwd_segment_size', 'init_win_bytes_forward', 'init_win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min'], 'flow_categorical_used': [], 'flow_binary_used': ['has_init_win_bytes_forward', 'has_init_win_bytes_backward'], 'packet_log1p_used': ['pkt_len', 'ip_len', 'payload_len', 'ttl_or_hop_limit', 'tcp_window', 'tcp_header_len', 'udp_len'], 'flow_log1p_used': ['flow_duration', 'total_fwd_packets', 'total_backward_packets', 'total_length_of_fwd_packets', 'total_length_of_bwd_packets', 'fwd_packet_length_max', 'fwd_packet_length_min', 'fwd_packet_length_mean', 'fwd_packet_length_std', 'bwd_packet_length_max', 'bwd_packet_length_min', 'bwd_packet_length_mean', 'bwd_packet_length_std', 'flow_bytes_per_s', 'flow_packets_per_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_total', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_total', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_header_length', 'bwd_header_length', 'fwd_packets_per_s', 'bwd_packets_per_s', 'min_packet_length', 'max_packet_length', 'packet_length_mean', 'packet_length_std', 'packet_length_variance', 'average_packet_size', 'avg_fwd_segment_size', 'avg_bwd_segment_size', 'init_win_bytes_forward', 'init_win_bytes_backward', 'act_data_pkt_fwd', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min'], 'scaler': 'standard', 'clip_enabled': True, 'clip_lower_quantile': 0.001, 'clip_upper_quantile': 0.999, 'packet_clip_bounds_count': 7, 'flow_clip_bounds_count': 66, 'packet_feature_dim': 51, 'flow_feature_dim': 68, 'input_dim': 51, 'has_flow_features': True}
#
# ============================================================
# [STEP 2] Building model...
# ============================================================
# [INFO] 方案C - 分层特征注入
# [INFO]   Packet input dim: 51
# [INFO]   Flow feature dim: 68
# [INFO]------model --- __init__---d_model=128, nhead=8, num_layers=2, dim_feedforward=128, dropout=0.3, max_seq_len=64, use_positional_encoding=True, use_time_encoding=True
# [INFO] 方案C - 分层特征注入已启用
# [INFO]   Flow特征维度: 68
# [INFO]   融合方法: gated
# [INFO]   模型维度: 128
# [INFO] Encoding: Time-Aware (TE(pos+p) from paper)
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
#
# ============================================================
# 📊 Model Statistics:
# ============================================================
#   Total parameters:      298,051
#   Trainable parameters:  298,051
#   Non-trainable params:  0
#
#   Parameter breakdown:
#   ────────────────────────────────────────
#     projection.proj.weight                        6,528
#     projection.proj.bias                            128
#     encoder.layers.0.self_attn.in_proj_weight     49,152
#     encoder.layers.0.self_attn.in_proj_bias         384
#     encoder.layers.0.self_attn.out_proj.weight     16,384
#     encoder.layers.0.self_attn.out_proj.bias        128
#     encoder.layers.0.linear1.weight              16,384
#     encoder.layers.0.linear1.bias                   128
#     encoder.layers.0.linear2.weight              16,384
#     encoder.layers.0.linear2.bias                   128
#     encoder.layers.0.norm1.weight                   128
#     encoder.layers.0.norm1.bias                     128
#     encoder.layers.0.norm2.weight                   128
#     encoder.layers.0.norm2.bias                     128
#     encoder.layers.1.self_attn.in_proj_weight     49,152
#     encoder.layers.1.self_attn.in_proj_bias         384
#     encoder.layers.1.self_attn.out_proj.weight     16,384
#     encoder.layers.1.self_attn.out_proj.bias        128
#     encoder.layers.1.linear1.weight              16,384
#     encoder.layers.1.linear1.bias                   128
#     encoder.layers.1.linear2.weight              16,384
#     encoder.layers.1.linear2.bias                   128
#     encoder.layers.1.norm1.weight                   128
#     encoder.layers.1.norm1.bias                     128
#     encoder.layers.1.norm2.weight                   128
#     encoder.layers.1.norm2.bias                     128
#     attention_pool.attention.0.weight             8,192
#     attention_pool.attention.0.bias                  64
#     attention_pool.attention.2.weight                64
#     attention_pool.attention.2.bias                   1
#     flow_encoder.encoder.0.weight                 8,704
#     flow_encoder.encoder.0.bias                     128
#     flow_encoder.encoder.1.weight                   128
#     flow_encoder.encoder.1.bias                     128
#     flow_encoder.encoder.4.weight                16,384
#     flow_encoder.encoder.4.bias                     128
#     flow_fusion.gate.0.weight                    32,768
#     flow_fusion.gate.0.bias                         128
#     flow_fusion.post_gate.0.weight                  128
#     flow_fusion.post_gate.0.bias                    128
#     classifier.0.weight                             128
#     classifier.0.bias                               128
#     classifier.1.weight                          16,384
#     classifier.1.bias                               128
#     classifier.4.weight                           8,192
#     classifier.4.bias                                64
#     classifier.7.weight                             128
#     classifier.7.bias                                 2
#
#   Model size: 1.14 MB
# ============================================================
#
#
# ============================================================
# [STEP 3] Training model...
# ============================================================
# [INFO] trainer.py ------ train_model
# [INFO] train_model收到的标签分布: {np.int64(0): np.int64(119522), np.int64(1): np.int64(4503)}
# [INFO] 不平衡比率 (多数:少数): 26.5:1
# [INFO] 自动推荐focal_gamma: 2.0 (配置值为: 2.0)
# [INFO] Class distribution: [119522   4503]
# [INFO] Imbalance ratio: 26.5:1
# [INFO] 极度不平衡，使用反比权重
# [INFO] Computed alpha weights: [0.0363072 0.9636928]
# [INFO] Few class weight / Many class weight: 26.54
# [Epoch 001] train_loss=0.011431 val_loss=0.012220 val_accuracy=0.6575 val_macro_f1=0.4856 val_weighted_f1=0.7593val_auc=0.9654*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 002] train_loss=0.008515 val_loss=0.009417 val_accuracy=0.6868 val_macro_f1=0.5038 val_weighted_f1=0.7812val_auc=0.9770*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 003] train_loss=0.007426 val_loss=0.008366 val_accuracy=0.7424 val_macro_f1=0.5403 val_weighted_f1=0.8209val_auc=0.9816*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 004] train_loss=0.006560 val_loss=0.007561 val_accuracy=0.7778 val_macro_f1=0.5660 val_weighted_f1=0.8451val_auc=0.9845*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 005] train_loss=0.006293 val_loss=0.008345 val_accuracy=0.7438 val_macro_f1=0.5413 val_weighted_f1=0.8219val_auc=0.9853
# [Epoch 006] train_loss=0.005990 val_loss=0.007104 val_accuracy=0.7881 val_macro_f1=0.5741 val_weighted_f1=0.8520val_auc=0.9846*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 007] train_loss=0.005833 val_loss=0.006932 val_accuracy=0.7972 val_macro_f1=0.5813 val_weighted_f1=0.8581val_auc=0.9855*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 008] train_loss=0.005744 val_loss=0.006413 val_accuracy=0.8071 val_macro_f1=0.5896 val_weighted_f1=0.8646val_auc=0.9861*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 009] train_loss=0.005577 val_loss=0.006621 val_accuracy=0.8045 val_macro_f1=0.5873 val_weighted_f1=0.8629val_auc=0.9859
# [Epoch 010] train_loss=0.005342 val_loss=0.007019 val_accuracy=0.7931 val_macro_f1=0.5781 val_weighted_f1=0.8553val_auc=0.9853
# [Epoch 011] train_loss=0.005542 val_loss=0.006600 val_accuracy=0.8070 val_macro_f1=0.5894 val_weighted_f1=0.8646val_auc=0.9855
# [Epoch 012] train_loss=0.005360 val_loss=0.006583 val_accuracy=0.7955 val_macro_f1=0.5798 val_weighted_f1=0.8570val_auc=0.9842
# [Epoch 013] train_loss=0.005281 val_loss=0.006722 val_accuracy=0.8152 val_macro_f1=0.5963 val_weighted_f1=0.8700val_auc=0.9865*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 014] train_loss=0.005329 val_loss=0.007386 val_accuracy=0.8014 val_macro_f1=0.5846 val_weighted_f1=0.8608val_auc=0.9855
# [Epoch 015] train_loss=0.005333 val_loss=0.006863 val_accuracy=0.8007 val_macro_f1=0.5838 val_weighted_f1=0.8603val_auc=0.9862
# [Epoch 016] train_loss=0.005279 val_loss=0.006973 val_accuracy=0.8112 val_macro_f1=0.5926 val_weighted_f1=0.8673val_auc=0.9860
# [Epoch 017] train_loss=0.005396 val_loss=0.006598 val_accuracy=0.7945 val_macro_f1=0.5790 val_weighted_f1=0.8563val_auc=0.9867
# [Epoch 018] train_loss=0.005194 val_loss=0.006943 val_accuracy=0.8062 val_macro_f1=0.5885 val_weighted_f1=0.8640val_auc=0.9863
# [Epoch 019] train_loss=0.005291 val_loss=0.007697 val_accuracy=0.8049 val_macro_f1=0.5871 val_weighted_f1=0.8632val_auc=0.9862
# [Epoch 020] train_loss=0.005385 val_loss=0.007530 val_accuracy=0.8074 val_macro_f1=0.5893 val_weighted_f1=0.8648val_auc=0.9861
# [Epoch 021] train_loss=0.005349 val_loss=0.006509 val_accuracy=0.8192 val_macro_f1=0.5992 val_weighted_f1=0.8725val_auc=0.9860*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 022] train_loss=0.005200 val_loss=0.008340 val_accuracy=0.8058 val_macro_f1=0.5879 val_weighted_f1=0.8637val_auc=0.9851
# [Epoch 023] train_loss=0.005437 val_loss=0.007711 val_accuracy=0.7969 val_macro_f1=0.5808 val_weighted_f1=0.8579val_auc=0.9860
# [Epoch 024] train_loss=0.005403 val_loss=0.007171 val_accuracy=0.8152 val_macro_f1=0.5959 val_weighted_f1=0.8699val_auc=0.9857
# [Epoch 025] train_loss=0.005425 val_loss=0.007294 val_accuracy=0.7843 val_macro_f1=0.5703 val_weighted_f1=0.8494val_auc=0.9833
# [Epoch 026] train_loss=0.005789 val_loss=0.007278 val_accuracy=0.8109 val_macro_f1=0.5924 val_weighted_f1=0.8671val_auc=0.9859
# [Epoch 027] train_loss=0.005396 val_loss=0.007331 val_accuracy=0.8073 val_macro_f1=0.5895 val_weighted_f1=0.8648val_auc=0.9853
# [Epoch 028] train_loss=0.005631 val_loss=0.006676 val_accuracy=0.8046 val_macro_f1=0.5869 val_weighted_f1=0.8629val_auc=0.9849
# [Epoch 029] train_loss=0.005662 val_loss=0.007048 val_accuracy=0.8023 val_macro_f1=0.5852 val_weighted_f1=0.8615val_auc=0.9851
# [Epoch 030] train_loss=0.005607 val_loss=0.006930 val_accuracy=0.8082 val_macro_f1=0.5903 val_weighted_f1=0.8654val_auc=0.9851
# [Epoch 031] train_loss=0.005611 val_loss=0.006867 val_accuracy=0.8187 val_macro_f1=0.5991 val_weighted_f1=0.8723val_auc=0.9859*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 032] train_loss=0.005623 val_loss=0.007394 val_accuracy=0.8134 val_macro_f1=0.5945 val_weighted_f1=0.8688val_auc=0.9843
# [Epoch 033] train_loss=0.005547 val_loss=0.008132 val_accuracy=0.7863 val_macro_f1=0.5721 val_weighted_f1=0.8508val_auc=0.9829
# [Epoch 034] train_loss=0.005405 val_loss=0.007683 val_accuracy=0.8159 val_macro_f1=0.5967 val_weighted_f1=0.8704val_auc=0.9854
# [Epoch 035] train_loss=0.005499 val_loss=0.006371 val_accuracy=0.8168 val_macro_f1=0.5979 val_weighted_f1=0.8710val_auc=0.9855
# [Epoch 036] train_loss=0.005627 val_loss=0.007323 val_accuracy=0.8180 val_macro_f1=0.5986 val_weighted_f1=0.8718val_auc=0.9852
# [Epoch 037] train_loss=0.005587 val_loss=0.007295 val_accuracy=0.8075 val_macro_f1=0.5894 val_weighted_f1=0.8648val_auc=0.9857
# [Epoch 038] train_loss=0.005488 val_loss=0.007159 val_accuracy=0.8036 val_macro_f1=0.5862 val_weighted_f1=0.8623val_auc=0.9856
# [Epoch 039] train_loss=0.005480 val_loss=0.007856 val_accuracy=0.8064 val_macro_f1=0.5887 val_weighted_f1=0.8641val_auc=0.9847
# [Epoch 040] train_loss=0.005704 val_loss=0.007494 val_accuracy=0.7557 val_macro_f1=0.5492 val_weighted_f1=0.8301val_auc=0.9847
# [Epoch 041] train_loss=0.005583 val_loss=0.007346 val_accuracy=0.8164 val_macro_f1=0.5975 val_weighted_f1=0.8707val_auc=0.9850
# [Epoch 042] train_loss=0.005605 val_loss=0.006877 val_accuracy=0.8080 val_macro_f1=0.5899 val_weighted_f1=0.8652val_auc=0.9850
# [Epoch 043] train_loss=0.005309 val_loss=0.007235 val_accuracy=0.8267 val_macro_f1=0.6062 val_weighted_f1=0.8774val_auc=0.9856*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 044] train_loss=0.005596 val_loss=0.007160 val_accuracy=0.8146 val_macro_f1=0.5955 val_weighted_f1=0.8696val_auc=0.9848
# [Epoch 045] train_loss=0.005364 val_loss=0.008875 val_accuracy=0.8296 val_macro_f1=0.6088 val_weighted_f1=0.8793val_auc=0.9853*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 046] train_loss=0.005606 val_loss=0.007865 val_accuracy=0.8212 val_macro_f1=0.6014 val_weighted_f1=0.8739val_auc=0.9854
# [Epoch 047] train_loss=0.005414 val_loss=0.008180 val_accuracy=0.7956 val_macro_f1=0.5795 val_weighted_f1=0.8570val_auc=0.9829
# [Epoch 048] train_loss=0.005601 val_loss=0.007794 val_accuracy=0.8119 val_macro_f1=0.5934 val_weighted_f1=0.8678val_auc=0.9850
# [Epoch 049] train_loss=0.005608 val_loss=0.007202 val_accuracy=0.8259 val_macro_f1=0.6059 val_weighted_f1=0.8770val_auc=0.9846
# [Epoch 050] train_loss=0.005569 val_loss=0.007913 val_accuracy=0.8280 val_macro_f1=0.6075 val_weighted_f1=0.8783val_auc=0.9854
# [Epoch 051] train_loss=0.005721 val_loss=0.008293 val_accuracy=0.8150 val_macro_f1=0.5958 val_weighted_f1=0.8698val_auc=0.9846
# [Epoch 052] train_loss=0.005384 val_loss=0.007983 val_accuracy=0.7952 val_macro_f1=0.5791 val_weighted_f1=0.8567val_auc=0.9836
# [Epoch 053] train_loss=0.005644 val_loss=0.007668 val_accuracy=0.8240 val_macro_f1=0.6040 val_weighted_f1=0.8757val_auc=0.9857
# [Epoch 054] train_loss=0.005473 val_loss=0.007709 val_accuracy=0.8195 val_macro_f1=0.5998 val_weighted_f1=0.8727val_auc=0.9851
# [Epoch 055] train_loss=0.005491 val_loss=0.007440 val_accuracy=0.8168 val_macro_f1=0.5977 val_weighted_f1=0.8710val_auc=0.9849
# [Epoch 056] train_loss=0.005615 val_loss=0.007333 val_accuracy=0.8230 val_macro_f1=0.6030 val_weighted_f1=0.8751val_auc=0.9849
# [Epoch 057] train_loss=0.005574 val_loss=0.007756 val_accuracy=0.8155 val_macro_f1=0.5964 val_weighted_f1=0.8702val_auc=0.9850
# [Epoch 058] train_loss=0.005648 val_loss=0.006653 val_accuracy=0.8181 val_macro_f1=0.5988 val_weighted_f1=0.8718val_auc=0.9847
# [Epoch 059] train_loss=0.005442 val_loss=0.007041 val_accuracy=0.8175 val_macro_f1=0.5983 val_weighted_f1=0.8714val_auc=0.9850
# [Epoch 060] train_loss=0.005536 val_loss=0.007968 val_accuracy=0.8238 val_macro_f1=0.6037 val_weighted_f1=0.8755val_auc=0.9852
# [Epoch 061] train_loss=0.005536 val_loss=0.007339 val_accuracy=0.8159 val_macro_f1=0.5969 val_weighted_f1=0.8704val_auc=0.9858
# [Epoch 062] train_loss=0.005445 val_loss=0.007850 val_accuracy=0.8309 val_macro_f1=0.6104 val_weighted_f1=0.8802val_auc=0.9857*
# [INFO] saved best model: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_best_model.pt
# [Epoch 063] train_loss=0.005593 val_loss=0.007569 val_accuracy=0.8257 val_macro_f1=0.6054 val_weighted_f1=0.8768val_auc=0.9843
# [Epoch 064] train_loss=0.005416 val_loss=0.007400 val_accuracy=0.7953 val_macro_f1=0.5792 val_weighted_f1=0.8568val_auc=0.9853
# [Epoch 065] train_loss=0.005612 val_loss=0.007806 val_accuracy=0.7674 val_macro_f1=0.5577 val_weighted_f1=0.8381val_auc=0.9853
# [Epoch 066] train_loss=0.005515 val_loss=0.007269 val_accuracy=0.7220 val_macro_f1=0.5261 val_weighted_f1=0.8066val_auc=0.9837
# [Epoch 067] train_loss=0.005416 val_loss=0.007684 val_accuracy=0.8299 val_macro_f1=0.6093 val_weighted_f1=0.8796val_auc=0.9858
# [Epoch 068] train_loss=0.005493 val_loss=0.008360 val_accuracy=0.7738 val_macro_f1=0.5626 val_weighted_f1=0.8424val_auc=0.9823
# [Epoch 069] train_loss=0.005638 val_loss=0.006838 val_accuracy=0.8162 val_macro_f1=0.5972 val_weighted_f1=0.8706val_auc=0.9855
# [Epoch 070] train_loss=0.005702 val_loss=0.008000 val_accuracy=0.7869 val_macro_f1=0.5726 val_weighted_f1=0.8512val_auc=0.9857
# [Epoch 071] train_loss=0.005522 val_loss=0.006489 val_accuracy=0.8106 val_macro_f1=0.5922 val_weighted_f1=0.8669val_auc=0.9851
# [Epoch 072] train_loss=0.005578 val_loss=0.007366 val_accuracy=0.8091 val_macro_f1=0.5908 val_weighted_f1=0.8659val_auc=0.9860
# [Epoch 073] train_loss=0.005422 val_loss=0.008054 val_accuracy=0.8200 val_macro_f1=0.6004 val_weighted_f1=0.8731val_auc=0.9865
# [Epoch 074] train_loss=0.005543 val_loss=0.007527 val_accuracy=0.8133 val_macro_f1=0.5943 val_weighted_f1=0.8687val_auc=0.9846
# [Epoch 075] train_loss=0.005711 val_loss=0.006710 val_accuracy=0.8177 val_macro_f1=0.5983 val_weighted_f1=0.8716val_auc=0.9858
# [Epoch 076] train_loss=0.005586 val_loss=0.007053 val_accuracy=0.7731 val_macro_f1=0.5620 val_weighted_f1=0.8419val_auc=0.9861
# [Epoch 077] train_loss=0.005447 val_loss=0.006831 val_accuracy=0.8023 val_macro_f1=0.5851 val_weighted_f1=0.8614val_auc=0.9864
# [Epoch 078] train_loss=0.005759 val_loss=0.007234 val_accuracy=0.8174 val_macro_f1=0.5984 val_weighted_f1=0.8714val_auc=0.9858
# [Epoch 079] train_loss=0.005897 val_loss=0.006804 val_accuracy=0.8031 val_macro_f1=0.5857 val_weighted_f1=0.8620val_auc=0.9851
# [Epoch 080] train_loss=0.005446 val_loss=0.007021 val_accuracy=0.8216 val_macro_f1=0.6018 val_weighted_f1=0.8741val_auc=0.9857
# [Epoch 081] train_loss=0.005556 val_loss=0.006172 val_accuracy=0.8163 val_macro_f1=0.5971 val_weighted_f1=0.8707val_auc=0.9862
# [Epoch 082] train_loss=0.005406 val_loss=0.007116 val_accuracy=0.8198 val_macro_f1=0.6002 val_weighted_f1=0.8730val_auc=0.9862
# [INFO] early stopping at epoch 82
#
# 在验证集上寻找最优决策阈值...
#
# [THRESHOLD] 最优阈值: 0.90
#   F1: 0.7311
#   Precision: 0.6602
#   Recall: 0.8190
#
# 使用阈值 0.900 评估测试集...
#
# ==================================================
#             Stage1 Transformer - 测试集结果
# ==================================================
#   Loss:              0.2718
#   F1 (Macro):        0.8534
#   F1 (Weighted):     0.9763
#   AUC (OvR Macro):   0.9824
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9871
#   Class_1                       : 0.7197
# Figure(1400x500)
# [INFO] 训练曲线已保存: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_training_curves.png
# Figure(1000x800)
# [INFO] 混淆矩阵已保存: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_confusion_matrix.png
# Figure(1000x600)
# [INFO] 各类别 F1 图已保存: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/seqLen64headstage1_per_class_f1.png
#
# [TEST] Full metrics: {'accuracy': 0.9753959276018099, 'macro_precision': 0.8284334539977957, 'macro_recall': 0.883128964036493, 'macro_f1': 0.8534248588755909, 'weighted_precision': 0.9776917857784646, 'weighted_recall': 0.9753959276018099, 'weighted_f1': 0.9763412638859603, 'precision_label1': 0.6660703637447823, 'recall_label1': 0.782761037140855, 'f1_label1': 0.7197164948453608, 'auc': 0.9823625706545551, 'per_class_f1': {'0': 0.9871332229058211, '1': 0.7197164948453608}, 'confusion_matrix': [[33373, 560], [310, 1117]], 'num_classes': 2, 'num_samples': 35360, 'loss': 0.27182739528458544, 'threshold': 0.9000000000000002}
#
# ============================================================
# [STEP 4] Exporting embeddings...args Namespace(packet_csv='/content/drive/MyDrive/s1/data/ar002_et12_20260511_002-stage1_packets.csv', flow_csv='/content/drive/MyDrive/s1/data/ar002_et12_20260511_002-stage1_flows.csv', config='/content/drive/MyDrive/s1/stage1_config_0617.yaml', out_dir='/content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617', external_packet_csv=None, external_flow_csv=None, export_embeddings=True)
# ============================================================
# [INFO] Exported Stage1 embeddings: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/stage1_train_embeddings.npz
# [INFO] Keys: ['flow_id', 'label', 'z', 'split', 'flow_start_timestamp_us', 'source_id', 'destination_id']
# [INFO] z shape: (124025, 128)
# [INFO] saved embeddings: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/stage1_train_embeddings.npz
# [INFO] Stage1 build_stage2_metadata_from_npz  npz_path:  /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/stage1_train_embeddings.npz
# [INFO] Exported Stage1 embeddings: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/stage1_val_embeddings.npz
# [INFO] Keys: ['flow_id', 'label', 'z', 'split', 'flow_start_timestamp_us', 'source_id', 'destination_id']
# [INFO] z shape: (17793, 128)
# [INFO] saved embeddings: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/stage1_val_embeddings.npz
# [INFO] Stage1 build_stage2_metadata_from_npz  npz_path:  /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/stage1_val_embeddings.npz
# [INFO] Exported Stage1 embeddings: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/stage1_test_embeddings.npz
# [INFO] Keys: ['flow_id', 'label', 'z', 'split', 'flow_start_timestamp_us', 'source_id', 'destination_id']
# [INFO] z shape: (35360, 128)
# [INFO] saved embeddings: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/stage1_test_embeddings.npz
# [INFO] Stage1 build_stage2_metadata_from_npz  npz_path:  /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/stage1_test_embeddings.npz
# [INFO] saved Stage2 flow metadata: /content/drive/MyDrive/s1/stage1_artifacts_chronological_ar_002_0617/stage1_flow_metadata.csv
