# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_chronological_split \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_both_C_timeonly_split_0605_16 \
  --config /content/drive/MyDrive/s2/stage2_config.yaml \
  --context_method time_only \
  --context_policy split_isolated \
  --window_size 16 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=16.99, p50=17.0, p95=17.0, max=17
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# /content/drive/MyDrive/s2/stage2/model.py:84: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_chronological_split \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_both_C_timeonly_split_0605_8 \
  --config /content/drive/MyDrive/s2/stage2_config.yaml \
  --context_method time_only \
  --context_policy split_isolated \
  --window_size 8 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=9.00, p50=9.0, p95=9.0, max=9
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# /content/drive/MyDrive/s2/stage2/model.py:84: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_chronological_split \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_both_C_timeonly_split_0605_32 \
  --config /content/drive/MyDrive/s2/stage2_config.yaml \
  --context_method time_only \
  --context_policy split_isolated \
  --window_size 32 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=32.96, p50=33.0, p95=33.0, max=33
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# /content/drive/MyDrive/s2/stage2/model.py:84: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_chronological_split \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_both_C_timeonly_split_0605_64 \
  --config /content/drive/MyDrive/s2/stage2_config.yaml \
  --context_method time_only \
  --context_policy split_isolated \
  --window_size 64 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=64.84, p50=65.0, p95=65.0, max=65
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# /content/drive/MyDrive/s2/stage2/model.py:84: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_chronological_split \
  --out_dir /content/drive/MyDrive/s2/stage2_artifacts_full_64_head_both_C_timeonly_split_0605_128 \
  --config /content/drive/MyDrive/s2/stage2_config.yaml \
  --context_method time_only \
  --context_policy split_isolated \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=128.36, p50=129.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# /content/drive/MyDrive/s2/stage2/model.py:84: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): SinusoidalPositionalEncoding()
# ...
