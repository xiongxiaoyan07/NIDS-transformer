# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/s1/run_stage1.py \
  --packet_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_packets.csv \
  --flow_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_flows.csv \
  --config /content/drive/MyDrive/s1/configs/stage1_full_64_head_both_C_gated_config.yaml \
  --out_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_gated_newtimeaware_notimeinX
# Out:
# [INFO] device=cuda
#
# ...
# [STEP 1] Building dataloaders...
# ...
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ stratified_train_val_test_split
# [INFO] 方案C模式：flow特征维度=68
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_gated_newtimeaware_notimeinX/precomputed/seqLen64headtrain.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_gated_newtimeaware_notimeinX/precomputed/seqLen64headval.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_gated_newtimeaware_notimeinX/precomputed/seqLen64headtest.npz
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_gated_newtimeaware_notimeinX/precomputed/seqLen64headtrain.npz
# ...

# %%
# !python /content/drive/MyDrive/s1/run_stage1.py \
  --packet_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_packets.csv \
  --flow_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_flows.csv \
  --config /content/drive/MyDrive/s1/configs/stage1_full_64_head_both_C_add_config.yaml \
  --out_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_add_newtimeaware_notimeinX
# Out:
# [INFO] device=cuda
#
# ...
# [STEP 1] Building dataloaders...
# ...
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ stratified_train_val_test_split
# [INFO] 方案C模式：flow特征维度=68
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_add_newtimeaware_notimeinX/precomputed/seqLen64headtrain.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_add_newtimeaware_notimeinX/precomputed/seqLen64headval.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_add_newtimeaware_notimeinX/precomputed/seqLen64headtest.npz
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_add_newtimeaware_notimeinX/precomputed/seqLen64headtrain.npz
# ...

# %%
# !python /content/drive/MyDrive/s1/run_stage1.py \
  --packet_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_packets.csv \
  --flow_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_flows.csv \
  --config /content/drive/MyDrive/s1/configs/stage1_full_64_head_both_C_concat_config.yaml \
  --out_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_concat_newtimeaware_notimeinX
# Out:
# [INFO] device=cuda
#
# ...
# [STEP 1] Building dataloaders...
# ...
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ stratified_train_val_test_split
# [INFO] 方案C模式：flow特征维度=68
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_concat_newtimeaware_notimeinX/precomputed/seqLen64headtrain.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_concat_newtimeaware_notimeinX/precomputed/seqLen64headval.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_concat_newtimeaware_notimeinX/precomputed/seqLen64headtest.npz
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_both_C_concat_newtimeaware_notimeinX/precomputed/seqLen64headtrain.npz
# ...
