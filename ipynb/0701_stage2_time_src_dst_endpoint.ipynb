# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0701_B/0701_asymmetric \
  --out_dir /content/drive/MyDrive/s2/0701_stage2/01_timeonly \
  --config /content/drive/MyDrive/s2/0701_stage2/01_timeonly/stage2_config_0701.yaml \
  --context_method time_only \
  --context_policy online \
  --window_size 128 \
  --epochs 500 \
  --batch_size 64
# Out:
# [INFO] Stage2 --------- seed: 42
# [INFO] 随机种子已设置: 42
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 --------- context_indices =  [array([0]), array([0, 1]), array([0, 1, 2])]
# [INFO] Stage2 loaded flows:
# split
# train    123935
# test      35410
# val       17705
# [INFO] label counts by split:
# label       0     1
# split
# test    34003  1407
# train  119488  4447
# val     17003   702
# [INFO] z shape: (177050, 128)
# [INFO] context lengths: min=1, mean=128.95, p50=129.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0701_B/0701_asymmetric \
  --out_dir /content/drive/MyDrive/s2/0701_stage2/use_weighted_sampler \
  --config /content/drive/MyDrive/s2/0701_stage2/use_weighted_sampler/stage2_config_0701.yaml \
  --context_method time_only \
  --context_policy online \
  --window_size 128 \
  --epochs 500 \
  --batch_size 64
# Out:
# [INFO] Stage2 --------- seed: 42
# [INFO] 随机种子已设置: 42
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 --------- context_indices =  [array([0]), array([0, 1]), array([0, 1, 2])]
# [INFO] Stage2 loaded flows:
# split
# train    123935
# test      35410
# val       17705
# [INFO] label counts by split:
# label       0     1
# split
# test    34003  1407
# train  119488  4447
# val     17003   702
# [INFO] z shape: (177050, 128)
# [INFO] context lengths: min=1, mean=128.95, p50=129.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0701_B/0701_asymmetric \
  --out_dir /content/drive/MyDrive/s2/0701_stage2/01_source_host \
  --config /content/drive/MyDrive/s2/0701_stage2/01_timeonly/stage2_config_0701.yaml \
  --context_method source_host \
  --context_policy online \
  --window_size 128 \
  --epochs 500 \
  --batch_size 64
# Out:
# [INFO] Stage2 --------- seed: 42
# [INFO] 随机种子已设置: 42
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 --------- context_indices =  [array([0]), array([1]), array([2])]
# [INFO] Stage2 loaded flows:
# split
# train    123935
# test      35410
# val       17705
# [INFO] label counts by split:
# label       0     1
# split
# test    34003  1407
# train  119488  4447
# val     17003   702
# [INFO] z shape: (177050, 128)
# [INFO] context lengths: min=1, mean=68.66, p50=65.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0701_B/0701_asymmetric \
  --out_dir /content/drive/MyDrive/s2/0701_stage2/01_destination_host \
  --config /content/drive/MyDrive/s2/0701_stage2/01_timeonly/stage2_config_0701.yaml \
  --context_method destination_host \
  --context_policy online \
  --window_size 128 \
  --epochs 500 \
  --batch_size 64
# Out:
# [INFO] Stage2 --------- seed: 42
# [INFO] 随机种子已设置: 42
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 --------- context_indices =  [array([0]), array([1]), array([2])]
# [INFO] Stage2 loaded flows:
# split
# train    123935
# test      35410
# val       17705
# [INFO] label counts by split:
# label       0     1
# split
# test    34003  1407
# train  119488  4447
# val     17003   702
# [INFO] z shape: (177050, 128)
# [INFO] context lengths: min=1, mean=57.47, p50=37.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0701_B/0701_asymmetric \
  --out_dir /content/drive/MyDrive/s2/0701_stage2/01_endpoint \
  --config /content/drive/MyDrive/s2/0701_stage2/01_timeonly/stage2_config_0701.yaml \
  --context_method endpoint \
  --context_policy online \
  --window_size 128 \
  --epochs 500 \
  --batch_size 64
# Out:
# [INFO] Stage2 --------- seed: 42
# [INFO] 随机种子已设置: 42
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 --------- context_indices =  [array([0]), array([1]), array([2])]
# [INFO] Stage2 loaded flows:
# split
# train    123935
# test      35410
# val       17705
# [INFO] label counts by split:
# label       0     1
# split
# test    34003  1407
# train  119488  4447
# val     17003   702
# [INFO] z shape: (177050, 128)
# [INFO] context lengths: min=1, mean=110.89, p50=129.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# ...
