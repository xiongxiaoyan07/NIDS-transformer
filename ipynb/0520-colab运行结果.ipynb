# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed May 20 07:16:35 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import psutil

ram_gb = psutil.virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/s1/run_stage1.py \
  --packet_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_packets.csv \
  --flow_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_flows.csv \
  --config /content/drive/MyDrive/s1/configs/stage1_config.yaml \
  --out_dir /content/drive/MyDrive/s1/stage1_artifacts_0520
# Out:
# [INFO] device=cuda
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ stratified_train_val_test_split
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_0520/precomputed/seqLen40headtrain.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_0520/precomputed/seqLen40headval.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_0520/precomputed/seqLen40headtest.npz
# [INFO] pipeline.py ------ build_dataloaders ----- end
# [INFO] preprocessor summary:
# ...

# %%
# !python /content/drive/MyDrive/s1/run_stage1.py \
  --packet_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_packets.csv \
  --flow_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_flows.csv \
  --config /content/drive/MyDrive/s1/configs/stage1_config.yaml \
  --out_dir /content/drive/MyDrive/s1/stage1_artifacts_0520
# Out:
# [INFO] device=cuda
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ stratified_train_val_test_split
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_0520/precomputed/seqLen40headtrain.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_0520/precomputed/seqLen40headval.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_0520/precomputed/seqLen40headtest.npz
# [INFO] pipeline.py ------ build_dataloaders ----- end
# [INFO] preprocessor summary:
# ...

# %%
# !python /content/drive/MyDrive/s1/run_stage1.py \
  --packet_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_packets.csv \
  --flow_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_flows.csv \
  --config /content/drive/MyDrive/s1/configs/stage1_config.yaml \
  --out_dir /content/drive/MyDrive/s1/stage1_artifacts_0520
# Out:
# [INFO] device=cuda
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ stratified_train_val_test_split
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_0520/precomputed/seqLen40headtrain.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_0520/precomputed/seqLen40headval.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_0520/precomputed/seqLen40headtest.npz
# [INFO] pipeline.py ------ build_dataloaders ----- end
# [INFO] preprocessor summary:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# max_seq_len = 100
# !python /content/drive/MyDrive/s1/run_stage1.py \
  --packet_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_packets.csv \
  --flow_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_flows.csv \
  --config /content/drive/MyDrive/s1/configs/stage1_config.yaml \
  --out_dir /content/drive/MyDrive/s1/stage1_artifacts_0520_100
# Out:
# [INFO] device=cuda
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ stratified_train_val_test_split
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_0520_100/precomputed/seqLen100headtrain.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_0520_100/precomputed/seqLen100headval.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/stage1_artifacts_0520_100/precomputed/seqLen100headtest.npz
# [INFO] pipeline.py ------ build_dataloaders ----- end
# [INFO] preprocessor summary:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# max_seq_len = 100
# !python /content/drive/MyDrive/s1/run_stage1.py \
  --packet_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_packets.csv \
  --flow_csv /content/drive/MyDrive/s1/data/firewall_test_20250731_160700-stage1_flows.csv \
  --config /content/drive/MyDrive/s1/configs/stage1_config.yaml \
  --out_dir /content/drive/MyDrive/s1/stage1_artifacts_0520_40
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/s1/run_stage1.py", line 33, in <module>
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 2350, in <module>
#     from torch import masked as masked
#   File "/usr/local/lib/python3.12/dist-packages/torch/masked/__init__.py", line 1, in <module>
#     from torch.masked._ops import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/masked/_ops.py", line 11, in <module>
#     from torch.masked.maskedtensor.core import is_masked_tensor, MaskedTensor
#   File "/usr/local/lib/python3.12/dist-packages/torch/masked/maskedtensor/__init__.py", line 3, in <module>
#     from .binary import _apply_native_binary, _is_native_binary
#   File "/usr/local/lib/python3.12/dist-packages/torch/masked/maskedtensor/binary.py", line 183, in <module>
#     getattr(torch.ops.aten, name): _torch_inplace_binary(name)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
