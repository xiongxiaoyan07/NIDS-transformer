# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/s2/verify_reproducibility.py \
  --stage1_dir /content/drive/MyDrive/s1/tensors_ar_002 \
  --output_dir /content/drive/MyDrive/s2/reproducibility_check_gpu \
  --config /content/drive/MyDrive/s2/stage2_config.yaml \
  --skip_training \
  --debug
# Out:
# ...
# REPRODUCIBILITY VERIFICATION SUITE
# Timestamp: 2026-06-18T12:00:57.092749
# Stage1 dir: /content/drive/MyDrive/s1/tensors_ar_002
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# PyTorch: 2.11.0+cu128
# NumPy: 2.0.2
# CUDA available: True
# CUDA version: 12.8
# cuDNN version: 91900
# ...
#
# ...
# VERIFICATION 1: Data Loading Consistency
# ...
#
# --- Load attempt 1/3 ---
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
#   meta_df shape: (177178, 6)
#   z_sorted type: ndarray
#   z_sorted shape: (177178, 128)
#   z_sorted stats: mean=-0.002428, std=0.955421
#   z_sorted hash (stats): shape=(177178, 128)_mean=-0.002428_std=0.955421_min=-6.746812_max=7.018741
#   z_sorted hash (md5): c1c7194bbac26e5c
#   load time: 14.30s
#
# --- Load attempt 2/3 ---
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
#   meta_df shape: (177178, 6)
#   z_sorted type: ndarray
#   z_sorted shape: (177178, 128)
# ...
