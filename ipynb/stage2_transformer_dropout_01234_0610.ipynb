# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_transformer_dropout_01_0610 \
  --config /content/drive/MyDrive/s2/stage2_config_noposition_dropout01.yaml \
  --context_method source_host \
  --context_policy split_isolated \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=35.78, p50=11.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:383: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** dropout= 0.1
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): Identity()
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.05, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): GELU(approximate='none')
#     (6): Dropout(p=0.03, inplace=False)
#     (7): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] weighted sampler class_counts: [26257, 899]
# [INFO]---trainer.py---make_loss_fn---label 分布: [26257.   899.]
# [INFO] Class distribution: [26257   899]
# [INFO] Imbalance ratio: 29.2:1
# [INFO] 极度不平衡，使用反比权重
# [INFO] Computed alpha weights: [0.03310502 0.96689498]
# [INFO] Few class weight / Many class weight: 29.21
# [INFO] Using FocalLoss: gamma=2.0, label_smoothing=0.02
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit----metric_for_best =  f1_label1
# [Stage2Trainer]---fit lr=  0.0003
# [EPOCH 001] train_loss=0.029578 val_loss=0.004978 val_macro_f1=0.6399 val_weighted_f1=0.9125208446876607 val_f1_label1=0.3472 val_auc=0.9736*
# [EPOCH 002] train_loss=0.002513 val_loss=0.005166 val_macro_f1=0.6569 val_weighted_f1=0.9216392820079441 val_f1_label1=0.3727 val_auc=0.9768*
# [EPOCH 003] train_loss=0.001953 val_loss=0.006646 val_macro_f1=0.6595 val_weighted_f1=0.9239597825206975 val_f1_label1=0.3756 val_auc=0.9759*
# [EPOCH 004] train_loss=0.001430 val_loss=0.007632 val_macro_f1=0.7272 val_weighted_f1=0.9493751407214911 val_f1_label1=0.4886 val_auc=0.9754*
# [EPOCH 041] train_loss=0.000645 val_loss=0.023669 val_macro_f1=0.8027 val_weighted_f1=0.970647864677279 val_f1_label1=0.6224 val_auc=0.9357
# [INFO] Early stopping at epoch=41, best_epoch=21
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.9400
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9802443462438264, 'macro_precision': 0.8607637957248904, 'macro_recall': 0.8290264692687304, 'macro_f1': 0.8441001949467415, 'weighted_precision': 0.9794493550565643, 'weighted_recall': 0.9802443462438264, 'weighted_f1': 0.9797899012325426, 'precision_label1': 0.7333333333333333, 'recall_label1': 0.6666666666666666, 'f1_label1': 0.6984126984126984, 'auc': 0.9522564133936947, 'per_class_f1': {'0': 0.9897876914807847, '1': 0.6984126984126984}, 'confusion_matrix': [[3683, 32], [44, 88]], 'num_classes': 2, 'num_samples': 3847, 'threshold': 0.9400000000000001}
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_transformer_dropout_01_0610/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_transformer_dropout_01_0610/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_transformer_dropout_01_0610/stage2_predictions_test.csv
#
# ==================================================
#             Stage1 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0412
#   F1 (Macro):        0.8304
#   F1 (Weighted):     0.9790
#   AUC (OvR Macro):   0.9337
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9898
#   Class_1                       : 0.6710
#
# [TEST] Full metrics: {'accuracy': 0.9801773604590506, 'macro_precision': 0.8766314884903974, 'macro_recall': 0.7949046768566207, 'macro_f1': 0.8303882482986961, 'weighted_precision': 0.9785238195520621, 'weighted_recall': 0.9801773604590506, 'weighted_f1': 0.9789717306359448, 'precision_label1': 0.7673267326732673, 'recall_label1': 0.5961538461538461, 'f1_label1': 0.670995670995671, 'auc': 0.9336678642631667, 'per_class_f1': {'0': 0.9897808256017211, '1': 0.670995670995671}, 'confusion_matrix': [[7361, 47], [105, 155]], 'num_classes': 2, 'num_samples': 7668, 'loss': 0.04124450973880205, 'threshold': 0.9400000000000001, 'positive_count': 260, 'positive_rate': 0.03390714658320292}
# [INFO] saved summary: /content/drive/MyDrive/s2/stage2_transformer_dropout_01_0610/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/stage2_transformer_dropout_01_0610

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_transformer_dropout_02_0610 \
  --config /content/drive/MyDrive/s2/stage2_config_noposition_dropout02.yaml \
  --context_method source_host \
  --context_policy split_isolated \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=35.78, p50=11.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:383: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** dropout= 0.2
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): Identity()
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): GELU(approximate='none')
#     (6): Dropout(p=0.06, inplace=False)
#     (7): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] weighted sampler class_counts: [26257, 899]
# [INFO]---trainer.py---make_loss_fn---label 分布: [26257.   899.]
# [INFO] Class distribution: [26257   899]
# [INFO] Imbalance ratio: 29.2:1
# [INFO] 极度不平衡，使用反比权重
# [INFO] Computed alpha weights: [0.03310502 0.96689498]
# [INFO] Few class weight / Many class weight: 29.21
# [INFO] Using FocalLoss: gamma=2.0, label_smoothing=0.02
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit----metric_for_best =  f1_label1
# [Stage2Trainer]---fit lr=  0.0003
# [EPOCH 001] train_loss=0.030708 val_loss=0.005063 val_macro_f1=0.6389 val_weighted_f1=0.9115776728373276 val_f1_label1=0.3462 val_auc=0.9736*
# [EPOCH 002] train_loss=0.002647 val_loss=0.005378 val_macro_f1=0.6562 val_weighted_f1=0.9213098234474053 val_f1_label1=0.3716 val_auc=0.9757*
# [EPOCH 003] train_loss=0.002039 val_loss=0.006842 val_macro_f1=0.6570 val_weighted_f1=0.9228067828858889 val_f1_label1=0.3715 val_auc=0.9759
# [EPOCH 004] train_loss=0.001542 val_loss=0.008041 val_macro_f1=0.7082 val_weighted_f1=0.9433709886829765 val_f1_label1=0.4556 val_auc=0.9756*
# [EPOCH 005] train_loss=0.001384 val_loss=0.010614 val_macro_f1=0.7593 val_weighted_f1=0.9592991868766794 val_f1_label1=0.5446 val_auc=0.9731*
# [EPOCH 006] train_loss=0.001180 val_loss=0.012756 val_macro_f1=0.7649 val_weighted_f1=0.9608681371848591 val_f1_label1=0.5545 val_auc=0.9709*
# [EPOCH 007] train_loss=0.001056 val_loss=0.012899 val_macro_f1=0.7671 val_weighted_f1=0.9610049264642555 val_f1_label1=0.5588 val_auc=0.9709*
# [EPOCH 044] train_loss=0.000666 val_loss=0.034760 val_macro_f1=0.7756 val_weighted_f1=0.9650443007437919 val_f1_label1=0.5722 val_auc=0.9427
# [EPOCH 045] train_loss=0.000620 val_loss=0.041491 val_macro_f1=0.7940 val_weighted_f1=0.9695542043483699 val_f1_label1=0.6055 val_auc=0.9275
# [EPOCH 046] train_loss=0.000722 val_loss=0.032668 val_macro_f1=0.7914 val_weighted_f1=0.9680589148598125 val_f1_label1=0.6017 val_auc=0.9336
# [EPOCH 047] train_loss=0.000638 val_loss=0.034949 val_macro_f1=0.7847 val_weighted_f1=0.9668313151505245 val_f1_label1=0.5892 val_auc=0.9434
# [EPOCH 048] train_loss=0.000560 val_loss=0.043110 val_macro_f1=0.7884 val_weighted_f1=0.968262550133973 val_f1_label1=0.5952 val_auc=0.9370
# [EPOCH 049] train_loss=0.000546 val_loss=0.036939 val_macro_f1=0.8014 val_weighted_f1=0.9706965675893796 val_f1_label1=0.6196 val_auc=0.9453
# [EPOCH 050] train_loss=0.000494 val_loss=0.041581 val_macro_f1=0.7913 val_weighted_f1=0.9695123389642994 val_f1_label1=0.6000 val_auc=0.9437
# [EPOCH 051] train_loss=0.000537 val_loss=0.045919 val_macro_f1=0.7999 val_weighted_f1=0.9708635058622141 val_f1_label1=0.6164 val_auc=0.9453
# [INFO] Early stopping at epoch=51, best_epoch=31
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.9300
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9810241746815701, 'macro_precision': 0.8576169483726243, 'macro_recall': 0.8550032627758065, 'macro_f1': 0.8563048742985531, 'weighted_precision': 0.9809553282512722, 'weighted_recall': 0.9810241746815701, 'weighted_f1': 0.9809893757696329, 'precision_label1': 0.7251908396946565, 'recall_label1': 0.7196969696969697, 'f1_label1': 0.7224334600760456, 'auc': 0.9613228516660549, 'per_class_f1': {'0': 0.9901762885210604, '1': 0.7224334600760456}, 'confusion_matrix': [[3679, 36], [37, 95]], 'num_classes': 2, 'num_samples': 3847, 'threshold': 0.93}
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_transformer_dropout_02_0610/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_transformer_dropout_02_0610/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_transformer_dropout_02_0610/stage2_predictions_test.csv
#
# ==================================================
#             Stage1 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0379
#   F1 (Macro):        0.8166
#   F1 (Weighted):     0.9767
#   AUC (OvR Macro):   0.9498
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9883
#   Class_1                       : 0.6448
#
# [TEST] Full metrics: {'accuracy': 0.9774387063119457, 'macro_precision': 0.8388938652199062, 'macro_recall': 0.7971984548928392, 'macro_f1': 0.8165566220832492, 'weighted_precision': 0.9761711765764212, 'weighted_recall': 0.9774387063119457, 'weighted_f1': 0.9766993790901733, 'precision_label1': 0.6916299559471366, 'recall_label1': 0.6038461538461538, 'f1_label1': 0.6447638603696099, 'auc': 0.9497964778202359, 'per_class_f1': {'0': 0.9883493837968886, '1': 0.6447638603696099}, 'confusion_matrix': [[7338, 70], [103, 157]], 'num_classes': 2, 'num_samples': 7668, 'loss': 0.03785197040633648, 'threshold': 0.93, 'positive_count': 260, 'positive_rate': 0.03390714658320292}
# [INFO] saved summary: /content/drive/MyDrive/s2/stage2_transformer_dropout_02_0610/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/stage2_transformer_dropout_02_0610

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/stage1_artifacts_full_64_head_T_C_gated_chronological \
  --out_dir /content/drive/MyDrive/s2/stage2_transformer_dropout_04_0610 \
  --config /content/drive/MyDrive/s2/stage2_config_noposition_dropout04.yaml \
  --context_method source_host \
  --context_policy split_isolated \
  --cls_head 3 \
  --window_size 128 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    27156
# test      7668
# val       3847
# [INFO] label counts by split:
# label      0    1
# split
# test    7408  260
# train  26257  899
# val     3715  132
# [INFO] z shape: (38671, 128)
# [INFO] context lengths: min=1, mean=35.78, p50=11.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:383: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** dropout= 0.4
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# Stage2Transformer(
#   (input_proj): Identity()
#   (pos): Identity()
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.4, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.4, inplace=False)
#         (dropout2): Dropout(p=0.4, inplace=False)
#       )
#     )
#   )
#   (cls_head): Sequential(
#     (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): GELU(approximate='none')
#     (6): Dropout(p=0.12, inplace=False)
#     (7): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# [INFO] Stage2 --------- Building trainer
# [INFO] weighted sampler class_counts: [26257, 899]
# [INFO]---trainer.py---make_loss_fn---label 分布: [26257.   899.]
# [INFO] Class distribution: [26257   899]
# [INFO] Imbalance ratio: 29.2:1
# [INFO] 极度不平衡，使用反比权重
# [INFO] Computed alpha weights: [0.03310502 0.96689498]
# [INFO] Few class weight / Many class weight: 29.21
# [INFO] Using FocalLoss: gamma=2.0, label_smoothing=0.02
# [INFO] Stage2 --------- Training
# [Stage2Trainer]---fit----metric_for_best =  f1_label1
# [EPOCH 037] train_loss=0.000744 val_loss=0.019286 val_macro_f1=0.7884 val_weighted_f1=0.9669318191007343 val_f1_label1=0.5967 val_auc=0.9659
# [EPOCH 038] train_loss=0.000669 val_loss=0.020038 val_macro_f1=0.7777 val_weighted_f1=0.9642403328576292 val_f1_label1=0.5774 val_auc=0.9621
# [EPOCH 039] train_loss=0.000737 val_loss=0.026037 val_macro_f1=0.7845 val_weighted_f1=0.9669478272203084 val_f1_label1=0.5886 val_auc=0.9609
# [EPOCH 040] train_loss=0.000673 val_loss=0.026846 val_macro_f1=0.7848 val_weighted_f1=0.9661704440593261 val_f1_label1=0.5902 val_auc=0.9604
# [EPOCH 041] train_loss=0.000685 val_loss=0.030058 val_macro_f1=0.7907 val_weighted_f1=0.9677463133532687 val_f1_label1=0.6006 val_auc=0.9594
# [INFO] Early stopping at epoch=41, best_epoch=21
# [INFO] Stage2 --------- Evaluating
# [INFO] Auto-selected threshold on val: 0.9300
# [INFO] Val metrics at selected threshold: {'accuracy': 0.9802443462438264, 'macro_precision': 0.8467310224639635, 'macro_recall': 0.8619060728414698, 'macro_f1': 0.8541407247765007, 'weighted_precision': 0.9806930048507595, 'weighted_recall': 0.9802443462438264, 'weighted_f1': 0.9804558703502854, 'precision_label1': 0.7028985507246377, 'recall_label1': 0.7348484848484849, 'f1_label1': 0.7185185185185186, 'auc': 0.9709031771279416, 'per_class_f1': {'0': 0.9897629310344828, '1': 0.7185185185185186}, 'confusion_matrix': [[3674, 41], [35, 97]], 'num_classes': 2, 'num_samples': 3847, 'threshold': 0.93}
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_transformer_dropout_04_0610/stage2_predictions_train.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_transformer_dropout_04_0610/stage2_predictions_val.csv
# [INFO] saved predictions: /content/drive/MyDrive/s2/stage2_transformer_dropout_04_0610/stage2_predictions_test.csv
#
# ==================================================
#             Stage1 Transformer - 测试集结果
# ==================================================
#   Loss:              0.0391
#   F1 (Macro):        0.8110
#   F1 (Weighted):     0.9751
#   AUC (OvR Macro):   0.9550
# ==================================================
#
# [RESULT] 各类别 F1 (降序):
#   Class_0                       : 0.9870
#   Class_1                       : 0.6350
#
# [TEST] Full metrics: {'accuracy': 0.974960876369327, 'macro_precision': 0.8076276885133666, 'macro_recall': 0.8144718807110816, 'macro_f1': 0.8110083876119054, 'weighted_precision': 0.9752422662592194, 'weighted_recall': 0.974960876369327, 'weighted_f1': 0.9750986129882775, 'precision_label1': 0.6278195488721805, 'recall_label1': 0.6423076923076924, 'f1_label1': 0.6349809885931559, 'auc': 0.9550138104336269, 'per_class_f1': {'0': 0.9870357866306549, '1': 0.6349809885931559}, 'confusion_matrix': [[7309, 99], [93, 167]], 'num_classes': 2, 'num_samples': 7668, 'loss': 0.03911273618105042, 'threshold': 0.93, 'positive_count': 260, 'positive_rate': 0.03390714658320292}
# [INFO] saved summary: /content/drive/MyDrive/s2/stage2_transformer_dropout_04_0610/stage2_run_summary.txt
# [INFO] Stage2 finished. Outputs saved to: /content/drive/MyDrive/s2/stage2_transformer_dropout_04_0610
