# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/s1/run_comparison_0619.py \
    --config /content/drive/MyDrive/s1/stage1_config_0619.yaml \
    --data_dir /content/drive/MyDrive/s1/data/ \
    --tensor_dir /content/drive/MyDrive/s1/tensors_ar_002 \
    --experiment_name 0619_seed42_v1 \
    --output_dir /content/drive/MyDrive/s1/0619_compare \
    --num_epochs 500 \
    --seed 42 \
    --device cuda
# Out:
# [INFO] 随机种子已设置: 42
#
# ============================================================
# 加载数据...seed 42
# ============================================================
#
# [INFO] Loading data...
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] pipeline.py ------ build_dataloaders --- split_method chronological
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ chronological_train_val_test_split-----------nominal_b1= 124025 nominal_b2= 141742
# [INFO] splits.py ------ chronological_train_val_test_split-----------b1= 124025 b2= 141818
# ********** splits.py *****************_sanitize_three_way_boundaries: 边界安全修正，保证每个 split 至少有一个样本
# [INFO] splits.py ------ chronological_train_val_test_split-----------train_df
#              flow_id  label  flow_start_timestamp_us
# 0  1051312184880716      0         1778495267572457
# 1  1051316147181637      0         1778495267572458
# 2  1051370242672817      0         1778495267572471
# [INFO] splits.py ------ chronological_train_val_test_split-----------val_df
#                  flow_id  label  flow_start_timestamp_us
# 124025  459827689366897      0         1778495289434741
# 124026  459877026526947      0         1778495289434753
# 124027  461372474545671      0         1778495289435101
# [INFO] splits.py ------ chronological_train_val_test_split-----------test_df
#                   flow_id  label  flow_start_timestamp_us
# 141818  1403934704123844      0         1778495292785631
# 141819  1403994154207061      0         1778495292785644
# 141820  1405386316874419      0         1778495292785969
#
# ================================================================================
# [INFO] Split report: chronological_train_val_test_split
# ================================================================================
# [INFO] train:
#        num_flows     = 124025
#        label_counts  = {0: 119522, 1: 4503}
#        label1_ratio  = 0.036307
#        time_range    = [1778495267572457, 1778495289434530]
# [INFO] val:
#        num_flows     = 17793
#        label_counts  = {0: 17086, 1: 707}
#        label1_ratio  = 0.039735
#        time_range    = [1778495289434741, 1778495292785562]
# [INFO] test:
#        num_flows     = 35360
#        label_counts  = {0: 33933, 1: 1427}
#        label1_ratio  = 0.040356
#        time_range    = [1778495292785631, 1778495299611559]
# ================================================================================
#
# [INFO] splits.py ------ chronological_train_val_test_split
# [INFO] 方案C模式：flow特征维度=68
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/tensors_ar_002/precomputed/seqLen64headtrain.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/tensors_ar_002/precomputed/seqLen64headval.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/tensors_ar_002/precomputed/seqLen64headtest.npz
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/tensors_ar_002/precomputed/seqLen64headtrain.npz
# [INFO] Dataset ------ Has separate flow features (方案C)
# [INFO]   Flow features shape: (124025, 68)
# [INFO] Dataset ------ Loaded 124025 flows
# [INFO]   X shape: (124025, 64, 51)
# [INFO]   Time shape: (124025, 64)
# [INFO]   Mask shape: (124025, 64)
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/tensors_ar_002/precomputed/seqLen64headval.npz
# [INFO] Dataset ------ Has separate flow features (方案C)
# [INFO]   Flow features shape: (17793, 68)
# [INFO] Dataset ------ Loaded 17793 flows
# [INFO]   X shape: (17793, 64, 51)
# [INFO]   Time shape: (17793, 64)
# [INFO]   Mask shape: (17793, 64)
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/tensors_ar_002/precomputed/seqLen64headtest.npz
# [INFO] Dataset ------ Has separate flow features (方案C)
# [INFO]   Flow features shape: (35360, 68)
# [INFO] Dataset ------ Loaded 35360 flows
# [INFO]   X shape: (35360, 64, 51)
# [INFO]   Time shape: (35360, 64)
# [INFO]   Mask shape: (35360, 64)
# 计算样本权重: class_counts [119522   4503]
# 计算样本权重: sample_weights [8.36666053e-06 8.36666053e-06 8.36666053e-06 ... 2.22074173e-04
#  8.36666053e-06 2.22074173e-04]
# [INFO] pipeline.py ------ build_dataloaders ----- end
#
# [DEBUG] --TRAIN--- Checking train_loader consistency...
# [DEBUG --TRAIN--- batch 0 flow_ids]: tensor([1398603733805505, 1404574231603104, 1451776648842120, 1399196488399918,
#         1845859089582727])
# [DEBUG --TRAIN--- batch 0 flow_ids]: tensor([ 681767750983936, 1338897300743988,  172809641321642, 2080111661473599,
#          614071469852413])
# [DEBUG --TRAIN--- batch 0 flow_ids]: tensor([2162546478148596,  854948871394984, 1695874089342836, 1938056152018682,
#         1616788242957058])
#
# [DEBUG] --VAL--- Checking VAL_loader consistency...
# [DEBUG --VAL--- batch 0 flow_ids]: tensor([459827689366897, 459877026526947, 461372474545671, 463942836130573,
#         464314188728827])
# [DEBUG --VAL--- batch 0 flow_ids]: tensor([508008924700322, 508730941541095, 509466006782946, 509860333897717,
#         509861146119437])
# [DEBUG --VAL--- batch 0 flow_ids]: tensor([541950448389964, 542144216433744, 542469370534637, 542783051393323,
#         542944490124386])
#
# [DEBUG] --TEST--- Checking TEST_loader consistency...
# [DEBUG --TEST--- batch 0 flow_ids]: tensor([1403934704123844, 1403994154207061, 1405386316874419, 1405989422326478,
#         1406711035449503])
# [DEBUG --TEST--- batch 0 flow_ids]: tensor([1173497521363076, 1174597819465351, 1175221586386020, 1175571117082639,
#         1180579692071447])
# [DEBUG --TEST--- batch 0 flow_ids]: tensor([1229139307901010, 1229144030219405, 1229890956434553, 1230439593682897,
#         1230446507465071])
# 训练集: 124025 个流
# 验证集: 17793 个流
# 测试集: 35360 个流
#   训练集分布: {np.int64(0): np.int64(62150), np.int64(1): np.int64(61875)}
#   验证集分布: {np.int64(0): np.int64(17086), np.int64(1): np.int64(707)}
#   测试集分布: {np.int64(0): np.int64(33933), np.int64(1): np.int64(1427)}
#
# 使用设备: cuda
# GPU: NVIDIA L4
# 显存: 22.0 GB
# [INFO] 方案C - 分层特征注入
# [INFO]   Packet input dim: 51
# [INFO]   Flow feature dim: 68
# [INFO]------model --- __init__---d_model=128, nhead=8, num_layers=2, dim_feedforward=128, dropout=0.3, max_seq_len=64, use_positional_encoding=True, use_time_encoding=True
# [INFO] 方案C - 分层特征注入已启用
# [INFO]   Flow特征维度: 68
# [INFO]   融合方法: gated
# [INFO]   模型维度: 128
# [INFO] Encoding: Time-Aware (TE(pos+p) from paper)
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# [✓] Time-Aware Transformer (Our Model - Both Time and Position Encoding)
# ============================================================
# 添加消融模型...
# ============================================================
# [INFO]------model --- __init__---d_model=128, nhead=8, num_layers=2, dim_feedforward=128, dropout=0.3, max_seq_len=64, use_positional_encoding=True, use_time_encoding=False
# [INFO] 方案C - 分层特征注入已启用
# [INFO]   Flow特征维度: 68
# [INFO]   融合方法: gated
# [INFO]   模型维度: 128
# [INFO] Encoding: Positional Encoding only
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# [✓] Ours - No Time Awareness - PositionOnly
# [INFO]------model --- __init__---d_model=128, nhead=8, num_layers=2, dim_feedforward=128, dropout=0.3, max_seq_len=64, use_positional_encoding=False, use_time_encoding=True
# [INFO] 方案C - 分层特征注入已启用
# [INFO]   Flow特征维度: 68
# [INFO]   融合方法: gated
# [INFO]   模型维度: 128
# [INFO] Encoding: Time Encoding only (no position index)
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# [✓] Ours - No Position Encoding - TimeOnly
# [INFO]------model --- __init__---d_model=128, nhead=8, num_layers=2, dim_feedforward=128, dropout=0.3, max_seq_len=64, use_positional_encoding=False, use_time_encoding=False
# [INFO] 方案C - 分层特征注入已启用
# [INFO]   Flow特征维度: 68
# [INFO]   融合方法: gated
# [INFO]   模型维度: 128
# [INFO] Encoding: None
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 3
# [✓] Ours - No Encoding
# 共添加 4 个模型（含消融）
#
# ============================================================
# 添加基线模型...self.input_dim 51
# ============================================================
# [✓] MLP (flow features only)
# [✓] LSTM-mean
# [✓] BiLSTM-mean
# [✓] GRU-mean
# [✓] CNN-1D-max
# [✓] Standard Transformer
# [✓] LSTM-mean + Time Feature
# [✓] CNN-1D-max + Time Feature
# 共添加 12 个基线模型
#
# [✓] XGBoost
# [✓] LightGBM
# [✓] Random Forest
#
# 开始训练和评估 15 个模型...
#
# ======================================================================
# 开始模型对比实验
# ======================================================================
# [INFO] 正在预缓存流级数据...
# [INFO] 流级数据缓存完成。
#
# ──────────────────────────────────────────────────
# 训练模型: Ours_BothEncoding
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# train_deep_model: Ours_BothEncoding,num_epochs=500,lr=0.001,weight_decay=0.0001,patience=10,verbose=True
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [Ours_BothEncoding] 已启用 torch.compile (reduce-overhead)
# W0619 09:10:54.178000 10516 torch/_inductor/utils.py:1731] [0/0] Not enough SMs to use max_autotune_gemm mode
# [Ours_BothEncoding] Epoch 5/500 | Train Loss: 0.0428 | Val Loss: 0.1591 | Val F1_class1: 0.7544 | Best F1_class1: 0.7544
# [Ours_BothEncoding] Epoch 10/500 | Train Loss: 0.0398 | Val Loss: 0.1413 | Val F1_class1: 0.7726 | Best F1_class1: 0.7726
# [Ours_BothEncoding] Epoch 15/500 | Train Loss: 0.0385 | Val Loss: 0.1432 | Val F1_class1: 0.7725 | Best F1_class1: 0.7837
# [Ours_BothEncoding] Epoch 20/500 | Train Loss: 0.0376 | Val Loss: 0.1448 | Val F1_class1: 0.7719 | Best F1_class1: 0.7837
# [Ours_BothEncoding] Epoch 25/500 | Train Loss: 0.0372 | Val Loss: 0.1376 | Val F1_class1: 0.7877 | Best F1_class1: 0.7916
# [Ours_BothEncoding] Epoch 30/500 | Train Loss: 0.0362 | Val Loss: 0.1295 | Val F1_class1: 0.7870 | Best F1_class1: 0.7916
# [Ours_BothEncoding] Early stopping at epoch 34
#
# [Ours_BothEncoding] 验证集:
#   F1 (macro): 0.8916
#   F1 (class1): 0.7916
#   ROC-AUC: 0.9887
#   PR-AUC: 0.8701
# [Ours_BothEncoding] 测试集:
#   F1 (macro): 0.8754
#   F1 (class1): 0.7604
#   ROC-AUC: 0.9866
#   PR-AUC: 0.8494
#   训练时间: 772.4s
#
# ──────────────────────────────────────────────────
# 训练模型: Ours_PositionOnly
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# train_deep_model: Ours_PositionOnly,num_epochs=500,lr=0.001,weight_decay=0.0001,patience=10,verbose=True
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [Ours_PositionOnly] 已启用 torch.compile (reduce-overhead)
# [Ours_PositionOnly] Epoch 5/500 | Train Loss: 0.0421 | Val Loss: 0.1451 | Val F1_class1: 0.7537 | Best F1_class1: 0.7567
# [Ours_PositionOnly] Epoch 10/500 | Train Loss: 0.0398 | Val Loss: 0.1567 | Val F1_class1: 0.7636 | Best F1_class1: 0.7695
# [Ours_PositionOnly] Epoch 15/500 | Train Loss: 0.0376 | Val Loss: 0.1467 | Val F1_class1: 0.7793 | Best F1_class1: 0.7793
# [Ours_PositionOnly] Epoch 20/500 | Train Loss: 0.0372 | Val Loss: 0.1541 | Val F1_class1: 0.7847 | Best F1_class1: 0.7847
# [Ours_PositionOnly] Epoch 25/500 | Train Loss: 0.0369 | Val Loss: 0.1297 | Val F1_class1: 0.7791 | Best F1_class1: 0.7847
# [Ours_PositionOnly] Epoch 30/500 | Train Loss: 0.0363 | Val Loss: 0.1344 | Val F1_class1: 0.7778 | Best F1_class1: 0.7847
# [Ours_PositionOnly] Early stopping at epoch 30
#
# [Ours_PositionOnly] 验证集:
#   F1 (macro): 0.8878
#   F1 (class1): 0.7847
#   ROC-AUC: 0.9884
#   PR-AUC: 0.8660
# [Ours_PositionOnly] 测试集:
#   F1 (macro): 0.8740
#   F1 (class1): 0.7583
#   ROC-AUC: 0.9864
#   PR-AUC: 0.8437
#   训练时间: 686.7s
#
# ──────────────────────────────────────────────────
# 训练模型: Ours_TimeOnly
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# train_deep_model: Ours_TimeOnly,num_epochs=500,lr=0.001,weight_decay=0.0001,patience=10,verbose=True
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [Ours_TimeOnly] 已启用 torch.compile (reduce-overhead)
# W0619 09:35:09.553000 10516 torch/_dynamo/convert_frame.py:1743] [0/8] torch._dynamo hit config.recompile_limit (8)
# W0619 09:35:09.553000 10516 torch/_dynamo/convert_frame.py:1743] [0/8]    function: 'forward' (/content/drive/MyDrive/s1/stage1/model.py:557)
# W0619 09:35:09.553000 10516 torch/_dynamo/convert_frame.py:1743] [0/8]    last reason: 0/7: GLOBAL_STATE changed: grad_mode autocast(cuda)_enabled
# W0619 09:35:09.553000 10516 torch/_dynamo/convert_frame.py:1743] [0/8] To log all recompilation reasons, use TORCH_LOGS="recompiles".
# W0619 09:35:09.553000 10516 torch/_dynamo/convert_frame.py:1743] [0/8] To diagnose recompilation issues, see https://docs.pytorch.org/docs/main/user_guide/torch_compiler/compile/programming_model.recompilation.html
# [Ours_TimeOnly] Epoch 5/500 | Train Loss: 0.0427 | Val Loss: 0.1706 | Val F1_class1: 0.7673 | Best F1_class1: 0.7673
# [Ours_TimeOnly] Epoch 10/500 | Train Loss: 0.0396 | Val Loss: 0.1536 | Val F1_class1: 0.7646 | Best F1_class1: 0.7739
# [Ours_TimeOnly] Epoch 15/500 | Train Loss: 0.0383 | Val Loss: 0.1528 | Val F1_class1: 0.7707 | Best F1_class1: 0.7739
# [Ours_TimeOnly] Epoch 20/500 | Train Loss: 0.0373 | Val Loss: 0.1318 | Val F1_class1: 0.7789 | Best F1_class1: 0.7789
# [Ours_TimeOnly] Epoch 25/500 | Train Loss: 0.0372 | Val Loss: 0.1389 | Val F1_class1: 0.7765 | Best F1_class1: 0.7789
# [Ours_TimeOnly] Epoch 30/500 | Train Loss: 0.0367 | Val Loss: 0.1352 | Val F1_class1: 0.7706 | Best F1_class1: 0.7850
# [Ours_TimeOnly] Epoch 35/500 | Train Loss: 0.0360 | Val Loss: 0.1430 | Val F1_class1: 0.7716 | Best F1_class1: 0.7850
# [Ours_TimeOnly] Early stopping at epoch 38
#
# [Ours_TimeOnly] 验证集:
#   F1 (macro): 0.8882
#   F1 (class1): 0.7850
#   ROC-AUC: 0.9872
#   PR-AUC: 0.8641
# [Ours_TimeOnly] 测试集:
#   F1 (macro): 0.8734
#   F1 (class1): 0.7567
#   ROC-AUC: 0.9854
#   PR-AUC: 0.8394
#   训练时间: 1987.6s
#
# ──────────────────────────────────────────────────
# 训练模型: Ours_NoEncoding
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# train_deep_model: Ours_NoEncoding,num_epochs=500,lr=0.001,weight_decay=0.0001,patience=10,verbose=True
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [Ours_NoEncoding] 已启用 torch.compile (reduce-overhead)
# [Ours_NoEncoding] Epoch 5/500 | Train Loss: 0.0435 | Val Loss: 0.1701 | Val F1_class1: 0.7486 | Best F1_class1: 0.7486
# [Ours_NoEncoding] Epoch 10/500 | Train Loss: 0.0406 | Val Loss: 0.1545 | Val F1_class1: 0.7662 | Best F1_class1: 0.7662
# [Ours_NoEncoding] Epoch 15/500 | Train Loss: 0.0401 | Val Loss: 0.1617 | Val F1_class1: 0.7500 | Best F1_class1: 0.7670
# [Ours_NoEncoding] Epoch 20/500 | Train Loss: 0.0390 | Val Loss: 0.1483 | Val F1_class1: 0.7592 | Best F1_class1: 0.7670
# [Ours_NoEncoding] Early stopping at epoch 22
#
# [Ours_NoEncoding] 验证集:
#   F1 (macro): 0.8787
#   F1 (class1): 0.7670
#   ROC-AUC: 0.9854
#   PR-AUC: 0.8413
# [Ours_NoEncoding] 测试集:
#   F1 (macro): 0.8621
#   F1 (class1): 0.7348
#   ROC-AUC: 0.9836
#   PR-AUC: 0.8184
#   训练时间: 1156.3s
#
# ──────────────────────────────────────────────────
# 训练模型: MLP_with_flow
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# train_deep_model: MLP_with_flow,num_epochs=500,lr=0.001,weight_decay=0.0001,patience=10,verbose=True
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [MLP_with_flow] 已启用 torch.compile (reduce-overhead)
# [MLP_with_flow] Epoch 5/500 | Train Loss: 0.0615 | Val Loss: 0.2359 | Val F1_class1: 0.6603 | Best F1_class1: 0.6603
# [MLP_with_flow] Epoch 10/500 | Train Loss: 0.0557 | Val Loss: 0.1875 | Val F1_class1: 0.6908 | Best F1_class1: 0.6920
# [MLP_with_flow] Epoch 15/500 | Train Loss: 0.0529 | Val Loss: 0.2016 | Val F1_class1: 0.6967 | Best F1_class1: 0.7015
# [MLP_with_flow] Epoch 20/500 | Train Loss: 0.0517 | Val Loss: 0.1841 | Val F1_class1: 0.6995 | Best F1_class1: 0.7076
# [MLP_with_flow] Epoch 25/500 | Train Loss: 0.0504 | Val Loss: 0.1900 | Val F1_class1: 0.7039 | Best F1_class1: 0.7076
# [MLP_with_flow] Epoch 30/500 | Train Loss: 0.0503 | Val Loss: 0.1779 | Val F1_class1: 0.7108 | Best F1_class1: 0.7113
# [MLP_with_flow] Epoch 35/500 | Train Loss: 0.0488 | Val Loss: 0.1807 | Val F1_class1: 0.7050 | Best F1_class1: 0.7113
# [MLP_with_flow] Early stopping at epoch 38
#
# [MLP_with_flow] 验证集:
#   F1 (macro): 0.8493
#   F1 (class1): 0.7113
#   ROC-AUC: 0.9812
#   PR-AUC: 0.7847
# [MLP_with_flow] 测试集:
#   F1 (macro): 0.7908
#   F1 (class1): 0.5975
#   ROC-AUC: 0.9593
#   PR-AUC: 0.6528
#   训练时间: 668.1s
#
# ──────────────────────────────────────────────────
# 训练模型: LSTM
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# train_deep_model: LSTM,num_epochs=500,lr=0.001,weight_decay=0.0001,patience=10,verbose=True
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [LSTM] 已启用 torch.compile (reduce-overhead)
# [LSTM] Epoch 5/500 | Train Loss: 0.0378 | Val Loss: 0.1495 | Val F1_class1: 0.7780 | Best F1_class1: 0.7780
# [LSTM] Epoch 10/500 | Train Loss: 0.0283 | Val Loss: 0.1239 | Val F1_class1: 0.7859 | Best F1_class1: 0.7859
# [LSTM] Epoch 15/500 | Train Loss: 0.0227 | Val Loss: 0.1066 | Val F1_class1: 0.7805 | Best F1_class1: 0.7896
# [LSTM] Epoch 20/500 | Train Loss: 0.0192 | Val Loss: 0.0981 | Val F1_class1: 0.7887 | Best F1_class1: 0.7896
# [LSTM] Early stopping at epoch 23
#
# [LSTM] 验证集:
#   F1 (macro): 0.8905
#   F1 (class1): 0.7896
#   ROC-AUC: 0.9847
#   PR-AUC: 0.8647
# [LSTM] 测试集:
#   F1 (macro): 0.8731
#   F1 (class1): 0.7563
#   ROC-AUC: 0.9822
#   PR-AUC: 0.8379
#   训练时间: 972.3s
#
# ──────────────────────────────────────────────────
# 训练模型: BiLSTM
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# train_deep_model: BiLSTM,num_epochs=500,lr=0.001,weight_decay=0.0001,patience=10,verbose=True
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [BiLSTM] 已启用 torch.compile (reduce-overhead)
# [BiLSTM] Epoch 5/500 | Train Loss: 0.0348 | Val Loss: 0.1268 | Val F1_class1: 0.7791 | Best F1_class1: 0.7791
# [BiLSTM] Epoch 10/500 | Train Loss: 0.0241 | Val Loss: 0.1031 | Val F1_class1: 0.7713 | Best F1_class1: 0.7791
# [BiLSTM] Epoch 15/500 | Train Loss: 0.0182 | Val Loss: 0.1006 | Val F1_class1: 0.7652 | Best F1_class1: 0.7908
# [BiLSTM] Epoch 20/500 | Train Loss: 0.0154 | Val Loss: 0.0963 | Val F1_class1: 0.7748 | Best F1_class1: 0.7908
# [BiLSTM] Early stopping at epoch 23
#
# [BiLSTM] 验证集:
#   F1 (macro): 0.8911
#   F1 (class1): 0.7908
#   ROC-AUC: 0.9797
#   PR-AUC: 0.8472
# [BiLSTM] 测试集:
#   F1 (macro): 0.8757
#   F1 (class1): 0.7613
#   ROC-AUC: 0.9761
#   PR-AUC: 0.8160
#   训练时间: 1343.3s
#
# ──────────────────────────────────────────────────
# 训练模型: GRU
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# train_deep_model: GRU,num_epochs=500,lr=0.001,weight_decay=0.0001,patience=10,verbose=True
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [GRU] 已启用 torch.compile (reduce-overhead)
# [GRU] Epoch 5/500 | Train Loss: 0.0338 | Val Loss: 0.1387 | Val F1_class1: 0.7871 | Best F1_class1: 0.7871
# [GRU] Epoch 10/500 | Train Loss: 0.0238 | Val Loss: 0.1214 | Val F1_class1: 0.7713 | Best F1_class1: 0.7871
# [GRU] Epoch 15/500 | Train Loss: 0.0196 | Val Loss: 0.1023 | Val F1_class1: 0.7906 | Best F1_class1: 0.7906
# [GRU] Epoch 20/500 | Train Loss: 0.0175 | Val Loss: 0.0992 | Val F1_class1: 0.7769 | Best F1_class1: 0.7911
# [GRU] Epoch 25/500 | Train Loss: 0.0157 | Val Loss: 0.0981 | Val F1_class1: 0.7690 | Best F1_class1: 0.7911
# [GRU] Early stopping at epoch 26
#
# [GRU] 验证集:
#   F1 (macro): 0.8912
#   F1 (class1): 0.7911
#   ROC-AUC: 0.9816
#   PR-AUC: 0.8536
# [GRU] 测试集:
#   F1 (macro): 0.8780
#   F1 (class1): 0.7661
#   ROC-AUC: 0.9764
#   PR-AUC: 0.8302
#   训练时间: 1061.6s
#
# ──────────────────────────────────────────────────
# 训练模型: CNN1D
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# train_deep_model: CNN1D,num_epochs=500,lr=0.001,weight_decay=0.0001,patience=10,verbose=True
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [CNN1D] 已启用 torch.compile (reduce-overhead)
# [CNN1D] Epoch 5/500 | Train Loss: 0.0410 | Val Loss: 0.1692 | Val F1_class1: 0.7401 | Best F1_class1: 0.7611
# [CNN1D] Epoch 10/500 | Train Loss: 0.0364 | Val Loss: 0.1427 | Val F1_class1: 0.7626 | Best F1_class1: 0.7680
# [CNN1D] Epoch 15/500 | Train Loss: 0.0335 | Val Loss: 0.1375 | Val F1_class1: 0.7741 | Best F1_class1: 0.7741
# [CNN1D] Epoch 20/500 | Train Loss: 0.0319 | Val Loss: 0.1352 | Val F1_class1: 0.7692 | Best F1_class1: 0.7808
# [CNN1D] Epoch 25/500 | Train Loss: 0.0305 | Val Loss: 0.1352 | Val F1_class1: 0.7777 | Best F1_class1: 0.7808
# [CNN1D] Early stopping at epoch 29
#
# [CNN1D] 验证集:
#   F1 (macro): 0.8860
#   F1 (class1): 0.7808
#   ROC-AUC: 0.9836
#   PR-AUC: 0.8400
# [CNN1D] 测试集:
#   F1 (macro): 0.8710
#   F1 (class1): 0.7522
#   ROC-AUC: 0.9824
#   PR-AUC: 0.8206
#   训练时间: 480.9s
#
# ──────────────────────────────────────────────────
# 训练模型: StandardTransformer
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# train_deep_model: StandardTransformer,num_epochs=500,lr=0.001,weight_decay=0.0001,patience=10,verbose=True
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [StandardTransformer] 已启用 torch.compile (reduce-overhead)
# [StandardTransformer] Epoch 5/500 | Train Loss: 0.0363 | Val Loss: 0.1630 | Val F1_class1: 0.7619 | Best F1_class1: 0.7619
# [StandardTransformer] Epoch 10/500 | Train Loss: 0.0317 | Val Loss: 0.1425 | Val F1_class1: 0.7533 | Best F1_class1: 0.7693
# [StandardTransformer] Epoch 15/500 | Train Loss: 0.0287 | Val Loss: 0.1228 | Val F1_class1: 0.7757 | Best F1_class1: 0.7757
# [StandardTransformer] Epoch 20/500 | Train Loss: 0.0265 | Val Loss: 0.1228 | Val F1_class1: 0.7737 | Best F1_class1: 0.7757
# [StandardTransformer] Epoch 25/500 | Train Loss: 0.0246 | Val Loss: 0.1099 | Val F1_class1: 0.7608 | Best F1_class1: 0.7757
# [StandardTransformer] Early stopping at epoch 25
#
# [StandardTransformer] 验证集:
#   F1 (macro): 0.8832
#   F1 (class1): 0.7757
#   ROC-AUC: 0.9846
#   PR-AUC: 0.8629
# [StandardTransformer] 测试集:
#   F1 (macro): 0.8658
#   F1 (class1): 0.7420
#   ROC-AUC: 0.9850
#   PR-AUC: 0.8328
#   训练时间: 555.6s
#
# ──────────────────────────────────────────────────
# 训练模型: LSTM_with_time
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# train_deep_model: LSTM_with_time,num_epochs=500,lr=0.001,weight_decay=0.0001,patience=10,verbose=True
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [LSTM_with_time] 已启用 torch.compile (reduce-overhead)
# W0619 11:53:04.671000 10516 torch/_dynamo/convert_frame.py:1743] [2/8] torch._dynamo hit config.recompile_limit (8)
# W0619 11:53:04.671000 10516 torch/_dynamo/convert_frame.py:1743] [2/8]    function: 'forward' (/content/drive/MyDrive/s1/stage1/baselines.py:130)
# W0619 11:53:04.671000 10516 torch/_dynamo/convert_frame.py:1743] [2/8]    last reason: 2/7: GLOBAL_STATE changed: grad_mode autocast(cuda)_enabled
# W0619 11:53:04.671000 10516 torch/_dynamo/convert_frame.py:1743] [2/8] To log all recompilation reasons, use TORCH_LOGS="recompiles".
# W0619 11:53:04.671000 10516 torch/_dynamo/convert_frame.py:1743] [2/8] To diagnose recompilation issues, see https://docs.pytorch.org/docs/main/user_guide/torch_compiler/compile/programming_model.recompilation.html
# [LSTM_with_time] Epoch 5/500 | Train Loss: 0.0360 | Val Loss: 0.1427 | Val F1_class1: 0.7684 | Best F1_class1: 0.7684
# [LSTM_with_time] Epoch 10/500 | Train Loss: 0.0257 | Val Loss: 0.1251 | Val F1_class1: 0.7840 | Best F1_class1: 0.7899
# [LSTM_with_time] Epoch 15/500 | Train Loss: 0.0198 | Val Loss: 0.1038 | Val F1_class1: 0.7654 | Best F1_class1: 0.7975
# [LSTM_with_time] Epoch 20/500 | Train Loss: 0.0160 | Val Loss: 0.0921 | Val F1_class1: 0.7817 | Best F1_class1: 0.7975
# [LSTM_with_time] Early stopping at epoch 24
#
# [LSTM_with_time] 验证集:
#   F1 (macro): 0.8945
#   F1 (class1): 0.7975
#   ROC-AUC: 0.9822
#   PR-AUC: 0.8564
# [LSTM_with_time] 测试集:
#   F1 (macro): 0.8877
#   F1 (class1): 0.7845
#   ROC-AUC: 0.9804
#   PR-AUC: 0.8433
#   训练时间: 1024.8s
#
# ──────────────────────────────────────────────────
# 训练模型: CNN1D_with_time
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# train_deep_model: CNN1D_with_time,num_epochs=500,lr=0.001,weight_decay=0.0001,patience=10,verbose=True
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [CNN1D_with_time] 已启用 torch.compile (reduce-overhead)
# [CNN1D_with_time] Epoch 5/500 | Train Loss: 0.0421 | Val Loss: 0.1539 | Val F1_class1: 0.7543 | Best F1_class1: 0.7543
# [CNN1D_with_time] Epoch 10/500 | Train Loss: 0.0369 | Val Loss: 0.1454 | Val F1_class1: 0.7599 | Best F1_class1: 0.7627
# [CNN1D_with_time] Epoch 15/500 | Train Loss: 0.0333 | Val Loss: 0.1282 | Val F1_class1: 0.7680 | Best F1_class1: 0.7685
# [CNN1D_with_time] Epoch 20/500 | Train Loss: 0.0310 | Val Loss: 0.1325 | Val F1_class1: 0.7606 | Best F1_class1: 0.7914
# [CNN1D_with_time] Epoch 25/500 | Train Loss: 0.0301 | Val Loss: 0.1238 | Val F1_class1: 0.7715 | Best F1_class1: 0.7914
# [CNN1D_with_time] Early stopping at epoch 29
#
# [CNN1D_with_time] 验证集:
#   F1 (macro): 0.8914
#   F1 (class1): 0.7914
#   ROC-AUC: 0.9826
#   PR-AUC: 0.8436
# [CNN1D_with_time] 测试集:
#   F1 (macro): 0.8779
#   F1 (class1): 0.7655
#   ROC-AUC: 0.9804
#   PR-AUC: 0.8185
#   训练时间: 477.4s
#
# ──────────────────────────────────────────────────
# 训练模型: XGBoost
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# [XGBoost] 验证集:
#   F1 (macro): 0.8405
#   F1 (class1): 0.6955
#   ROC-AUC: 0.9811
#   PR-AUC: 0.6674
# [XGBoost] 测试集:
#   F1 (macro): 0.7858
#   F1 (class1): 0.5909
#   ROC-AUC: 0.9667
#   PR-AUC: 0.5573
#   训练时间: 8.3s
#
# ──────────────────────────────────────────────────
# 训练模型: LightGBM
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
# [LightGBM] [Info] Number of positive: 61891, number of negative: 62134
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009503 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 14090
# [LightGBM] [Info] Number of data points in the train set: 124025, number of used features: 65
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# Training until validation scores don't improve for 20 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [200]	valid_0's binary_logloss: 0.137657
#
# [LightGBM] 验证集:
#   F1 (macro): 0.8384
#   F1 (class1): 0.6922
#   ROC-AUC: 0.9816
#   PR-AUC: 0.6855
# [LightGBM] 测试集:
#   F1 (macro): 0.7834
#   F1 (class1): 0.5869
#   ROC-AUC: 0.9666
#   PR-AUC: 0.5716
#   训练时间: 2.4s
#
# ──────────────────────────────────────────────────
# 训练模型: RandomForest
# ──────────────────────────────────────────────────
# [INFO] 随机种子已设置: 42
#
# [RandomForest] 验证集:
#   F1 (macro): 0.7483
#   F1 (class1): 0.5214
#   ROC-AUC: 0.9608
#   PR-AUC: 0.4349
# [RandomForest] 测试集:
#   F1 (macro): 0.6987
#   F1 (class1): 0.4385
#   ROC-AUC: 0.9436
#   PR-AUC: 0.3700
#   训练时间: 9.5s
#
# 对比表格已保存至: /content/drive/MyDrive/s1/0619_compare/0619_seed42_v1/comparison_table.csv
# LaTeX 表格已保存至: /content/drive/MyDrive/s1/0619_compare/0619_seed42_v1/comparison_table.tex
#   ML Models: 3 个模型
#   DL Without Sequence: 1 个模型
#   Sequence Models: 5 个模型
#   Sequence + Raw Time: 2 个模型
#   Ablation Models: 4 个模型
#
# 对比图表已保存至: /content/drive/MyDrive/s1/0619_compare/0619_seed42_v1/comparison_plots.png
# 消融实验图已保存至: /content/drive/MyDrive/s1/0619_compare/0619_seed42_v1/ablation_study.png
#
# 原始结果已保存至: /content/drive/MyDrive/s1/0619_compare/0619_seed42_v1/all_results.json
#
# 对比实验完成！报告保存在: /content/drive/MyDrive/s1/0619_compare/0619_seed42_v1

# %%
# !python /content/drive/MyDrive/s1/run_comparison_0619.py \
    --config /content/drive/MyDrive/s1/stage1_config_0619.yaml \
    --data_dir /content/drive/MyDrive/s1/data/ \
    --tensor_dir /content/drive/MyDrive/s1/tensors_ar_002 \
    --experiment_name 0619_seed42_v2 \
    --output_dir /content/drive/MyDrive/s1/0619_compare \
    --num_epochs 500 \
    --seed 42 \
    --device cuda
# Out:
# [INFO] 随机种子已设置: 42
#
# ============================================================
# 加载数据...seed 42
# ============================================================
#
# [INFO] Loading data...
# [INFO] pipeline.py ------ build_dataloaders --- start
# [INFO] pipeline.py ------ build_dataloaders --- split_method chronological
# [INFO] data_io.py ------ read_stage1_csvs --- start
# [INFO] data_io.py ------ read_stage1_csvs --- end
# [INFO] splits.py ------ chronological_train_val_test_split-----------nominal_b1= 124025 nominal_b2= 141742
# [INFO] splits.py ------ chronological_train_val_test_split-----------b1= 124025 b2= 141818
# ********** splits.py *****************_sanitize_three_way_boundaries: 边界安全修正，保证每个 split 至少有一个样本
# [INFO] splits.py ------ chronological_train_val_test_split-----------train_df
#              flow_id  label  flow_start_timestamp_us
# 0  1051312184880716      0         1778495267572457
# 1  1051316147181637      0         1778495267572458
# 2  1051370242672817      0         1778495267572471
# [INFO] splits.py ------ chronological_train_val_test_split-----------val_df
#                  flow_id  label  flow_start_timestamp_us
# 124025  459827689366897      0         1778495289434741
# 124026  459877026526947      0         1778495289434753
# 124027  461372474545671      0         1778495289435101
# [INFO] splits.py ------ chronological_train_val_test_split-----------test_df
#                   flow_id  label  flow_start_timestamp_us
# 141818  1403934704123844      0         1778495292785631
# 141819  1403994154207061      0         1778495292785644
# 141820  1405386316874419      0         1778495292785969
#
# ================================================================================
# [INFO] Split report: chronological_train_val_test_split
# ================================================================================
# [INFO] train:
#        num_flows     = 124025
#        label_counts  = {0: 119522, 1: 4503}
#        label1_ratio  = 0.036307
#        time_range    = [1778495267572457, 1778495289434530]
# [INFO] val:
#        num_flows     = 17793
#        label_counts  = {0: 17086, 1: 707}
#        label1_ratio  = 0.039735
#        time_range    = [1778495289434741, 1778495292785562]
# [INFO] test:
#        num_flows     = 35360
#        label_counts  = {0: 33933, 1: 1427}
#        label1_ratio  = 0.040356
#        time_range    = [1778495292785631, 1778495299611559]
# ================================================================================
#
# [INFO] splits.py ------ chronological_train_val_test_split
# [INFO] 方案C模式：flow特征维度=68
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/tensors_ar_002/precomputed/seqLen64headtrain.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/tensors_ar_002/precomputed/seqLen64headval.npz
# [INFO] found existing precomputed tensor: /content/drive/MyDrive/s1/tensors_ar_002/precomputed/seqLen64headtest.npz
# [INFO] Dataset ------ Loading /content/drive/MyDrive/s1/tensors_ar_002/precomputed/seqLen64headtrain.npz
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/s1/run_comparison_0619.py", line 341, in <module>
#     main()
#   File "/content/drive/MyDrive/s1/run_comparison_0619.py", line 337, in main
#     run_single_experiment(args, config)
#   File "/content/drive/MyDrive/s1/run_comparison_0619.py", line 90, in run_single_experiment
#     loaders, preprocessor, metadata = build_dataloaders(
#                                       ^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/s1/stage1/pipeline.py", line 241, in build_dataloaders
#     "train": PrecomputedFlowDataset(train_npz),
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/s1/stage1/dataset.py", line 15, in __init__
#     self.x = data['x']  # [N, max_seq_len, feature_dim]
#              ~~~~^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py", line 256, in __getitem__
#     return format.read_array(bytes,
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/format.py", line 858, in read_array
#     data = _read_bytes(fp, read_size, "array data")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/format.py", line 993, in _read_bytes
#     r = fp.read(size - len(data))
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/zipfile/__init__.py", line 1008, in read
#     data = self._read1(n)
#            ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/zipfile/__init__.py", line 1084, in _read1
#     data = self._decompressor.decompress(data, n)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
