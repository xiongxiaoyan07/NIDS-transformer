# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip -q install optuna

# %%
# !python /content/drive/MyDrive/s2/tune_stage2_optuna.py \
  --stage1_dir /content/drive/MyDrive/s1/tensors_ar_002 \
  --config /content/drive/MyDrive/s2/stage2_config_0619.yaml \
  --out_dir /content/drive/MyDrive/s2/stage2_optuna_0619 \
  --study_name stage2_transformer_v1 \
  --n_trials 30 \
  --max_epochs 35 \
  --patience 6 \
  --final_epochs 150 \
  --final_patience 15 \
  --objective_metric macro_f1 \
  --profile fast \
  --num_workers 2 \
  --batch_sizes 64,128,256 \
  --eval_batch_sizes 128,256,512
# Out:
# [TUNE] device=cuda
# [TUNE] Loading and sorting Stage1 outputs once...
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [TUNE] flows=177178, input_dim=128
# [TUNE] split counts={'train': 124025, 'test': 35360, 'val': 17793}
# [I 2026-06-19 14:26:33,831] A new study created in RDB with name: stage2_transformer_v1
#   0% 0/30 [00:00<?, ?it/s][TUNE] Building exact context indices for window_size=128
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:535: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= mean
# [INFO] Stage2Transformer.__init__*********** dropout= 0.30000000000000004
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 2
# [TRIAL 000][EPOCH 001] train_loss=0.703263 val_macro_f1=0.44049 val_f1_label1=0.08331 val_auc=0.54987 objective=0.44049
# [TRIAL 000][EPOCH 002] train_loss=0.684920 val_macro_f1=0.25729 val_f1_label1=0.08465 val_auc=0.58647 objective=0.25729
# [TRIAL 000][EPOCH 003] train_loss=0.676714 val_macro_f1=0.44268 val_f1_label1=0.09522 val_auc=0.58655 objective=0.44268
# [TRIAL 000][EPOCH 004] train_loss=0.675680 val_macro_f1=0.38358 val_f1_label1=0.09111 val_auc=0.58746 objective=0.38358
# [TRIAL 000][EPOCH 005] train_loss=0.671620 val_macro_f1=0.41094 val_f1_label1=0.09285 val_auc=0.58897 objective=0.41094
# [TRIAL 000][EPOCH 006] train_loss=0.671904 val_macro_f1=0.26599 val_f1_label1=0.08568 val_auc=0.58596 objective=0.26599
# [TRIAL 000][EPOCH 007] train_loss=0.671831 val_macro_f1=0.33171 val_f1_label1=0.08911 val_auc=0.58716 objective=0.33171
# [TRIAL 000][EPOCH 008] train_loss=0.670818 val_macro_f1=0.39935 val_f1_label1=0.09293 val_auc=0.58747 objective=0.39935
# [TRIAL 000][EPOCH 009] train_loss=0.670776 val_macro_f1=0.39148 val_f1_label1=0.09223 val_auc=0.58633 objective=0.39148
# [I 2026-06-19 14:29:45,787] Trial 0 finished with value: 0.44268221655690254 and parameters: {'d_model': '128', 'nhead': 2, 'num_layers': 1, 'ff_multiplier': 2, 'dropout': 0.30000000000000004, 'pooling': 'mean', 'use_positional_encoding': False, 'cls_head': 2, 'lr': 0.00012439367209907224, 'weight_decay': 3.752055855124284e-05, 'batch_size': 256, 'eval_batch_size': 512, 'grad_clip_norm': 1.0, 'loss_type': 'ce'}. Best is trial 0 with value: 0.44268221655690254.
# Best trial: 0. Best value: 0.442682:   3% 1/30 [03:12<1:32:51, 192.11s/it][INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:535: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** dropout= 0.30000000000000004
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [TRIAL 001][EPOCH 001] train_loss=0.224167 val_macro_f1=0.75549 val_f1_label1=0.54501 val_auc=0.98557 objective=0.75549
# [TRIAL 001][EPOCH 002] train_loss=0.144551 val_macro_f1=0.76394 val_f1_label1=0.55997 val_auc=0.98753 objective=0.76394
# [TRIAL 001][EPOCH 003] train_loss=0.133790 val_macro_f1=0.82924 val_f1_label1=0.67679 val_auc=0.98782 objective=0.82924
# [TRIAL 001][EPOCH 004] train_loss=0.128544 val_macro_f1=0.76973 val_f1_label1=0.57010 val_auc=0.98776 objective=0.76973
# [TRIAL 001][EPOCH 005] train_loss=0.127113 val_macro_f1=0.76722 val_f1_label1=0.56583 val_auc=0.98831 objective=0.76722
# [TRIAL 001][EPOCH 006] train_loss=0.122872 val_macro_f1=0.78701 val_f1_label1=0.60080 val_auc=0.98817 objective=0.78701
# [TRIAL 001][EPOCH 007] train_loss=0.121513 val_macro_f1=0.78663 val_f1_label1=0.60000 val_auc=0.98780 objective=0.78663
# [TRIAL 001][EPOCH 008] train_loss=0.117165 val_macro_f1=0.77549 val_f1_label1=0.58028 val_auc=0.98809 objective=0.77549
# [TRIAL 001][EPOCH 009] train_loss=0.113898 val_macro_f1=0.79679 val_f1_label1=0.61830 val_auc=0.98738 objective=0.79679
# [I 2026-06-19 14:33:07,548] Trial 1 finished with value: 0.829236511845741 and parameters: {'d_model': '128', 'nhead': 8, 'num_layers': 1, 'ff_multiplier': 2, 'dropout': 0.30000000000000004, 'pooling': 'last', 'use_positional_encoding': False, 'cls_head': 1, 'lr': 0.000363857531708547, 'weight_decay': 8.61257919259488e-06, 'batch_size': 128, 'eval_batch_size': 128, 'grad_clip_norm': 2.0, 'loss_type': 'ce'}. Best is trial 1 with value: 0.829236511845741.
# Best trial: 1. Best value: 0.829237:   7% 2/30 [06:33<1:32:19, 197.82s/it][INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:535: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= mean
# [INFO] Stage2Transformer.__init__*********** dropout= 0.35
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 2
# [TRIAL 002][EPOCH 001] train_loss=0.685036 val_macro_f1=0.40066 val_f1_label1=0.09306 val_auc=0.58718 objective=0.40066
# [TRIAL 002][EPOCH 002] train_loss=0.677755 val_macro_f1=0.38617 val_f1_label1=0.09045 val_auc=0.58722 objective=0.38617
# [TRIAL 002][EPOCH 003] train_loss=0.679636 val_macro_f1=0.42783 val_f1_label1=0.09681 val_auc=0.59214 objective=0.42783
# [TRIAL 002][EPOCH 004] train_loss=0.687286 val_macro_f1=0.35280 val_f1_label1=0.09022 val_auc=0.59300 objective=0.35280
# [TRIAL 002][EPOCH 005] train_loss=0.687527 val_macro_f1=0.37024 val_f1_label1=0.09186 val_auc=0.59411 objective=0.37024
# [TRIAL 002][EPOCH 006] train_loss=0.688853 val_macro_f1=0.34554 val_f1_label1=0.08954 val_auc=0.59045 objective=0.34554
# [TRIAL 002][EPOCH 007] train_loss=0.691698 val_macro_f1=0.28265 val_f1_label1=0.08675 val_auc=0.58935 objective=0.28265
# [TRIAL 002][EPOCH 008] train_loss=0.690850 val_macro_f1=0.25874 val_f1_label1=0.08577 val_auc=0.58594 objective=0.25874
# [TRIAL 002][EPOCH 009] train_loss=0.688353 val_macro_f1=0.45444 val_f1_label1=0.09273 val_auc=0.58060 objective=0.45444
# [TRIAL 002][EPOCH 010] train_loss=0.695872 val_macro_f1=0.33235 val_f1_label1=0.09014 val_auc=0.58564 objective=0.33235
# [TRIAL 002][EPOCH 011] train_loss=0.693935 val_macro_f1=0.37671 val_f1_label1=0.08977 val_auc=0.58616 objective=0.37671
# [TRIAL 002][EPOCH 012] train_loss=0.696541 val_macro_f1=0.25544 val_f1_label1=0.08613 val_auc=0.58593 objective=0.25544
# [TRIAL 002][EPOCH 013] train_loss=0.692823 val_macro_f1=0.37462 val_f1_label1=0.08946 val_auc=0.57804 objective=0.37462
# [TRIAL 002][EPOCH 014] train_loss=0.697442 val_macro_f1=0.40204 val_f1_label1=0.08769 val_auc=0.57647 objective=0.40204
# [TRIAL 002][EPOCH 015] train_loss=0.695178 val_macro_f1=0.38421 val_f1_label1=0.08880 val_auc=0.57502 objective=0.38421
# [I 2026-06-19 14:41:09,193] Trial 2 finished with value: 0.4544412958870181 and parameters: {'d_model': '128', 'nhead': 8, 'num_layers': 1, 'ff_multiplier': 2, 'dropout': 0.35, 'pooling': 'mean', 'use_positional_encoding': False, 'cls_head': 2, 'lr': 0.0004155397855708038, 'weight_decay': 0.00015382308040278996, 'batch_size': 64, 'eval_batch_size': 256, 'grad_clip_norm': 0.5, 'loss_type': 'ce'}. Best is trial 1 with value: 0.829236511845741.
# Best trial: 1. Best value: 0.829237:  10% 3/30 [14:35<2:27:20, 327.42s/it][INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:535: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** dropout= 0.25
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [TRIAL 003][EPOCH 001] train_loss=0.322010 val_macro_f1=0.75262 val_f1_label1=0.54000 val_auc=0.98348 objective=0.75262
# [TRIAL 003][EPOCH 002] train_loss=0.149887 val_macro_f1=0.75805 val_f1_label1=0.54966 val_auc=0.98705 objective=0.75805
# [TRIAL 003][EPOCH 003] train_loss=0.137862 val_macro_f1=0.79597 val_f1_label1=0.61674 val_auc=0.98796 objective=0.79597
# [TRIAL 003][EPOCH 004] train_loss=0.130545 val_macro_f1=0.74968 val_f1_label1=0.53527 val_auc=0.98801 objective=0.74968
# [TRIAL 003][EPOCH 005] train_loss=0.126147 val_macro_f1=0.77683 val_f1_label1=0.58276 val_auc=0.98829 objective=0.77683
# [TRIAL 003][EPOCH 006] train_loss=0.123687 val_macro_f1=0.77433 val_f1_label1=0.57818 val_auc=0.98846 objective=0.77433
# [TRIAL 003][EPOCH 007] train_loss=0.121606 val_macro_f1=0.77381 val_f1_label1=0.57730 val_auc=0.98794 objective=0.77381
# [TRIAL 003][EPOCH 008] train_loss=0.118003 val_macro_f1=0.78660 val_f1_label1=0.59991 val_auc=0.98854 objective=0.78660
# [TRIAL 003][EPOCH 009] train_loss=0.116836 val_macro_f1=0.78122 val_f1_label1=0.59055 val_auc=0.98823 objective=0.78122
# [I 2026-06-19 14:44:06,975] Trial 3 finished with value: 0.7959663678076294 and parameters: {'d_model': '128', 'nhead': 8, 'num_layers': 1, 'ff_multiplier': 2, 'dropout': 0.25, 'pooling': 'last', 'use_positional_encoding': False, 'cls_head': 1, 'lr': 0.0002294223523656216, 'weight_decay': 0.0005280796376895364, 'batch_size': 256, 'eval_batch_size': 512, 'grad_clip_norm': 1.0, 'loss_type': 'ce'}. Best is trial 1 with value: 0.829236511845741.
# Best trial: 1. Best value: 0.829237:  13% 4/30 [17:33<1:56:16, 268.33s/it][INFO] Stage2Transformer.__init__ use_positional_encoding= True
# /content/drive/MyDrive/s2/stage2/model.py:535: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= mean
# [INFO] Stage2Transformer.__init__*********** dropout= 0.2
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [INFO] Class distribution: [119522   4503]
# [INFO] Imbalance ratio: 26.5:1
# [INFO] 极度不平衡，使用反比权重
# [INFO] Computed alpha weights: [0.0363072 0.9636928]
# [INFO] Few class weight / Many class weight: 26.54
# [TRIAL 004][EPOCH 001] train_loss=0.025558 val_macro_f1=0.22013 val_f1_label1=0.07733 val_auc=0.53320 objective=0.22013
# [TRIAL 004][EPOCH 002] train_loss=0.022538 val_macro_f1=0.68170 val_f1_label1=0.41845 val_auc=0.96006 objective=0.68170
# [TRIAL 004][EPOCH 003] train_loss=0.006522 val_macro_f1=0.76887 val_f1_label1=0.56840 val_auc=0.98492 objective=0.76887
# [TRIAL 004][EPOCH 004] train_loss=0.005308 val_macro_f1=0.75396 val_f1_label1=0.54263 val_auc=0.98689 objective=0.75396
# [TRIAL 004][EPOCH 005] train_loss=0.004978 val_macro_f1=0.77597 val_f1_label1=0.58106 val_auc=0.98727 objective=0.77597
# [TRIAL 004][EPOCH 006] train_loss=0.004765 val_macro_f1=0.77095 val_f1_label1=0.57228 val_auc=0.98756 objective=0.77095
# [TRIAL 004][EPOCH 007] train_loss=0.004617 val_macro_f1=0.77806 val_f1_label1=0.58475 val_auc=0.98744 objective=0.77806
# [TRIAL 004][EPOCH 008] train_loss=0.004544 val_macro_f1=0.75959 val_f1_label1=0.55234 val_auc=0.98779 objective=0.75959
# [TRIAL 004][EPOCH 009] train_loss=0.004462 val_macro_f1=0.77504 val_f1_label1=0.57962 val_auc=0.98768 objective=0.77504
# [TRIAL 004][EPOCH 010] train_loss=0.004380 val_macro_f1=0.75913 val_f1_label1=0.55158 val_auc=0.98729 objective=0.75913
# [TRIAL 004][EPOCH 011] train_loss=0.004347 val_macro_f1=0.78454 val_f1_label1=0.59626 val_auc=0.98621 objective=0.78454
# [TRIAL 004][EPOCH 012] train_loss=0.004300 val_macro_f1=0.75126 val_f1_label1=0.53782 val_auc=0.98654 objective=0.75126
# [TRIAL 004][EPOCH 013] train_loss=0.004277 val_macro_f1=0.77867 val_f1_label1=0.58588 val_auc=0.98662 objective=0.77867
# [TRIAL 004][EPOCH 014] train_loss=0.004214 val_macro_f1=0.78175 val_f1_label1=0.59125 val_auc=0.98697 objective=0.78175
# [TRIAL 004][EPOCH 015] train_loss=0.004156 val_macro_f1=0.81707 val_f1_label1=0.65462 val_auc=0.98550 objective=0.81707
# [TRIAL 004][EPOCH 016] train_loss=0.004135 val_macro_f1=0.76837 val_f1_label1=0.56770 val_auc=0.98694 objective=0.76837
# [TRIAL 004][EPOCH 017] train_loss=0.004107 val_macro_f1=0.78567 val_f1_label1=0.59801 val_auc=0.98602 objective=0.78567
# [TRIAL 004][EPOCH 018] train_loss=0.004086 val_macro_f1=0.75323 val_f1_label1=0.54125 val_auc=0.98715 objective=0.75323
# [TRIAL 004][EPOCH 019] train_loss=0.004008 val_macro_f1=0.78196 val_f1_label1=0.59171 val_auc=0.98499 objective=0.78196
# [TRIAL 004][EPOCH 020] train_loss=0.003941 val_macro_f1=0.77660 val_f1_label1=0.58210 val_auc=0.98480 objective=0.77660
# [TRIAL 004][EPOCH 021] train_loss=0.003937 val_macro_f1=0.79014 val_f1_label1=0.60612 val_auc=0.98395 objective=0.79014
# [I 2026-06-19 14:56:09,937] Trial 4 finished with value: 0.8170693131518753 and parameters: {'d_model': '64', 'nhead': 2, 'num_layers': 1, 'ff_multiplier': 4, 'dropout': 0.2, 'pooling': 'mean', 'use_positional_encoding': True, 'cls_head': 1, 'lr': 7.160089363547228e-05, 'weight_decay': 1.0300196600986763e-05, 'batch_size': 64, 'eval_batch_size': 512, 'grad_clip_norm': 0.5, 'loss_type': 'focal', 'focal_gamma': 1.0, 'label_smoothing': 0.0}. Best is trial 1 with value: 0.829236511845741.
# Best trial: 1. Best value: 0.829237:  17% 5/30 [29:36<3:00:06, 432.27s/it][INFO] Stage2Transformer.__init__ use_positional_encoding= False
# /content/drive/MyDrive/s2/stage2/model.py:535: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= mean
# [INFO] Stage2Transformer.__init__*********** dropout= 0.35
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 2
# [TRIAL 005][EPOCH 001] train_loss=0.696209 val_macro_f1=0.48473 val_f1_label1=0.08740 val_auc=0.55282 objective=0.48473
# [TRIAL 005][EPOCH 002] train_loss=0.690026 val_macro_f1=0.26197 val_f1_label1=0.08386 val_auc=0.57922 objective=0.26197
# [TRIAL 005][EPOCH 003] train_loss=0.679959 val_macro_f1=0.44492 val_f1_label1=0.09262 val_auc=0.58805 objective=0.44492
# [TRIAL 005][EPOCH 004] train_loss=0.677957 val_macro_f1=0.37619 val_f1_label1=0.09109 val_auc=0.58923 objective=0.37619
# [I 2026-06-19 14:57:57,596] Trial 5 pruned. Pruned at epoch=5, score=0.433534
# Best trial: 1. Best value: 0.829237:  20% 6/30 [31:23<2:08:45, 321.90s/it][INFO] Stage2Transformer.__init__ use_positional_encoding= True
# /content/drive/MyDrive/s2/stage2/model.py:535: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(
# [INFO] Stage2Transformer.__init__*********** pooling= last
# [INFO] Stage2Transformer.__init__*********** dropout= 0.25
# [INFO] Stage2Transformer.__init__*********** cls_head_config= 1
# [TRIAL 006][EPOCH 001] train_loss=0.266262 val_macro_f1=0.82898 val_f1_label1=0.67594 val_auc=0.98494 objective=0.82898
# [TRIAL 006][EPOCH 002] train_loss=0.196278 val_macro_f1=0.84637 val_f1_label1=0.70783 val_auc=0.98747 objective=0.84637
# [TRIAL 006][EPOCH 003] train_loss=0.184245 val_macro_f1=0.86794 val_f1_label1=0.74783 val_auc=0.98808 objective=0.86794
# [TRIAL 006][EPOCH 004] train_loss=0.177354 val_macro_f1=0.86933 val_f1_label1=0.75061 val_auc=0.98837 objective=0.86933
# [TRIAL 006][EPOCH 005] train_loss=0.172114 val_macro_f1=0.85689 val_f1_label1=0.72759 val_auc=0.98856 objective=0.85689
# [TRIAL 006][EPOCH 006] train_loss=0.168133 val_macro_f1=0.86422 val_f1_label1=0.74114 val_auc=0.98837 objective=0.86422
