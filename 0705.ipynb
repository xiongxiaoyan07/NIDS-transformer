# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0705ar002_et12_20260511_001/Atimeonly/stage2_config_timeonly.yaml \
  --out_dir /content/drive/MyDrive/s2/0705ar002_et12_20260511_001/Atimeonly \
  --context_method time_only \
  --context_policy online \
  --window_size 128 \
  --seed 130 \
  --epochs 500 \
  --batch_size 64
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] context lengths: min=1, mean=128.98, p50=129.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# ...

# %%
# !python /content/drive/MyDrive/s2/run_stage2.py \
  --stage1_dir /content/drive/MyDrive/s1/0704/0704C_ar002_et12_20260511_001 \
  --config /content/drive/MyDrive/s2/0705ar002_et12_20260511_001/Atimeonly2/stage2_config_timeonly.yaml \
  --out_dir /content/drive/MyDrive/s2/0705ar002_et12_20260511_001/Atimeonly2 \
  --context_method time_only \
  --context_policy online \
  --window_size 128 \
  --seed 130 \
  --epochs 500 \
  --batch_size 128
# Out:
# [INFO] Stage2 --------- seed: 130
# [INFO] 随机种子已设置: 130
# [INFO] Stage2 --------- device: cuda
# [INFO] Stage2 --------- loading data... prepare_sorted_stage2_data
# [INFO] Stage1 split:  train
# [INFO] Stage1 split:  val
# [INFO] Stage1 split:  test
# [INFO] Stage2 --------- ContextIndexBuilder
# [INFO] Stage2 loaded flows:
# split
# train    295329
# test      84380
# val       42189
# [INFO] label counts by split:
# label       0      1
# split
# test    80860   3520
# train  283999  11330
# val     40395   1794
# [INFO] z shape: (421898, 128)
# [INFO] context lengths: min=1, mean=128.98, p50=129.0, p95=129.0, max=129
# [INFO] Stage2 --------- build_datasets
# [INFO] Stage2 --------- input_dim =  128
# [INFO] Stage2 --------- Building model
# [INFO] Stage2 --------- model_type = transformer
# [INFO] Stage2 --------- model.pooling = last
# [INFO] Stage2Transformer.__init__ use_positional_encoding= False
# ...
