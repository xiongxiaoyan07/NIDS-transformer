# %%
import pandas as pd

# Wednesday-workingHours-stage1_flows
# firewall_test_20250731_160700-stage1_flows
flows = pd.read_csv("Wednesday-workingHours-stage1_flows.csv")
print("1flows.shape", flows.shape)
flows.columns = [str(c).strip() for c in flows.columns]
required = {"flow_id", "flow_start_timestamp_us", "label"}
missing = sorted(required - set(flows.columns))
if missing:
    raise ValueError(f"flow CSV missing columns: {missing}")

flows["flow_id"] = pd.to_numeric(flows["flow_id"], errors="coerce")
flows["flow_start_timestamp_us"] = pd.to_numeric(
    flows["flow_start_timestamp_us"], errors="coerce"
)
flows = flows[
    flows["flow_id"].notna()
    & flows["flow_start_timestamp_us"].notna()
    & (flows["flow_id"] != 0)
    & (flows["flow_start_timestamp_us"] != 0)
].copy()
flows["flow_id"] = flows["flow_id"].astype("int64")
flows["flow_start_timestamp_us"] = flows[
    "flow_start_timestamp_us"
].astype("int64")
flows = flows.drop_duplicates("flow_id", keep="first")
print("flows.shape", flows.shape)
print(flows["label"].value_counts())
# Out:
# 1flows.shape (475809, 77)
# flows.shape (475567, 77)
# label
# 0    265623
# 1    209944
# Name: count, dtype: int64

# %%
from sys import displayhook

import pandas as pd

# Wednesday-workingHours-stage1_flows
# firewall_test_20250731_160700-stage1_flows
df = pd.read_csv("wednesday_external_windows/Wednesday-workingHours-external-w01-stage1_flows.csv")
print("1",df.shape)
df = df[(df['flow_id'] != 0) & (df['flow_start_timestamp_us'] != 0) &
        df['flow_id'].notna() & df['flow_start_timestamp_us'].notna()]
# 转换时间戳
df["datetime"] = pd.to_datetime(
    df["flow_start_timestamp_us"],
    unit="us"
)
print("df.shape", df.shape)
print(df["label"].value_counts())
# Out:
# 1 (20000, 77)
# df.shape (20000, 78)
# label
# 0    16361
# 1     3639
# Name: count, dtype: int64

# %%
from sys import displayhook

import pandas as pd

# Wednesday-workingHours-stage1_flows
# firewall_test_20250731_160700-stage1_flows
df = pd.read_csv("wednesday_external_windows/Wednesday-workingHours-external-w02-stage1_flows.csv")
print("1",df.shape)
df = df[(df['flow_id'] != 0) & (df['flow_start_timestamp_us'] != 0) &
        df['flow_id'].notna() & df['flow_start_timestamp_us'].notna()]
# 转换时间戳
df["datetime"] = pd.to_datetime(
    df["flow_start_timestamp_us"],
    unit="us"
)
print("df.shape", df.shape)
print(df["label"].value_counts())
# Out:
# 1 (20000, 77)
# df.shape (20000, 78)
# label
# 0    17297
# 1     2703
# Name: count, dtype: int64

# %%
from sys import displayhook

import pandas as pd

# Wednesday-workingHours-stage1_flows
# firewall_test_20250731_160700-stage1_flows
df = pd.read_csv("wednesday_external_windows/Wednesday-workingHours-external-w06-stage1_flows.csv")
print("1",df.shape)
df = df[(df['flow_id'] != 0) & (df['flow_start_timestamp_us'] != 0) &
        df['flow_id'].notna() & df['flow_start_timestamp_us'].notna()]
# 转换时间戳
df["datetime"] = pd.to_datetime(
    df["flow_start_timestamp_us"],
    unit="us"
)
print("df.shape", df.shape)
print(df["label"].value_counts())
# Out:
# 1 (20000, 77)
# df.shape (20000, 78)
# label
# 0    16704
# 1     3296
# Name: count, dtype: int64

# %%
from sys import displayhook

import pandas as pd

# Wednesday-workingHours-stage1_flows
# firewall_test_20250731_160700-stage1_flows
df = pd.read_csv("wednesday_external_windows/Wednesday-workingHours-external-w07-stage1_flows.csv")
print("1",df.shape)
df = df[(df['flow_id'] != 0) & (df['flow_start_timestamp_us'] != 0) &
        df['flow_id'].notna() & df['flow_start_timestamp_us'].notna()]
# 转换时间戳
df["datetime"] = pd.to_datetime(
    df["flow_start_timestamp_us"],
    unit="us"
)
print("df.shape", df.shape)
print(df["label"].value_counts())
# Out:
# 1 (20000, 77)
# df.shape (20000, 78)
# label
# 0    17332
# 1     2668
# Name: count, dtype: int64

# %%
from sys import displayhook

import pandas as pd

# Wednesday-workingHours-stage1_flows
# firewall_test_20250731_160700-stage1_flows
df = pd.read_csv("wednesday_external_windows/Wednesday-workingHours-external-w08-stage1_flows.csv")
print("1",df.shape)
df = df[(df['flow_id'] != 0) & (df['flow_start_timestamp_us'] != 0) &
        df['flow_id'].notna() & df['flow_start_timestamp_us'].notna()]
# 转换时间戳
df["datetime"] = pd.to_datetime(
    df["flow_start_timestamp_us"],
    unit="us"
)
print("df.shape", df.shape)
print(df["label"].value_counts())
# Out:
# 1 (20000, 77)
# df.shape (20000, 78)
# label
# 0    16953
# 1     3047
# Name: count, dtype: int64
