# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/s1/flow_only_baseline.py \
      --train_npz /content/drive/MyDrive/s1/0630_C/full_gated/precomputed/seqLen64headtrainC.npz \
      --val_npz   /content/drive/MyDrive/s1/0630_C/full_gated/precomputed/seqLen64headvalC.npz \
      --test_npz  /content/drive/MyDrive/s1/0630_C/full_gated/precomputed/seqLen64headtestC.npz \
      --out_dir   /content/drive/MyDrive/s1/0701_flow_baseline/flow_only_diagnosis \
      --models mlp xgb lgbm \
      --loss cb_focal
# Out:
# [INFO] seed=130
# [INFO] device=cuda
#
# [DATA] train
#   X shape      : (123935, 68)
#   y shape      : (123935,)
#   class_counts : {0: 119488, 1: 4447}
#   label1_ratio : 0.035882
#
# [DATA] val
#   X shape      : (17705, 68)
#   y shape      : (17705,)
#   class_counts : {0: 17003, 1: 702}
#   label1_ratio : 0.039650
#
# [DATA] test
#   X shape      : (35410, 68)
#   y shape      : (35410,)
#   class_counts : {0: 34003, 1: 1407}
#   label1_ratio : 0.039735
#
# ################################################################################
# [MODEL] Flow-only MLP
# ################################################################################
#
# [LOSS]
#   loss       : cb_focal
#   alpha_mode : none
#   alpha      : None
#   counts     : class0=119488, class1=4447
# [INFO] ClassBalancedFocalLoss counts: [119488   4447]
# [INFO] ClassBalancedFocalLoss weights: [0.52832968 1.47167032]
# ...
